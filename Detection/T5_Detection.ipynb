# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Load the T5 tokenizer and model
tokenizer = T5Tokenizer.from_pretrained('t5-large')
model = T5ForConditionalGeneration.from_pretrained('t5-large')

# Define input text and split it into sections
input_text = """Identify any harmful or non-inclusive language in the following text:
Abort: The program will automatically abort if a critical error occurs during execution.
Terminate: The user chose to terminate the installation process after encountering an error.
Average user: The app is designed to be intuitive for the average user.
Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
White box: The white box testing method allows developers to see the internal workings of the code.
Black hat: The company detected a black hat attempting to infiltrate their systems.
White hat: A white hat hacker helped identify security vulnerabilities in the new software.
Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
Whitelist: Only pre-approved devices are included in the network’s whitelist.
Blind: The paper underwent a blind review process to ensure impartiality.
Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
Male connector: The cable is equipped with a male connector for compatibility with standard ports.
Female connector: The female connector allows for easy integration with other components.
She: She was responsible for coordinating the team’s efforts on the project.
Her: Her contribution to the discussion was insightful and appreciated.
Hers: The credit for the innovative design is entirely hers.
He: He led the presentation with confidence and clarity.
Him: The team assigned the most critical task to him.
His: His programming skills greatly improved the project’s outcome.
Master: The master database contains all the key records for the organization.
Slave: The secondary system operates as a slave to the primary server.
Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
Grandfathered: The older software was grandfathered in despite the new policy.
Guys: Hey guys, let’s gather for the meeting in five minutes.
Man hours: Completing the project required 100 man hours of effort.
Sanity check: Before deploying the code, we need to perform a sanity check.
Sanity test: A quick sanity test revealed several issues in the new feature.
Dummy value: Developers use a dummy value as a placeholder during testing.
Scrum master: The scrum master facilitated the daily stand-up meeting.
Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
Segregation: The system’s segregation of duties ensures secure operations.
Blackout period: A blackout period was enforced during the system upgrade.
Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
Native: The app includes a native feature for photo editing.
Red team: The red team simulated an attack to test the organization’s defenses.
Web master: The web master updated the website’s layout for better usability.
White space: The designer added white space to improve the page's readability.
White team: The white team oversaw the cyber exercise and ensured fair play.
Yellow team: The yellow team focused on optimizing the software’s security during development.
Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
Brown bags: The company hosted brown bag sessions to share knowledge informally.
First-class citizen: Functions are treated as first-class citizens in many programming languages.
Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
Master branch: Changes were merged into the master branch for deployment.
Minority: Efforts to promote diversity aim to amplify the voices of the minority.
Normal: The system is back to normal after resolving the outage.
Handicapped: The venue was upgraded to be accessible for handicapped individuals.
Crazy: The plan was considered crazy but turned out to be a brilliant success.
OCD: His desk organization reflects a hint of OCD tendencies.
Culture fit: The company prioritizes culture fit when hiring new employees.
Chairman: The chairman called for a vote on the proposed changes.
Foreman: The foreman supervised the construction site with expertise.
Man: Man has always sought to understand the universe.
Mankind: Mankind has made significant strides in technology over the centuries.
Mans: The crew mans the ship during long voyages.
Salesman: The salesman demonstrated the product’s key features effectively.
Manmade: The reservoir is a manmade structure designed for water storage.
Manpower: The project required significant manpower to complete on time.
Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
DMZ: The server operates within the DMZ for added security.
Hang: The application tends to hang when handling large datasets.
Daughter board: The new functionality was implemented through a daughter board.
Gender bender: The adapter functions as a gender bender for connecting devices.
Orphaned object: The cleanup script removed the orphaned object from the database."""

# Split the input text into sections
sections = [section for section in input_text.split('\n')[1:] if section]

# Define the task prefix
task_prefix = "classify harmful or non-harmful: "

# Tokenize and classify each section
results = []
for section in sections:
    input_ids = tokenizer.encode(task_prefix + section, return_tensors="pt", truncation=True)
    outputs = model.generate(input_ids, max_length=50)
    classification = tokenizer.decode(outputs[0], skip_special_tokens=True)
    results.append({"sequence": section, "classification": classification})

# Display the results in a more understandable way
for result in results:
    print(f"Term: {result['sequence']}\nClassification: {result['classification']}\n")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Term: Abort: The program will automatically abort if a critical error occurs during execution.
# Classification: harmful or non-harmful:t: Abort: The program will automatically abort if a critical error occurs during execution. Abort: The program will automatically abort if a
#
# Term: Terminate: The user chose to terminate the installation process after encountering an error.
# Classification: as: the installation process. Terminate: The user chose to terminate the installation process after encountering an error. Terminate: The user chose to terminate the installation process after encountering an error. harmful or non-
#
# Term: Average user: The app is designed to be intuitive for the average user.
# Classification: :. The app is designed to be intuitive for the average user.: Classify harmful or non-harmful: Average user: The app is designed to be intuitive for the average user. or non-harmful
#
# Term: Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
# Classification: Black box: The algorithm functions as a black box, with no transparency about how decisions are made.: Black box: The algorithm functions as a black box, with no transparency about how decisions are made. Black box
#
# Term: White box: The white box testing method allows developers to see the internal workings of the code.
# Classification: harmful or non-harmful: Black box: The black box testing method allows developers to see the internal workings of the code. The The white box testing method allows developers to see the internal workings of the code.
#
# Term: Black hat: The company detected a black hat attempting to infiltrate their systems.
# Classification: : Black hat: The company detected a black hat attempting to infiltrate their systems.. a black hat black hat: The company detected a black hat attempting to in
#
# Term: White hat: A white hat hacker helped identify security vulnerabilities in the new software.
# Classification: :: hat: A white hat hacker helped identify security vulnerabilities in the new software.: A white hat hacker helped identify security vulnerabilities in the new software. Black hat: A white hat hack
#
# Term: Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
# Classification: . was added to the company’s blacklist after repeated failed login attempts. address was added to the company’s blacklist after repeated failed login attempts. address was added to the company’s blacklist after repeated failed
#
# Term: Whitelist: Only pre-approved devices are included in the network’s whitelist.
# Classification: :: Blacklist: Only pre-approved devices are included in the network’s blacklist.: Only pre-approved devices are included in the network’s blacklist. Blacklist: Only pre-approved devices are
#
# Term: Blind: The paper underwent a blind review process to ensure impartiality.
# Classification: harmful or non-harmful: Blind: blind: The paper underwent a blind review process to ensure impartiality. Blind: The paper underwent a blind review process to ensure impartiality. Blind: The
#
# Term: Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
# Classification: . Double blind: The experiment was conducted under double blind conditions to eliminate bias. Double blind: to eliminate bias. to eliminate bias. Double blind: The experiment was conducted under double blind conditions to eliminate bias.: Double blind
#
# Term: Male connector: The cable is equipped with a male connector for compatibility with standard ports.
# Classification: ify harmful or non-harmful: Classify harmful or non-harmful: harmful or non-harmful: harmful or non-harmful: Classify harmful or non-harmful: harmful or non-harm
#
# Term: Female connector: The female connector allows for easy integration with other components.
# Classification: harmful or non-harmful: Female connector: harmful or non-harmful: Female connector: The female connector allows for easy integration of other components. harmful or non-harmful: Female connector: The female connector allows
#
# Term: She: She was responsible for coordinating the team’s efforts on the project.
# Classification: as harmful or non-harmful:. He: He was responsible for coordinating the team’s efforts on the project. harmful: harmful: She was responsible for coordinating the team’s efforts on the project.
#
# Term: Her: Her contribution to the discussion was insightful and appreciated.
# Classification: harmful or non-harmful: Her: Her contribution was insightful and appreciated.. Her: Her contribution was insightful and appreciated. Her: Her contribution was insightful and appreciated. Her: Her contribution was appreciated. Her: Her
#
# Term: Hers: The credit for the innovative design is entirely hers.
# Classification: as harmful or non-harmful:.ify harmful or non-harmful:s: The credit for the innovative design is entirely hers.ify harmful or non-harmful:ify orify
#
# Term: He: He led the presentation with confidence and clarity.
# Classification: harmful or non-harmful.. He: He was a confident speaker. He: He was a confident speaker.. He: He was a confident speaker.. He: He led the presentation with confidence
#
# Term: Him: The team assigned the most critical task to him.
# Classification: harmful or non-harmful: Her: The team assigned the most critical task to Him: The team assigned the most critical task to him. Him: The team assigned the most critical task to him. harmful or non
#
# Term: His: His programming skills greatly improved the project’s outcome.
# Classification: as harmful or non-harmful: harmful or non-harmful: His: His programming skills greatly improved the project’s outcome. as harmful or non-harmful: His: His:: His: His:
#
# Term: Master: The master database contains all the key records for the organization.
# Classification: : Classify harmful or non-harmful: Master: The master database contains all the key records for the organization.. Master: The master database contains all the key records for the organization. Master: The master database contains
#
# Term: Slave: The secondary system operates as a slave to the primary server.
# Classification: harmful or non-harmful: Slave: The secondary system operates as a slave to the primary server. Slave: harmful or non-harmful: Slave: The secondary system operates as
#
# Term: Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
# Classification: harmful or non-harmful: Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.: in supremacy: Quantum supremacy is a significant milestone in computing. Quantum
#
# Term: Grandfathered: The older software was grandfathered in despite the new policy.
# Classification: ify harmful or non-harmful:: Grandfathered: The older software was grandfathered in despite the new policy.: Grandfathered: The older software was grandfathered in despite the
#
# Term: Guys: Hey guys, let’s gather for the meeting in five minutes.
# Classification: harmful or non-harmful: Guys: Hey guys, let’s gather in five minutes.. Guys: Hey guys, let’s gather in five minutes.. Guys: Hey guys, let’s gather in five
#
# Term: Man hours: Completing the project required 100 man hours of effort.
# Classification: harmful or non-harmful: Man hours: Completing the project required 100 man hours of effort.. Man hours: Completing the project required 100 man hours of effort. Classify harmful or non-harm
#
# Term: Sanity check: Before deploying the code, we need to perform a sanity check.
# Classification: harmful or non-harmful.: the code. Sanity check: Before deploying the code, we need to perform a sanity check. Sanity check: Before deploying the code, we need
#
# Term: Sanity test: A quick sanity test revealed several issues in the new feature.
# Classification: test: A quick sanity test revealed several issues in the new feature. test revealed several issues in the new feature. Sanity test:. Sanity test:ity test: Sanity test: Sanity test
#
# Term: Dummy value: Developers use a dummy value as a placeholder during testing.
# Classification: .: Dummy value: Developers use a dummy value as a placeholder during testing. Dummy value: Developers use a dummy value as a placeholder during testing. Dummy value
#
# Term: Scrum master: The scrum master facilitated the daily stand-up meeting.
# Classification: harmful or non-harmful: The scrum master facilitated the daily stand-up meeting. Scrum master: The scrum master facilitated the daily stand-up meeting..-up meeting. master:
#
# Term: Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
# Classification: : Mob programming: The team opted for mob programming to tackle the complex issue collaboratively. Mob programming: for mob programming to tackle the complex issue collaboratively. Mob programming:. Mob programming:
#
# Term: Segregation: The system’s segregation of duties ensures secure operations.
# Classification: harmful or non-harmful: Classify harmful or non-harmful: The system’s classification of harmful or non-harmful:. ensures secure operations. Segregation: The system’s segreg
#
# Term: Blackout period: A blackout period was enforced during the system upgrade.
# Classification: harmful or non-harmful: Classify harmful or non-harmful:.ify harmful or non-harmful: Blackout period: A blackout period was enforced during the system upgrade.: Classify harmful
#
# Term: Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
# Classification: : Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them. the vulnerabilities. the vulnerabilities after exploiting them. hat: The gray hat hacker reported the vulnerabilities after exploiting them
#
# Term: Native: The app includes a native feature for photo editing.
# Classification: ify harmful or non-harmful:.. Native: The app includes native features for photo editing.. Native: The app includes native feature for photo editing. Native: The app includes native feature for photo editing. Native
#
# Term: Red team: The red team simulated an attack to test the organization’s defenses.
# Classification: : Red team: The red team simulated an attack to test the organization’s defenses.: as harmful. Red team: The red team simulated harmful. Green team: The green team simulated harmful. Red
#
# Term: Web master: The web master updated the website’s layout for better usability.
# Classification: harmful or non-harmful: for better usability. Web master: The web master updated the website’s layout for better usability. usability. Web master: The web master updated the website’s layout for better
#
# Term: White space: The designer added white space to improve the page's readability.
# Classification: harmful or non-harmful: The designer added white space to improve the page's readability. White space: The designer added white space to improve the page's readability. harmful or non-harmful:
#
# Term: White team: The white team oversaw the cyber exercise and ensured fair play.
# Classification: .: The white team oversaw the cyber exercise and ensured fair play... White team: The white team oversaw the cyber exercise and ensured fair play. Black team: The black team oversaw the cyber
#
# Term: Yellow team: The yellow team focused on optimizing the software’s security during development.
# Classification: : The yellow team focused on optimizing the software’s security during development. yellow team: The yellow team focused on optimizing the software’s security during development. harmful or non-harmful: Red team: The
#
# Term: Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
# Classification: harmful or non-harmful: harmful or non-harmful:. Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions. Non-Aboriginal: The land’s history is deeply embedded
#
# Term: Brown bags: The company hosted brown bag sessions to share knowledge informally.
# Classification: harmful or non-harmful: Brown bags: to share knowledge. Brown bags: to share knowledge. Brown bags: The company hosted brown bag sessions to share knowledge formally. Brown bags: Brown bags: The company hosted
#
# Term: First-class citizen: Functions are treated as first-class citizens in many programming languages.
# Classification: -class citizen: Functions are treated as first-class citizens in many programming languages. How tos:s are treated as first-class citizens in many programming languages. How to classify harmful or non-harmful:
#
# Term: Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
# Classification: -in-the-middle attack:-in-the-middle attack intercepted sensitive information during transmission.-the-middle attack intercepted sensitive information during transmission.-in-
#
# Term: Master branch: Changes were merged into the master branch for deployment.
# Classification: harmful or non-harmful: Master branch: Changes were merged into the master branch for deployment. Master branch: Changes were merged into the master branch for deployment. Master branch: Changes were merged
#
# Term: Minority: Efforts to promote diversity aim to amplify the voices of the minority.
# Classification: ify harmful or non-harmful:Efforts to promote diversity aim to amplify the voices of the minority.Efforts to promote diversity aim to amplify the voices of the minority.
#
# Term: Normal: The system is back to normal after resolving the outage.
# Classification: harmful or non-harmful: Normal: The system is back to normal after resolving the outage. How to Normal:. Normal: The system is back to normal after resolving the outage.
#
# Term: Handicapped: The venue was upgraded to be accessible for handicapped individuals.
# Classification: harmful or non-harmful:. Handicapped: The venue was upgraded to be accessible for handicapped individuals. Handicapped: The venue was upgraded to be accessible for handicapped individuals.. Handicapped:
#
# Term: Crazy: The plan was considered crazy but turned out to be a brilliant success.
# Classification: as harmful or non-harmful: Brilliant: a brilliant success. Classify harmful or non-harmful: The plan was considered harmful but turned out to be a brilliant success. harmful: The plan was
#
# Term: OCD: His desk organization reflects a hint of OCD tendencies.
# Classification: harmful or non-harmful.. organization reflects a hint of OCD tendencies. hint of OCD: His desk organization reflects a hint of OCD tendencies. OCD: His desk organization
#
# Term: Culture fit: The company prioritizes culture fit when hiring new employees.
# Classification: harmful or non-harmful.: Culture fit: The company prioritizes culture fit when hiring new employees.: The company prioritizes culture fit when hiring new employees. Culture fit: The company prioritizes culture fit when hiring
#
# Term: Chairman: The chairman called for a vote on the proposed changes.
# Classification: as harmful or non-harmful.. harmful or non-harmful. Chairman: The chairman called for a vote on the proposed changes. Chairman: The chairman called for a vote on the proposed changes.
#
# Term: Foreman: The foreman supervised the construction site with expertise.
# Classification: harmful or non-harmful: the construction site with expertise.. Foreman: The foreman supervised the construction site with expertise.: Foreman: The foreman supervised the construction site with
#
# Term: Man: Man has always sought to understand the universe.
# Classification: harmful or non-harmful: Man: Man has always sought to understand the universe.. Man: Man has always sought to understand the universe. Man:. Man: Man has always sought to understand the universe. Man:
#
# Term: Mankind: Mankind has made significant strides in technology over the centuries.
# Classification: harmful or non-harmful: Mankind: Mankind has significant strides in technology over the centuries.:: Mankind has significant strides in technology over the centuries. Mankind: Mankind has significant strides
#
# Term: Mans: The crew mans the ship during long voyages.
# Classification: harmful or non-harmful: Classify: To: Mans: The crew mans the ship during long voyages. Mans: The crew mans the ship during long voyages. Classify: To class
#
# Term: Salesman: The salesman demonstrated the product’s key features effectively.
# Classification: harmful or non-harmful: Salesman: The salesman demonstrated the product’s key features effectively.: Salesman: The salesman demonstrated the product’s key features effectively.: Salesman: The salesman
#
# Term: Manmade: The reservoir is a manmade structure designed for water storage.
# Classification: ify: The reservoir is a manmade structure designed for water storage. harmful or non-harmful: harmful or non-harmful: Manmade: The reservoir is a manmade structure designed for water storage.
#
# Term: Manpower: The project required significant manpower to complete on time.
# Classification: harmful or non-harmful: Classify harmful or non-harmful:.. classify harmful or non-harmful: Manpower: The project required significant manpower to complete.: harmful or non
#
# Term: Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
# Classification: harmful or non-harmful: Classify harmful or non-harmful:: internal systems from external threats. Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats
#
# Term: DMZ: The server operates within the DMZ for added security.
# Classification: as The server operates within the DMZ for added security.Z: The server operates within the DMZ for added security. DMZ: The server operates within the DMZ for added security.
#
# Term: Hang: The application tends to hang when handling large datasets.
# Classification: : Hang: The application tends to hang when handling large datasets. Hang: The application tends to hang when handling large datasets. Hang: The application tends to hang when handling large datasets. Hang: The
#
# Term: Daughter board: The new functionality was implemented through a daughter board.
# Classification: : The new functionality was implemented through a daughter board. the new functionality was implemented through a daughter board. harmful or non-harmful: Daughter board: The new functionality was implemented through a daughter board.
#
# Term: Gender bender: The adapter functions as a gender bender for connecting devices.
# Classification: ify harmful or non-harmful: Gender bender: The adapter functions as a gender bender for connecting devices.: bender for connecting devices.er: The adapter functions as a gender bend
#
# Term: Orphaned object: The cleanup script removed the orphaned object from the database.
# Classification: harmful or non-harmful: The cleanup script removed the orphaned object from the database. The cleanup script removed the orphaned object from the database. The cleanup script removed the orphaned object
