# %%
pip install sentence-transformers pandas
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\hana_\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: pandas in c:\users\hana_\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.48.0)
# Requirement already satisfied: tqdm in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\hana_\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hana_\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hana_\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hana_\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# PROMPT 1:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Terminate", "Halt", "Stop"],
    "Terminate": ["End", "Stop", "Conclude", "Finish"],
    "Average user": ["Typical user", "Standard user", "Common user"],
    "Black box": ["Opaque system", "Undocumented system", "System with limited visibility"],
    "White box": ["Transparent system", "System with visible internals"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Cybercriminal"],
    "White hat": ["Ethical hacker", "Security researcher", "Security specialist"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Safelist", "Inclusion list"],
    "Blind": ["Anonymous review", "Masked review"],
    "Double blind": ["Double-anonymous review", "Double-masked review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Socket connector", "Port connector"],
    "She": ["They", "The person", "The developer", "The engineer"],
    "Her": ["Their", "The person's", "The developer's"],
    "Hers": ["Theirs", "The person's", "The developer's"],
    "He": ["They", "The person", "The developer", "The engineer"],
    "Him": ["Them", "The person", "The developer"],
    "His": ["Their", "The person's", "The developer's"],
    "Master": ["Primary", "Main", "Principal", "Leading"],
    "Slave": ["Secondary", "Replica", "Follower", "Dependent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum superiority"],
    "Grandfathered": ["Legacy", "Previously approved", "Exempt"],
    "Guys": ["Everyone", "Folks", "Team", "People", "You all"],
    "Man hours": ["Person-hours", "Staff-hours", "Work-hours"],
    "Sanity check": ["Quick check", "Basic check", "Preliminary check", "Confidence check"],
    "Sanity test": ["Quick test", "Basic test", "Preliminary test", "Confidence test"],
    "Dummy value": ["Placeholder value", "Sample value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Team lead"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Division"],
    "Blackout period": ["Maintenance window", "Downtime", "Service interruption"],
    "Gray hat": ["Ambiguous hacker", "Security researcher with mixed methods"],
    "Native": ["Built-in", "Integrated", "Core"],
    "Red team": ["Attack simulation team", "Security testing team"],
    "Web master": ["Web developer", "Web administrator", "Web maintainer"],
    "White space": ["Empty space", "Padding", "Margin"],
    "White team": ["Oversight team", "Moderation team"],
    "Yellow team": ["Security optimization team", "Improvement team"],
    "Aboriginal": ["Indigenous", "Native", "Original"],
    "Brown bags": ["Informal learning sessions", "Lunch and learns"],
    "First-class citizen": ["First-class element", "Primary element"],
    "Man-in-the-middle": ["Interception attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch"],
    "Minority": ["Underrepresented group", "Smaller group"],
    "Normal": ["Usual", "Standard", "Typical", "Expected"],
    "Handicapped": ["Person with a disability", "Accessible", "Person with access needs"],
    "Crazy": ["Unconventional", "Innovative", "Bold", "Unique"],
    "OCD": ["Detail-oriented", "Highly organized", "Meticulous"],
    "Culture fit": ["Team compatibility", "Alignment with team values", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Moderator"],
    "Foreman": ["Supervisor", "Lead", "Site manager"],
    "Man": ["Humanity", "People", "Humankind", "Individuals"],
    "Mankind": ["Humanity", "People", "Humankind"],
    "Mans": ["Staffs", "Operates", "Works"],
    "Salesman": ["Salesperson", "Sales representative", "Sales associate"],
    "Manmade": ["Synthetic", "Artificial", "Engineered"],
    "Manpower": ["Workforce", "Personnel", "Staffing"],
    "Demilitarized zone": ["Network perimeter", "Protected network area"],
    "DMZ": ["Network perimeter", "Protected network area"],
    "Hang": ["Freeze", "Stall", "Become unresponsive"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Adapter", "Converter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Disconnected object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 17   The company detected a black hat attempting to...           Black hat
# 16   The company detected a black hat attempting to...           Black hat
# 18   The company detected a black hat attempting to...           Black hat
# 103  A blackout period was enforced during the syst...     Blackout period
# 34   The female connector allows for easy integrati...    Female connector
# 97   The scrum master facilitated the daily stand-u...        Scrum master
# 15   The white box testing method allows developers...           White box
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 201  The adapter functions as a gender bender for c...       Gender bender
# 107  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 35   The female connector allows for easy integrati...    Female connector
# 168  The foreman supervised the construction site w...             Foreman
# 29   The paper underwent a blind review process to ...               Blind
# 98   The team opted for mob programming to tackle t...     Mob programming
# 14   The white box testing method allows developers...           White box
# 199  The adapter functions as a gender bender for c...       Gender bender
# 104  A blackout period was enforced during the syst...     Blackout period
# 42   Her contribution to the discussion was insight...                 Her
# 200  The adapter functions as a gender bender for c...       Gender bender
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 105  A blackout period was enforced during the syst...     Blackout period
# 28   The paper underwent a blind review process to ...               Blind
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 169  The foreman supervised the construction site w...             Foreman
# 167  The foreman supervised the construction site w...             Foreman
# 197  The new functionality was implemented through ...      Daughter board
# 39   She was responsible for coordinating the team’...                 She
# 191  The server operates within the DMZ for added s...                 DMZ
# 166  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 126  The yellow team focused on optimizing the soft...         Yellow team
# 131  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 99   The team opted for mob programming to tackle t...     Mob programming
# 106  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 52    The team assigned the most critical task to him.                 Him
# 125  The yellow team focused on optimizing the soft...         Yellow team
# 192  The server operates within the DMZ for added s...                 DMZ
# 124  The white team oversaw the cyber exercise and ...          White team
# 45   The credit for the innovative design is entire...                Hers
# 196  The new functionality was implemented through ...      Daughter board
# 198  The new functionality was implemented through ...      Daughter board
# 38   She was responsible for coordinating the team’...                 She
# 88   A quick sanity test revealed several issues in...         Sanity test
# 153  The plan was considered crazy but turned out t...               Crazy
# 90   Developers use a dummy value as a placeholder ...         Dummy value
# 113  The web master updated the website’s layout fo...              Master
# 129  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 19   A white hat hacker helped identify security vu...           White hat
# 150  The venue was upgraded to be accessible for ha...         Handicapped
# 130  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 112  The red team simulated an attack to test the o...            Red team
# 157  His desk organization reflects a hint of OCD t...                 His
# 48   He led the presentation with confidence and cl...                  He
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 123  The white team oversaw the cyber exercise and ...          White team
# 49   He led the presentation with confidence and cl...                  He
# 89   Developers use a dummy value as a placeholder ...         Dummy value
# 84   Before deploying the code, we need to perform ...        Sanity check
# 111  The red team simulated an attack to test the o...            Red team
# 190  The network’s demilitarized zone protects inte...  Demilitarized zone
# 21   A white hat hacker helped identify security vu...           White hat
# 189  The network’s demilitarized zone protects inte...  Demilitarized zone
# 59   The master database contains all the key recor...              Master
# 58   The master database contains all the key recor...              Master
# 56   The master database contains all the key recor...              Master
# 20   A white hat hacker helped identify security vu...           White hat
# 115  The web master updated the website’s layout fo...              Master
# 36   She was responsible for coordinating the team’...                 She
# 30   The experiment was conducted under double-blin...               Blind
# 152  The plan was considered crazy but turned out t...               Crazy
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 178        The crew mans the ship during long voyages.                Mans
# 154  The plan was considered crazy but turned out t...               Crazy
# 33   The cable is equipped with a male connector fo...      Male connector
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 114  The web master updated the website’s layout fo...              Master
# 62   The secondary system operates as a slave to th...               Slave
# 116  The web master updated the website’s layout fo...              Master
# 91   Developers use a dummy value as a placeholder ...         Dummy value
# 177        The crew mans the ship during long voyages.                Mans
# 118  The web master updated the website’s layout fo...          Web master
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 119  The web master updated the website’s layout fo...          Web master
# 81   Before deploying the code, we need to perform ...        Sanity check
# 121  The designer added white space to improve the ...         White space
# 43   The credit for the innovative design is entire...                Hers
# 37   She was responsible for coordinating the team’...                 She
# 83   Before deploying the code, we need to perform ...        Sanity check
# 40   Her contribution to the discussion was insight...                 Her
# 128  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 31   The experiment was conducted under double-blin...               Blind
# 203  The cleanup script removed the orphaned object...     Orphaned object
# 32   The cable is equipped with a male connector fo...      Male connector
# 55   His programming skills greatly improved the pr...                 His
# 44   The credit for the innovative design is entire...                Hers
# 63   The secondary system operates as a slave to th...               Slave
# 122  The designer added white space to improve the ...         White space
# 179        The crew mans the ship during long voyages.                Mans
# 151  The plan was considered crazy but turned out t...               Crazy
# 64   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 117  The web master updated the website’s layout fo...          Web master
# 26   Only pre-approved devices are included in the ...           Whitelist
# 82   Before deploying the code, we need to perform ...        Sanity check
# 57   The master database contains all the key recor...              Master
# 53   His programming skills greatly improved the pr...                 His
# 188  The project required significant manpower to c...            Manpower
# 61   The secondary system operates as a slave to th...               Slave
# 12   The algorithm functions as a black box, with n...           Black box
# 180  The salesman demonstrated the product’s key fe...            Salesman
# 195  The application tends to hang when handling la...                Hang
# 41   Her contribution to the discussion was insight...                 Her
# 27   Only pre-approved devices are included in the ...           Whitelist
# 138  Changes were merged into the master branch for...              Master
# 68   The older software was grandfathered in despit...       Grandfathered
# 173  Man has always sought to understand the universe.                 Man
# 67   The older software was grandfathered in despit...       Grandfathered
# 46   He led the presentation with confidence and cl...                  He
# 186  The project required significant manpower to c...            Manpower
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 60   The secondary system operates as a slave to th...               Slave
# 13   The algorithm functions as a black box, with n...           Black box
# 136  Changes were merged into the master branch for...              Master
# 170  Man has always sought to understand the universe.                 Man
# 96   The scrum master facilitated the daily stand-u...        Scrum master
# 51    The team assigned the most critical task to him.                 Him
# 155  His desk organization reflects a hint of OCD t...                 His
# 11   The algorithm functions as a black box, with n...           Black box
# 187  The project required significant manpower to c...            Manpower
# 171  Man has always sought to understand the universe.                 Man
# 50    The team assigned the most critical task to him.                 Him
# 25   Only pre-approved devices are included in the ...           Whitelist
# 87   A quick sanity test revealed several issues in...         Sanity test
# 165  The chairman called for a vote on the proposed...            Chairman
# 6    The user chose to terminate the installation p...           Terminate
# 47   He led the presentation with confidence and cl...                  He
# 141  Changes were merged into the master branch for...       Master branch
# 132  The man-in-the-middle attack intercepted sensi...                 Man
# 54   His programming skills greatly improved the pr...                 His
# 86   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 2    The program will automatically abort if a crit...               Abort
# 202  The cleanup script removed the orphaned object...     Orphaned object
# 156  His desk organization reflects a hint of OCD t...                 His
# 193  The application tends to hang when handling la...                Hang
# 94   The scrum master facilitated the daily stand-u...              Master
# 139  Changes were merged into the master branch for...              Master
# 85   A quick sanity test revealed several issues in...         Sanity test
# 120  The designer added white space to improve the ...         White space
# 77   Completing the project required 100 man hours ...                 Man
# 145  The system is back to normal after resolving t...              Normal
# 3    The program will automatically abort if a crit...               Abort
# 92   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 102  The system’s segregation of duties ensures sec...         Segregation
# 24   The IP address was added to the company’s blac...           Blacklist
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 185  The reservoir is a manmade structure designed ...             Manmade
# 137  Changes were merged into the master branch for...              Master
# 140  Changes were merged into the master branch for...       Master branch
# 133  The man-in-the-middle attack intercepted sensi...                 Man
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 175  Mankind has made significant strides in techno...             Mankind
# 143  Efforts to promote diversity aim to amplify th...            Minority
# 93   The scrum master facilitated the daily stand-u...              Master
# 142  Efforts to promote diversity aim to amplify th...            Minority
# 110  The app includes a native feature for photo ed...              Native
# 95   The scrum master facilitated the daily stand-u...              Master
# 66   The older software was grandfathered in despit...       Grandfathered
# 194  The application tends to hang when handling la...                Hang
# 75   Completing the project required 100 man hours ...           Man hours
# 135  The man-in-the-middle attack intercepted sensi...                 Man
# 108  The app includes a native feature for photo ed...              Native
# 22   The IP address was added to the company’s blac...           Blacklist
# 23   The IP address was added to the company’s blac...           Blacklist
# 109  The app includes a native feature for photo ed...              Native
# 184  The reservoir is a manmade structure designed ...             Manmade
# 127  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 134  The man-in-the-middle attack intercepted sensi...                 Man
# 164  The chairman called for a vote on the proposed...            Chairman
# 80   Completing the project required 100 man hours ...                 Man
# 1    The program will automatically abort if a crit...               Abort
# 65   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 7    The user chose to terminate the installation p...           Terminate
# 71   Hey guys, let’s gather for the meeting in five...                Guys
# 146  The system is back to normal after resolving t...              Normal
# 144  The system is back to normal after resolving t...              Normal
# 8    The app is designed to be intuitive for the av...        Average user
# 147  The system is back to normal after resolving t...              Normal
# 72   Hey guys, let’s gather for the meeting in five...                Guys
# 100  The system’s segregation of duties ensures sec...         Segregation
# 78   Completing the project required 100 man hours ...                 Man
# 76   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 79   Completing the project required 100 man hours ...                 Man
# 74   Completing the project required 100 man hours ...           Man hours
# 5    The user chose to terminate the installation p...           Terminate
# 69   Hey guys, let’s gather for the meeting in five...                Guys
# 73   Hey guys, let’s gather for the meeting in five...                Guys
# 174  Mankind has made significant strides in techno...             Mankind
# 70   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                                 Replacement  \
# 17                         Unethical hacker
# 16                          Malicious actor
# 18                            Cybercriminal
# 103                      Maintenance window
# 34                         Socket connector
# 97                                Team lead
# 15            System with visible internals
# 161                      Team compatibility
# 201                       Connector adapter
# 107  Security researcher with mixed methods
# 35                           Port connector
# 168                                    Lead
# 29                            Masked review
# 98                     Ensemble programming
# 14                       Transparent system
# 199                                 Adapter
# 104                                Downtime
# 42                          The developer's
# 200                               Converter
# 163                           Shared values
# 105                    Service interruption
# 28                         Anonymous review
# 162              Alignment with team values
# 169                            Site manager
# 167                              Supervisor
# 197                            Add-on board
# 39                             The engineer
# 191                       Network perimeter
# 166                               Moderator
# 158                         Detail-oriented
# 126                        Improvement team
# 131                            Relay attack
# 99                Collaborative programming
# 106                        Ambiguous hacker
# 52                            The developer
# 125              Security optimization team
# 192                  Protected network area
# 124                         Moderation team
# 45                          The developer's
# 196                         Expansion board
# 198                         Secondary board
# 38                            The developer
# 88                          Confidence test
# 153                                    Bold
# 90                             Sample value
# 113                                 Primary
# 129                                Original
# 19                           Ethical hacker
# 150                Person with access needs
# 130                     Interception attack
# 112                   Security testing team
# 157                         The developer's
# 48                            The developer
# 159                        Highly organized
# 123                          Oversight team
# 49                             The engineer
# 89                        Placeholder value
# 84                         Confidence check
# 111                  Attack simulation team
# 190                  Protected network area
# 21                      Security specialist
# 189                       Network perimeter
# 59                                  Leading
# 58                                Principal
# 56                                  Primary
# 20                      Security researcher
# 115                               Principal
# 36                                     They
# 30                         Anonymous review
# 152                              Innovative
# 181                    Sales representative
# 178                                Operates
# 154                                  Unique
# 33                            Pin connector
# 160                              Meticulous
# 114                                    Main
# 62                                 Follower
# 116                                 Leading
# 91                               Test value
# 177                                  Staffs
# 118                       Web administrator
# 182                         Sales associate
# 119                          Web maintainer
# 81                              Quick check
# 121                                 Padding
# 43                                   Theirs
# 37                               The person
# 83                        Preliminary check
# 40                                    Their
# 128                                  Native
# 31                            Masked review
# 203                     Disconnected object
# 32                           Plug connector
# 55                          The developer's
# 44                             The person's
# 63                                Dependent
# 122                                  Margin
# 179                                   Works
# 151                          Unconventional
# 64                        Quantum advantage
# 117                           Web developer
# 26                                 Safelist
# 82                              Basic check
# 57                                     Main
# 53                                    Their
# 188                                Staffing
# 61                                  Replica
# 12                      Undocumented system
# 180                             Salesperson
# 195                     Become unresponsive
# 41                             The person's
# 27                           Inclusion list
# 138                               Principal
# 68                                   Exempt
# 173                             Individuals
# 67                      Previously approved
# 46                                     They
# 186                               Workforce
# 149                              Accessible
# 60                                Secondary
# 13           System with limited visibility
# 136                                 Primary
# 170                                Humanity
# 96                        Scrum facilitator
# 51                               The person
# 155                                   Their
# 11                            Opaque system
# 187                               Personnel
# 171                                  People
# 50                                     Them
# 25                                Allowlist
# 87                         Preliminary test
# 165                                   Chair
# 6                                  Conclude
# 47                               The person
# 141                          Default branch
# 132                                Humanity
# 54                             The person's
# 86                               Basic test
# 0                                    Cancel
# 2                                      Halt
# 202                     Unreferenced object
# 156                            The person's
# 193                                  Freeze
# 94                                Principal
# 139                                 Leading
# 85                               Quick test
# 120                             Empty space
# 77                                 Humanity
# 145                                Standard
# 3                                      Stop
# 92                                  Primary
# 172                               Humankind
# 102                                Division
# 24                           Exclusion list
# 148                Person with a disability
# 185                              Engineered
# 137                                    Main
# 140                             Main branch
# 133                                  People
# 10                              Common user
# 101                               Isolation
# 9                             Standard user
# 183                               Synthetic
# 175                                  People
# 143                           Smaller group
# 93                                     Main
# 142                  Underrepresented group
# 110                                    Core
# 95                                  Leading
# 66                                   Legacy
# 194                                   Stall
# 75                              Staff-hours
# 135                             Individuals
# 108                                Built-in
# 22                                 Denylist
# 23                                Blocklist
# 109                              Integrated
# 184                              Artificial
# 127                              Indigenous
# 134                               Humankind
# 164                             Chairperson
# 80                              Individuals
# 1                                 Terminate
# 65                      Quantum superiority
# 7                                    Finish
# 71                                     Team
# 146                                 Typical
# 144                                   Usual
# 8                              Typical user
# 147                                Expected
# 72                                   People
# 100                              Separation
# 78                                   People
# 76                               Work-hours
# 176                               Humankind
# 79                                Humankind
# 74                             Person-hours
# 5                                      Stop
# 69                                 Everyone
# 73                                  You all
# 174                                Humanity
# 70                                    Folks
# 4                                       End
#
#                                      Modified Sentence  Similarity Score
# 17   The company detected a Unethical hacker attemp...          0.584426
# 16   The company detected a Malicious actor attempt...          0.610877
# 18   The company detected a Cybercriminal attemptin...          0.645379
# 103  A Maintenance window was enforced during the s...          0.658593
# 34   The Socket connector allows for easy integrati...          0.679458
# 97   The Team lead facilitated the daily stand-up m...          0.700074
# 15   The System with visible internals testing meth...          0.700742
# 161  The company prioritizes Team compatibility whe...          0.702953
# 201  The adapter functions as a Connector adapter f...          0.703491
# 107  The Security researcher with mixed methods hac...          0.708395
# 35   The Port connector allows for easy integration...          0.708663
# 168  The Lead supervised the construction site with...          0.717832
# 29   The paper underwent a Masked review review pro...          0.720732
# 98   The team opted for Ensemble programming to tac...          0.721668
# 14   The Transparent system testing method allows d...          0.722767
# 199  The adapter functions as a Adapter for connect...          0.727360
# 104  A Downtime was enforced during the system upgr...          0.728261
# 42   The developer's contribution to the discussion...          0.728824
# 200  The adapter functions as a Converter for conne...          0.734185
# 163  The company prioritizes Shared values when hir...          0.734874
# 105  A Service interruption was enforced during the...          0.739151
# 28   The paper underwent a Anonymous review review ...          0.740956
# 162  The company prioritizes Alignment with team va...          0.743285
# 169  The Site manager supervised the construction s...          0.743306
# 167  The Supervisor supervised the construction sit...          0.744094
# 197  The new functionality was implemented through ...          0.754634
# 39   The engineer was responsible for coordinating ...          0.755648
# 191  The server operates within the Network perimet...          0.756696
# 166  The Moderator called for a vote on the propose...          0.757036
# 158  His desk organization reflects a hint of Detai...          0.762296
# 126  The Improvement team focused on optimizing the...          0.776996
# 131  The Relay attack attack intercepted sensitive ...          0.777748
# 99   The team opted for Collaborative programming t...          0.777778
# 106  The Ambiguous hacker hacker reported the vulne...          0.778805
# 52   The team assigned the most critical task to Th...          0.782267
# 125  The Security optimization team focused on opti...          0.783778
# 192  The server operates within the Protected netwo...          0.785175
# 124  The Moderation team oversaw the cyber exercise...          0.785924
# 45   The credit for the innovative design is entire...          0.787886
# 196  The new functionality was implemented through ...          0.787963
# 198  The new functionality was implemented through ...          0.790100
# 38   The developer was responsible for coordinating...          0.790731
# 88   A quick Confidence test revealed several issue...          0.790785
# 153  The plan was considered Bold but turned out to...          0.792576
# 90   Developers use a Sample value as a placeholder...          0.795430
# 113  The web Primary updated the website’s layout f...          0.810848
# 129  The land’s history is deeply rooted in Origina...          0.814958
# 19   A Ethical hacker hacker helped identify securi...          0.817126
# 150  The venue was upgraded to be accessible for Pe...          0.817557
# 130  The Interception attack attack intercepted sen...          0.817796
# 112  The Security testing team simulated an attack ...          0.819837
# 157  The developer's desk organization reflects a h...          0.820212
# 48   The developer led the presentation with confid...          0.823391
# 159  His desk organization reflects a hint of Highl...          0.824690
# 123  The Oversight team oversaw the cyber exercise ...          0.826038
# 49   The engineer led the presentation with confide...          0.826881
# 89   Developers use a Placeholder value as a placeh...          0.829454
# 84   Before deploying the code, we need to perform ...          0.829483
# 111  The Attack simulation team simulated an attack...          0.829734
# 190  The network’s Protected network area protects ...          0.830743
# 21   A Security specialist hacker helped identify s...          0.831141
# 189  The network’s Network perimeter protects inter...          0.831660
# 59   The Leading database contains all the key reco...          0.831812
# 58   The Principal database contains all the key re...          0.832170
# 56   The Primary database contains all the key reco...          0.832613
# 20   A Security researcher hacker helped identify s...          0.832633
# 115  The web Principal updated the website’s layout...          0.833944
# 36   They was responsible for coordinating the team...          0.836792
# 30   The experiment was conducted under double-Anon...          0.838880
# 152  The plan was considered Innovative but turned ...          0.840000
# 181  The Sales representative demonstrated the prod...          0.842884
# 178    The crew Operates the ship during long voyages.          0.843587
# 154  The plan was considered Unique but turned out ...          0.844129
# 33   The cable is equipped with a Pin connector for...          0.844309
# 160  His desk organization reflects a hint of Metic...          0.844329
# 114  The web Main updated the website’s layout for ...          0.845296
# 62   The secondary system operates as a Follower to...          0.849255
# 116  The web Leading updated the website’s layout f...          0.850531
# 91   Developers use a Test value as a placeholder d...          0.850563
# 177      The crew Staffs the ship during long voyages.          0.851084
# 118  The Web administrator updated the website’s la...          0.852008
# 182  The Sales associate demonstrated the product’s...          0.853444
# 119  The Web maintainer updated the website’s layou...          0.854057
# 81   Before deploying the code, we need to perform ...          0.854385
# 121  The designer added Padding to improve the page...          0.855119
# 43   The credit for the innovative design is entire...          0.856372
# 37   The person was responsible for coordinating th...          0.857053
# 83   Before deploying the code, we need to perform ...          0.857224
# 40   Their contribution to the discussion was insig...          0.857565
# 128  The land’s history is deeply rooted in Native ...          0.857885
# 31   The experiment was conducted under double-Mask...          0.859742
# 203  The cleanup script removed the Disconnected ob...          0.859831
# 32   The cable is equipped with a Plug connector fo...          0.860130
# 55   The developer's programming skills greatly imp...          0.862446
# 44   The credit for the innovative design is entire...          0.862666
# 63   The secondary system operates as a Dependent t...          0.862953
# 122  The designer added Margin to improve the page'...          0.864702
# 179       The crew Works the ship during long voyages.          0.866085
# 151  The plan was considered Unconventional but tur...          0.867457
# 64   Achieving Quantum advantage marks a significan...          0.867519
# 117  The Web developer updated the website’s layout...          0.870446
# 26   Only pre-approved devices are included in the ...          0.870903
# 82   Before deploying the code, we need to perform ...          0.870917
# 57   The Main database contains all the key records...          0.872235
# 53   Their programming skills greatly improved the ...          0.873098
# 188  The project required significant Staffing to c...          0.876994
# 61   The secondary system operates as a Replica to ...          0.877979
# 12   The algorithm functions as a Undocumented syst...          0.878565
# 180  The Salesperson demonstrated the product’s key...          0.878644
# 195  The application tends to Become unresponsive w...          0.879780
# 41   The person's contribution to the discussion wa...          0.880988
# 27   Only pre-approved devices are included in the ...          0.882783
# 138  Changes were merged into the Principal branch ...          0.883970
# 68   The older software was Exempt in despite the n...          0.884822
# 173  Individuals has always sought to understand th...          0.884981
# 67   The older software was Previously approved in ...          0.886144
# 46   They led the presentation with confidence and ...          0.886162
# 186  The project required significant Workforce to ...          0.888754
# 149  The venue was upgraded to be accessible for Ac...          0.891089
# 60   The secondary system operates as a Secondary t...          0.892284
# 13   The algorithm functions as a System with limit...          0.892938
# 136  Changes were merged into the Primary branch fo...          0.894577
# 170  Humanity has always sought to understand the u...          0.895734
# 96   The Scrum facilitator facilitated the daily st...          0.895948
# 51   The team assigned the most critical task to Th...          0.896134
# 155  Their desk organization reflects a hint of OCD...          0.897488
# 11   The algorithm functions as a Opaque system, wi...          0.898719
# 187  The project required significant Personnel to ...          0.898788
# 171  People has always sought to understand the uni...          0.899577
# 50   The team assigned the most critical task to Them.          0.900533
# 25   Only pre-approved devices are included in the ...          0.901145
# 87   A quick Preliminary test revealed several issu...          0.902828
# 165  The Chair called for a vote on the proposed ch...          0.903277
# 6    The user chose to Conclude the installation pr...          0.904197
# 47   The person led the presentation with confidenc...          0.905801
# 141  Changes were merged into the Default branch fo...          0.905802
# 132  The Humanity-in-the-middle attack intercepted ...          0.906904
# 54   The person's programming skills greatly improv...          0.906941
# 86   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 2    The program will automatically Halt if a criti...          0.909458
# 202  The cleanup script removed the Unreferenced ob...          0.911102
# 156  The person's desk organization reflects a hint...          0.914325
# 193  The application tends to Freeze when handling ...          0.914745
# 94   The scrum Principal facilitated the daily stan...          0.915100
# 139  Changes were merged into the Leading branch fo...          0.915709
# 85   A quick Quick test revealed several issues in ...          0.918039
# 120  The designer added Empty space to improve the ...          0.918833
# 77   Completing the project required 100 Humanity h...          0.920907
# 145  The system is back to Standard after resolving...          0.921492
# 3    The program will automatically Stop if a criti...          0.922640
# 92   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 102  The system’s Division of duties ensures secure...          0.924723
# 24   The IP address was added to the company’s Excl...          0.925768
# 148  The venue was upgraded to be accessible for Pe...          0.926213
# 185  The reservoir is a Engineered structure design...          0.928353
# 137  Changes were merged into the Main branch for d...          0.928553
# 140  Changes were merged into the Main branch for d...          0.928553
# 133  The People-in-the-middle attack intercepted se...          0.929361
# 10   The app is designed to be intuitive for the Co...          0.929378
# 101  The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 175  People has made significant strides in technol...          0.931211
# 143  Efforts to promote diversity aim to amplify th...          0.931902
# 93   The scrum Main facilitated the daily stand-up ...          0.932176
# 142  Efforts to promote diversity aim to amplify th...          0.932201
# 110  The app includes a Core feature for photo edit...          0.933925
# 95   The scrum Leading facilitated the daily stand-...          0.934094
# 66   The older software was Legacy in despite the n...          0.934483
# 194  The application tends to Stall when handling l...          0.935331
# 75   Completing the project required 100 Staff-hour...          0.936402
# 135  The Individuals-in-the-middle attack intercept...          0.937020
# 108  The app includes a Built-in feature for photo ...          0.937234
# 22   The IP address was added to the company’s Deny...          0.937353
# 23   The IP address was added to the company’s Bloc...          0.937636
# 109  The app includes a Integrated feature for phot...          0.938498
# 184  The reservoir is a Artificial structure design...          0.939255
# 127  The land’s history is deeply rooted in Indigen...          0.939329
# 134  The Humankind-in-the-middle attack intercepted...          0.940031
# 164  The Chairperson called for a vote on the propo...          0.943595
# 80   Completing the project required 100 Individual...          0.944255
# 1    The program will automatically Terminate if a ...          0.945206
# 65   Achieving Quantum superiority marks a signific...          0.946091
# 7    The user chose to Finish the installation proc...          0.948518
# 71   Hey Team, let’s gather for the meeting in five...          0.950417
# 146  The system is back to Typical after resolving ...          0.950920
# 144  The system is back to Usual after resolving th...          0.953534
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 147  The system is back to Expected after resolving...          0.956891
# 72   Hey People, let’s gather for the meeting in fi...          0.957925
# 100  The system’s Separation of duties ensures secu...          0.958804
# 78   Completing the project required 100 People hou...          0.959826
# 76   Completing the project required 100 Work-hours...          0.961485
# 176  Humankind has made significant strides in tech...          0.961535
# 79   Completing the project required 100 Humankind ...          0.962538
# 74   Completing the project required 100 Person-hou...          0.963118
# 5    The user chose to Stop the installation proces...          0.964866
# 69   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 73   Hey You all, let’s gather for the meeting in f...          0.967226
# 174  Humanity has made significant strides in techn...          0.968785
# 70   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2-1_replacements.csv", index=False)

# %%
# PROMPT 1:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Terminate", "Halt", "Stop"],
    "Terminate": ["End", "Stop", "Conclude", "Finish"],
    "Average user": ["Typical user", "Standard user", "Common user"],
    "Black box": ["Opaque system", "Undocumented system", "System with limited visibility"],
    "White box": ["Transparent system", "System with visible internals"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Cybercriminal"],
    "White hat": ["Ethical hacker", "Security researcher", "Security specialist"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Safelist", "Inclusion list"],
    "Blind": ["Anonymous review", "Masked review"],
    "Double blind": ["Double-anonymous review", "Double-masked review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Socket connector", "Port connector"],
    "She": ["They", "The person", "The developer", "The engineer"],
    "Her": ["Their", "The person's", "The developer's"],
    "Hers": ["Theirs", "The person's", "The developer's"],
    "He": ["They", "The person", "The developer", "The engineer"],
    "Him": ["Them", "The person", "The developer"],
    "His": ["Their", "The person's", "The developer's"],
    "Master": ["Primary", "Main", "Principal", "Leading"],
    "Slave": ["Secondary", "Replica", "Follower", "Dependent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum superiority"],
    "Grandfathered": ["Legacy", "Previously approved", "Exempt"],
    "Guys": ["Everyone", "Folks", "Team", "People", "You all"],
    "Man hours": ["Person-hours", "Staff-hours", "Work-hours"],
    "Sanity check": ["Quick check", "Basic check", "Preliminary check", "Confidence check"],
    "Sanity test": ["Quick test", "Basic test", "Preliminary test", "Confidence test"],
    "Dummy value": ["Placeholder value", "Sample value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Team lead"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Division"],
    "Blackout period": ["Maintenance window", "Downtime", "Service interruption"],
    "Gray hat": ["Ambiguous hacker", "Security researcher with mixed methods"],
    "Native": ["Built-in", "Integrated", "Core"],
    "Red team": ["Attack simulation team", "Security testing team"],
    "Web master": ["Web developer", "Web administrator", "Web maintainer"],
    "White space": ["Empty space", "Padding", "Margin"],
    "White team": ["Oversight team", "Moderation team"],
    "Yellow team": ["Security optimization team", "Improvement team"],
    "Aboriginal": ["Indigenous", "Native", "Original"],
    "Brown bags": ["Informal learning sessions", "Lunch and learns"],
    "First-class citizen": ["First-class element", "Primary element"],
    "Man-in-the-middle": ["Interception attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch"],
    "Minority": ["Underrepresented group", "Smaller group"],
    "Normal": ["Usual", "Standard", "Typical", "Expected"],
    "Handicapped": ["Person with a disability", "Accessible", "Person with access needs"],
    "Crazy": ["Unconventional", "Innovative", "Bold", "Unique"],
    "OCD": ["Detail-oriented", "Highly organized", "Meticulous"],
    "Culture fit": ["Team compatibility", "Alignment with team values", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Moderator"],
    "Foreman": ["Supervisor", "Lead", "Site manager"],
    "Man": ["Humanity", "People", "Humankind", "Individuals"],
    "Mankind": ["Humanity", "People", "Humankind"],
    "Mans": ["Staffs", "Operates", "Works"],
    "Salesman": ["Salesperson", "Sales representative", "Sales associate"],
    "Manmade": ["Synthetic", "Artificial", "Engineered"],
    "Manpower": ["Workforce", "Personnel", "Staffing"],
    "Demilitarized zone": ["Network perimeter", "Protected network area"],
    "DMZ": ["Network perimeter", "Protected network area"],
    "Hang": ["Freeze", "Stall", "Become unresponsive"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Adapter", "Converter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Disconnected object"]
}


# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 17   The company detected a black hat attempting to...           Black hat
# 16   The company detected a black hat attempting to...           Black hat
# 18   The company detected a black hat attempting to...           Black hat
# 103  A blackout period was enforced during the syst...     Blackout period
# 34   The female connector allows for easy integrati...    Female connector
# 97   The scrum master facilitated the daily stand-u...        Scrum master
# 15   The white box testing method allows developers...           White box
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 201  The adapter functions as a gender bender for c...       Gender bender
# 107  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 35   The female connector allows for easy integrati...    Female connector
# 168  The foreman supervised the construction site w...             Foreman
# 29   The paper underwent a blind review process to ...               Blind
# 98   The team opted for mob programming to tackle t...     Mob programming
# 14   The white box testing method allows developers...           White box
# 199  The adapter functions as a gender bender for c...       Gender bender
# 104  A blackout period was enforced during the syst...     Blackout period
# 42   Her contribution to the discussion was insight...                 Her
# 200  The adapter functions as a gender bender for c...       Gender bender
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 105  A blackout period was enforced during the syst...     Blackout period
# 28   The paper underwent a blind review process to ...               Blind
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 169  The foreman supervised the construction site w...             Foreman
# 167  The foreman supervised the construction site w...             Foreman
# 197  The new functionality was implemented through ...      Daughter board
# 39   She was responsible for coordinating the team’...                 She
# 191  The server operates within the DMZ for added s...                 DMZ
# 166  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 126  The yellow team focused on optimizing the soft...         Yellow team
# 131  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 99   The team opted for mob programming to tackle t...     Mob programming
# 106  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 52    The team assigned the most critical task to him.                 Him
# 125  The yellow team focused on optimizing the soft...         Yellow team
# 192  The server operates within the DMZ for added s...                 DMZ
# 124  The white team oversaw the cyber exercise and ...          White team
# 45   The credit for the innovative design is entire...                Hers
# 196  The new functionality was implemented through ...      Daughter board
# 198  The new functionality was implemented through ...      Daughter board
# 38   She was responsible for coordinating the team’...                 She
# 88   A quick sanity test revealed several issues in...         Sanity test
# 153  The plan was considered crazy but turned out t...               Crazy
# 90   Developers use a dummy value as a placeholder ...         Dummy value
# 113  The web master updated the website’s layout fo...              Master
# 129  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 19   A white hat hacker helped identify security vu...           White hat
# 150  The venue was upgraded to be accessible for ha...         Handicapped
# 130  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 112  The red team simulated an attack to test the o...            Red team
# 157  His desk organization reflects a hint of OCD t...                 His
# 48   He led the presentation with confidence and cl...                  He
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 123  The white team oversaw the cyber exercise and ...          White team
# 49   He led the presentation with confidence and cl...                  He
# 89   Developers use a dummy value as a placeholder ...         Dummy value
# 84   Before deploying the code, we need to perform ...        Sanity check
# 111  The red team simulated an attack to test the o...            Red team
# 190  The network’s demilitarized zone protects inte...  Demilitarized zone
# 21   A white hat hacker helped identify security vu...           White hat
# 189  The network’s demilitarized zone protects inte...  Demilitarized zone
# 59   The master database contains all the key recor...              Master
# 58   The master database contains all the key recor...              Master
# 56   The master database contains all the key recor...              Master
# 20   A white hat hacker helped identify security vu...           White hat
# 115  The web master updated the website’s layout fo...              Master
# 36   She was responsible for coordinating the team’...                 She
# 30   The experiment was conducted under double-blin...               Blind
# 152  The plan was considered crazy but turned out t...               Crazy
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 178        The crew mans the ship during long voyages.                Mans
# 154  The plan was considered crazy but turned out t...               Crazy
# 33   The cable is equipped with a male connector fo...      Male connector
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 114  The web master updated the website’s layout fo...              Master
# 62   The secondary system operates as a slave to th...               Slave
# 116  The web master updated the website’s layout fo...              Master
# 91   Developers use a dummy value as a placeholder ...         Dummy value
# 177        The crew mans the ship during long voyages.                Mans
# 118  The web master updated the website’s layout fo...          Web master
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 119  The web master updated the website’s layout fo...          Web master
# 81   Before deploying the code, we need to perform ...        Sanity check
# 121  The designer added white space to improve the ...         White space
# 43   The credit for the innovative design is entire...                Hers
# 37   She was responsible for coordinating the team’...                 She
# 83   Before deploying the code, we need to perform ...        Sanity check
# 40   Her contribution to the discussion was insight...                 Her
# 128  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 31   The experiment was conducted under double-blin...               Blind
# 203  The cleanup script removed the orphaned object...     Orphaned object
# 32   The cable is equipped with a male connector fo...      Male connector
# 55   His programming skills greatly improved the pr...                 His
# 44   The credit for the innovative design is entire...                Hers
# 63   The secondary system operates as a slave to th...               Slave
# 122  The designer added white space to improve the ...         White space
# 179        The crew mans the ship during long voyages.                Mans
# 151  The plan was considered crazy but turned out t...               Crazy
# 64   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 117  The web master updated the website’s layout fo...          Web master
# 26   Only pre-approved devices are included in the ...           Whitelist
# 82   Before deploying the code, we need to perform ...        Sanity check
# 57   The master database contains all the key recor...              Master
# 53   His programming skills greatly improved the pr...                 His
# 188  The project required significant manpower to c...            Manpower
# 61   The secondary system operates as a slave to th...               Slave
# 12   The algorithm functions as a black box, with n...           Black box
# 180  The salesman demonstrated the product’s key fe...            Salesman
# 195  The application tends to hang when handling la...                Hang
# 41   Her contribution to the discussion was insight...                 Her
# 27   Only pre-approved devices are included in the ...           Whitelist
# 138  Changes were merged into the master branch for...              Master
# 68   The older software was grandfathered in despit...       Grandfathered
# 173  Man has always sought to understand the universe.                 Man
# 67   The older software was grandfathered in despit...       Grandfathered
# 46   He led the presentation with confidence and cl...                  He
# 186  The project required significant manpower to c...            Manpower
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 60   The secondary system operates as a slave to th...               Slave
# 13   The algorithm functions as a black box, with n...           Black box
# 136  Changes were merged into the master branch for...              Master
# 170  Man has always sought to understand the universe.                 Man
# 96   The scrum master facilitated the daily stand-u...        Scrum master
# 51    The team assigned the most critical task to him.                 Him
# 155  His desk organization reflects a hint of OCD t...                 His
# 11   The algorithm functions as a black box, with n...           Black box
# 187  The project required significant manpower to c...            Manpower
# 171  Man has always sought to understand the universe.                 Man
# 50    The team assigned the most critical task to him.                 Him
# 25   Only pre-approved devices are included in the ...           Whitelist
# 87   A quick sanity test revealed several issues in...         Sanity test
# 165  The chairman called for a vote on the proposed...            Chairman
# 6    The user chose to terminate the installation p...           Terminate
# 47   He led the presentation with confidence and cl...                  He
# 141  Changes were merged into the master branch for...       Master branch
# 132  The man-in-the-middle attack intercepted sensi...                 Man
# 54   His programming skills greatly improved the pr...                 His
# 86   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 2    The program will automatically abort if a crit...               Abort
# 202  The cleanup script removed the orphaned object...     Orphaned object
# 156  His desk organization reflects a hint of OCD t...                 His
# 193  The application tends to hang when handling la...                Hang
# 94   The scrum master facilitated the daily stand-u...              Master
# 139  Changes were merged into the master branch for...              Master
# 85   A quick sanity test revealed several issues in...         Sanity test
# 120  The designer added white space to improve the ...         White space
# 77   Completing the project required 100 man hours ...                 Man
# 145  The system is back to normal after resolving t...              Normal
# 3    The program will automatically abort if a crit...               Abort
# 92   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 102  The system’s segregation of duties ensures sec...         Segregation
# 24   The IP address was added to the company’s blac...           Blacklist
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 185  The reservoir is a manmade structure designed ...             Manmade
# 137  Changes were merged into the master branch for...              Master
# 140  Changes were merged into the master branch for...       Master branch
# 133  The man-in-the-middle attack intercepted sensi...                 Man
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 175  Mankind has made significant strides in techno...             Mankind
# 143  Efforts to promote diversity aim to amplify th...            Minority
# 93   The scrum master facilitated the daily stand-u...              Master
# 142  Efforts to promote diversity aim to amplify th...            Minority
# 110  The app includes a native feature for photo ed...              Native
# 95   The scrum master facilitated the daily stand-u...              Master
# 66   The older software was grandfathered in despit...       Grandfathered
# 194  The application tends to hang when handling la...                Hang
# 75   Completing the project required 100 man hours ...           Man hours
# 135  The man-in-the-middle attack intercepted sensi...                 Man
# 108  The app includes a native feature for photo ed...              Native
# 22   The IP address was added to the company’s blac...           Blacklist
# 23   The IP address was added to the company’s blac...           Blacklist
# 109  The app includes a native feature for photo ed...              Native
# 184  The reservoir is a manmade structure designed ...             Manmade
# 127  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 134  The man-in-the-middle attack intercepted sensi...                 Man
# 164  The chairman called for a vote on the proposed...            Chairman
# 80   Completing the project required 100 man hours ...                 Man
# 1    The program will automatically abort if a crit...               Abort
# 65   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 7    The user chose to terminate the installation p...           Terminate
# 71   Hey guys, let’s gather for the meeting in five...                Guys
# 146  The system is back to normal after resolving t...              Normal
# 144  The system is back to normal after resolving t...              Normal
# 8    The app is designed to be intuitive for the av...        Average user
# 147  The system is back to normal after resolving t...              Normal
# 72   Hey guys, let’s gather for the meeting in five...                Guys
# 100  The system’s segregation of duties ensures sec...         Segregation
# 78   Completing the project required 100 man hours ...                 Man
# 76   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 79   Completing the project required 100 man hours ...                 Man
# 74   Completing the project required 100 man hours ...           Man hours
# 5    The user chose to terminate the installation p...           Terminate
# 69   Hey guys, let’s gather for the meeting in five...                Guys
# 73   Hey guys, let’s gather for the meeting in five...                Guys
# 174  Mankind has made significant strides in techno...             Mankind
# 70   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                                 Replacement  \
# 17                         Unethical hacker
# 16                          Malicious actor
# 18                            Cybercriminal
# 103                      Maintenance window
# 34                         Socket connector
# 97                                Team lead
# 15            System with visible internals
# 161                      Team compatibility
# 201                       Connector adapter
# 107  Security researcher with mixed methods
# 35                           Port connector
# 168                                    Lead
# 29                            Masked review
# 98                     Ensemble programming
# 14                       Transparent system
# 199                                 Adapter
# 104                                Downtime
# 42                          The developer's
# 200                               Converter
# 163                           Shared values
# 105                    Service interruption
# 28                         Anonymous review
# 162              Alignment with team values
# 169                            Site manager
# 167                              Supervisor
# 197                            Add-on board
# 39                             The engineer
# 191                       Network perimeter
# 166                               Moderator
# 158                         Detail-oriented
# 126                        Improvement team
# 131                            Relay attack
# 99                Collaborative programming
# 106                        Ambiguous hacker
# 52                            The developer
# 125              Security optimization team
# 192                  Protected network area
# 124                         Moderation team
# 45                          The developer's
# 196                         Expansion board
# 198                         Secondary board
# 38                            The developer
# 88                          Confidence test
# 153                                    Bold
# 90                             Sample value
# 113                                 Primary
# 129                                Original
# 19                           Ethical hacker
# 150                Person with access needs
# 130                     Interception attack
# 112                   Security testing team
# 157                         The developer's
# 48                            The developer
# 159                        Highly organized
# 123                          Oversight team
# 49                             The engineer
# 89                        Placeholder value
# 84                         Confidence check
# 111                  Attack simulation team
# 190                  Protected network area
# 21                      Security specialist
# 189                       Network perimeter
# 59                                  Leading
# 58                                Principal
# 56                                  Primary
# 20                      Security researcher
# 115                               Principal
# 36                                     They
# 30                         Anonymous review
# 152                              Innovative
# 181                    Sales representative
# 178                                Operates
# 154                                  Unique
# 33                            Pin connector
# 160                              Meticulous
# 114                                    Main
# 62                                 Follower
# 116                                 Leading
# 91                               Test value
# 177                                  Staffs
# 118                       Web administrator
# 182                         Sales associate
# 119                          Web maintainer
# 81                              Quick check
# 121                                 Padding
# 43                                   Theirs
# 37                               The person
# 83                        Preliminary check
# 40                                    Their
# 128                                  Native
# 31                            Masked review
# 203                     Disconnected object
# 32                           Plug connector
# 55                          The developer's
# 44                             The person's
# 63                                Dependent
# 122                                  Margin
# 179                                   Works
# 151                          Unconventional
# 64                        Quantum advantage
# 117                           Web developer
# 26                                 Safelist
# 82                              Basic check
# 57                                     Main
# 53                                    Their
# 188                                Staffing
# 61                                  Replica
# 12                      Undocumented system
# 180                             Salesperson
# 195                     Become unresponsive
# 41                             The person's
# 27                           Inclusion list
# 138                               Principal
# 68                                   Exempt
# 173                             Individuals
# 67                      Previously approved
# 46                                     They
# 186                               Workforce
# 149                              Accessible
# 60                                Secondary
# 13           System with limited visibility
# 136                                 Primary
# 170                                Humanity
# 96                        Scrum facilitator
# 51                               The person
# 155                                   Their
# 11                            Opaque system
# 187                               Personnel
# 171                                  People
# 50                                     Them
# 25                                Allowlist
# 87                         Preliminary test
# 165                                   Chair
# 6                                  Conclude
# 47                               The person
# 141                          Default branch
# 132                                Humanity
# 54                             The person's
# 86                               Basic test
# 0                                    Cancel
# 2                                      Halt
# 202                     Unreferenced object
# 156                            The person's
# 193                                  Freeze
# 94                                Principal
# 139                                 Leading
# 85                               Quick test
# 120                             Empty space
# 77                                 Humanity
# 145                                Standard
# 3                                      Stop
# 92                                  Primary
# 172                               Humankind
# 102                                Division
# 24                           Exclusion list
# 148                Person with a disability
# 185                              Engineered
# 137                                    Main
# 140                             Main branch
# 133                                  People
# 10                              Common user
# 101                               Isolation
# 9                             Standard user
# 183                               Synthetic
# 175                                  People
# 143                           Smaller group
# 93                                     Main
# 142                  Underrepresented group
# 110                                    Core
# 95                                  Leading
# 66                                   Legacy
# 194                                   Stall
# 75                              Staff-hours
# 135                             Individuals
# 108                                Built-in
# 22                                 Denylist
# 23                                Blocklist
# 109                              Integrated
# 184                              Artificial
# 127                              Indigenous
# 134                               Humankind
# 164                             Chairperson
# 80                              Individuals
# 1                                 Terminate
# 65                      Quantum superiority
# 7                                    Finish
# 71                                     Team
# 146                                 Typical
# 144                                   Usual
# 8                              Typical user
# 147                                Expected
# 72                                   People
# 100                              Separation
# 78                                   People
# 76                               Work-hours
# 176                               Humankind
# 79                                Humankind
# 74                             Person-hours
# 5                                      Stop
# 69                                 Everyone
# 73                                  You all
# 174                                Humanity
# 70                                    Folks
# 4                                       End
#
#                                      Modified Sentence  Similarity Score
# 17   The company detected a Unethical hacker attemp...          0.584426
# 16   The company detected a Malicious actor attempt...          0.610877
# 18   The company detected a Cybercriminal attemptin...          0.645379
# 103  A Maintenance window was enforced during the s...          0.658593
# 34   The Socket connector allows for easy integrati...          0.679458
# 97   The Team lead facilitated the daily stand-up m...          0.700074
# 15   The System with visible internals testing meth...          0.700742
# 161  The company prioritizes Team compatibility whe...          0.702953
# 201  The adapter functions as a Connector adapter f...          0.703491
# 107  The Security researcher with mixed methods hac...          0.708395
# 35   The Port connector allows for easy integration...          0.708663
# 168  The Lead supervised the construction site with...          0.717832
# 29   The paper underwent a Masked review review pro...          0.720732
# 98   The team opted for Ensemble programming to tac...          0.721668
# 14   The Transparent system testing method allows d...          0.722767
# 199  The adapter functions as a Adapter for connect...          0.727360
# 104  A Downtime was enforced during the system upgr...          0.728261
# 42   The developer's contribution to the discussion...          0.728824
# 200  The adapter functions as a Converter for conne...          0.734185
# 163  The company prioritizes Shared values when hir...          0.734874
# 105  A Service interruption was enforced during the...          0.739151
# 28   The paper underwent a Anonymous review review ...          0.740956
# 162  The company prioritizes Alignment with team va...          0.743285
# 169  The Site manager supervised the construction s...          0.743306
# 167  The Supervisor supervised the construction sit...          0.744094
# 197  The new functionality was implemented through ...          0.754634
# 39   The engineer was responsible for coordinating ...          0.755648
# 191  The server operates within the Network perimet...          0.756696
# 166  The Moderator called for a vote on the propose...          0.757036
# 158  His desk organization reflects a hint of Detai...          0.762296
# 126  The Improvement team focused on optimizing the...          0.776996
# 131  The Relay attack attack intercepted sensitive ...          0.777748
# 99   The team opted for Collaborative programming t...          0.777778
# 106  The Ambiguous hacker hacker reported the vulne...          0.778805
# 52   The team assigned the most critical task to Th...          0.782267
# 125  The Security optimization team focused on opti...          0.783778
# 192  The server operates within the Protected netwo...          0.785175
# 124  The Moderation team oversaw the cyber exercise...          0.785924
# 45   The credit for the innovative design is entire...          0.787886
# 196  The new functionality was implemented through ...          0.787963
# 198  The new functionality was implemented through ...          0.790100
# 38   The developer was responsible for coordinating...          0.790731
# 88   A quick Confidence test revealed several issue...          0.790785
# 153  The plan was considered Bold but turned out to...          0.792576
# 90   Developers use a Sample value as a placeholder...          0.795430
# 113  The web Primary updated the website’s layout f...          0.810848
# 129  The land’s history is deeply rooted in Origina...          0.814958
# 19   A Ethical hacker hacker helped identify securi...          0.817126
# 150  The venue was upgraded to be accessible for Pe...          0.817557
# 130  The Interception attack attack intercepted sen...          0.817796
# 112  The Security testing team simulated an attack ...          0.819837
# 157  The developer's desk organization reflects a h...          0.820212
# 48   The developer led the presentation with confid...          0.823391
# 159  His desk organization reflects a hint of Highl...          0.824690
# 123  The Oversight team oversaw the cyber exercise ...          0.826038
# 49   The engineer led the presentation with confide...          0.826881
# 89   Developers use a Placeholder value as a placeh...          0.829454
# 84   Before deploying the code, we need to perform ...          0.829483
# 111  The Attack simulation team simulated an attack...          0.829734
# 190  The network’s Protected network area protects ...          0.830743
# 21   A Security specialist hacker helped identify s...          0.831141
# 189  The network’s Network perimeter protects inter...          0.831660
# 59   The Leading database contains all the key reco...          0.831812
# 58   The Principal database contains all the key re...          0.832170
# 56   The Primary database contains all the key reco...          0.832613
# 20   A Security researcher hacker helped identify s...          0.832633
# 115  The web Principal updated the website’s layout...          0.833944
# 36   They was responsible for coordinating the team...          0.836792
# 30   The experiment was conducted under double-Anon...          0.838880
# 152  The plan was considered Innovative but turned ...          0.840000
# 181  The Sales representative demonstrated the prod...          0.842884
# 178    The crew Operates the ship during long voyages.          0.843587
# 154  The plan was considered Unique but turned out ...          0.844129
# 33   The cable is equipped with a Pin connector for...          0.844309
# 160  His desk organization reflects a hint of Metic...          0.844329
# 114  The web Main updated the website’s layout for ...          0.845296
# 62   The secondary system operates as a Follower to...          0.849255
# 116  The web Leading updated the website’s layout f...          0.850531
# 91   Developers use a Test value as a placeholder d...          0.850563
# 177      The crew Staffs the ship during long voyages.          0.851084
# 118  The Web administrator updated the website’s la...          0.852008
# 182  The Sales associate demonstrated the product’s...          0.853444
# 119  The Web maintainer updated the website’s layou...          0.854057
# 81   Before deploying the code, we need to perform ...          0.854385
# 121  The designer added Padding to improve the page...          0.855119
# 43   The credit for the innovative design is entire...          0.856372
# 37   The person was responsible for coordinating th...          0.857053
# 83   Before deploying the code, we need to perform ...          0.857224
# 40   Their contribution to the discussion was insig...          0.857565
# 128  The land’s history is deeply rooted in Native ...          0.857885
# 31   The experiment was conducted under double-Mask...          0.859742
# 203  The cleanup script removed the Disconnected ob...          0.859831
# 32   The cable is equipped with a Plug connector fo...          0.860130
# 55   The developer's programming skills greatly imp...          0.862446
# 44   The credit for the innovative design is entire...          0.862666
# 63   The secondary system operates as a Dependent t...          0.862953
# 122  The designer added Margin to improve the page'...          0.864702
# 179       The crew Works the ship during long voyages.          0.866085
# 151  The plan was considered Unconventional but tur...          0.867457
# 64   Achieving Quantum advantage marks a significan...          0.867519
# 117  The Web developer updated the website’s layout...          0.870446
# 26   Only pre-approved devices are included in the ...          0.870903
# 82   Before deploying the code, we need to perform ...          0.870917
# 57   The Main database contains all the key records...          0.872235
# 53   Their programming skills greatly improved the ...          0.873098
# 188  The project required significant Staffing to c...          0.876994
# 61   The secondary system operates as a Replica to ...          0.877979
# 12   The algorithm functions as a Undocumented syst...          0.878565
# 180  The Salesperson demonstrated the product’s key...          0.878644
# 195  The application tends to Become unresponsive w...          0.879780
# 41   The person's contribution to the discussion wa...          0.880988
# 27   Only pre-approved devices are included in the ...          0.882783
# 138  Changes were merged into the Principal branch ...          0.883970
# 68   The older software was Exempt in despite the n...          0.884822
# 173  Individuals has always sought to understand th...          0.884981
# 67   The older software was Previously approved in ...          0.886144
# 46   They led the presentation with confidence and ...          0.886162
# 186  The project required significant Workforce to ...          0.888754
# 149  The venue was upgraded to be accessible for Ac...          0.891089
# 60   The secondary system operates as a Secondary t...          0.892284
# 13   The algorithm functions as a System with limit...          0.892938
# 136  Changes were merged into the Primary branch fo...          0.894577
# 170  Humanity has always sought to understand the u...          0.895734
# 96   The Scrum facilitator facilitated the daily st...          0.895948
# 51   The team assigned the most critical task to Th...          0.896134
# 155  Their desk organization reflects a hint of OCD...          0.897488
# 11   The algorithm functions as a Opaque system, wi...          0.898719
# 187  The project required significant Personnel to ...          0.898788
# 171  People has always sought to understand the uni...          0.899577
# 50   The team assigned the most critical task to Them.          0.900533
# 25   Only pre-approved devices are included in the ...          0.901145
# 87   A quick Preliminary test revealed several issu...          0.902828
# 165  The Chair called for a vote on the proposed ch...          0.903277
# 6    The user chose to Conclude the installation pr...          0.904197
# 47   The person led the presentation with confidenc...          0.905801
# 141  Changes were merged into the Default branch fo...          0.905802
# 132  The Humanity-in-the-middle attack intercepted ...          0.906904
# 54   The person's programming skills greatly improv...          0.906941
# 86   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 2    The program will automatically Halt if a criti...          0.909458
# 202  The cleanup script removed the Unreferenced ob...          0.911102
# 156  The person's desk organization reflects a hint...          0.914325
# 193  The application tends to Freeze when handling ...          0.914745
# 94   The scrum Principal facilitated the daily stan...          0.915100
# 139  Changes were merged into the Leading branch fo...          0.915709
# 85   A quick Quick test revealed several issues in ...          0.918039
# 120  The designer added Empty space to improve the ...          0.918833
# 77   Completing the project required 100 Humanity h...          0.920907
# 145  The system is back to Standard after resolving...          0.921492
# 3    The program will automatically Stop if a criti...          0.922640
# 92   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 102  The system’s Division of duties ensures secure...          0.924723
# 24   The IP address was added to the company’s Excl...          0.925768
# 148  The venue was upgraded to be accessible for Pe...          0.926213
# 185  The reservoir is a Engineered structure design...          0.928353
# 137  Changes were merged into the Main branch for d...          0.928553
# 140  Changes were merged into the Main branch for d...          0.928553
# 133  The People-in-the-middle attack intercepted se...          0.929361
# 10   The app is designed to be intuitive for the Co...          0.929378
# 101  The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 175  People has made significant strides in technol...          0.931211
# 143  Efforts to promote diversity aim to amplify th...          0.931902
# 93   The scrum Main facilitated the daily stand-up ...          0.932176
# 142  Efforts to promote diversity aim to amplify th...          0.932201
# 110  The app includes a Core feature for photo edit...          0.933925
# 95   The scrum Leading facilitated the daily stand-...          0.934094
# 66   The older software was Legacy in despite the n...          0.934483
# 194  The application tends to Stall when handling l...          0.935331
# 75   Completing the project required 100 Staff-hour...          0.936402
# 135  The Individuals-in-the-middle attack intercept...          0.937020
# 108  The app includes a Built-in feature for photo ...          0.937234
# 22   The IP address was added to the company’s Deny...          0.937353
# 23   The IP address was added to the company’s Bloc...          0.937636
# 109  The app includes a Integrated feature for phot...          0.938498
# 184  The reservoir is a Artificial structure design...          0.939255
# 127  The land’s history is deeply rooted in Indigen...          0.939329
# 134  The Humankind-in-the-middle attack intercepted...          0.940031
# 164  The Chairperson called for a vote on the propo...          0.943595
# 80   Completing the project required 100 Individual...          0.944255
# 1    The program will automatically Terminate if a ...          0.945206
# 65   Achieving Quantum superiority marks a signific...          0.946091
# 7    The user chose to Finish the installation proc...          0.948518
# 71   Hey Team, let’s gather for the meeting in five...          0.950417
# 146  The system is back to Typical after resolving ...          0.950920
# 144  The system is back to Usual after resolving th...          0.953534
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 147  The system is back to Expected after resolving...          0.956891
# 72   Hey People, let’s gather for the meeting in fi...          0.957925
# 100  The system’s Separation of duties ensures secu...          0.958804
# 78   Completing the project required 100 People hou...          0.959826
# 76   Completing the project required 100 Work-hours...          0.961485
# 176  Humankind has made significant strides in tech...          0.961535
# 79   Completing the project required 100 Humankind ...          0.962538
# 74   Completing the project required 100 Person-hou...          0.963118
# 5    The user chose to Stop the installation proces...          0.964866
# 69   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 73   Hey You all, let’s gather for the meeting in f...          0.967226
# 174  Humanity has made significant strides in techn...          0.968785
# 70   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2-2_replacements.csv", index=False)

# %%
# PROMPT 3:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Terminate", "Halt", "Stop"],
    "Terminate": ["End", "Stop", "Conclude", "Finish"],
    "Average user": ["Typical user", "Standard user", "Common user"],
    "Black box": ["Opaque system", "Undocumented system", "System with limited visibility"],
    "White box": ["Transparent system", "System with visible internals"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Cybercriminal"],
    "White hat": ["Ethical hacker", "Security researcher", "Security specialist"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Safelist", "Inclusion list"],
    "Blind": ["Anonymous review", "Masked review"],
    "Double blind": ["Double-anonymous review", "Double-masked review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Socket connector", "Port connector"],
    "She": ["They", "The person", "The developer", "The engineer"],
    "Her": ["Their", "The person's", "The developer's"],
    "Hers": ["Theirs", "The person's", "The developer's"],
    "He": ["They", "The person", "The developer", "The engineer"],
    "Him": ["Them", "The person", "The developer"],
    "His": ["Their", "The person's", "The developer's"],
    "Master": ["Primary", "Main", "Principal", "Leading"],
    "Slave": ["Secondary", "Replica", "Follower", "Dependent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum superiority"],
    "Grandfathered": ["Legacy", "Previously approved", "Exempt"],
    "Guys": ["Everyone", "Folks", "Team", "People", "You all"],
    "Man hours": ["Person-hours", "Staff-hours", "Work-hours"],
    "Sanity check": ["Quick check", "Basic check", "Preliminary check", "Confidence check"],
    "Sanity test": ["Quick test", "Basic test", "Preliminary test", "Confidence test"],
    "Dummy value": ["Placeholder value", "Sample value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Team lead"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Division"],
    "Blackout period": ["Maintenance window", "Downtime", "Service interruption"],
    "Gray hat": ["Ambiguous hacker", "Security researcher with mixed methods"],
    "Native": ["Built-in", "Integrated", "Core"],
    "Red team": ["Attack simulation team", "Security testing team"],
    "Web master": ["Web developer", "Web administrator", "Web maintainer"],
    "White space": ["Empty space", "Padding", "Margin"],
    "White team": ["Oversight team", "Moderation team"],
    "Yellow team": ["Security optimization team", "Improvement team"],
    "Aboriginal": ["Indigenous", "Native", "Original"],
    "Brown bags": ["Informal learning sessions", "Lunch and learns"],
    "First-class citizen": ["First-class element", "Primary element"],
    "Man-in-the-middle": ["Interception attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch"],
    "Minority": ["Underrepresented group", "Smaller group"],
    "Normal": ["Usual", "Standard", "Typical", "Expected"],
    "Handicapped": ["Person with a disability", "Accessible", "Person with access needs"],
    "Crazy": ["Unconventional", "Innovative", "Bold", "Unique"],
    "OCD": ["Detail-oriented", "Highly organized", "Meticulous"],
    "Culture fit": ["Team compatibility", "Alignment with team values", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Moderator"],
    "Foreman": ["Supervisor", "Lead", "Site manager"],
    "Man": ["Humanity", "People", "Humankind", "Individuals"],
    "Mankind": ["Humanity", "People", "Humankind"],
    "Mans": ["Staffs", "Operates", "Works"],
    "Salesman": ["Salesperson", "Sales representative", "Sales associate"],
    "Manmade": ["Synthetic", "Artificial", "Engineered"],
    "Manpower": ["Workforce", "Personnel", "Staffing"],
    "Demilitarized zone": ["Network perimeter", "Protected network area"],
    "DMZ": ["Network perimeter", "Protected network area"],
    "Hang": ["Freeze", "Stall", "Become unresponsive"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Adapter", "Converter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Disconnected object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 17   The company detected a black hat attempting to...           Black hat
# 16   The company detected a black hat attempting to...           Black hat
# 18   The company detected a black hat attempting to...           Black hat
# 103  A blackout period was enforced during the syst...     Blackout period
# 34   The female connector allows for easy integrati...    Female connector
# 97   The scrum master facilitated the daily stand-u...        Scrum master
# 15   The white box testing method allows developers...           White box
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 201  The adapter functions as a gender bender for c...       Gender bender
# 107  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 35   The female connector allows for easy integrati...    Female connector
# 168  The foreman supervised the construction site w...             Foreman
# 29   The paper underwent a blind review process to ...               Blind
# 98   The team opted for mob programming to tackle t...     Mob programming
# 14   The white box testing method allows developers...           White box
# 199  The adapter functions as a gender bender for c...       Gender bender
# 104  A blackout period was enforced during the syst...     Blackout period
# 42   Her contribution to the discussion was insight...                 Her
# 200  The adapter functions as a gender bender for c...       Gender bender
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 105  A blackout period was enforced during the syst...     Blackout period
# 28   The paper underwent a blind review process to ...               Blind
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 169  The foreman supervised the construction site w...             Foreman
# 167  The foreman supervised the construction site w...             Foreman
# 197  The new functionality was implemented through ...      Daughter board
# 39   She was responsible for coordinating the team’...                 She
# 191  The server operates within the DMZ for added s...                 DMZ
# 166  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 126  The yellow team focused on optimizing the soft...         Yellow team
# 131  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 99   The team opted for mob programming to tackle t...     Mob programming
# 106  The gray hat hacker reported the vulnerabiliti...            Gray hat
# 52    The team assigned the most critical task to him.                 Him
# 125  The yellow team focused on optimizing the soft...         Yellow team
# 192  The server operates within the DMZ for added s...                 DMZ
# 124  The white team oversaw the cyber exercise and ...          White team
# 45   The credit for the innovative design is entire...                Hers
# 196  The new functionality was implemented through ...      Daughter board
# 198  The new functionality was implemented through ...      Daughter board
# 38   She was responsible for coordinating the team’...                 She
# 88   A quick sanity test revealed several issues in...         Sanity test
# 153  The plan was considered crazy but turned out t...               Crazy
# 90   Developers use a dummy value as a placeholder ...         Dummy value
# 113  The web master updated the website’s layout fo...              Master
# 129  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 19   A white hat hacker helped identify security vu...           White hat
# 150  The venue was upgraded to be accessible for ha...         Handicapped
# 130  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 112  The red team simulated an attack to test the o...            Red team
# 157  His desk organization reflects a hint of OCD t...                 His
# 48   He led the presentation with confidence and cl...                  He
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 123  The white team oversaw the cyber exercise and ...          White team
# 49   He led the presentation with confidence and cl...                  He
# 89   Developers use a dummy value as a placeholder ...         Dummy value
# 84   Before deploying the code, we need to perform ...        Sanity check
# 111  The red team simulated an attack to test the o...            Red team
# 190  The network’s demilitarized zone protects inte...  Demilitarized zone
# 21   A white hat hacker helped identify security vu...           White hat
# 189  The network’s demilitarized zone protects inte...  Demilitarized zone
# 59   The master database contains all the key recor...              Master
# 58   The master database contains all the key recor...              Master
# 56   The master database contains all the key recor...              Master
# 20   A white hat hacker helped identify security vu...           White hat
# 115  The web master updated the website’s layout fo...              Master
# 36   She was responsible for coordinating the team’...                 She
# 30   The experiment was conducted under double-blin...               Blind
# 152  The plan was considered crazy but turned out t...               Crazy
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 178        The crew mans the ship during long voyages.                Mans
# 154  The plan was considered crazy but turned out t...               Crazy
# 33   The cable is equipped with a male connector fo...      Male connector
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 114  The web master updated the website’s layout fo...              Master
# 62   The secondary system operates as a slave to th...               Slave
# 116  The web master updated the website’s layout fo...              Master
# 91   Developers use a dummy value as a placeholder ...         Dummy value
# 177        The crew mans the ship during long voyages.                Mans
# 118  The web master updated the website’s layout fo...          Web master
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 119  The web master updated the website’s layout fo...          Web master
# 81   Before deploying the code, we need to perform ...        Sanity check
# 121  The designer added white space to improve the ...         White space
# 43   The credit for the innovative design is entire...                Hers
# 37   She was responsible for coordinating the team’...                 She
# 83   Before deploying the code, we need to perform ...        Sanity check
# 40   Her contribution to the discussion was insight...                 Her
# 128  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 31   The experiment was conducted under double-blin...               Blind
# 203  The cleanup script removed the orphaned object...     Orphaned object
# 32   The cable is equipped with a male connector fo...      Male connector
# 55   His programming skills greatly improved the pr...                 His
# 44   The credit for the innovative design is entire...                Hers
# 63   The secondary system operates as a slave to th...               Slave
# 122  The designer added white space to improve the ...         White space
# 179        The crew mans the ship during long voyages.                Mans
# 151  The plan was considered crazy but turned out t...               Crazy
# 64   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 117  The web master updated the website’s layout fo...          Web master
# 26   Only pre-approved devices are included in the ...           Whitelist
# 82   Before deploying the code, we need to perform ...        Sanity check
# 57   The master database contains all the key recor...              Master
# 53   His programming skills greatly improved the pr...                 His
# 188  The project required significant manpower to c...            Manpower
# 61   The secondary system operates as a slave to th...               Slave
# 12   The algorithm functions as a black box, with n...           Black box
# 180  The salesman demonstrated the product’s key fe...            Salesman
# 195  The application tends to hang when handling la...                Hang
# 41   Her contribution to the discussion was insight...                 Her
# 27   Only pre-approved devices are included in the ...           Whitelist
# 138  Changes were merged into the master branch for...              Master
# 68   The older software was grandfathered in despit...       Grandfathered
# 173  Man has always sought to understand the universe.                 Man
# 67   The older software was grandfathered in despit...       Grandfathered
# 46   He led the presentation with confidence and cl...                  He
# 186  The project required significant manpower to c...            Manpower
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 60   The secondary system operates as a slave to th...               Slave
# 13   The algorithm functions as a black box, with n...           Black box
# 136  Changes were merged into the master branch for...              Master
# 170  Man has always sought to understand the universe.                 Man
# 96   The scrum master facilitated the daily stand-u...        Scrum master
# 51    The team assigned the most critical task to him.                 Him
# 155  His desk organization reflects a hint of OCD t...                 His
# 11   The algorithm functions as a black box, with n...           Black box
# 187  The project required significant manpower to c...            Manpower
# 171  Man has always sought to understand the universe.                 Man
# 50    The team assigned the most critical task to him.                 Him
# 25   Only pre-approved devices are included in the ...           Whitelist
# 87   A quick sanity test revealed several issues in...         Sanity test
# 165  The chairman called for a vote on the proposed...            Chairman
# 6    The user chose to terminate the installation p...           Terminate
# 47   He led the presentation with confidence and cl...                  He
# 141  Changes were merged into the master branch for...       Master branch
# 132  The man-in-the-middle attack intercepted sensi...                 Man
# 54   His programming skills greatly improved the pr...                 His
# 86   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 2    The program will automatically abort if a crit...               Abort
# 202  The cleanup script removed the orphaned object...     Orphaned object
# 156  His desk organization reflects a hint of OCD t...                 His
# 193  The application tends to hang when handling la...                Hang
# 94   The scrum master facilitated the daily stand-u...              Master
# 139  Changes were merged into the master branch for...              Master
# 85   A quick sanity test revealed several issues in...         Sanity test
# 120  The designer added white space to improve the ...         White space
# 77   Completing the project required 100 man hours ...                 Man
# 145  The system is back to normal after resolving t...              Normal
# 3    The program will automatically abort if a crit...               Abort
# 92   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 102  The system’s segregation of duties ensures sec...         Segregation
# 24   The IP address was added to the company’s blac...           Blacklist
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 185  The reservoir is a manmade structure designed ...             Manmade
# 137  Changes were merged into the master branch for...              Master
# 140  Changes were merged into the master branch for...       Master branch
# 133  The man-in-the-middle attack intercepted sensi...                 Man
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 175  Mankind has made significant strides in techno...             Mankind
# 143  Efforts to promote diversity aim to amplify th...            Minority
# 93   The scrum master facilitated the daily stand-u...              Master
# 142  Efforts to promote diversity aim to amplify th...            Minority
# 110  The app includes a native feature for photo ed...              Native
# 95   The scrum master facilitated the daily stand-u...              Master
# 66   The older software was grandfathered in despit...       Grandfathered
# 194  The application tends to hang when handling la...                Hang
# 75   Completing the project required 100 man hours ...           Man hours
# 135  The man-in-the-middle attack intercepted sensi...                 Man
# 108  The app includes a native feature for photo ed...              Native
# 22   The IP address was added to the company’s blac...           Blacklist
# 23   The IP address was added to the company’s blac...           Blacklist
# 109  The app includes a native feature for photo ed...              Native
# 184  The reservoir is a manmade structure designed ...             Manmade
# 127  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 134  The man-in-the-middle attack intercepted sensi...                 Man
# 164  The chairman called for a vote on the proposed...            Chairman
# 80   Completing the project required 100 man hours ...                 Man
# 1    The program will automatically abort if a crit...               Abort
# 65   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 7    The user chose to terminate the installation p...           Terminate
# 71   Hey guys, let’s gather for the meeting in five...                Guys
# 146  The system is back to normal after resolving t...              Normal
# 144  The system is back to normal after resolving t...              Normal
# 8    The app is designed to be intuitive for the av...        Average user
# 147  The system is back to normal after resolving t...              Normal
# 72   Hey guys, let’s gather for the meeting in five...                Guys
# 100  The system’s segregation of duties ensures sec...         Segregation
# 78   Completing the project required 100 man hours ...                 Man
# 76   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 79   Completing the project required 100 man hours ...                 Man
# 74   Completing the project required 100 man hours ...           Man hours
# 5    The user chose to terminate the installation p...           Terminate
# 69   Hey guys, let’s gather for the meeting in five...                Guys
# 73   Hey guys, let’s gather for the meeting in five...                Guys
# 174  Mankind has made significant strides in techno...             Mankind
# 70   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                                 Replacement  \
# 17                         Unethical hacker
# 16                          Malicious actor
# 18                            Cybercriminal
# 103                      Maintenance window
# 34                         Socket connector
# 97                                Team lead
# 15            System with visible internals
# 161                      Team compatibility
# 201                       Connector adapter
# 107  Security researcher with mixed methods
# 35                           Port connector
# 168                                    Lead
# 29                            Masked review
# 98                     Ensemble programming
# 14                       Transparent system
# 199                                 Adapter
# 104                                Downtime
# 42                          The developer's
# 200                               Converter
# 163                           Shared values
# 105                    Service interruption
# 28                         Anonymous review
# 162              Alignment with team values
# 169                            Site manager
# 167                              Supervisor
# 197                            Add-on board
# 39                             The engineer
# 191                       Network perimeter
# 166                               Moderator
# 158                         Detail-oriented
# 126                        Improvement team
# 131                            Relay attack
# 99                Collaborative programming
# 106                        Ambiguous hacker
# 52                            The developer
# 125              Security optimization team
# 192                  Protected network area
# 124                         Moderation team
# 45                          The developer's
# 196                         Expansion board
# 198                         Secondary board
# 38                            The developer
# 88                          Confidence test
# 153                                    Bold
# 90                             Sample value
# 113                                 Primary
# 129                                Original
# 19                           Ethical hacker
# 150                Person with access needs
# 130                     Interception attack
# 112                   Security testing team
# 157                         The developer's
# 48                            The developer
# 159                        Highly organized
# 123                          Oversight team
# 49                             The engineer
# 89                        Placeholder value
# 84                         Confidence check
# 111                  Attack simulation team
# 190                  Protected network area
# 21                      Security specialist
# 189                       Network perimeter
# 59                                  Leading
# 58                                Principal
# 56                                  Primary
# 20                      Security researcher
# 115                               Principal
# 36                                     They
# 30                         Anonymous review
# 152                              Innovative
# 181                    Sales representative
# 178                                Operates
# 154                                  Unique
# 33                            Pin connector
# 160                              Meticulous
# 114                                    Main
# 62                                 Follower
# 116                                 Leading
# 91                               Test value
# 177                                  Staffs
# 118                       Web administrator
# 182                         Sales associate
# 119                          Web maintainer
# 81                              Quick check
# 121                                 Padding
# 43                                   Theirs
# 37                               The person
# 83                        Preliminary check
# 40                                    Their
# 128                                  Native
# 31                            Masked review
# 203                     Disconnected object
# 32                           Plug connector
# 55                          The developer's
# 44                             The person's
# 63                                Dependent
# 122                                  Margin
# 179                                   Works
# 151                          Unconventional
# 64                        Quantum advantage
# 117                           Web developer
# 26                                 Safelist
# 82                              Basic check
# 57                                     Main
# 53                                    Their
# 188                                Staffing
# 61                                  Replica
# 12                      Undocumented system
# 180                             Salesperson
# 195                     Become unresponsive
# 41                             The person's
# 27                           Inclusion list
# 138                               Principal
# 68                                   Exempt
# 173                             Individuals
# 67                      Previously approved
# 46                                     They
# 186                               Workforce
# 149                              Accessible
# 60                                Secondary
# 13           System with limited visibility
# 136                                 Primary
# 170                                Humanity
# 96                        Scrum facilitator
# 51                               The person
# 155                                   Their
# 11                            Opaque system
# 187                               Personnel
# 171                                  People
# 50                                     Them
# 25                                Allowlist
# 87                         Preliminary test
# 165                                   Chair
# 6                                  Conclude
# 47                               The person
# 141                          Default branch
# 132                                Humanity
# 54                             The person's
# 86                               Basic test
# 0                                    Cancel
# 2                                      Halt
# 202                     Unreferenced object
# 156                            The person's
# 193                                  Freeze
# 94                                Principal
# 139                                 Leading
# 85                               Quick test
# 120                             Empty space
# 77                                 Humanity
# 145                                Standard
# 3                                      Stop
# 92                                  Primary
# 172                               Humankind
# 102                                Division
# 24                           Exclusion list
# 148                Person with a disability
# 185                              Engineered
# 137                                    Main
# 140                             Main branch
# 133                                  People
# 10                              Common user
# 101                               Isolation
# 9                             Standard user
# 183                               Synthetic
# 175                                  People
# 143                           Smaller group
# 93                                     Main
# 142                  Underrepresented group
# 110                                    Core
# 95                                  Leading
# 66                                   Legacy
# 194                                   Stall
# 75                              Staff-hours
# 135                             Individuals
# 108                                Built-in
# 22                                 Denylist
# 23                                Blocklist
# 109                              Integrated
# 184                              Artificial
# 127                              Indigenous
# 134                               Humankind
# 164                             Chairperson
# 80                              Individuals
# 1                                 Terminate
# 65                      Quantum superiority
# 7                                    Finish
# 71                                     Team
# 146                                 Typical
# 144                                   Usual
# 8                              Typical user
# 147                                Expected
# 72                                   People
# 100                              Separation
# 78                                   People
# 76                               Work-hours
# 176                               Humankind
# 79                                Humankind
# 74                             Person-hours
# 5                                      Stop
# 69                                 Everyone
# 73                                  You all
# 174                                Humanity
# 70                                    Folks
# 4                                       End
#
#                                      Modified Sentence  Similarity Score
# 17   The company detected a Unethical hacker attemp...          0.584426
# 16   The company detected a Malicious actor attempt...          0.610877
# 18   The company detected a Cybercriminal attemptin...          0.645379
# 103  A Maintenance window was enforced during the s...          0.658593
# 34   The Socket connector allows for easy integrati...          0.679458
# 97   The Team lead facilitated the daily stand-up m...          0.700074
# 15   The System with visible internals testing meth...          0.700742
# 161  The company prioritizes Team compatibility whe...          0.702953
# 201  The adapter functions as a Connector adapter f...          0.703491
# 107  The Security researcher with mixed methods hac...          0.708395
# 35   The Port connector allows for easy integration...          0.708663
# 168  The Lead supervised the construction site with...          0.717832
# 29   The paper underwent a Masked review review pro...          0.720732
# 98   The team opted for Ensemble programming to tac...          0.721668
# 14   The Transparent system testing method allows d...          0.722767
# 199  The adapter functions as a Adapter for connect...          0.727360
# 104  A Downtime was enforced during the system upgr...          0.728261
# 42   The developer's contribution to the discussion...          0.728824
# 200  The adapter functions as a Converter for conne...          0.734185
# 163  The company prioritizes Shared values when hir...          0.734874
# 105  A Service interruption was enforced during the...          0.739151
# 28   The paper underwent a Anonymous review review ...          0.740956
# 162  The company prioritizes Alignment with team va...          0.743285
# 169  The Site manager supervised the construction s...          0.743306
# 167  The Supervisor supervised the construction sit...          0.744094
# 197  The new functionality was implemented through ...          0.754634
# 39   The engineer was responsible for coordinating ...          0.755648
# 191  The server operates within the Network perimet...          0.756696
# 166  The Moderator called for a vote on the propose...          0.757036
# 158  His desk organization reflects a hint of Detai...          0.762296
# 126  The Improvement team focused on optimizing the...          0.776996
# 131  The Relay attack attack intercepted sensitive ...          0.777748
# 99   The team opted for Collaborative programming t...          0.777778
# 106  The Ambiguous hacker hacker reported the vulne...          0.778805
# 52   The team assigned the most critical task to Th...          0.782267
# 125  The Security optimization team focused on opti...          0.783778
# 192  The server operates within the Protected netwo...          0.785175
# 124  The Moderation team oversaw the cyber exercise...          0.785924
# 45   The credit for the innovative design is entire...          0.787886
# 196  The new functionality was implemented through ...          0.787963
# 198  The new functionality was implemented through ...          0.790100
# 38   The developer was responsible for coordinating...          0.790731
# 88   A quick Confidence test revealed several issue...          0.790785
# 153  The plan was considered Bold but turned out to...          0.792576
# 90   Developers use a Sample value as a placeholder...          0.795430
# 113  The web Primary updated the website’s layout f...          0.810848
# 129  The land’s history is deeply rooted in Origina...          0.814958
# 19   A Ethical hacker hacker helped identify securi...          0.817126
# 150  The venue was upgraded to be accessible for Pe...          0.817557
# 130  The Interception attack attack intercepted sen...          0.817796
# 112  The Security testing team simulated an attack ...          0.819837
# 157  The developer's desk organization reflects a h...          0.820212
# 48   The developer led the presentation with confid...          0.823391
# 159  His desk organization reflects a hint of Highl...          0.824690
# 123  The Oversight team oversaw the cyber exercise ...          0.826038
# 49   The engineer led the presentation with confide...          0.826881
# 89   Developers use a Placeholder value as a placeh...          0.829454
# 84   Before deploying the code, we need to perform ...          0.829483
# 111  The Attack simulation team simulated an attack...          0.829734
# 190  The network’s Protected network area protects ...          0.830743
# 21   A Security specialist hacker helped identify s...          0.831141
# 189  The network’s Network perimeter protects inter...          0.831660
# 59   The Leading database contains all the key reco...          0.831812
# 58   The Principal database contains all the key re...          0.832170
# 56   The Primary database contains all the key reco...          0.832613
# 20   A Security researcher hacker helped identify s...          0.832633
# 115  The web Principal updated the website’s layout...          0.833944
# 36   They was responsible for coordinating the team...          0.836792
# 30   The experiment was conducted under double-Anon...          0.838880
# 152  The plan was considered Innovative but turned ...          0.840000
# 181  The Sales representative demonstrated the prod...          0.842884
# 178    The crew Operates the ship during long voyages.          0.843587
# 154  The plan was considered Unique but turned out ...          0.844129
# 33   The cable is equipped with a Pin connector for...          0.844309
# 160  His desk organization reflects a hint of Metic...          0.844329
# 114  The web Main updated the website’s layout for ...          0.845296
# 62   The secondary system operates as a Follower to...          0.849255
# 116  The web Leading updated the website’s layout f...          0.850531
# 91   Developers use a Test value as a placeholder d...          0.850563
# 177      The crew Staffs the ship during long voyages.          0.851084
# 118  The Web administrator updated the website’s la...          0.852008
# 182  The Sales associate demonstrated the product’s...          0.853444
# 119  The Web maintainer updated the website’s layou...          0.854057
# 81   Before deploying the code, we need to perform ...          0.854385
# 121  The designer added Padding to improve the page...          0.855119
# 43   The credit for the innovative design is entire...          0.856372
# 37   The person was responsible for coordinating th...          0.857053
# 83   Before deploying the code, we need to perform ...          0.857224
# 40   Their contribution to the discussion was insig...          0.857565
# 128  The land’s history is deeply rooted in Native ...          0.857885
# 31   The experiment was conducted under double-Mask...          0.859742
# 203  The cleanup script removed the Disconnected ob...          0.859831
# 32   The cable is equipped with a Plug connector fo...          0.860130
# 55   The developer's programming skills greatly imp...          0.862446
# 44   The credit for the innovative design is entire...          0.862666
# 63   The secondary system operates as a Dependent t...          0.862953
# 122  The designer added Margin to improve the page'...          0.864702
# 179       The crew Works the ship during long voyages.          0.866085
# 151  The plan was considered Unconventional but tur...          0.867457
# 64   Achieving Quantum advantage marks a significan...          0.867519
# 117  The Web developer updated the website’s layout...          0.870446
# 26   Only pre-approved devices are included in the ...          0.870903
# 82   Before deploying the code, we need to perform ...          0.870917
# 57   The Main database contains all the key records...          0.872235
# 53   Their programming skills greatly improved the ...          0.873098
# 188  The project required significant Staffing to c...          0.876994
# 61   The secondary system operates as a Replica to ...          0.877979
# 12   The algorithm functions as a Undocumented syst...          0.878565
# 180  The Salesperson demonstrated the product’s key...          0.878644
# 195  The application tends to Become unresponsive w...          0.879780
# 41   The person's contribution to the discussion wa...          0.880988
# 27   Only pre-approved devices are included in the ...          0.882783
# 138  Changes were merged into the Principal branch ...          0.883970
# 68   The older software was Exempt in despite the n...          0.884822
# 173  Individuals has always sought to understand th...          0.884981
# 67   The older software was Previously approved in ...          0.886144
# 46   They led the presentation with confidence and ...          0.886162
# 186  The project required significant Workforce to ...          0.888754
# 149  The venue was upgraded to be accessible for Ac...          0.891089
# 60   The secondary system operates as a Secondary t...          0.892284
# 13   The algorithm functions as a System with limit...          0.892938
# 136  Changes were merged into the Primary branch fo...          0.894577
# 170  Humanity has always sought to understand the u...          0.895734
# 96   The Scrum facilitator facilitated the daily st...          0.895948
# 51   The team assigned the most critical task to Th...          0.896134
# 155  Their desk organization reflects a hint of OCD...          0.897488
# 11   The algorithm functions as a Opaque system, wi...          0.898719
# 187  The project required significant Personnel to ...          0.898788
# 171  People has always sought to understand the uni...          0.899577
# 50   The team assigned the most critical task to Them.          0.900533
# 25   Only pre-approved devices are included in the ...          0.901145
# 87   A quick Preliminary test revealed several issu...          0.902828
# 165  The Chair called for a vote on the proposed ch...          0.903277
# 6    The user chose to Conclude the installation pr...          0.904197
# 47   The person led the presentation with confidenc...          0.905801
# 141  Changes were merged into the Default branch fo...          0.905802
# 132  The Humanity-in-the-middle attack intercepted ...          0.906904
# 54   The person's programming skills greatly improv...          0.906941
# 86   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 2    The program will automatically Halt if a criti...          0.909458
# 202  The cleanup script removed the Unreferenced ob...          0.911102
# 156  The person's desk organization reflects a hint...          0.914325
# 193  The application tends to Freeze when handling ...          0.914745
# 94   The scrum Principal facilitated the daily stan...          0.915100
# 139  Changes were merged into the Leading branch fo...          0.915709
# 85   A quick Quick test revealed several issues in ...          0.918039
# 120  The designer added Empty space to improve the ...          0.918833
# 77   Completing the project required 100 Humanity h...          0.920907
# 145  The system is back to Standard after resolving...          0.921492
# 3    The program will automatically Stop if a criti...          0.922640
# 92   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 102  The system’s Division of duties ensures secure...          0.924723
# 24   The IP address was added to the company’s Excl...          0.925768
# 148  The venue was upgraded to be accessible for Pe...          0.926213
# 185  The reservoir is a Engineered structure design...          0.928353
# 137  Changes were merged into the Main branch for d...          0.928553
# 140  Changes were merged into the Main branch for d...          0.928553
# 133  The People-in-the-middle attack intercepted se...          0.929361
# 10   The app is designed to be intuitive for the Co...          0.929378
# 101  The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 175  People has made significant strides in technol...          0.931211
# 143  Efforts to promote diversity aim to amplify th...          0.931902
# 93   The scrum Main facilitated the daily stand-up ...          0.932176
# 142  Efforts to promote diversity aim to amplify th...          0.932201
# 110  The app includes a Core feature for photo edit...          0.933925
# 95   The scrum Leading facilitated the daily stand-...          0.934094
# 66   The older software was Legacy in despite the n...          0.934483
# 194  The application tends to Stall when handling l...          0.935331
# 75   Completing the project required 100 Staff-hour...          0.936402
# 135  The Individuals-in-the-middle attack intercept...          0.937020
# 108  The app includes a Built-in feature for photo ...          0.937234
# 22   The IP address was added to the company’s Deny...          0.937353
# 23   The IP address was added to the company’s Bloc...          0.937636
# 109  The app includes a Integrated feature for phot...          0.938498
# 184  The reservoir is a Artificial structure design...          0.939255
# 127  The land’s history is deeply rooted in Indigen...          0.939329
# 134  The Humankind-in-the-middle attack intercepted...          0.940031
# 164  The Chairperson called for a vote on the propo...          0.943595
# 80   Completing the project required 100 Individual...          0.944255
# 1    The program will automatically Terminate if a ...          0.945206
# 65   Achieving Quantum superiority marks a signific...          0.946091
# 7    The user chose to Finish the installation proc...          0.948518
# 71   Hey Team, let’s gather for the meeting in five...          0.950417
# 146  The system is back to Typical after resolving ...          0.950920
# 144  The system is back to Usual after resolving th...          0.953534
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 147  The system is back to Expected after resolving...          0.956891
# 72   Hey People, let’s gather for the meeting in fi...          0.957925
# 100  The system’s Separation of duties ensures secu...          0.958804
# 78   Completing the project required 100 People hou...          0.959826
# 76   Completing the project required 100 Work-hours...          0.961485
# 176  Humankind has made significant strides in tech...          0.961535
# 79   Completing the project required 100 Humankind ...          0.962538
# 74   Completing the project required 100 Person-hou...          0.963118
# 5    The user chose to Stop the installation proces...          0.964866
# 69   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 73   Hey You all, let’s gather for the meeting in f...          0.967226
# 174  Humanity has made significant strides in techn...          0.968785
# 70   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2-3_replacements.csv", index=False)
