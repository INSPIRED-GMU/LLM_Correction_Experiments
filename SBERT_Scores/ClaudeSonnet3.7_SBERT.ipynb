# %%
pip install sentence-transformers pandas
# Out:
# Collecting sentence-transformersNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\hana_\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.48.0)
# Requirement already satisfied: tqdm in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\hana_\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hana_\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hana_\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hana_\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#    ---------------------------------------- 0.0/275.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/275.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/275.9 kB 445.2 kB/s eta 0:00:01
#    ----------------- ---------------------- 122.9/275.9 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 275.9/275.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.4.1

# %%
# PROMPT 1:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)

harmful_terms = {
    "abort": ["cancel", "stop", "halt", "end", "discontinue"],
    "terminate": ["end", "close", "stop", "discontinue", "conclude"],

    # User References
    "average user": ["typical user", "general user", "most users", "mainstream user"],

    # Testing Terminology
    "black box": ["closed box", "opaque system", "hidden implementation"],
    "white box": ["clear box", "transparent box", "open box", "visible implementation"],
    "black hat": ["malicious actor", "unauthorized hacker", "adversarial hacker"],
    "white hat": ["ethical hacker", "security researcher", "authorized tester"],
    "blacklist": ["blocklist", "deny list", "exclusion list"],
    "whitelist": ["allowlist", "permit list", "inclusion list"],
    "blind": ["anonymous", "unnamed", "unidentified"],
    "double blind": ["double anonymous", "dual anonymous"],

    # Hardware Terms
    "male connector": ["plug", "outward connector", "protruding connector"],
    "female connector": ["socket", "inward connector", "receptacle"],

    # Pronouns
    "she": "they",
    "her": "their",
    "hers": "theirs",
    "he": "they",
    "him": "them",
    "his": "their",

    # System Relationships
    "master": ["primary", "main", "leader", "controller", "host"],
    "slave": ["secondary", "replica", "follower", "worker", "client"],

    # Other Technical Terms
    "quantum supremacy": ["quantum advantage", "quantum computational advantage"],
    "grandfathered": ["legacy-approved", "previously exempt", "historically allowed"],
    "guys": ["everyone", "team", "folks", "all", "people"],
    "man hours": ["person hours", "labor hours", "work hours", "staff hours"],
    "sanity check": ["quick check", "basic check", "coherence check", "logic check"],
    "sanity test": ["quick test", "basic test", "coherence test", "logic test"],
    "dummy value": ["placeholder", "sample value", "test value", "mock value"],
    "scrum master": ["scrum facilitator", "agile coach", "scrum coordinator"],
    "mob programming": ["ensemble programming", "team programming", "collaborative programming"],
    "segregation": ["separation", "division", "partition", "isolation"],
    "blackout period": ["restricted period", "maintenance window", "downtime period"],
    "gray hat": ["semi-ethical hacker", "boundary hacker", "conditional hacker"],
    "native": ["built-in", "integrated", "core", "inherent"],
    "red team": ["attack team", "adversary team", "offensive team"],
    "web master": ["web administrator", "website manager", "web coordinator"],
    "white space": ["negative space", "empty space", "blank space"],
    "white team": ["oversight team", "evaluation team", "monitoring team"],
    "yellow team": ["build security team", "security development team"],
    "aboriginal": ["indigenous", "first nations", "first peoples"],

    # Workplace & Learning Terms
    "brown bags": ["lunch and learn", "knowledge sharing session", "informal learning session"],
    "first-class citizen": ["first-class entity", "first-class object", "core feature"],
    "man-in-the-middle": ["person-in-the-middle", "interception attack", "MITM attack"],
    "master branch": ["main branch", "primary branch", "default branch"],
    "minority": ["underrepresented group", "marginalized community"],
    "normal": ["expected", "standard", "typical", "default", "baseline"],
    "handicapped": ["person with disabilities", "accessible", "disability-friendly"],
    "crazy": ["unexpected", "surprising", "unconventional", "bold", "remarkable"],
    "OCD": ["detail-oriented", "thorough", "meticulous", "precise"],
    "culture fit": ["values alignment", "team compatibility", "organizational fit"],

    # Gendered Role Terms
    "chairman": ["chair", "chairperson", "meeting leader"],
    "foreman": ["supervisor", "team leader", "site manager"],
    "man": ["person", "individual", "human", "people"],
    "mankind": ["humanity", "humankind", "people", "human species"],
    "mans": ["operates", "staffs", "runs", "works"],
    "salesman": ["salesperson", "sales representative", "sales associate"],
    "manmade": ["artificial", "manufactured", "synthetic", "human-made"],
    "manpower": ["workforce", "staff", "personnel", "human resources"],

    # Networking Terms
    "demilitarized zone": ["perimeter network", "edge network", "buffer zone"],
    "demilitarized zones": ["perimeter networks", "edge networks", "buffer zones"],
    "DMZ": ["perimeter network", "edge network", "buffer zone"],
    "hang": ["freeze", "become unresponsive", "stop responding"],

    # Other Hardware/Software Terms
    "daughter board": ["expansion board", "secondary board", "auxiliary board"],
    "gender bender": ["adapter", "connector converter", "interface adapter"],
    "orphaned object": ["unreferenced object", "disconnected object", "isolated object"]
}


# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 44   The female connector allows for easy integrati...    female connector
# 42   The female connector allows for easy integrati...    female connector
# 22   The company detected a black hat attempting to...           black hat
# 21   The company detected a black hat attempting to...           black hat
# 23   The company detected a black hat attempting to...           black hat
# 129  A blackout period was enforced during the syst...     blackout period
# 53   Her contribution to the discussion was insight...                 her
# 20   The white box testing method allows developers...           white box
# 235  The server operates within the DMZ for added s...                 DMZ
# 43   The female connector allows for easy integrati...    female connector
# 200  The company prioritizes culture fit when hirin...         culture fit
# 244  The adapter functions as a gender bender for c...       gender bender
# 245  The adapter functions as a gender bender for c...       gender bender
# 46   She was responsible for coordinating the team’...                 she
# 70   His programming skills greatly improved the pr...                 his
# 121  The team opted for mob programming to tackle t...     mob programming
# 232  The network’s demilitarized zone protects inte...  demilitarized zone
# 243  The adapter functions as a gender bender for c...       gender bender
# 234  The server operates within the DMZ for added s...                 DMZ
# 72   His programming skills greatly improved the pr...                 his
# 159  The land’s history is deeply rooted in Aborigi...          aboriginal
# 107  A quick sanity test revealed several issues in...         sanity test
# 47   She was responsible for coordinating the team’...                 she
# 50   Her contribution to the discussion was insight...                 her
# 207  The foreman supervised the construction site w...             foreman
# 205  The foreman supervised the construction site w...             foreman
# 33   The paper underwent a blind review process to ...               blind
# 158  The land’s history is deeply rooted in Aborigi...          aboriginal
# 242  The new functionality was implemented through ...      daughter board
# 48   She was responsible for coordinating the team’...                 she
# 68   His programming skills greatly improved the pr...                 his
# 236  The server operates within the DMZ for added s...                 DMZ
# 195  His desk organization reflects a hint of OCD t...                 OCD
# 35   The paper underwent a blind review process to ...               blind
# 131  The gray hat hacker reported the vulnerabiliti...            gray hat
# 49   Her contribution to the discussion was insight...                 her
# 109  Developers use a dummy value as a placeholder ...         dummy value
# 45   She was responsible for coordinating the team’...                 she
# 132  The gray hat hacker reported the vulnerabiliti...            gray hat
# 133  The gray hat hacker reported the vulnerabiliti...            gray hat
# 34   The paper underwent a blind review process to ...               blind
# 56   The credit for the innovative design is entire...                hers
# 206  The foreman supervised the construction site w...             foreman
# 66    The team assigned the most critical task to him.                 him
# 123  The team opted for mob programming to tackle t...     mob programming
# 199  The company prioritizes culture fit when hirin...         culture fit
# 155  The yellow team focused on optimizing the soft...         yellow team
# 58   The credit for the innovative design is entire...                hers
# 130  A blackout period was enforced during the syst...     blackout period
# 55   The credit for the innovative design is entire...                hers
# 240  The new functionality was implemented through ...      daughter board
# 67    The team assigned the most critical task to him.                 him
# 241  The new functionality was implemented through ...      daughter board
# 51   Her contribution to the discussion was insight...                 her
# 188  The plan was considered crazy but turned out t...               crazy
# 110  Developers use a dummy value as a placeholder ...         dummy value
# 69   His programming skills greatly improved the pr...                 his
# 156  The yellow team focused on optimizing the soft...         yellow team
# 153  The white team oversaw the cyber exercise and ...          white team
# 108  A quick sanity test revealed several issues in...         sanity test
# 201  The company prioritizes culture fit when hirin...         culture fit
# 54   The credit for the innovative design is entire...                hers
# 196  His desk organization reflects a hint of OCD t...                 OCD
# 122  The team opted for mob programming to tackle t...     mob programming
# 198  His desk organization reflects a hint of OCD t...                 OCD
# 17   The white box testing method allows developers...           white box
# 40   The cable is equipped with a male connector fo...      male connector
# 75   The master database contains all the key recor...              master
# 26   A white hat hacker helped identify security vu...           white hat
# 194  His desk organization reflects a hint of OCD t...                 his
# 128  A blackout period was enforced during the syst...     blackout period
# 141  The web master updated the website’s layout fo...              master
# 71   His programming skills greatly improved the pr...                 his
# 162  The man-in-the-middle attack intercepted sensi...   man-in-the-middle
# 119  The scrum master facilitated the daily stand-u...        scrum master
# 76   The master database contains all the key recor...              master
# 24   A white hat hacker helped identify security vu...           white hat
# 161  The man-in-the-middle attack intercepted sensi...   man-in-the-middle
# 112  Developers use a dummy value as a placeholder ...         dummy value
# 204  The chairman called for a vote on the proposed...            chairman
# 218        The crew mans the ship during long voyages.                mans
# 192  His desk organization reflects a hint of OCD t...                 his
# 64    The team assigned the most critical task to him.                 him
# 59   The credit for the innovative design is entire...                hers
# 41   The cable is equipped with a male connector fo...      male connector
# 60   He led the presentation with confidence and cl...                  he
# 231  The network’s demilitarized zone protects inte...  demilitarized zone
# 18   The white box testing method allows developers...           white box
# 152  The white team oversaw the cyber exercise and ...          white team
# 139  The red team simulated an attack to test the o...            red team
# 62   He led the presentation with confidence and cl...                  he
# 193  His desk organization reflects a hint of OCD t...                 his
# 61   He led the presentation with confidence and cl...                  he
# 52   Her contribution to the discussion was insight...                 her
# 73   The master database contains all the key recor...              master
# 25   A white hat hacker helped identify security vu...           white hat
# 144  The web master updated the website’s layout fo...              master
# 77   The master database contains all the key recor...              master
# 57   The credit for the innovative design is entire...                hers
# 215  Mankind has made significant strides in techno...             mankind
# 191  His desk organization reflects a hint of OCD t...                 his
# 65    The team assigned the most critical task to him.                 him
# 190  His desk organization reflects a hint of OCD t...                 his
# 103  Before deploying the code, we need to perform ...        sanity check
# 221  The salesman demonstrated the product’s key fe...            salesman
# 216        The crew mans the ship during long voyages.                mans
# 170  Changes were merged into the master branch for...              master
# 197  His desk organization reflects a hint of OCD t...                 OCD
# 63   He led the presentation with confidence and cl...                  he
# 142  The web master updated the website’s layout fo...              master
# 154  The white team oversaw the cyber exercise and ...          white team
# 80   The secondary system operates as a slave to th...               slave
# 31   Only pre-approved devices are included in the ...           whitelist
# 233  The network’s demilitarized zone protects inte...  demilitarized zone
# 39   The cable is equipped with a male connector fo...      male connector
# 148  The web master updated the website’s layout fo...          web master
# 111  Developers use a dummy value as a placeholder ...         dummy value
# 19   The white box testing method allows developers...           white box
# 217        The crew mans the ship during long voyages.                mans
# 146  The web master updated the website’s layout fo...          web master
# 222  The salesman demonstrated the product’s key fe...            salesman
# 101  Before deploying the code, we need to perform ...        sanity check
# 104  Before deploying the code, we need to perform ...        sanity check
# 140  The red team simulated an attack to test the o...            red team
# 247  The cleanup script removed the orphaned object...     orphaned object
# 186  The plan was considered crazy but turned out t...               crazy
# 219        The crew mans the ship during long voyages.                mans
# 187  The plan was considered crazy but turned out t...               crazy
# 83   Achieving quantum supremacy marks a significan...   quantum supremacy
# 81   The secondary system operates as a slave to th...               slave
# 189  The plan was considered crazy but turned out t...               crazy
# 138  The red team simulated an attack to test the o...            red team
# 102  Before deploying the code, we need to perform ...        sanity check
# 84   Achieving quantum supremacy marks a significan...   quantum supremacy
# 74   The master database contains all the key recor...              master
# 181  The system is back to normal after resolving t...              normal
# 180  The system is back to normal after resolving t...              normal
# 185  The plan was considered crazy but turned out t...               crazy
# 145  The web master updated the website’s layout fo...              master
# 82   The secondary system operates as a slave to th...               slave
# 143  The web master updated the website’s layout fo...              master
# 147  The web master updated the website’s layout fo...          web master
# 79   The secondary system operates as a slave to th...               slave
# 220  The salesman demonstrated the product’s key fe...            salesman
# 238  The application tends to hang when handling la...                hang
# 169  Changes were merged into the master branch for...              master
# 228  The project required significant manpower to c...            manpower
# 4    The program will automatically abort if a crit...               abort
# 32   Only pre-approved devices are included in the ...           whitelist
# 230  The project required significant manpower to c...            manpower
# 36   The experiment was conducted under double-blin...               blind
# 227  The project required significant manpower to c...            manpower
# 171  Changes were merged into the master branch for...              master
# 248  The cleanup script removed the orphaned object...     orphaned object
# 87   The older software was grandfathered in despit...       grandfathered
# 86   The older software was grandfathered in despit...       grandfathered
# 183  The venue was upgraded to be accessible for ha...         handicapped
# 78   The secondary system operates as a slave to th...               slave
# 167  Changes were merged into the master branch for...              master
# 173  Changes were merged into the master branch for...       master branch
# 16   The algorithm functions as a black box, with n...           black box
# 118  The scrum master facilitated the daily stand-u...        scrum master
# 239  The application tends to hang when handling la...                hang
# 15   The algorithm functions as a black box, with n...           black box
# 229  The project required significant manpower to c...            manpower
# 211  Man has always sought to understand the universe.                 man
# 30   Only pre-approved devices are included in the ...           whitelist
# 149  The designer added white space to improve the ...         white space
# 202  The chairman called for a vote on the proposed...            chairman
# 13   The app is designed to be intuitive for the av...        average user
# 9    The user chose to terminate the installation p...           terminate
# 174  Changes were merged into the master branch for...       master branch
# 106  A quick sanity test revealed several issues in...         sanity test
# 0    The program will automatically abort if a crit...               abort
# 2    The program will automatically abort if a crit...               abort
# 246  The cleanup script removed the orphaned object...     orphaned object
# 208  Man has always sought to understand the universe.                 man
# 85   The older software was grandfathered in despit...       grandfathered
# 237  The application tends to hang when handling la...                hang
# 105  A quick sanity test revealed several issues in...         sanity test
# 3    The program will automatically abort if a crit...               abort
# 150  The designer added white space to improve the ...         white space
# 37   The experiment was conducted under double-blin...               blind
# 38   The experiment was conducted under double-blin...               blind
# 209  Man has always sought to understand the universe.                 man
# 178  The system is back to normal after resolving t...              normal
# 1    The program will automatically abort if a crit...               abort
# 113  The scrum master facilitated the daily stand-u...              master
# 125  The system’s segregation of duties ensures sec...         segregation
# 184  The venue was upgraded to be accessible for ha...         handicapped
# 116  The scrum master facilitated the daily stand-u...              master
# 120  The scrum master facilitated the daily stand-u...        scrum master
# 29   The IP address was added to the company’s blac...           blacklist
# 168  Changes were merged into the master branch for...              master
# 172  Changes were merged into the master branch for...       master branch
# 126  The system’s segregation of duties ensures sec...         segregation
# 117  The scrum master facilitated the daily stand-u...              master
# 166  The man-in-the-middle attack intercepted sensi...                 man
# 160  The man-in-the-middle attack intercepted sensi...   man-in-the-middle
# 163  The man-in-the-middle attack intercepted sensi...                 man
# 127  The system’s segregation of duties ensures sec...         segregation
# 28   The IP address was added to the company’s blac...           blacklist
# 225  The reservoir is a manmade structure designed ...             manmade
# 176  Efforts to promote diversity aim to amplify th...            minority
# 214  Mankind has made significant strides in techno...             mankind
# 210  Man has always sought to understand the universe.                 man
# 114  The scrum master facilitated the daily stand-u...              master
# 175  Efforts to promote diversity aim to amplify th...            minority
# 136  The app includes a native feature for photo ed...              native
# 134  The app includes a native feature for photo ed...              native
# 27   The IP address was added to the company’s blac...           blacklist
# 6    The user chose to terminate the installation p...           terminate
# 96   Completing the project required 100 man hours ...           man hours
# 135  The app includes a native feature for photo ed...              native
# 223  The reservoir is a manmade structure designed ...             manmade
# 157  The land’s history is deeply rooted in Aborigi...          aboriginal
# 8    The user chose to terminate the installation p...           terminate
# 165  The man-in-the-middle attack intercepted sensi...                 man
# 151  The designer added white space to improve the ...         white space
# 115  The scrum master facilitated the daily stand-u...              master
# 203  The chairman called for a vote on the proposed...            chairman
# 224  The reservoir is a manmade structure designed ...             manmade
# 11   The app is designed to be intuitive for the av...        average user
# 137  The app includes a native feature for photo ed...              native
# 164  The man-in-the-middle attack intercepted sensi...                 man
# 12   The app is designed to be intuitive for the av...        average user
# 89   Hey guys, let’s gather for the meeting in five...                guys
# 179  The system is back to normal after resolving t...              normal
# 94   Completing the project required 100 man hours ...           man hours
# 14   The algorithm functions as a black box, with n...           black box
# 182  The venue was upgraded to be accessible for ha...         handicapped
# 10   The app is designed to be intuitive for the av...        average user
# 177  The system is back to normal after resolving t...              normal
# 92   Hey guys, let’s gather for the meeting in five...                guys
# 124  The system’s segregation of duties ensures sec...         segregation
# 100  Completing the project required 100 man hours ...                 man
# 226  The reservoir is a manmade structure designed ...             manmade
# 213  Mankind has made significant strides in techno...             mankind
# 98   Completing the project required 100 man hours ...                 man
# 7    The user chose to terminate the installation p...           terminate
# 88   Hey guys, let’s gather for the meeting in five...                guys
# 95   Completing the project required 100 man hours ...           man hours
# 212  Mankind has made significant strides in techno...             mankind
# 91   Hey guys, let’s gather for the meeting in five...                guys
# 93   Completing the project required 100 man hours ...           man hours
# 97   Completing the project required 100 man hours ...                 man
# 90   Hey guys, let’s gather for the meeting in five...                guys
# 5    The user chose to terminate the installation p...           terminate
# 99   Completing the project required 100 man hours ...                 man
#
#                          Replacement  \
# 44                        receptacle
# 42                            socket
# 22               unauthorized hacker
# 21                   malicious actor
# 23                adversarial hacker
# 129               maintenance window
# 53                                 r
# 20            visible implementation
# 235                     edge network
# 43                  inward connector
# 200               team compatibility
# 244              connector converter
# 245                interface adapter
# 46                                 h
# 70                                 e
# 121             ensemble programming
# 232                     edge network
# 243                          adapter
# 234                perimeter network
# 72                                 r
# 159                    first peoples
# 107                   coherence test
# 47                                 e
# 50                                 h
# 207                     site manager
# 205                       supervisor
# 33                         anonymous
# 158                    first nations
# 242                  auxiliary board
# 48                                 y
# 68                                 t
# 236                      buffer zone
# 195                  detail-oriented
# 35                      unidentified
# 131              semi-ethical hacker
# 49                                 t
# 109                      placeholder
# 45                                 t
# 132                  boundary hacker
# 133               conditional hacker
# 34                           unnamed
# 56                                 e
# 206                      team leader
# 66                                 e
# 123        collaborative programming
# 199                 values alignment
# 155              build security team
# 58                                 r
# 130                  downtime period
# 55                                 h
# 240                  expansion board
# 67                                 m
# 241                  secondary board
# 51                                 e
# 188                             bold
# 110                     sample value
# 69                                 h
# 156        security development team
# 153                  evaluation team
# 108                       logic test
# 201               organizational fit
# 54                                 t
# 196                         thorough
# 122                 team programming
# 198                          precise
# 17                         clear box
# 40                 outward connector
# 75                            leader
# 26                 authorized tester
# 194                                r
# 128                restricted period
# 141                          primary
# 71                                 i
# 162                      MITM attack
# 119                      agile coach
# 76                        controller
# 24                    ethical hacker
# 161              interception attack
# 112                       mock value
# 204                   meeting leader
# 218                             runs
# 192                                e
# 64                                 t
# 59                                 s
# 41              protruding connector
# 60                                 t
# 231                perimeter network
# 18                   transparent box
# 152                   oversight team
# 139                   adversary team
# 62                                 e
# 193                                i
# 61                                 h
# 52                                 i
# 73                           primary
# 25               security researcher
# 144                       controller
# 77                              host
# 57                                 i
# 215                    human species
# 191                                h
# 65                                 h
# 190                                t
# 103                  coherence check
# 221             sales representative
# 216                         operates
# 170                       controller
# 197                       meticulous
# 63                                 y
# 142                             main
# 154                  monitoring team
# 80                          follower
# 31                       permit list
# 233                      buffer zone
# 39                              plug
# 148                  web coordinator
# 111                       test value
# 19                          open box
# 217                           staffs
# 146                web administrator
# 222                  sales associate
# 101                      quick check
# 104                      logic check
# 140                   offensive team
# 247              disconnected object
# 186                       surprising
# 219                            works
# 187                   unconventional
# 83                 quantum advantage
# 81                            worker
# 189                       remarkable
# 138                      attack team
# 102                      basic check
# 84   quantum computational advantage
# 74                              main
# 181                         baseline
# 180                          default
# 185                       unexpected
# 145                             host
# 82                            client
# 143                           leader
# 147                  website manager
# 79                           replica
# 220                      salesperson
# 238              become unresponsive
# 169                           leader
# 228                            staff
# 4                        discontinue
# 32                    inclusion list
# 230                  human resources
# 36                         anonymous
# 227                        workforce
# 171                             host
# 248                  isolated object
# 87              historically allowed
# 86                 previously exempt
# 183                       accessible
# 78                         secondary
# 167                          primary
# 173                   primary branch
# 16             hidden implementation
# 118                scrum facilitator
# 239                  stop responding
# 15                     opaque system
# 229                        personnel
# 211                           people
# 30                         allowlist
# 149                   negative space
# 202                            chair
# 13                   mainstream user
# 9                           conclude
# 174                   default branch
# 106                       basic test
# 0                             cancel
# 2                               halt
# 246              unreferenced object
# 208                           person
# 85                   legacy-approved
# 237                           freeze
# 105                       quick test
# 3                                end
# 150                      empty space
# 37                           unnamed
# 38                      unidentified
# 209                       individual
# 178                         standard
# 1                               stop
# 113                          primary
# 125                         division
# 184              disability-friendly
# 116                       controller
# 120                scrum coordinator
# 29                    exclusion list
# 168                             main
# 172                      main branch
# 126                        partition
# 117                             host
# 166                           people
# 160             person-in-the-middle
# 163                           person
# 127                        isolation
# 28                         deny list
# 225                        synthetic
# 176           marginalized community
# 214                           people
# 210                            human
# 114                             main
# 175           underrepresented group
# 136                             core
# 134                         built-in
# 27                         blocklist
# 6                              close
# 96                       staff hours
# 135                       integrated
# 223                       artificial
# 157                       indigenous
# 8                        discontinue
# 165                            human
# 151                      blank space
# 115                           leader
# 203                      chairperson
# 224                     manufactured
# 11                      general user
# 137                         inherent
# 164                       individual
# 12                        most users
# 89                              team
# 179                          typical
# 94                       labor hours
# 14                        closed box
# 182         person with disabilities
# 10                      typical user
# 177                         expected
# 92                            people
# 124                       separation
# 100                           people
# 226                       human-made
# 213                        humankind
# 98                        individual
# 7                               stop
# 88                          everyone
# 95                        work hours
# 212                         humanity
# 91                               all
# 93                      person hours
# 97                            person
# 90                             folks
# 5                                end
# 99                             human
#
#                                      Modified Sentence  Similarity Score
# 44   The receptacle allows for easy integration wit...          0.510210
# 42   The socket allows for easy integration with ot...          0.573467
# 22   The company detected a unauthorized hacker att...          0.594909
# 21   The company detected a malicious actor attempt...          0.610877
# 23   The company detected a adversarial hacker atte...          0.611928
# 129  A maintenance window was enforced during the s...          0.658593
# 53   r contribution to the discussion was insightfu...          0.691604
# 20   The visible implementation testing method allo...          0.693767
# 235  The server operates within the edge network fo...          0.694725
# 43   The inward connector allows for easy integrati...          0.701439
# 200  The company prioritizes team compatibility whe...          0.702953
# 244  The adapter functions as a connector converter...          0.717010
# 245  The adapter functions as a interface adapter f...          0.718079
# 46   h was responsible for coordinating the team’s ...          0.720209
# 70   e programming skills greatly improved the proj...          0.721613
# 121  The team opted for ensemble programming to tac...          0.721668
# 232  The network’s edge network protects internal s...          0.724516
# 243  The adapter functions as a adapter for connect...          0.727360
# 234  The server operates within the perimeter netwo...          0.728124
# 72   r programming skills greatly improved the proj...          0.734961
# 159  The land’s history is deeply rooted in first p...          0.736355
# 107  A quick coherence test revealed several issues...          0.737621
# 47   e was responsible for coordinating the team’s ...          0.739997
# 50   h contribution to the discussion was insightfu...          0.740288
# 207  The site manager supervised the construction s...          0.743306
# 205  The supervisor supervised the construction sit...          0.744094
# 33   The paper underwent a anonymous review process...          0.744736
# 158  The land’s history is deeply rooted in first n...          0.746485
# 242  The new functionality was implemented through ...          0.750979
# 48   y was responsible for coordinating the team’s ...          0.757748
# 68   t programming skills greatly improved the proj...          0.760157
# 236  The server operates within the buffer zone for...          0.761033
# 195  His desk organization reflects a hint of detai...          0.762296
# 35   The paper underwent a unidentified review proc...          0.762904
# 131  The semi-ethical hacker hacker reported the vu...          0.763539
# 49   t contribution to the discussion was insightfu...          0.763810
# 109  Developers use a placeholder as a placeholder ...          0.766475
# 45   t was responsible for coordinating the team’s ...          0.767980
# 132  The boundary hacker hacker reported the vulner...          0.768472
# 133  The conditional hacker hacker reported the vul...          0.769166
# 34   The paper underwent a unnamed review process t...          0.769620
# 56   The credit for the innovative design is entire...          0.770192
# 206  The team leader supervised the construction si...          0.772069
# 66      The team assigned the most critical task to e.          0.775197
# 123  The team opted for collaborative programming t...          0.777778
# 199  The company prioritizes values alignment when ...          0.778899
# 155  The build security team focused on optimizing ...          0.780419
# 58   The credit for the innovative design is entire...          0.782892
# 130  A downtime period was enforced during the syst...          0.785668
# 55   The credit for the innovative design is entire...          0.786087
# 240  The new functionality was implemented through ...          0.787963
# 67      The team assigned the most critical task to m.          0.788057
# 241  The new functionality was implemented through ...          0.790100
# 51   e contribution to the discussion was insightfu...          0.792463
# 188  The plan was considered bold but turned out to...          0.792576
# 110  Developers use a sample value as a placeholder...          0.795430
# 69   h programming skills greatly improved the proj...          0.795577
# 156  The security development team focused on optim...          0.797390
# 153  The evaluation team oversaw the cyber exercise...          0.798185
# 108  A quick logic test revealed several issues in ...          0.799555
# 201  The company prioritizes organizational fit whe...          0.800476
# 54   The credit for the innovative design is entire...          0.801475
# 196  His desk organization reflects a hint of thoro...          0.801717
# 122  The team opted for team programming to tackle ...          0.801736
# 198  His desk organization reflects a hint of preci...          0.802397
# 17   The clear box testing method allows developers...          0.804669
# 40   The cable is equipped with a outward connector...          0.805821
# 75   The leader database contains all the key recor...          0.805919
# 26   A authorized tester hacker helped identify sec...          0.808039
# 194  r desk organization reflects a hint of OCD ten...          0.810572
# 128  A restricted period was enforced during the sy...          0.810575
# 141  The web primary updated the website’s layout f...          0.810848
# 71   i programming skills greatly improved the proj...          0.811454
# 162  The MITM attack attack intercepted sensitive i...          0.812426
# 119  The agile coach facilitated the daily stand-up...          0.815039
# 76   The controller database contains all the key r...          0.816892
# 24   A ethical hacker hacker helped identify securi...          0.817126
# 161  The interception attack attack intercepted sen...          0.817796
# 112  Developers use a mock value as a placeholder d...          0.818040
# 204  The meeting leader called for a vote on the pr...          0.819052
# 218        The crew runs the ship during long voyages.          0.819893
# 192  e desk organization reflects a hint of OCD ten...          0.822263
# 64      The team assigned the most critical task to t.          0.822790
# 59   The credit for the innovative design is entire...          0.822957
# 41   The cable is equipped with a protruding connec...          0.823286
# 60   t led the presentation with confidence and cla...          0.824100
# 231  The network’s perimeter network protects inter...          0.824664
# 18   The transparent box testing method allows deve...          0.825408
# 152  The oversight team oversaw the cyber exercise ...          0.826038
# 139  The adversary team simulated an attack to test...          0.829016
# 62   e led the presentation with confidence and cla...          0.829612
# 193  i desk organization reflects a hint of OCD ten...          0.829691
# 61   h led the presentation with confidence and cla...          0.830584
# 52   i contribution to the discussion was insightfu...          0.832515
# 73   The primary database contains all the key reco...          0.832613
# 25   A security researcher hacker helped identify s...          0.832633
# 144  The web controller updated the website’s layou...          0.833191
# 77   The host database contains all the key records...          0.834691
# 57   The credit for the innovative design is entire...          0.834846
# 215  human species has made significant strides in ...          0.838603
# 191  h desk organization reflects a hint of OCD ten...          0.839764
# 65      The team assigned the most critical task to h.          0.839806
# 190  t desk organization reflects a hint of OCD ten...          0.841256
# 103  Before deploying the code, we need to perform ...          0.842882
# 221  The sales representative demonstrated the prod...          0.842884
# 216    The crew operates the ship during long voyages.          0.843587
# 170  Changes were merged into the controller branch...          0.844265
# 197  His desk organization reflects a hint of metic...          0.844329
# 63   y led the presentation with confidence and cla...          0.844980
# 142  The web main updated the website’s layout for ...          0.845296
# 154  The monitoring team oversaw the cyber exercise...          0.846402
# 80   The secondary system operates as a follower to...          0.849255
# 31   Only pre-approved devices are included in the ...          0.849591
# 233  The network’s buffer zone protects internal sy...          0.849631
# 39   The cable is equipped with a plug for compatib...          0.849646
# 148  The web coordinator updated the website’s layo...          0.849835
# 111  Developers use a test value as a placeholder d...          0.850563
# 19   The open box testing method allows developers ...          0.850860
# 217      The crew staffs the ship during long voyages.          0.851084
# 146  The web administrator updated the website’s la...          0.852008
# 222  The sales associate demonstrated the product’s...          0.853444
# 101  Before deploying the code, we need to perform ...          0.854385
# 104  Before deploying the code, we need to perform ...          0.855941
# 140  The offensive team simulated an attack to test...          0.856035
# 247  The cleanup script removed the disconnected ob...          0.859831
# 186  The plan was considered surprising but turned ...          0.861411
# 219       The crew works the ship during long voyages.          0.866085
# 187  The plan was considered unconventional but tur...          0.867457
# 83   Achieving quantum advantage marks a significan...          0.867519
# 81   The secondary system operates as a worker to t...          0.867971
# 189  The plan was considered remarkable but turned ...          0.869086
# 138  The attack team simulated an attack to test th...          0.870433
# 102  Before deploying the code, we need to perform ...          0.870917
# 84   Achieving quantum computational advantage mark...          0.871936
# 74   The main database contains all the key records...          0.872235
# 181  The system is back to baseline after resolving...          0.873188
# 180  The system is back to default after resolving ...          0.873858
# 185  The plan was considered unexpected but turned ...          0.874205
# 145  The web host updated the website’s layout for ...          0.875561
# 82   The secondary system operates as a client to t...          0.875677
# 143  The web leader updated the website’s layout fo...          0.876580
# 147  The website manager updated the website’s layo...          0.876592
# 79   The secondary system operates as a replica to ...          0.877979
# 220  The salesperson demonstrated the product’s key...          0.878644
# 238  The application tends to become unresponsive w...          0.879780
# 169  Changes were merged into the leader branch for...          0.880295
# 228  The project required significant staff to comp...          0.881556
# 4    The program will automatically discontinue if ...          0.882610
# 32   Only pre-approved devices are included in the ...          0.882783
# 230  The project required significant human resourc...          0.882928
# 36   The experiment was conducted under double-anon...          0.883819
# 227  The project required significant workforce to ...          0.888754
# 171  Changes were merged into the host branch for d...          0.888907
# 248  The cleanup script removed the isolated object...          0.889182
# 87   The older software was historically allowed in...          0.889732
# 86   The older software was previously exempt in de...          0.890389
# 183  The venue was upgraded to be accessible for ac...          0.891089
# 78   The secondary system operates as a secondary t...          0.892284
# 167  Changes were merged into the primary branch fo...          0.894577
# 173  Changes were merged into the primary branch fo...          0.894577
# 16   The algorithm functions as a hidden implementa...          0.895238
# 118  The scrum facilitator facilitated the daily st...          0.895948
# 239  The application tends to stop responding when ...          0.897520
# 15   The algorithm functions as a opaque system, wi...          0.898719
# 229  The project required significant personnel to ...          0.898788
# 211  people has always sought to understand the uni...          0.899577
# 30   Only pre-approved devices are included in the ...          0.901145
# 149  The designer added negative space to improve t...          0.902180
# 202  The chair called for a vote on the proposed ch...          0.903277
# 13   The app is designed to be intuitive for the ma...          0.903460
# 9    The user chose to conclude the installation pr...          0.904197
# 174  Changes were merged into the default branch fo...          0.905802
# 106  A quick basic test revealed several issues in ...          0.907914
# 0    The program will automatically cancel if a cri...          0.908169
# 2    The program will automatically halt if a criti...          0.909458
# 246  The cleanup script removed the unreferenced ob...          0.911102
# 208  person has always sought to understand the uni...          0.911396
# 85   The older software was legacy-approved in desp...          0.911681
# 237  The application tends to freeze when handling ...          0.914745
# 105  A quick quick test revealed several issues in ...          0.918039
# 3    The program will automatically end if a critic...          0.918662
# 150  The designer added empty space to improve the ...          0.918833
# 37   The experiment was conducted under double-unna...          0.919375
# 38   The experiment was conducted under double-unid...          0.919892
# 209  individual has always sought to understand the...          0.920260
# 178  The system is back to standard after resolving...          0.921492
# 1    The program will automatically stop if a criti...          0.922640
# 113  The scrum primary facilitated the daily stand-...          0.923873
# 125  The system’s division of duties ensures secure...          0.924723
# 184  The venue was upgraded to be accessible for di...          0.924812
# 116  The scrum controller facilitated the daily sta...          0.925107
# 120  The scrum coordinator facilitated the daily st...          0.925548
# 29   The IP address was added to the company’s excl...          0.925768
# 168  Changes were merged into the main branch for d...          0.928553
# 172  Changes were merged into the main branch for d...          0.928553
# 126  The system’s partition of duties ensures secur...          0.928710
# 117  The scrum host facilitated the daily stand-up ...          0.928827
# 166  The people-in-the-middle attack intercepted se...          0.929361
# 160  The person-in-the-middle attack intercepted se...          0.929446
# 163  The person-in-the-middle attack intercepted se...          0.929446
# 127  The system’s isolation of duties ensures secur...          0.929556
# 28   The IP address was added to the company’s deny...          0.929633
# 225  The reservoir is a synthetic structure designe...          0.929992
# 176  Efforts to promote diversity aim to amplify th...          0.930468
# 214  people has made significant strides in technol...          0.931211
# 210  human has always sought to understand the univ...          0.931410
# 114  The scrum main facilitated the daily stand-up ...          0.932176
# 175  Efforts to promote diversity aim to amplify th...          0.932201
# 136  The app includes a core feature for photo edit...          0.933925
# 134  The app includes a built-in feature for photo ...          0.937234
# 27   The IP address was added to the company’s bloc...          0.937636
# 6    The user chose to close the installation proce...          0.937832
# 96   Completing the project required 100 staff hour...          0.937897
# 135  The app includes a integrated feature for phot...          0.938498
# 223  The reservoir is a artificial structure design...          0.939255
# 157  The land’s history is deeply rooted in indigen...          0.939329
# 8    The user chose to discontinue the installation...          0.939527
# 165  The human-in-the-middle attack intercepted sen...          0.941567
# 151  The designer added blank space to improve the ...          0.942629
# 115  The scrum leader facilitated the daily stand-u...          0.942709
# 203  The chairperson called for a vote on the propo...          0.943595
# 224  The reservoir is a manufactured structure desi...          0.944345
# 11   The app is designed to be intuitive for the ge...          0.944776
# 137  The app includes a inherent feature for photo ...          0.945201
# 164  The individual-in-the-middle attack intercepte...          0.946122
# 12   The app is designed to be intuitive for the mo...          0.949315
# 89   Hey team, let’s gather for the meeting in five...          0.950417
# 179  The system is back to typical after resolving ...          0.950920
# 94   Completing the project required 100 labor hour...          0.951819
# 14   The algorithm functions as a closed box, with ...          0.951952
# 182  The venue was upgraded to be accessible for pe...          0.954893
# 10   The app is designed to be intuitive for the ty...          0.955607
# 177  The system is back to expected after resolving...          0.956891
# 92   Hey people, let’s gather for the meeting in fi...          0.957925
# 124  The system’s separation of duties ensures secu...          0.958804
# 100  Completing the project required 100 people hou...          0.959826
# 226  The reservoir is a human-made structure design...          0.960701
# 213  humankind has made significant strides in tech...          0.961535
# 98   Completing the project required 100 individual...          0.963030
# 7    The user chose to stop the installation proces...          0.964866
# 88   Hey everyone, let’s gather for the meeting in ...          0.965056
# 95   Completing the project required 100 work hours...          0.965177
# 212  humanity has made significant strides in techn...          0.968785
# 91   Hey all, let’s gather for the meeting in five ...          0.970328
# 93   Completing the project required 100 person hou...          0.970870
# 97   Completing the project required 100 person hou...          0.970870
# 90   Hey folks, let’s gather for the meeting in fiv...          0.975638
# 5    The user chose to end the installation process...          0.975999
# 99   Completing the project required 100 human hour...          0.980357

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/ClaudeSonnet3.7-1_replacements.csv", index=False)

# %%
# PROMPT 2:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "abort": ["cancel", "stop", "halt", "end", "discontinue"],
    "terminate": ["end", "close", "stop", "conclude", "exit"],
    "average user": ["typical user", "general user", "most users", "target user"],
    "black box": ["closed box", "opaque system", "hidden implementation"],
    "white box": ["clear box", "transparent box", "open box", "visible implementation"],
    "black hat": ["malicious actor", "unauthorized hacker", "threat actor"],
    "white hat": ["ethical hacker", "security researcher", "authorized tester"],
    "blacklist": ["blocklist", "deny list", "exclusion list"],
    "whitelist": ["allowlist", "permit list", "inclusion list"],
    "blind": ["anonymous", "unnamed", "unidentified"],
    "double blind": ["double anonymous", "dual anonymous"],
    "male connector": ["plug", "outward connector", "protruding connector"],
    "female connector": ["socket", "inward connector", "receptacle"],
    "she": "they",
    "her": "their",
    "hers": "theirs",
    "he": "they",
    "him": "them",
    "his": "their",
    "master": ["primary", "main", "leader", "controller", "host"],
    "slave": ["secondary", "follower", "worker", "client", "replica"],
    "quantum supremacy": ["quantum advantage", "quantum computational advantage"],
    "grandfathered": ["legacy-approved", "previously exempt", "historically allowed"],
    "guys": ["everyone", "team", "folks", "all", "people", "colleagues"],
    "man hours": ["person hours", "labor hours", "work hours", "staff hours"],
    "sanity check": ["quick check", "basic check", "coherence check", "logic check"],
    "sanity test": ["quick test", "basic test", "coherence test", "logic test"],
    "dummy value": ["placeholder", "sample value", "test value", "mock value"],
    "scrum master": ["scrum facilitator", "agile coach", "scrum coordinator"],
    "mob programming": ["ensemble programming", "team programming", "collaborative programming"],
    "segregation": ["separation", "division", "partition, Isolation"],
    "blackout period": ["restricted period", "maintenance window", "downtime period"],
    "gray hat": ["semi-ethical hacker", "boundary hacker"],
    "native": ["built-in", "integrated", "core", "inherent"],
    "red team": ["attack team", "adversary team", "offensive team"],
    "web master": ["web administrator", "site manager", "web coordinator"],
    "white space": ["negative space", "empty space", "blank space"],
    "white team": ["oversight team", "evaluation team", "monitoring team"],
    "yellow team": ["build security team", "security development team"],
    "aboriginal": ["indigenous", "first nations", "first peoples"],
    "brown bags": ["lunch and learn sessions", "knowledge sharing sessions"],
    "brown bag": ["lunch and learn session", "knowledge sharing session"],
    "first-class citizen": ["first-class entity", "first-class object", "core feature"],
    "first-class citizens": ["first-class entities", "first-class objects", "core features"],
    "man-in-the-middle": ["person-in-the-middle", "interception attack", "MITM attack"],
    "master branch": ["main branch", "primary branch", "default branch"],
    "minority": ["underrepresented group", "marginalized community"],
    "normal": ["expected", "standard", "typical", "default", "baseline"],
    "handicapped": ["person with disabilities", "accessible", "disability-friendly"],
    "crazy": ["unexpected", "surprising", "unconventional", "bold"],
    "OCD": ["detail-oriented", "thorough", "meticulous", "precise"],
    "culture fit": ["values alignment", "team compatibility", "organizational fit"],
    "chairman": ["chair", "chairperson", "meeting leader"],
    "foreman": ["supervisor", "team leader", "site manager"],
    "man": ["person", "individual", "human", "people"],
    "mankind": ["humanity", "humankind", "people"],
    "mans": ["operates", "staffs", "runs", "works"],
    "salesman": ["salesperson", "sales representative", "sales associate"],
    "manmade": ["artificial", "manufactured", "synthetic", "human-made"],
    "manpower": ["workforce", "staff", "personnel", "human resources"],
    "demilitarized zone": ["perimeter network", "edge network", "buffer zone"],
    "demilitarized zones": ["perimeter networks", "edge networks", "buffer zones"],
    "DMZ": ["perimeter network", "edge network", "buffer zone"],
    "hang": ["freeze", "become unresponsive", "stop responding"],
    "daughter board": ["expansion board", "secondary board", "auxiliary board"],
    "gender bender": ["adapter", "connector converter", "interface adapter"],
    "orphaned object": ["unreferenced object", "disconnected object", "isolated object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]


# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence          Harmful Term  \
# 44   The female connector allows for easy integrati...      female connector
# 42   The female connector allows for easy integrati...      female connector
# 22   The company detected a black hat attempting to...             black hat
# 23   The company detected a black hat attempting to...             black hat
# 21   The company detected a black hat attempting to...             black hat
# 163  Functions are treated as first-class citizens ...  first-class citizens
# 129  A blackout period was enforced during the syst...       blackout period
# 159  The company hosted brown bag sessions to share...             brown bag
# 160  The company hosted brown bag sessions to share...             brown bag
# 53   Her contribution to the discussion was insight...                   her
# 20   The white box testing method allows developers...             white box
# 237  The server operates within the DMZ for added s...                   DMZ
# 43   The female connector allows for easy integrati...      female connector
# 203  The company prioritizes culture fit when hirin...           culture fit
# 246  The adapter functions as a gender bender for c...         gender bender
# 247  The adapter functions as a gender bender for c...         gender bender
# 46   She was responsible for coordinating the team’...                   she
# 70   His programming skills greatly improved the pr...                   his
# 122  The team opted for mob programming to tackle t...       mob programming
# 234  The network’s demilitarized zone protects inte...    demilitarized zone
# 245  The adapter functions as a gender bender for c...         gender bender
# 236  The server operates within the DMZ for added s...                   DMZ
# 72   His programming skills greatly improved the pr...                   his
# 158  The land’s history is deeply rooted in Aborigi...            aboriginal
# 108  A quick sanity test revealed several issues in...           sanity test
# 47   She was responsible for coordinating the team’...                   she
# 50   Her contribution to the discussion was insight...                   her
# 210  The foreman supervised the construction site w...               foreman
# 208  The foreman supervised the construction site w...               foreman
# 33   The paper underwent a blind review process to ...                 blind
# 157  The land’s history is deeply rooted in Aborigi...            aboriginal
# 244  The new functionality was implemented through ...        daughter board
# 48   She was responsible for coordinating the team’...                   she
# 68   His programming skills greatly improved the pr...                   his
# 238  The server operates within the DMZ for added s...                   DMZ
# 198  His desk organization reflects a hint of OCD t...                   OCD
# 35   The paper underwent a blind review process to ...                 blind
# 131  The gray hat hacker reported the vulnerabiliti...              gray hat
# 49   Her contribution to the discussion was insight...                   her
# 110  Developers use a dummy value as a placeholder ...           dummy value
# 45   She was responsible for coordinating the team’...                   she
# 132  The gray hat hacker reported the vulnerabiliti...              gray hat
# 34   The paper underwent a blind review process to ...                 blind
# 56   The credit for the innovative design is entire...                  hers
# 209  The foreman supervised the construction site w...               foreman
# 66    The team assigned the most critical task to him.                   him
# 124  The team opted for mob programming to tackle t...       mob programming
# 202  The company prioritizes culture fit when hirin...           culture fit
# 154  The yellow team focused on optimizing the soft...           yellow team
# 58   The credit for the innovative design is entire...                  hers
# 130  A blackout period was enforced during the syst...       blackout period
# 55   The credit for the innovative design is entire...                  hers
# 242  The new functionality was implemented through ...        daughter board
# 67    The team assigned the most critical task to him.                   him
# 243  The new functionality was implemented through ...        daughter board
# 51   Her contribution to the discussion was insight...                   her
# 192  The plan was considered crazy but turned out t...                 crazy
# 111  Developers use a dummy value as a placeholder ...           dummy value
# 69   His programming skills greatly improved the pr...                   his
# 155  The yellow team focused on optimizing the soft...           yellow team
# 152  The white team oversaw the cyber exercise and ...            white team
# 109  A quick sanity test revealed several issues in...           sanity test
# 204  The company prioritizes culture fit when hirin...           culture fit
# 54   The credit for the innovative design is entire...                  hers
# 199  His desk organization reflects a hint of OCD t...                   OCD
# 123  The team opted for mob programming to tackle t...       mob programming
# 201  His desk organization reflects a hint of OCD t...                   OCD
# 17   The white box testing method allows developers...             white box
# 40   The cable is equipped with a male connector fo...        male connector
# 75   The master database contains all the key recor...                master
# 26   A white hat hacker helped identify security vu...             white hat
# 197  His desk organization reflects a hint of OCD t...                   his
# 128  A blackout period was enforced during the syst...       blackout period
# 140  The web master updated the website’s layout fo...                master
# 71   His programming skills greatly improved the pr...                   his
# 166  The man-in-the-middle attack intercepted sensi...     man-in-the-middle
# 120  The scrum master facilitated the daily stand-u...          scrum master
# 76   The master database contains all the key recor...                master
# 24   A white hat hacker helped identify security vu...             white hat
# 165  The man-in-the-middle attack intercepted sensi...     man-in-the-middle
# 113  Developers use a dummy value as a placeholder ...           dummy value
# 207  The chairman called for a vote on the proposed...              chairman
# 220        The crew mans the ship during long voyages.                  mans
# 161  Functions are treated as first-class citizens ...  first-class citizens
# 195  His desk organization reflects a hint of OCD t...                   his
# 64    The team assigned the most critical task to him.                   him
# 59   The credit for the innovative design is entire...                  hers
# 41   The cable is equipped with a male connector fo...        male connector
# 60   He led the presentation with confidence and cl...                    he
# 233  The network’s demilitarized zone protects inte...    demilitarized zone
# 18   The white box testing method allows developers...             white box
# 151  The white team oversaw the cyber exercise and ...            white team
# 138  The red team simulated an attack to test the o...              red team
# 62   He led the presentation with confidence and cl...                    he
# 196  His desk organization reflects a hint of OCD t...                   his
# 61   He led the presentation with confidence and cl...                    he
# 52   Her contribution to the discussion was insight...                   her
# 73   The master database contains all the key recor...                master
# 25   A white hat hacker helped identify security vu...             white hat
# 143  The web master updated the website’s layout fo...                master
# 77   The master database contains all the key recor...                master
# 57   The credit for the innovative design is entire...                  hers
# 194  His desk organization reflects a hint of OCD t...                   his
# 65    The team assigned the most critical task to him.                   him
# 193  His desk organization reflects a hint of OCD t...                   his
# 104  Before deploying the code, we need to perform ...          sanity check
# 223  The salesman demonstrated the product’s key fe...              salesman
# 218        The crew mans the ship during long voyages.                  mans
# 162  Functions are treated as first-class citizens ...  first-class citizens
# 174  Changes were merged into the master branch for...                master
# 200  His desk organization reflects a hint of OCD t...                   OCD
# 63   He led the presentation with confidence and cl...                    he
# 141  The web master updated the website’s layout fo...                master
# 153  The white team oversaw the cyber exercise and ...            white team
# 79   The secondary system operates as a slave to th...                 slave
# 31   Only pre-approved devices are included in the ...             whitelist
# 235  The network’s demilitarized zone protects inte...    demilitarized zone
# 39   The cable is equipped with a male connector fo...        male connector
# 147  The web master updated the website’s layout fo...            web master
# 112  Developers use a dummy value as a placeholder ...           dummy value
# 19   The white box testing method allows developers...             white box
# 219        The crew mans the ship during long voyages.                  mans
# 145  The web master updated the website’s layout fo...            web master
# 224  The salesman demonstrated the product’s key fe...              salesman
# 102  Before deploying the code, we need to perform ...          sanity check
# 105  Before deploying the code, we need to perform ...          sanity check
# 139  The red team simulated an attack to test the o...              red team
# 249  The cleanup script removed the orphaned object...       orphaned object
# 190  The plan was considered crazy but turned out t...                 crazy
# 146  The web master updated the website’s layout fo...            web master
# 221        The crew mans the ship during long voyages.                  mans
# 191  The plan was considered crazy but turned out t...                 crazy
# 83   Achieving quantum supremacy marks a significan...     quantum supremacy
# 80   The secondary system operates as a slave to th...                 slave
# 137  The red team simulated an attack to test the o...              red team
# 103  Before deploying the code, we need to perform ...          sanity check
# 84   Achieving quantum supremacy marks a significan...     quantum supremacy
# 74   The master database contains all the key recor...                master
# 185  The system is back to normal after resolving t...                normal
# 184  The system is back to normal after resolving t...                normal
# 189  The plan was considered crazy but turned out t...                 crazy
# 144  The web master updated the website’s layout fo...                master
# 81   The secondary system operates as a slave to th...                 slave
# 142  The web master updated the website’s layout fo...                master
# 82   The secondary system operates as a slave to th...                 slave
# 222  The salesman demonstrated the product’s key fe...              salesman
# 240  The application tends to hang when handling la...                  hang
# 173  Changes were merged into the master branch for...                master
# 230  The project required significant manpower to c...              manpower
# 4    The program will automatically abort if a crit...                 abort
# 32   Only pre-approved devices are included in the ...             whitelist
# 232  The project required significant manpower to c...              manpower
# 36   The experiment was conducted under double-blin...                 blind
# 229  The project required significant manpower to c...              manpower
# 175  Changes were merged into the master branch for...                master
# 250  The cleanup script removed the orphaned object...       orphaned object
# 87   The older software was grandfathered in despit...         grandfathered
# 86   The older software was grandfathered in despit...         grandfathered
# 187  The venue was upgraded to be accessible for ha...           handicapped
# 78   The secondary system operates as a slave to th...                 slave
# 171  Changes were merged into the master branch for...                master
# 177  Changes were merged into the master branch for...         master branch
# 16   The algorithm functions as a black box, with n...             black box
# 119  The scrum master facilitated the daily stand-u...          scrum master
# 127  The system’s segregation of duties ensures sec...           segregation
# 241  The application tends to hang when handling la...                  hang
# 15   The algorithm functions as a black box, with n...             black box
# 231  The project required significant manpower to c...              manpower
# 214  Man has always sought to understand the universe.                   man
# 30   Only pre-approved devices are included in the ...             whitelist
# 148  The designer added white space to improve the ...           white space
# 205  The chairman called for a vote on the proposed...              chairman
# 8    The user chose to terminate the installation p...             terminate
# 178  Changes were merged into the master branch for...         master branch
# 107  A quick sanity test revealed several issues in...           sanity test
# 0    The program will automatically abort if a crit...                 abort
# 2    The program will automatically abort if a crit...                 abort
# 13   The app is designed to be intuitive for the av...          average user
# 248  The cleanup script removed the orphaned object...       orphaned object
# 211  Man has always sought to understand the universe.                   man
# 85   The older software was grandfathered in despit...         grandfathered
# 93   Hey guys, let’s gather for the meeting in five...                  guys
# 239  The application tends to hang when handling la...                  hang
# 106  A quick sanity test revealed several issues in...           sanity test
# 3    The program will automatically abort if a crit...                 abort
# 149  The designer added white space to improve the ...           white space
# 37   The experiment was conducted under double-blin...                 blind
# 38   The experiment was conducted under double-blin...                 blind
# 212  Man has always sought to understand the universe.                   man
# 182  The system is back to normal after resolving t...                normal
# 1    The program will automatically abort if a crit...                 abort
# 114  The scrum master facilitated the daily stand-u...                master
# 126  The system’s segregation of duties ensures sec...           segregation
# 188  The venue was upgraded to be accessible for ha...           handicapped
# 117  The scrum master facilitated the daily stand-u...                master
# 121  The scrum master facilitated the daily stand-u...          scrum master
# 29   The IP address was added to the company’s blac...             blacklist
# 172  Changes were merged into the master branch for...                master
# 176  Changes were merged into the master branch for...         master branch
# 118  The scrum master facilitated the daily stand-u...                master
# 170  The man-in-the-middle attack intercepted sensi...                   man
# 167  The man-in-the-middle attack intercepted sensi...                   man
# 164  The man-in-the-middle attack intercepted sensi...     man-in-the-middle
# 28   The IP address was added to the company’s blac...             blacklist
# 227  The reservoir is a manmade structure designed ...               manmade
# 180  Efforts to promote diversity aim to amplify th...              minority
# 217  Mankind has made significant strides in techno...               mankind
# 213  Man has always sought to understand the universe.                   man
# 115  The scrum master facilitated the daily stand-u...                master
# 179  Efforts to promote diversity aim to amplify th...              minority
# 135  The app includes a native feature for photo ed...                native
# 133  The app includes a native feature for photo ed...                native
# 27   The IP address was added to the company’s blac...             blacklist
# 6    The user chose to terminate the installation p...             terminate
# 97   Completing the project required 100 man hours ...             man hours
# 134  The app includes a native feature for photo ed...                native
# 225  The reservoir is a manmade structure designed ...               manmade
# 156  The land’s history is deeply rooted in Aborigi...            aboriginal
# 169  The man-in-the-middle attack intercepted sensi...                   man
# 150  The designer added white space to improve the ...           white space
# 116  The scrum master facilitated the daily stand-u...                master
# 206  The chairman called for a vote on the proposed...              chairman
# 226  The reservoir is a manmade structure designed ...               manmade
# 11   The app is designed to be intuitive for the av...          average user
# 136  The app includes a native feature for photo ed...                native
# 168  The man-in-the-middle attack intercepted sensi...                   man
# 12   The app is designed to be intuitive for the av...          average user
# 89   Hey guys, let’s gather for the meeting in five...                  guys
# 183  The system is back to normal after resolving t...                normal
# 95   Completing the project required 100 man hours ...             man hours
# 14   The algorithm functions as a black box, with n...             black box
# 186  The venue was upgraded to be accessible for ha...           handicapped
# 10   The app is designed to be intuitive for the av...          average user
# 181  The system is back to normal after resolving t...                normal
# 92   Hey guys, let’s gather for the meeting in five...                  guys
# 125  The system’s segregation of duties ensures sec...           segregation
# 101  Completing the project required 100 man hours ...                   man
# 228  The reservoir is a manmade structure designed ...               manmade
# 216  Mankind has made significant strides in techno...               mankind
# 99   Completing the project required 100 man hours ...                   man
# 7    The user chose to terminate the installation p...             terminate
# 88   Hey guys, let’s gather for the meeting in five...                  guys
# 96   Completing the project required 100 man hours ...             man hours
# 9    The user chose to terminate the installation p...             terminate
# 215  Mankind has made significant strides in techno...               mankind
# 91   Hey guys, let’s gather for the meeting in five...                  guys
# 94   Completing the project required 100 man hours ...             man hours
# 98   Completing the project required 100 man hours ...                   man
# 90   Hey guys, let’s gather for the meeting in five...                  guys
# 5    The user chose to terminate the installation p...             terminate
# 100  Completing the project required 100 man hours ...                   man
#
#                          Replacement  \
# 44                        receptacle
# 42                            socket
# 22               unauthorized hacker
# 23                      threat actor
# 21                   malicious actor
# 163                    core features
# 129               maintenance window
# 159          lunch and learn session
# 160        knowledge sharing session
# 53                                 r
# 20            visible implementation
# 237                     edge network
# 43                  inward connector
# 203               team compatibility
# 246              connector converter
# 247                interface adapter
# 46                                 h
# 70                                 e
# 122             ensemble programming
# 234                     edge network
# 245                          adapter
# 236                perimeter network
# 72                                 r
# 158                    first peoples
# 108                   coherence test
# 47                                 e
# 50                                 h
# 210                     site manager
# 208                       supervisor
# 33                         anonymous
# 157                    first nations
# 244                  auxiliary board
# 48                                 y
# 68                                 t
# 238                      buffer zone
# 198                  detail-oriented
# 35                      unidentified
# 131              semi-ethical hacker
# 49                                 t
# 110                      placeholder
# 45                                 t
# 132                  boundary hacker
# 34                           unnamed
# 56                                 e
# 209                      team leader
# 66                                 e
# 124        collaborative programming
# 202                 values alignment
# 154              build security team
# 58                                 r
# 130                  downtime period
# 55                                 h
# 242                  expansion board
# 67                                 m
# 243                  secondary board
# 51                                 e
# 192                             bold
# 111                     sample value
# 69                                 h
# 155        security development team
# 152                  evaluation team
# 109                       logic test
# 204               organizational fit
# 54                                 t
# 199                         thorough
# 123                 team programming
# 201                          precise
# 17                         clear box
# 40                 outward connector
# 75                            leader
# 26                 authorized tester
# 197                                r
# 128                restricted period
# 140                          primary
# 71                                 i
# 166                      MITM attack
# 120                      agile coach
# 76                        controller
# 24                    ethical hacker
# 165              interception attack
# 113                       mock value
# 207                   meeting leader
# 220                             runs
# 161             first-class entities
# 195                                e
# 64                                 t
# 59                                 s
# 41              protruding connector
# 60                                 t
# 233                perimeter network
# 18                   transparent box
# 151                   oversight team
# 138                   adversary team
# 62                                 e
# 196                                i
# 61                                 h
# 52                                 i
# 73                           primary
# 25               security researcher
# 143                       controller
# 77                              host
# 57                                 i
# 194                                h
# 65                                 h
# 193                                t
# 104                  coherence check
# 223             sales representative
# 218                         operates
# 162              first-class objects
# 174                       controller
# 200                       meticulous
# 63                                 y
# 141                             main
# 153                  monitoring team
# 79                          follower
# 31                       permit list
# 235                      buffer zone
# 39                              plug
# 147                  web coordinator
# 112                       test value
# 19                          open box
# 219                           staffs
# 145                web administrator
# 224                  sales associate
# 102                      quick check
# 105                      logic check
# 139                   offensive team
# 249              disconnected object
# 190                       surprising
# 146                     site manager
# 221                            works
# 191                   unconventional
# 83                 quantum advantage
# 80                            worker
# 137                      attack team
# 103                      basic check
# 84   quantum computational advantage
# 74                              main
# 185                         baseline
# 184                          default
# 189                       unexpected
# 144                             host
# 81                            client
# 142                           leader
# 82                           replica
# 222                      salesperson
# 240              become unresponsive
# 173                           leader
# 230                            staff
# 4                        discontinue
# 32                    inclusion list
# 232                  human resources
# 36                         anonymous
# 229                        workforce
# 175                             host
# 250                  isolated object
# 87              historically allowed
# 86                 previously exempt
# 187                       accessible
# 78                         secondary
# 171                          primary
# 177                   primary branch
# 16             hidden implementation
# 119                scrum facilitator
# 127             partition, Isolation
# 241                  stop responding
# 15                     opaque system
# 231                        personnel
# 214                           people
# 30                         allowlist
# 148                   negative space
# 205                            chair
# 8                           conclude
# 178                   default branch
# 107                       basic test
# 0                             cancel
# 2                               halt
# 13                       target user
# 248              unreferenced object
# 211                           person
# 85                   legacy-approved
# 93                        colleagues
# 239                           freeze
# 106                       quick test
# 3                                end
# 149                      empty space
# 37                           unnamed
# 38                      unidentified
# 212                       individual
# 182                         standard
# 1                               stop
# 114                          primary
# 126                         division
# 188              disability-friendly
# 117                       controller
# 121                scrum coordinator
# 29                    exclusion list
# 172                             main
# 176                      main branch
# 118                             host
# 170                           people
# 167                           person
# 164             person-in-the-middle
# 28                         deny list
# 227                        synthetic
# 180           marginalized community
# 217                           people
# 213                            human
# 115                             main
# 179           underrepresented group
# 135                             core
# 133                         built-in
# 27                         blocklist
# 6                              close
# 97                       staff hours
# 134                       integrated
# 225                       artificial
# 156                       indigenous
# 169                            human
# 150                      blank space
# 116                           leader
# 206                      chairperson
# 226                     manufactured
# 11                      general user
# 136                         inherent
# 168                       individual
# 12                        most users
# 89                              team
# 183                          typical
# 95                       labor hours
# 14                        closed box
# 186         person with disabilities
# 10                      typical user
# 181                         expected
# 92                            people
# 125                       separation
# 101                           people
# 228                       human-made
# 216                        humankind
# 99                        individual
# 7                               stop
# 88                          everyone
# 96                        work hours
# 9                               exit
# 215                         humanity
# 91                               all
# 94                      person hours
# 98                            person
# 90                             folks
# 5                                end
# 100                            human
#
#                                      Modified Sentence  Similarity Score
# 44   The receptacle allows for easy integration wit...          0.510210
# 42   The socket allows for easy integration with ot...          0.573467
# 22   The company detected a unauthorized hacker att...          0.594909
# 23   The company detected a threat actor attempting...          0.606656
# 21   The company detected a malicious actor attempt...          0.610877
# 163  Functions are treated as core features in many...          0.641356
# 129  A maintenance window was enforced during the s...          0.658593
# 159  The company hosted lunch and learn session ses...          0.682555
# 160  The company hosted knowledge sharing session s...          0.687225
# 53   r contribution to the discussion was insightfu...          0.691604
# 20   The visible implementation testing method allo...          0.693767
# 237  The server operates within the edge network fo...          0.694725
# 43   The inward connector allows for easy integrati...          0.701439
# 203  The company prioritizes team compatibility whe...          0.702953
# 246  The adapter functions as a connector converter...          0.717010
# 247  The adapter functions as a interface adapter f...          0.718079
# 46   h was responsible for coordinating the team’s ...          0.720209
# 70   e programming skills greatly improved the proj...          0.721613
# 122  The team opted for ensemble programming to tac...          0.721668
# 234  The network’s edge network protects internal s...          0.724516
# 245  The adapter functions as a adapter for connect...          0.727360
# 236  The server operates within the perimeter netwo...          0.728124
# 72   r programming skills greatly improved the proj...          0.734961
# 158  The land’s history is deeply rooted in first p...          0.736355
# 108  A quick coherence test revealed several issues...          0.737621
# 47   e was responsible for coordinating the team’s ...          0.739997
# 50   h contribution to the discussion was insightfu...          0.740288
# 210  The site manager supervised the construction s...          0.743306
# 208  The supervisor supervised the construction sit...          0.744094
# 33   The paper underwent a anonymous review process...          0.744736
# 157  The land’s history is deeply rooted in first n...          0.746485
# 244  The new functionality was implemented through ...          0.750979
# 48   y was responsible for coordinating the team’s ...          0.757748
# 68   t programming skills greatly improved the proj...          0.760157
# 238  The server operates within the buffer zone for...          0.761033
# 198  His desk organization reflects a hint of detai...          0.762296
# 35   The paper underwent a unidentified review proc...          0.762904
# 131  The semi-ethical hacker hacker reported the vu...          0.763539
# 49   t contribution to the discussion was insightfu...          0.763810
# 110  Developers use a placeholder as a placeholder ...          0.766475
# 45   t was responsible for coordinating the team’s ...          0.767980
# 132  The boundary hacker hacker reported the vulner...          0.768472
# 34   The paper underwent a unnamed review process t...          0.769620
# 56   The credit for the innovative design is entire...          0.770192
# 209  The team leader supervised the construction si...          0.772069
# 66      The team assigned the most critical task to e.          0.775197
# 124  The team opted for collaborative programming t...          0.777778
# 202  The company prioritizes values alignment when ...          0.778899
# 154  The build security team focused on optimizing ...          0.780419
# 58   The credit for the innovative design is entire...          0.782892
# 130  A downtime period was enforced during the syst...          0.785668
# 55   The credit for the innovative design is entire...          0.786087
# 242  The new functionality was implemented through ...          0.787963
# 67      The team assigned the most critical task to m.          0.788057
# 243  The new functionality was implemented through ...          0.790100
# 51   e contribution to the discussion was insightfu...          0.792463
# 192  The plan was considered bold but turned out to...          0.792576
# 111  Developers use a sample value as a placeholder...          0.795430
# 69   h programming skills greatly improved the proj...          0.795577
# 155  The security development team focused on optim...          0.797390
# 152  The evaluation team oversaw the cyber exercise...          0.798185
# 109  A quick logic test revealed several issues in ...          0.799555
# 204  The company prioritizes organizational fit whe...          0.800476
# 54   The credit for the innovative design is entire...          0.801475
# 199  His desk organization reflects a hint of thoro...          0.801717
# 123  The team opted for team programming to tackle ...          0.801736
# 201  His desk organization reflects a hint of preci...          0.802397
# 17   The clear box testing method allows developers...          0.804669
# 40   The cable is equipped with a outward connector...          0.805821
# 75   The leader database contains all the key recor...          0.805919
# 26   A authorized tester hacker helped identify sec...          0.808039
# 197  r desk organization reflects a hint of OCD ten...          0.810572
# 128  A restricted period was enforced during the sy...          0.810575
# 140  The web primary updated the website’s layout f...          0.810848
# 71   i programming skills greatly improved the proj...          0.811454
# 166  The MITM attack attack intercepted sensitive i...          0.812426
# 120  The agile coach facilitated the daily stand-up...          0.815039
# 76   The controller database contains all the key r...          0.816892
# 24   A ethical hacker hacker helped identify securi...          0.817126
# 165  The interception attack attack intercepted sen...          0.817796
# 113  Developers use a mock value as a placeholder d...          0.818040
# 207  The meeting leader called for a vote on the pr...          0.819052
# 220        The crew runs the ship during long voyages.          0.819893
# 161  Functions are treated as first-class entities ...          0.820047
# 195  e desk organization reflects a hint of OCD ten...          0.822263
# 64      The team assigned the most critical task to t.          0.822790
# 59   The credit for the innovative design is entire...          0.822957
# 41   The cable is equipped with a protruding connec...          0.823286
# 60   t led the presentation with confidence and cla...          0.824100
# 233  The network’s perimeter network protects inter...          0.824664
# 18   The transparent box testing method allows deve...          0.825408
# 151  The oversight team oversaw the cyber exercise ...          0.826038
# 138  The adversary team simulated an attack to test...          0.829016
# 62   e led the presentation with confidence and cla...          0.829612
# 196  i desk organization reflects a hint of OCD ten...          0.829691
# 61   h led the presentation with confidence and cla...          0.830584
# 52   i contribution to the discussion was insightfu...          0.832515
# 73   The primary database contains all the key reco...          0.832613
# 25   A security researcher hacker helped identify s...          0.832633
# 143  The web controller updated the website’s layou...          0.833191
# 77   The host database contains all the key records...          0.834691
# 57   The credit for the innovative design is entire...          0.834846
# 194  h desk organization reflects a hint of OCD ten...          0.839764
# 65      The team assigned the most critical task to h.          0.839806
# 193  t desk organization reflects a hint of OCD ten...          0.841256
# 104  Before deploying the code, we need to perform ...          0.842882
# 223  The sales representative demonstrated the prod...          0.842884
# 218    The crew operates the ship during long voyages.          0.843587
# 162  Functions are treated as first-class objects i...          0.843841
# 174  Changes were merged into the controller branch...          0.844265
# 200  His desk organization reflects a hint of metic...          0.844329
# 63   y led the presentation with confidence and cla...          0.844980
# 141  The web main updated the website’s layout for ...          0.845296
# 153  The monitoring team oversaw the cyber exercise...          0.846402
# 79   The secondary system operates as a follower to...          0.849255
# 31   Only pre-approved devices are included in the ...          0.849591
# 235  The network’s buffer zone protects internal sy...          0.849631
# 39   The cable is equipped with a plug for compatib...          0.849646
# 147  The web coordinator updated the website’s layo...          0.849835
# 112  Developers use a test value as a placeholder d...          0.850563
# 19   The open box testing method allows developers ...          0.850860
# 219      The crew staffs the ship during long voyages.          0.851084
# 145  The web administrator updated the website’s la...          0.852008
# 224  The sales associate demonstrated the product’s...          0.853444
# 102  Before deploying the code, we need to perform ...          0.854385
# 105  Before deploying the code, we need to perform ...          0.855941
# 139  The offensive team simulated an attack to test...          0.856035
# 249  The cleanup script removed the disconnected ob...          0.859831
# 190  The plan was considered surprising but turned ...          0.861411
# 146  The site manager updated the website’s layout ...          0.865234
# 221       The crew works the ship during long voyages.          0.866085
# 191  The plan was considered unconventional but tur...          0.867457
# 83   Achieving quantum advantage marks a significan...          0.867519
# 80   The secondary system operates as a worker to t...          0.867971
# 137  The attack team simulated an attack to test th...          0.870433
# 103  Before deploying the code, we need to perform ...          0.870917
# 84   Achieving quantum computational advantage mark...          0.871936
# 74   The main database contains all the key records...          0.872235
# 185  The system is back to baseline after resolving...          0.873188
# 184  The system is back to default after resolving ...          0.873858
# 189  The plan was considered unexpected but turned ...          0.874205
# 144  The web host updated the website’s layout for ...          0.875561
# 81   The secondary system operates as a client to t...          0.875677
# 142  The web leader updated the website’s layout fo...          0.876580
# 82   The secondary system operates as a replica to ...          0.877979
# 222  The salesperson demonstrated the product’s key...          0.878644
# 240  The application tends to become unresponsive w...          0.879780
# 173  Changes were merged into the leader branch for...          0.880295
# 230  The project required significant staff to comp...          0.881556
# 4    The program will automatically discontinue if ...          0.882610
# 32   Only pre-approved devices are included in the ...          0.882783
# 232  The project required significant human resourc...          0.882928
# 36   The experiment was conducted under double-anon...          0.883819
# 229  The project required significant workforce to ...          0.888754
# 175  Changes were merged into the host branch for d...          0.888907
# 250  The cleanup script removed the isolated object...          0.889182
# 87   The older software was historically allowed in...          0.889732
# 86   The older software was previously exempt in de...          0.890389
# 187  The venue was upgraded to be accessible for ac...          0.891089
# 78   The secondary system operates as a secondary t...          0.892284
# 171  Changes were merged into the primary branch fo...          0.894577
# 177  Changes were merged into the primary branch fo...          0.894577
# 16   The algorithm functions as a hidden implementa...          0.895238
# 119  The scrum facilitator facilitated the daily st...          0.895948
# 127  The system’s partition, Isolation of duties en...          0.896487
# 241  The application tends to stop responding when ...          0.897520
# 15   The algorithm functions as a opaque system, wi...          0.898719
# 231  The project required significant personnel to ...          0.898788
# 214  people has always sought to understand the uni...          0.899577
# 30   Only pre-approved devices are included in the ...          0.901145
# 148  The designer added negative space to improve t...          0.902180
# 205  The chair called for a vote on the proposed ch...          0.903277
# 8    The user chose to conclude the installation pr...          0.904197
# 178  Changes were merged into the default branch fo...          0.905802
# 107  A quick basic test revealed several issues in ...          0.907914
# 0    The program will automatically cancel if a cri...          0.908169
# 2    The program will automatically halt if a criti...          0.909458
# 13   The app is designed to be intuitive for the ta...          0.911061
# 248  The cleanup script removed the unreferenced ob...          0.911102
# 211  person has always sought to understand the uni...          0.911396
# 85   The older software was legacy-approved in desp...          0.911681
# 93   Hey colleagues, let’s gather for the meeting i...          0.912047
# 239  The application tends to freeze when handling ...          0.914745
# 106  A quick quick test revealed several issues in ...          0.918039
# 3    The program will automatically end if a critic...          0.918662
# 149  The designer added empty space to improve the ...          0.918833
# 37   The experiment was conducted under double-unna...          0.919375
# 38   The experiment was conducted under double-unid...          0.919892
# 212  individual has always sought to understand the...          0.920260
# 182  The system is back to standard after resolving...          0.921492
# 1    The program will automatically stop if a criti...          0.922640
# 114  The scrum primary facilitated the daily stand-...          0.923873
# 126  The system’s division of duties ensures secure...          0.924723
# 188  The venue was upgraded to be accessible for di...          0.924812
# 117  The scrum controller facilitated the daily sta...          0.925107
# 121  The scrum coordinator facilitated the daily st...          0.925548
# 29   The IP address was added to the company’s excl...          0.925768
# 172  Changes were merged into the main branch for d...          0.928553
# 176  Changes were merged into the main branch for d...          0.928553
# 118  The scrum host facilitated the daily stand-up ...          0.928827
# 170  The people-in-the-middle attack intercepted se...          0.929361
# 167  The person-in-the-middle attack intercepted se...          0.929446
# 164  The person-in-the-middle attack intercepted se...          0.929446
# 28   The IP address was added to the company’s deny...          0.929633
# 227  The reservoir is a synthetic structure designe...          0.929992
# 180  Efforts to promote diversity aim to amplify th...          0.930468
# 217  people has made significant strides in technol...          0.931211
# 213  human has always sought to understand the univ...          0.931410
# 115  The scrum main facilitated the daily stand-up ...          0.932176
# 179  Efforts to promote diversity aim to amplify th...          0.932201
# 135  The app includes a core feature for photo edit...          0.933925
# 133  The app includes a built-in feature for photo ...          0.937234
# 27   The IP address was added to the company’s bloc...          0.937636
# 6    The user chose to close the installation proce...          0.937832
# 97   Completing the project required 100 staff hour...          0.937897
# 134  The app includes a integrated feature for phot...          0.938498
# 225  The reservoir is a artificial structure design...          0.939255
# 156  The land’s history is deeply rooted in indigen...          0.939329
# 169  The human-in-the-middle attack intercepted sen...          0.941567
# 150  The designer added blank space to improve the ...          0.942629
# 116  The scrum leader facilitated the daily stand-u...          0.942709
# 206  The chairperson called for a vote on the propo...          0.943595
# 226  The reservoir is a manufactured structure desi...          0.944345
# 11   The app is designed to be intuitive for the ge...          0.944776
# 136  The app includes a inherent feature for photo ...          0.945201
# 168  The individual-in-the-middle attack intercepte...          0.946122
# 12   The app is designed to be intuitive for the mo...          0.949315
# 89   Hey team, let’s gather for the meeting in five...          0.950417
# 183  The system is back to typical after resolving ...          0.950920
# 95   Completing the project required 100 labor hour...          0.951819
# 14   The algorithm functions as a closed box, with ...          0.951952
# 186  The venue was upgraded to be accessible for pe...          0.954893
# 10   The app is designed to be intuitive for the ty...          0.955607
# 181  The system is back to expected after resolving...          0.956891
# 92   Hey people, let’s gather for the meeting in fi...          0.957925
# 125  The system’s separation of duties ensures secu...          0.958804
# 101  Completing the project required 100 people hou...          0.959826
# 228  The reservoir is a human-made structure design...          0.960701
# 216  humankind has made significant strides in tech...          0.961535
# 99   Completing the project required 100 individual...          0.963030
# 7    The user chose to stop the installation proces...          0.964866
# 88   Hey everyone, let’s gather for the meeting in ...          0.965056
# 96   Completing the project required 100 work hours...          0.965177
# 9    The user chose to exit the installation proces...          0.965641
# 215  humanity has made significant strides in techn...          0.968785
# 91   Hey all, let’s gather for the meeting in five ...          0.970328
# 94   Completing the project required 100 person hou...          0.970870
# 98   Completing the project required 100 person hou...          0.970870
# 90   Hey folks, let’s gather for the meeting in fiv...          0.975638
# 5    The user chose to end the installation process...          0.975999
# 100  Completing the project required 100 human hour...          0.980357

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/ClaudeSonnet3.7-2_replacements.csv", index=False)

# %%
# No replacements from prompt 3, model recognized that prompt was the same.
