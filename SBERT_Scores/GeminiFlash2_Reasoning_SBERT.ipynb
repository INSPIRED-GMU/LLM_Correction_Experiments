# %%
# PROMPT 1:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Halt", "Stop", "Interrupt"],
    "Terminate": ["End", "Close", "Stop", "Finish"],
    "Average user": ["Typical user", "Standard user", "General user", "Intended user"],
    "Black box": ["Opaque box", "Non-transparent box", "Undocumented process"],
    "White box": ["Transparent box", "Glass box", "Open box"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Attacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Passlist", "Inclusion list"],
    "Blind": ["Blinded review", "Anonymized review"],
    "Double blind": ["Double-blinded review", "Fully anonymized review", "Independent review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Receptacle connector", "Socket connector"],
    "She": ["They"],
    "Her": ["Them"],
    "Hers": ["Theirs"],
    "He": ["They"],
    "Him": ["Them"],
    "His": ["Theirs"],
    "Master": ["Primary", "Main", "Leader", "Controller"],
    "Slave": ["Secondary", "Replica", "Follower", "Agent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum preeminence"],
    "Grandfathered": ["Legacy status", "Retained status", "Exempt under previous policy", "Previously approved"],
    "Guys": ["Everyone", "Folks", "Team", "People"],
    "Man hours": ["Person-hours", "Work hours", "Labor hours", "Staff hours"],
    "Sanity check": ["Quick check", "Basic check", "Initial check", "Confidence test", "Smoke test"],
    "Sanity test": ["Quick test", "Basic test", "Initial test", "Confidence test", "Smoke test"],
    "Dummy value": ["Placeholder value", "Sample value", "Example value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Project facilitator"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Compartmentalization", "Distinction"],
    "Blackout period": ["Maintenance window", "Downtime", "Outage period"],
    "Gray hat": ["Ambiguous actor", "Actor with unclear motives", "Semi-authorized actor"],
    "Native": ["Built-in", "Inherent", "Default", "Platform-specific"],
    "Red team": ["Security testing team", "Offensive security team", "Attack simulation team"],
    "Web master": ["Web administrator", "Web lead", "Website maintainer"],
    "White space": ["Spacing", "Negative space", "Padding"],
    "White team": ["Oversight team", "Moderation team", "Control team"],
    "Yellow team": ["Security optimization team", "Performance team", "Team [Specific Function]"],
    "Aboriginal": ["Indigenous", "First Peoples", "Original"],
    "Brown bags": ["Informal learning session", "Lunch and learn session", "Knowledge sharing session"],
    "First-class citizen": ["Primary citizen", "Essential citizen", "Core component", "Fundamental element"],
    "Man-in-the-middle": ["Intermediary attack", "Eavesdropping attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch", "Primary branch"],
    "Minority": ["Underrepresented group", "Marginalized group", "Specific demographic group"],
    "Normal": ["Typical", "Expected", "Standard", "Regular"],
    "Handicapped": ["Accessible", "People with disabilities", "Persons with disabilities", "Users with disabilities"],
    "Crazy": ["Unconventional", "Unexpected", "Surprising", "Innovative", "Remarkable"],
    "OCD": ["Meticulous", "Organized", "Detail-oriented", "Orderly", "Neat"],
    "Culture fit": ["Team contribution", "Values alignment", "Collaborative spirit", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Presiding officer", "Coordinator"],
    "Foreman": ["Supervisor", "Team lead", "Site supervisor"],
    "Man": ["Humankind", "People", "Humanity"],
    "Mankind": ["Humankind", "Humanity", "People"],
    "Mans": ["Crews", "Staffs", "Operates"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Synthetic", "Engineered", "Artificial", "Constructed"],
    "Manpower": ["Staffing", "Workforce", "Personnel", "Team members"],
    "Demilitarized zone": ["Perimeter network", "Screened subnet", "Isolated network"],
    "DMZ": ["Perimeter network", "Screened subnet", "Isolated network"],
    "Hang": ["Freeze", "Become unresponsive", "Stall", "Become blocked"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Gender changer", "Gender adapter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Unlinked object", "Detached object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 19   The company detected a black hat attempting to...           Black hat
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 18   The company detected a black hat attempting to...           Black hat
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 35   The female connector allows for easy integrati...    Female connector
# 20   The company detected a black hat attempting to...           Black hat
# 87   The scrum master facilitated the daily stand-u...        Scrum master
# 94   A blackout period was enforced during the syst...     Blackout period
# 30   The paper underwent a blind review process to ...               Blind
# 36   The female connector allows for easy integrati...    Female connector
# 98   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 72   Before deploying the code, we need to perform ...        Sanity check
# 97   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 206  The adapter functions as a gender bender for c...       Gender bender
# 99   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 195  The server operates within the DMZ for added s...                 DMZ
# 196  The server operates within the DMZ for added s...                 DMZ
# 88   The team opted for mob programming to tackle t...     Mob programming
# 194  The server operates within the DMZ for added s...                 DMZ
# 95   A blackout period was enforced during the syst...     Blackout period
# 71   Before deploying the code, we need to perform ...        Sanity check
# 32   The experiment was conducted under double-blin...               Blind
# 164  The company prioritizes culture fit when hirin...         Culture fit
# 170  The foreman supervised the construction site w...             Foreman
# 124  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 169  The foreman supervised the construction site w...             Foreman
# 171  The foreman supervised the construction site w...             Foreman
# 202  The new functionality was implemented through ...      Daughter board
# 192  The network’s demilitarized zone protects inte...  Demilitarized zone
# 16   The white box testing method allows developers...           White box
# 77   A quick sanity test revealed several issues in...         Sanity test
# 168  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 128  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 89   The team opted for mob programming to tackle t...     Mob programming
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 120  The yellow team focused on optimizing the soft...         Yellow team
# 127  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 118  The white team oversaw the cyber exercise and ...          White team
# 121  The yellow team focused on optimizing the soft...         Yellow team
# 201  The new functionality was implemented through ...      Daughter board
# 193  The network’s demilitarized zone protects inte...  Demilitarized zone
# 203  The new functionality was implemented through ...      Daughter board
# 76   A quick sanity test revealed several issues in...         Sanity test
# 79   Developers use a dummy value as a placeholder ...         Dummy value
# 52   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 45   The master database contains all the key recor...              Master
# 112  The web master updated the website’s layout fo...          Web master
# 107  The web master updated the website’s layout fo...              Master
# 167  The chairman called for a vote on the proposed...            Chairman
# 122  The yellow team focused on optimizing the soft...         Yellow team
# 125  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 46   The master database contains all the key recor...              Master
# 21   A white hat hacker helped identify security vu...           White hat
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 104  The red team simulated an attack to test the o...            Red team
# 126  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 191  The network’s demilitarized zone protects inte...  Demilitarized zone
# 15   The white box testing method allows developers...           White box
# 70   Before deploying the code, we need to perform ...        Sanity check
# 96   A blackout period was enforced during the syst...     Blackout period
# 117  The white team oversaw the cyber exercise and ...          White team
# 157  His desk organization reflects a hint of OCD t...                 OCD
# 200  The application tends to hang when handling la...                Hang
# 78   Developers use a dummy value as a placeholder ...         Dummy value
# 106  The red team simulated an attack to test the o...            Red team
# 80   Developers use a dummy value as a placeholder ...         Dummy value
# 43   The master database contains all the key recor...              Master
# 22   A white hat hacker helped identify security vu...           White hat
# 110  The web master updated the website’s layout fo...              Master
# 113  The web master updated the website’s layout fo...          Web master
# 190  The project required significant manpower to c...            Manpower
# 37   She was responsible for coordinating the team’...                 She
# 105  The red team simulated an attack to test the o...            Red team
# 153  The plan was considered crazy but turned out t...               Crazy
# 42   His programming skills greatly improved the pr...                 His
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 180        The crew mans the ship during long voyages.                Mans
# 135  Changes were merged into the master branch for...              Master
# 34   The cable is equipped with a male connector fo...      Male connector
# 156  His desk organization reflects a hint of OCD t...                 OCD
# 108  The web master updated the website’s layout fo...              Master
# 49   The secondary system operates as a slave to th...               Slave
# 81   Developers use a dummy value as a placeholder ...         Dummy value
# 17   The white box testing method allows developers...           White box
# 179        The crew mans the ship during long voyages.                Mans
# 111  The web master updated the website’s layout fo...          Web master
# 68   Before deploying the code, we need to perform ...        Sanity check
# 116  The designer added white space to improve the ...         White space
# 39   The credit for the innovative design is entire...                Hers
# 50   The secondary system operates as a slave to th...               Slave
# 38   Her contribution to the discussion was insight...                 Her
# 27   Only pre-approved devices are included in the ...           Whitelist
# 33   The cable is equipped with a male connector fo...      Male connector
# 152  The plan was considered crazy but turned out t...               Crazy
# 150  The plan was considered crazy but turned out t...               Crazy
# 51   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 119  The white team oversaw the cyber exercise and ...          White team
# 154  The plan was considered crazy but turned out t...               Crazy
# 69   Before deploying the code, we need to perform ...        Sanity check
# 44   The master database contains all the key recor...              Master
# 151  The plan was considered crazy but turned out t...               Crazy
# 208  The cleanup script removed the orphaned object...     Orphaned object
# 109  The web master updated the website’s layout fo...              Master
# 187  The project required significant manpower to c...            Manpower
# 155  His desk organization reflects a hint of OCD t...                 His
# 54   The older software was grandfathered in despit...       Grandfathered
# 48   The secondary system operates as a slave to th...               Slave
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 198  The application tends to hang when handling la...                Hang
# 134  Changes were merged into the master branch for...              Master
# 102  The app includes a native feature for photo ed...              Native
# 28   Only pre-approved devices are included in the ...           Whitelist
# 14   The algorithm functions as a black box, with n...           Black box
# 56   The older software was grandfathered in despit...       Grandfathered
# 40   He led the presentation with confidence and cl...                  He
# 178        The crew mans the ship during long voyages.                Mans
# 188  The project required significant manpower to c...            Manpower
# 146  The venue was upgraded to be accessible for ha...         Handicapped
# 3    The program will automatically abort if a crit...               Abort
# 47   The secondary system operates as a slave to th...               Slave
# 132  Changes were merged into the master branch for...              Master
# 138  Changes were merged into the master branch for...       Master branch
# 174  Man has always sought to understand the universe.                 Man
# 86   The scrum master facilitated the daily stand-u...        Scrum master
# 55   The older software was grandfathered in despit...       Grandfathered
# 189  The project required significant manpower to c...            Manpower
# 173  Man has always sought to understand the universe.                 Man
# 41    The team assigned the most critical task to him.                 Him
# 26   Only pre-approved devices are included in the ...           Whitelist
# 115  The designer added white space to improve the ...         White space
# 166  The chairman called for a vote on the proposed...            Chairman
# 137  Changes were merged into the master branch for...       Master branch
# 131  The man-in-the-middle attack intercepted sensi...                 Man
# 209  The cleanup script removed the orphaned object...     Orphaned object
# 13   The algorithm functions as a black box, with n...           Black box
# 74   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 1    The program will automatically abort if a crit...               Abort
# 114  The designer added white space to improve the ...         White space
# 207  The cleanup script removed the orphaned object...     Orphaned object
# 29   The paper underwent a blind review process to ...               Blind
# 197  The application tends to hang when handling la...                Hang
# 103  The app includes a native feature for photo ed...              Native
# 12   The algorithm functions as a black box, with n...           Black box
# 73   A quick sanity test revealed several issues in...         Sanity test
# 67   Completing the project required 100 man hours ...                 Man
# 144  The system is back to normal after resolving t...              Normal
# 75   A quick sanity test revealed several issues in...         Sanity test
# 204  The adapter functions as a gender bender for c...       Gender bender
# 2    The program will automatically abort if a crit...               Abort
# 82   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 85   The scrum master facilitated the daily stand-u...              Master
# 25   The IP address was added to the company’s blac...           Blacklist
# 53   The older software was grandfathered in despit...       Grandfathered
# 92   The system’s segregation of duties ensures sec...         Segregation
# 184  The reservoir is a manmade structure designed ...             Manmade
# 133  Changes were merged into the master branch for...              Master
# 136  Changes were merged into the master branch for...       Master branch
# 130  The man-in-the-middle attack intercepted sensi...                 Man
# 91   The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 93   The system’s segregation of duties ensures sec...         Segregation
# 11   The app is designed to be intuitive for the av...        Average user
# 177  Mankind has made significant strides in techno...             Mankind
# 205  The adapter functions as a gender bender for c...       Gender bender
# 140  Efforts to promote diversity aim to amplify th...            Minority
# 31   The experiment was conducted under double-blin...               Blind
# 83   The scrum master facilitated the daily stand-u...              Master
# 139  Efforts to promote diversity aim to amplify th...            Minority
# 199  The application tends to hang when handling la...                Hang
# 100  The app includes a native feature for photo ed...              Native
# 23   The IP address was added to the company’s blac...           Blacklist
# 24   The IP address was added to the company’s blac...           Blacklist
# 5    The user chose to terminate the installation p...           Terminate
# 64   Completing the project required 100 man hours ...           Man hours
# 185  The reservoir is a manmade structure designed ...             Manmade
# 123  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 129  The man-in-the-middle attack intercepted sensi...                 Man
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 141  Efforts to promote diversity aim to amplify th...            Minority
# 84   The scrum master facilitated the daily stand-u...              Master
# 165  The chairman called for a vote on the proposed...            Chairman
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The app includes a native feature for photo ed...              Native
# 7    The user chose to terminate the installation p...           Terminate
# 59   Hey guys, let’s gather for the meeting in five...                Guys
# 142  The system is back to normal after resolving t...              Normal
# 63   Completing the project required 100 man hours ...           Man hours
# 186  The reservoir is a manmade structure designed ...             Manmade
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 8    The app is designed to be intuitive for the av...        Average user
# 143  The system is back to normal after resolving t...              Normal
# 60   Hey guys, let’s gather for the meeting in five...                Guys
# 145  The system is back to normal after resolving t...              Normal
# 147  The venue was upgraded to be accessible for ha...         Handicapped
# 90   The system’s segregation of duties ensures sec...         Segregation
# 66   Completing the project required 100 man hours ...                 Man
# 175  Mankind has made significant strides in techno...             Mankind
# 65   Completing the project required 100 man hours ...                 Man
# 61   Completing the project required 100 man hours ...           Man hours
# 6    The user chose to terminate the installation p...           Terminate
# 57   Hey guys, let’s gather for the meeting in five...                Guys
# 62   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 58   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                       Replacement  \
# 19               Unethical hacker
# 161             Team contribution
# 18                Malicious actor
# 163          Collaborative spirit
# 35           Receptacle connector
# 20                       Attacker
# 87            Project facilitator
# 94             Maintenance window
# 30              Anonymized review
# 36               Socket connector
# 98     Actor with unclear motives
# 72                     Smoke test
# 97                Ambiguous actor
# 206             Connector adapter
# 99          Semi-authorized actor
# 195               Screened subnet
# 196              Isolated network
# 88           Ensemble programming
# 194             Perimeter network
# 95                       Downtime
# 71                Confidence test
# 32              Anonymized review
# 164                 Shared values
# 170                     Team lead
# 124                 First Peoples
# 169                    Supervisor
# 171               Site supervisor
# 202                  Add-on board
# 192               Screened subnet
# 16                      Glass box
# 77                     Smoke test
# 168                   Coordinator
# 158               Detail-oriented
# 159                       Orderly
# 128                  Relay attack
# 89      Collaborative programming
# 162              Values alignment
# 120    Security optimization team
# 127          Eavesdropping attack
# 118               Moderation team
# 121              Performance team
# 201               Expansion board
# 193              Isolated network
# 203               Secondary board
# 76                Confidence test
# 79                   Sample value
# 52            Quantum preeminence
# 45                         Leader
# 112                      Web lead
# 107                       Primary
# 167             Presiding officer
# 122      Team [Specific Function]
# 125                      Original
# 46                     Controller
# 21                 Ethical hacker
# 160                          Neat
# 104         Security testing team
# 126           Intermediary attack
# 191             Perimeter network
# 15                Transparent box
# 70                  Initial check
# 96                  Outage period
# 117                Oversight team
# 157                     Organized
# 200                Become blocked
# 78              Placeholder value
# 106        Attack simulation team
# 80                  Example value
# 43                        Primary
# 22            Security researcher
# 110                    Controller
# 113            Website maintainer
# 190                  Team members
# 37                           They
# 105       Offensive security team
# 153                    Innovative
# 42                         Theirs
# 182          Sales representative
# 180                      Operates
# 135                    Controller
# 34                  Pin connector
# 156                    Meticulous
# 108                          Main
# 49                       Follower
# 81                     Test value
# 17                       Open box
# 179                        Staffs
# 111             Web administrator
# 68                    Quick check
# 116                       Padding
# 39                         Theirs
# 50                          Agent
# 38                           Them
# 27                       Passlist
# 33                 Plug connector
# 152                    Surprising
# 150                Unconventional
# 51              Quantum advantage
# 119                  Control team
# 154                    Remarkable
# 69                    Basic check
# 44                           Main
# 151                    Unexpected
# 208               Unlinked object
# 109                        Leader
# 187                      Staffing
# 155                        Theirs
# 54                Retained status
# 48                        Replica
# 181                   Salesperson
# 198           Become unresponsive
# 134                        Leader
# 102                       Default
# 28                 Inclusion list
# 14           Undocumented process
# 56            Previously approved
# 40                           They
# 178                         Crews
# 188                     Workforce
# 146                    Accessible
# 3                       Interrupt
# 47                      Secondary
# 132                       Primary
# 138                Primary branch
# 174                      Humanity
# 86              Scrum facilitator
# 55   Exempt under previous policy
# 189                     Personnel
# 173                        People
# 41                           Them
# 26                      Allowlist
# 115                Negative space
# 166                         Chair
# 137                Default branch
# 131                      Humanity
# 209               Detached object
# 13            Non-transparent box
# 74                     Basic test
# 0                          Cancel
# 1                            Halt
# 114                       Spacing
# 207           Unreferenced object
# 29                 Blinded review
# 197                        Freeze
# 103             Platform-specific
# 12                     Opaque box
# 73                     Quick test
# 67                       Humanity
# 144                      Standard
# 75                   Initial test
# 204                Gender changer
# 2                            Stop
# 82                        Primary
# 172                     Humankind
# 85                     Controller
# 25                 Exclusion list
# 53                  Legacy status
# 92           Compartmentalization
# 184                    Engineered
# 133                          Main
# 136                   Main branch
# 130                        People
# 91                      Isolation
# 9                   Standard user
# 183                     Synthetic
# 93                    Distinction
# 11                  Intended user
# 177                        People
# 205                Gender adapter
# 140            Marginalized group
# 31                 Blinded review
# 83                           Main
# 139        Underrepresented group
# 199                         Stall
# 100                      Built-in
# 23                       Denylist
# 24                      Blocklist
# 5                           Close
# 64                    Staff hours
# 185                    Artificial
# 123                    Indigenous
# 129                     Humankind
# 149       Users with disabilities
# 141    Specific demographic group
# 84                         Leader
# 165                   Chairperson
# 10                   General user
# 101                      Inherent
# 7                          Finish
# 59                           Team
# 142                       Typical
# 63                    Labor hours
# 186                   Constructed
# 148     Persons with disabilities
# 8                    Typical user
# 143                      Expected
# 60                         People
# 145                       Regular
# 147      People with disabilities
# 90                     Separation
# 66                         People
# 175                     Humankind
# 65                      Humankind
# 61                   Person-hours
# 6                            Stop
# 57                       Everyone
# 62                     Work hours
# 176                      Humanity
# 58                          Folks
# 4                             End
#
#                                      Modified Sentence  Similarity Score
# 19   The company detected a Unethical hacker attemp...          0.584426
# 161  The company prioritizes Team contribution when...          0.606165
# 18   The company detected a Malicious actor attempt...          0.610877
# 163  The company prioritizes Collaborative spirit w...          0.626185
# 35   The Receptacle connector allows for easy integ...          0.627351
# 20   The company detected a Attacker attempting to ...          0.638441
# 87   The Project facilitator facilitated the daily ...          0.642606
# 94   A Maintenance window was enforced during the s...          0.658593
# 30   The paper underwent a Anonymized review review...          0.661169
# 36   The Socket connector allows for easy integrati...          0.679458
# 98   The Actor with unclear motives hacker reported...          0.682887
# 72   Before deploying the code, we need to perform ...          0.690537
# 97   The Ambiguous actor hacker reported the vulner...          0.696217
# 206  The adapter functions as a Connector adapter f...          0.703491
# 99   The Semi-authorized actor hacker reported the ...          0.706695
# 195  The server operates within the Screened subnet...          0.715793
# 196  The server operates within the Isolated networ...          0.718277
# 88   The team opted for Ensemble programming to tac...          0.721668
# 194  The server operates within the Perimeter netwo...          0.728124
# 95   A Downtime was enforced during the system upgr...          0.728261
# 71   Before deploying the code, we need to perform ...          0.728782
# 32   The experiment was conducted under double-Anon...          0.731766
# 164  The company prioritizes Shared values when hir...          0.734874
# 170  The Team lead supervised the construction site...          0.734928
# 124  The land’s history is deeply rooted in First P...          0.736355
# 169  The Supervisor supervised the construction sit...          0.744094
# 171  The Site supervisor supervised the constructio...          0.745977
# 202  The new functionality was implemented through ...          0.754634
# 192  The network’s Screened subnet protects interna...          0.755507
# 16   The Glass box testing method allows developers...          0.759352
# 77   A quick Smoke test revealed several issues in ...          0.760604
# 168  The Coordinator called for a vote on the propo...          0.761286
# 158  His desk organization reflects a hint of Detai...          0.762296
# 159  His desk organization reflects a hint of Order...          0.771285
# 128  The Relay attack attack intercepted sensitive ...          0.777748
# 89   The team opted for Collaborative programming t...          0.777778
# 162  The company prioritizes Values alignment when ...          0.778899
# 120  The Security optimization team focused on opti...          0.783778
# 127  The Eavesdropping attack attack intercepted se...          0.785670
# 118  The Moderation team oversaw the cyber exercise...          0.785924
# 121  The Performance team focused on optimizing the...          0.787735
# 201  The new functionality was implemented through ...          0.787963
# 193  The network’s Isolated network protects intern...          0.788988
# 203  The new functionality was implemented through ...          0.790100
# 76   A quick Confidence test revealed several issue...          0.790785
# 79   Developers use a Sample value as a placeholder...          0.795430
# 52   Achieving Quantum preeminence marks a signific...          0.801404
# 45   The Leader database contains all the key recor...          0.805919
# 112  The Web lead updated the website’s layout for ...          0.809284
# 107  The web Primary updated the website’s layout f...          0.810848
# 167  The Presiding officer called for a vote on the...          0.812963
# 122  The Team [Specific Function] focused on optimi...          0.814945
# 125  The land’s history is deeply rooted in Origina...          0.814958
# 46   The Controller database contains all the key r...          0.816892
# 21   A Ethical hacker hacker helped identify securi...          0.817126
# 160  His desk organization reflects a hint of Neat ...          0.819068
# 104  The Security testing team simulated an attack ...          0.819837
# 126  The Intermediary attack attack intercepted sen...          0.824432
# 191  The network’s Perimeter network protects inter...          0.824664
# 15   The Transparent box testing method allows deve...          0.825408
# 70   Before deploying the code, we need to perform ...          0.825560
# 96   A Outage period was enforced during the system...          0.825777
# 117  The Oversight team oversaw the cyber exercise ...          0.826038
# 157  His desk organization reflects a hint of Organ...          0.827162
# 200  The application tends to Become blocked when h...          0.828610
# 78   Developers use a Placeholder value as a placeh...          0.829454
# 106  The Attack simulation team simulated an attack...          0.829734
# 80   Developers use a Example value as a placeholde...          0.831063
# 43   The Primary database contains all the key reco...          0.832613
# 22   A Security researcher hacker helped identify s...          0.832633
# 110  The web Controller updated the website’s layou...          0.833191
# 113  The Website maintainer updated the website’s l...          0.833405
# 190  The project required significant Team members ...          0.833890
# 37   They was responsible for coordinating the team...          0.836792
# 105  The Offensive security team simulated an attac...          0.838205
# 153  The plan was considered Innovative but turned ...          0.840000
# 42   Theirs programming skills greatly improved the...          0.840863
# 182  The Sales representative demonstrated the prod...          0.842884
# 180    The crew Operates the ship during long voyages.          0.843587
# 135  Changes were merged into the Controller branch...          0.844265
# 34   The cable is equipped with a Pin connector for...          0.844309
# 156  His desk organization reflects a hint of Metic...          0.844329
# 108  The web Main updated the website’s layout for ...          0.845296
# 49   The secondary system operates as a Follower to...          0.849255
# 81   Developers use a Test value as a placeholder d...          0.850563
# 17   The Open box testing method allows developers ...          0.850860
# 179      The crew Staffs the ship during long voyages.          0.851084
# 111  The Web administrator updated the website’s la...          0.852008
# 68   Before deploying the code, we need to perform ...          0.854385
# 116  The designer added Padding to improve the page...          0.855119
# 39   The credit for the innovative design is entire...          0.856372
# 50   The secondary system operates as a Agent to th...          0.857448
# 38   Them contribution to the discussion was insigh...          0.857843
# 27   Only pre-approved devices are included in the ...          0.859077
# 33   The cable is equipped with a Plug connector fo...          0.860130
# 152  The plan was considered Surprising but turned ...          0.861411
# 150  The plan was considered Unconventional but tur...          0.867457
# 51   Achieving Quantum advantage marks a significan...          0.867519
# 119  The Control team oversaw the cyber exercise an...          0.867743
# 154  The plan was considered Remarkable but turned ...          0.869086
# 69   Before deploying the code, we need to perform ...          0.870917
# 44   The Main database contains all the key records...          0.872235
# 151  The plan was considered Unexpected but turned ...          0.874205
# 208  The cleanup script removed the Unlinked object...          0.875080
# 109  The web Leader updated the website’s layout fo...          0.876580
# 187  The project required significant Staffing to c...          0.876994
# 155  Theirs desk organization reflects a hint of OC...          0.877313
# 54   The older software was Retained status in desp...          0.877785
# 48   The secondary system operates as a Replica to ...          0.877979
# 181  The Salesperson demonstrated the product’s key...          0.878644
# 198  The application tends to Become unresponsive w...          0.879780
# 134  Changes were merged into the Leader branch for...          0.880295
# 102  The app includes a Default feature for photo e...          0.880555
# 28   Only pre-approved devices are included in the ...          0.882783
# 14   The algorithm functions as a Undocumented proc...          0.883828
# 56   The older software was Previously approved in ...          0.886144
# 40   They led the presentation with confidence and ...          0.886162
# 178       The crew Crews the ship during long voyages.          0.887521
# 188  The project required significant Workforce to ...          0.888754
# 146  The venue was upgraded to be accessible for Ac...          0.891089
# 3    The program will automatically Interrupt if a ...          0.891834
# 47   The secondary system operates as a Secondary t...          0.892284
# 132  Changes were merged into the Primary branch fo...          0.894577
# 138  Changes were merged into the Primary branch fo...          0.894577
# 174  Humanity has always sought to understand the u...          0.895734
# 86   The Scrum facilitator facilitated the daily st...          0.895948
# 55   The older software was Exempt under previous p...          0.897570
# 189  The project required significant Personnel to ...          0.898788
# 173  People has always sought to understand the uni...          0.899577
# 41   The team assigned the most critical task to Them.          0.900533
# 26   Only pre-approved devices are included in the ...          0.901145
# 115  The designer added Negative space to improve t...          0.902180
# 166  The Chair called for a vote on the proposed ch...          0.903277
# 137  Changes were merged into the Default branch fo...          0.905802
# 131  The Humanity-in-the-middle attack intercepted ...          0.906904
# 209  The cleanup script removed the Detached object...          0.907230
# 13   The algorithm functions as a Non-transparent b...          0.907371
# 74   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 1    The program will automatically Halt if a criti...          0.909458
# 114  The designer added Spacing to improve the page...          0.910357
# 207  The cleanup script removed the Unreferenced ob...          0.911102
# 29   The paper underwent a Blinded review review pr...          0.913216
# 197  The application tends to Freeze when handling ...          0.914745
# 103  The app includes a Platform-specific feature f...          0.917282
# 12   The algorithm functions as a Opaque box, with ...          0.917817
# 73   A quick Quick test revealed several issues in ...          0.918039
# 67   Completing the project required 100 Humanity h...          0.920907
# 144  The system is back to Standard after resolving...          0.921492
# 75   A quick Initial test revealed several issues i...          0.921538
# 204  The adapter functions as a Gender changer for ...          0.922449
# 2    The program will automatically Stop if a criti...          0.922640
# 82   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 85   The scrum Controller facilitated the daily sta...          0.925107
# 25   The IP address was added to the company’s Excl...          0.925768
# 53   The older software was Legacy status in despit...          0.925821
# 92   The system’s Compartmentalization of duties en...          0.926073
# 184  The reservoir is a Engineered structure design...          0.928353
# 133  Changes were merged into the Main branch for d...          0.928553
# 136  Changes were merged into the Main branch for d...          0.928553
# 130  The People-in-the-middle attack intercepted se...          0.929361
# 91   The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 93   The system’s Distinction of duties ensures sec...          0.930267
# 11   The app is designed to be intuitive for the In...          0.930680
# 177  People has made significant strides in technol...          0.931211
# 205  The adapter functions as a Gender adapter for ...          0.931559
# 140  Efforts to promote diversity aim to amplify th...          0.931869
# 31   The experiment was conducted under double-Blin...          0.931959
# 83   The scrum Main facilitated the daily stand-up ...          0.932176
# 139  Efforts to promote diversity aim to amplify th...          0.932201
# 199  The application tends to Stall when handling l...          0.935331
# 100  The app includes a Built-in feature for photo ...          0.937234
# 23   The IP address was added to the company’s Deny...          0.937353
# 24   The IP address was added to the company’s Bloc...          0.937636
# 5    The user chose to Close the installation proce...          0.937832
# 64   Completing the project required 100 Staff hour...          0.937897
# 185  The reservoir is a Artificial structure design...          0.939255
# 123  The land’s history is deeply rooted in Indigen...          0.939329
# 129  The Humankind-in-the-middle attack intercepted...          0.940031
# 149  The venue was upgraded to be accessible for Us...          0.940271
# 141  Efforts to promote diversity aim to amplify th...          0.941738
# 84   The scrum Leader facilitated the daily stand-u...          0.942709
# 165  The Chairperson called for a vote on the propo...          0.943595
# 10   The app is designed to be intuitive for the Ge...          0.944776
# 101  The app includes a Inherent feature for photo ...          0.945201
# 7    The user chose to Finish the installation proc...          0.948518
# 59   Hey Team, let’s gather for the meeting in five...          0.950417
# 142  The system is back to Typical after resolving ...          0.950920
# 63   Completing the project required 100 Labor hour...          0.951819
# 186  The reservoir is a Constructed structure desig...          0.953625
# 148  The venue was upgraded to be accessible for Pe...          0.954317
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 143  The system is back to Expected after resolving...          0.956891
# 60   Hey People, let’s gather for the meeting in fi...          0.957925
# 145  The system is back to Regular after resolving ...          0.958380
# 147  The venue was upgraded to be accessible for Pe...          0.958386
# 90   The system’s Separation of duties ensures secu...          0.958804
# 66   Completing the project required 100 People hou...          0.959826
# 175  Humankind has made significant strides in tech...          0.961535
# 65   Completing the project required 100 Humankind ...          0.962538
# 61   Completing the project required 100 Person-hou...          0.963118
# 6    The user chose to Stop the installation proces...          0.964866
# 57   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 62   Completing the project required 100 Work hours...          0.965177
# 176  Humanity has made significant strides in techn...          0.968785
# 58   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2_Reasoning-1_replacements.csv", index=False)

# %%
# PROMPT 1:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Halt", "Stop", "Interrupt"],
    "Terminate": ["End", "Close", "Stop", "Finish"],
    "Average user": ["Typical user", "Standard user", "General user", "Intended user"],
    "Black box": ["Opaque box", "Non-transparent box", "Undocumented process"],
    "White box": ["Transparent box", "Glass box", "Open box"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Attacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Passlist", "Inclusion list"],
    "Blind": ["Blinded review", "Anonymized review"],
    "Double blind": ["Double-blinded review", "Fully anonymized review", "Independent review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Receptacle connector", "Socket connector"],
    "She": ["They"],
    "Her": ["They"],
    "Hers": ["Theirs"],
    "He": ["They"],
    "Him": ["Them"],
    "His": ["Theirs"],
    "Master": ["Primary", "Main", "Leader", "Controller"],
    "Slave": ["Secondary", "Replica", "Follower", "Agent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum preeminence"],
    "Grandfathered": ["Legacy status", "Retained status", "Exempt under previous policy", "Previously approved"],
    "Guys": ["Everyone", "Folks", "Team", "People"],
    "Man hours": ["Person-hours", "Work hours", "Labor hours", "Staff hours"],
    "Sanity check": ["Quick check", "Basic check", "Initial check", "Confidence test", "Smoke test"],
    "Sanity test": ["Quick test", "Basic test", "Initial test", "Confidence test", "Smoke test"],
    "Dummy value": ["Placeholder value", "Sample value", "Example value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Project facilitator"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Compartmentalization", "Distinction"],
    "Blackout period": ["Maintenance window", "Downtime", "Outage period"],
    "Gray hat": ["Ambiguous actor", "Actor with unclear motives", "Semi-authorized actor"],
    "Native": ["Built-in", "Inherent", "Default", "Platform-specific"],
    "Red team": ["Security testing team", "Offensive security team", "Attack simulation team"],
    "Web master": ["Web administrator", "Web lead", "Website maintainer"],
    "White space": ["Spacing", "Negative space", "Padding"],
    "White team": ["Oversight team", "Moderation team", "Control team"],
    "Yellow team": ["Security optimization team", "Performance team", "Team [Specific Function]"],
    "Aboriginal": ["Indigenous", "First Peoples", "Original"],
    "Brown bags": ["Informal learning session", "Lunch and learn session", "Knowledge sharing session"],
    "First-class citizen": ["Primary citizen", "Essential citizen", "Core component", "Fundamental element"],
    "Man-in-the-middle": ["Intermediary attack", "Eavesdropping attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch", "Primary branch"],
    "Minority": ["Underrepresented group", "Marginalized group", "Specific demographic group"],
    "Normal": ["Typical", "Expected", "Standard", "Regular"],
    "Handicapped": ["Accessible", "People with disabilities", "Persons with disabilities", "Users with disabilities"],
    "Crazy": ["Unconventional", "Unexpected", "Surprising", "Innovative", "Remarkable"],
    "OCD": ["Meticulous", "Organized", "Detail-oriented", "Orderly", "Neat"],
    "Culture fit": ["Team contribution", "Values alignment", "Collaborative spirit", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Presiding officer", "Coordinator"],
    "Foreman": ["Supervisor", "Team lead", "Site supervisor"],
    "Man": ["Humankind", "People", "Humanity"],
    "Mankind": ["Humankind", "Humanity", "People"],
    "Mans": ["Crews", "Staffs", "Operates"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Synthetic", "Engineered", "Artificial", "Constructed"],
    "Manpower": ["Staffing", "Workforce", "Personnel", "Team members"],
    "Demilitarized zone": ["Perimeter network", "Screened subnet", "Isolated network"],
    "DMZ": ["Perimeter network", "Screened subnet", "Isolated network"],
    "Hang": ["Freeze", "Become unresponsive", "Stall", "Become blocked"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Gender changer", "Gender adapter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Unlinked object", "Detached object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 19   The company detected a black hat attempting to...           Black hat
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 18   The company detected a black hat attempting to...           Black hat
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 35   The female connector allows for easy integrati...    Female connector
# 20   The company detected a black hat attempting to...           Black hat
# 87   The scrum master facilitated the daily stand-u...        Scrum master
# 94   A blackout period was enforced during the syst...     Blackout period
# 30   The paper underwent a blind review process to ...               Blind
# 36   The female connector allows for easy integrati...    Female connector
# 98   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 72   Before deploying the code, we need to perform ...        Sanity check
# 97   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 206  The adapter functions as a gender bender for c...       Gender bender
# 99   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 195  The server operates within the DMZ for added s...                 DMZ
# 196  The server operates within the DMZ for added s...                 DMZ
# 88   The team opted for mob programming to tackle t...     Mob programming
# 194  The server operates within the DMZ for added s...                 DMZ
# 95   A blackout period was enforced during the syst...     Blackout period
# 71   Before deploying the code, we need to perform ...        Sanity check
# 32   The experiment was conducted under double-blin...               Blind
# 164  The company prioritizes culture fit when hirin...         Culture fit
# 170  The foreman supervised the construction site w...             Foreman
# 124  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 169  The foreman supervised the construction site w...             Foreman
# 171  The foreman supervised the construction site w...             Foreman
# 202  The new functionality was implemented through ...      Daughter board
# 192  The network’s demilitarized zone protects inte...  Demilitarized zone
# 16   The white box testing method allows developers...           White box
# 77   A quick sanity test revealed several issues in...         Sanity test
# 168  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 128  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 89   The team opted for mob programming to tackle t...     Mob programming
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 120  The yellow team focused on optimizing the soft...         Yellow team
# 127  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 118  The white team oversaw the cyber exercise and ...          White team
# 121  The yellow team focused on optimizing the soft...         Yellow team
# 201  The new functionality was implemented through ...      Daughter board
# 193  The network’s demilitarized zone protects inte...  Demilitarized zone
# 203  The new functionality was implemented through ...      Daughter board
# 76   A quick sanity test revealed several issues in...         Sanity test
# 79   Developers use a dummy value as a placeholder ...         Dummy value
# 52   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 45   The master database contains all the key recor...              Master
# 112  The web master updated the website’s layout fo...          Web master
# 107  The web master updated the website’s layout fo...              Master
# 167  The chairman called for a vote on the proposed...            Chairman
# 122  The yellow team focused on optimizing the soft...         Yellow team
# 125  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 46   The master database contains all the key recor...              Master
# 21   A white hat hacker helped identify security vu...           White hat
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 104  The red team simulated an attack to test the o...            Red team
# 126  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 191  The network’s demilitarized zone protects inte...  Demilitarized zone
# 15   The white box testing method allows developers...           White box
# 70   Before deploying the code, we need to perform ...        Sanity check
# 96   A blackout period was enforced during the syst...     Blackout period
# 117  The white team oversaw the cyber exercise and ...          White team
# 157  His desk organization reflects a hint of OCD t...                 OCD
# 200  The application tends to hang when handling la...                Hang
# 78   Developers use a dummy value as a placeholder ...         Dummy value
# 106  The red team simulated an attack to test the o...            Red team
# 80   Developers use a dummy value as a placeholder ...         Dummy value
# 43   The master database contains all the key recor...              Master
# 22   A white hat hacker helped identify security vu...           White hat
# 110  The web master updated the website’s layout fo...              Master
# 113  The web master updated the website’s layout fo...          Web master
# 190  The project required significant manpower to c...            Manpower
# 37   She was responsible for coordinating the team’...                 She
# 105  The red team simulated an attack to test the o...            Red team
# 153  The plan was considered crazy but turned out t...               Crazy
# 42   His programming skills greatly improved the pr...                 His
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 180        The crew mans the ship during long voyages.                Mans
# 135  Changes were merged into the master branch for...              Master
# 34   The cable is equipped with a male connector fo...      Male connector
# 156  His desk organization reflects a hint of OCD t...                 OCD
# 108  The web master updated the website’s layout fo...              Master
# 49   The secondary system operates as a slave to th...               Slave
# 81   Developers use a dummy value as a placeholder ...         Dummy value
# 17   The white box testing method allows developers...           White box
# 179        The crew mans the ship during long voyages.                Mans
# 111  The web master updated the website’s layout fo...          Web master
# 68   Before deploying the code, we need to perform ...        Sanity check
# 116  The designer added white space to improve the ...         White space
# 39   The credit for the innovative design is entire...                Hers
# 50   The secondary system operates as a slave to th...               Slave
# 27   Only pre-approved devices are included in the ...           Whitelist
# 38   Her contribution to the discussion was insight...                 Her
# 33   The cable is equipped with a male connector fo...      Male connector
# 152  The plan was considered crazy but turned out t...               Crazy
# 150  The plan was considered crazy but turned out t...               Crazy
# 51   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 119  The white team oversaw the cyber exercise and ...          White team
# 154  The plan was considered crazy but turned out t...               Crazy
# 69   Before deploying the code, we need to perform ...        Sanity check
# 44   The master database contains all the key recor...              Master
# 151  The plan was considered crazy but turned out t...               Crazy
# 208  The cleanup script removed the orphaned object...     Orphaned object
# 109  The web master updated the website’s layout fo...              Master
# 187  The project required significant manpower to c...            Manpower
# 155  His desk organization reflects a hint of OCD t...                 His
# 54   The older software was grandfathered in despit...       Grandfathered
# 48   The secondary system operates as a slave to th...               Slave
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 198  The application tends to hang when handling la...                Hang
# 134  Changes were merged into the master branch for...              Master
# 102  The app includes a native feature for photo ed...              Native
# 28   Only pre-approved devices are included in the ...           Whitelist
# 14   The algorithm functions as a black box, with n...           Black box
# 56   The older software was grandfathered in despit...       Grandfathered
# 40   He led the presentation with confidence and cl...                  He
# 178        The crew mans the ship during long voyages.                Mans
# 188  The project required significant manpower to c...            Manpower
# 146  The venue was upgraded to be accessible for ha...         Handicapped
# 3    The program will automatically abort if a crit...               Abort
# 47   The secondary system operates as a slave to th...               Slave
# 132  Changes were merged into the master branch for...              Master
# 138  Changes were merged into the master branch for...       Master branch
# 174  Man has always sought to understand the universe.                 Man
# 86   The scrum master facilitated the daily stand-u...        Scrum master
# 55   The older software was grandfathered in despit...       Grandfathered
# 189  The project required significant manpower to c...            Manpower
# 173  Man has always sought to understand the universe.                 Man
# 41    The team assigned the most critical task to him.                 Him
# 26   Only pre-approved devices are included in the ...           Whitelist
# 115  The designer added white space to improve the ...         White space
# 166  The chairman called for a vote on the proposed...            Chairman
# 137  Changes were merged into the master branch for...       Master branch
# 131  The man-in-the-middle attack intercepted sensi...                 Man
# 209  The cleanup script removed the orphaned object...     Orphaned object
# 13   The algorithm functions as a black box, with n...           Black box
# 74   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 1    The program will automatically abort if a crit...               Abort
# 114  The designer added white space to improve the ...         White space
# 207  The cleanup script removed the orphaned object...     Orphaned object
# 29   The paper underwent a blind review process to ...               Blind
# 197  The application tends to hang when handling la...                Hang
# 103  The app includes a native feature for photo ed...              Native
# 12   The algorithm functions as a black box, with n...           Black box
# 73   A quick sanity test revealed several issues in...         Sanity test
# 67   Completing the project required 100 man hours ...                 Man
# 144  The system is back to normal after resolving t...              Normal
# 75   A quick sanity test revealed several issues in...         Sanity test
# 204  The adapter functions as a gender bender for c...       Gender bender
# 2    The program will automatically abort if a crit...               Abort
# 82   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 85   The scrum master facilitated the daily stand-u...              Master
# 25   The IP address was added to the company’s blac...           Blacklist
# 53   The older software was grandfathered in despit...       Grandfathered
# 92   The system’s segregation of duties ensures sec...         Segregation
# 184  The reservoir is a manmade structure designed ...             Manmade
# 133  Changes were merged into the master branch for...              Master
# 136  Changes were merged into the master branch for...       Master branch
# 130  The man-in-the-middle attack intercepted sensi...                 Man
# 91   The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 93   The system’s segregation of duties ensures sec...         Segregation
# 11   The app is designed to be intuitive for the av...        Average user
# 177  Mankind has made significant strides in techno...             Mankind
# 205  The adapter functions as a gender bender for c...       Gender bender
# 140  Efforts to promote diversity aim to amplify th...            Minority
# 31   The experiment was conducted under double-blin...               Blind
# 83   The scrum master facilitated the daily stand-u...              Master
# 139  Efforts to promote diversity aim to amplify th...            Minority
# 199  The application tends to hang when handling la...                Hang
# 100  The app includes a native feature for photo ed...              Native
# 23   The IP address was added to the company’s blac...           Blacklist
# 24   The IP address was added to the company’s blac...           Blacklist
# 5    The user chose to terminate the installation p...           Terminate
# 64   Completing the project required 100 man hours ...           Man hours
# 185  The reservoir is a manmade structure designed ...             Manmade
# 123  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 129  The man-in-the-middle attack intercepted sensi...                 Man
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 141  Efforts to promote diversity aim to amplify th...            Minority
# 84   The scrum master facilitated the daily stand-u...              Master
# 165  The chairman called for a vote on the proposed...            Chairman
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The app includes a native feature for photo ed...              Native
# 7    The user chose to terminate the installation p...           Terminate
# 59   Hey guys, let’s gather for the meeting in five...                Guys
# 142  The system is back to normal after resolving t...              Normal
# 63   Completing the project required 100 man hours ...           Man hours
# 186  The reservoir is a manmade structure designed ...             Manmade
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 8    The app is designed to be intuitive for the av...        Average user
# 143  The system is back to normal after resolving t...              Normal
# 60   Hey guys, let’s gather for the meeting in five...                Guys
# 145  The system is back to normal after resolving t...              Normal
# 147  The venue was upgraded to be accessible for ha...         Handicapped
# 90   The system’s segregation of duties ensures sec...         Segregation
# 66   Completing the project required 100 man hours ...                 Man
# 175  Mankind has made significant strides in techno...             Mankind
# 65   Completing the project required 100 man hours ...                 Man
# 61   Completing the project required 100 man hours ...           Man hours
# 6    The user chose to terminate the installation p...           Terminate
# 57   Hey guys, let’s gather for the meeting in five...                Guys
# 62   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 58   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                       Replacement  \
# 19               Unethical hacker
# 161             Team contribution
# 18                Malicious actor
# 163          Collaborative spirit
# 35           Receptacle connector
# 20                       Attacker
# 87            Project facilitator
# 94             Maintenance window
# 30              Anonymized review
# 36               Socket connector
# 98     Actor with unclear motives
# 72                     Smoke test
# 97                Ambiguous actor
# 206             Connector adapter
# 99          Semi-authorized actor
# 195               Screened subnet
# 196              Isolated network
# 88           Ensemble programming
# 194             Perimeter network
# 95                       Downtime
# 71                Confidence test
# 32              Anonymized review
# 164                 Shared values
# 170                     Team lead
# 124                 First Peoples
# 169                    Supervisor
# 171               Site supervisor
# 202                  Add-on board
# 192               Screened subnet
# 16                      Glass box
# 77                     Smoke test
# 168                   Coordinator
# 158               Detail-oriented
# 159                       Orderly
# 128                  Relay attack
# 89      Collaborative programming
# 162              Values alignment
# 120    Security optimization team
# 127          Eavesdropping attack
# 118               Moderation team
# 121              Performance team
# 201               Expansion board
# 193              Isolated network
# 203               Secondary board
# 76                Confidence test
# 79                   Sample value
# 52            Quantum preeminence
# 45                         Leader
# 112                      Web lead
# 107                       Primary
# 167             Presiding officer
# 122      Team [Specific Function]
# 125                      Original
# 46                     Controller
# 21                 Ethical hacker
# 160                          Neat
# 104         Security testing team
# 126           Intermediary attack
# 191             Perimeter network
# 15                Transparent box
# 70                  Initial check
# 96                  Outage period
# 117                Oversight team
# 157                     Organized
# 200                Become blocked
# 78              Placeholder value
# 106        Attack simulation team
# 80                  Example value
# 43                        Primary
# 22            Security researcher
# 110                    Controller
# 113            Website maintainer
# 190                  Team members
# 37                           They
# 105       Offensive security team
# 153                    Innovative
# 42                         Theirs
# 182          Sales representative
# 180                      Operates
# 135                    Controller
# 34                  Pin connector
# 156                    Meticulous
# 108                          Main
# 49                       Follower
# 81                     Test value
# 17                       Open box
# 179                        Staffs
# 111             Web administrator
# 68                    Quick check
# 116                       Padding
# 39                         Theirs
# 50                          Agent
# 27                       Passlist
# 38                           They
# 33                 Plug connector
# 152                    Surprising
# 150                Unconventional
# 51              Quantum advantage
# 119                  Control team
# 154                    Remarkable
# 69                    Basic check
# 44                           Main
# 151                    Unexpected
# 208               Unlinked object
# 109                        Leader
# 187                      Staffing
# 155                        Theirs
# 54                Retained status
# 48                        Replica
# 181                   Salesperson
# 198           Become unresponsive
# 134                        Leader
# 102                       Default
# 28                 Inclusion list
# 14           Undocumented process
# 56            Previously approved
# 40                           They
# 178                         Crews
# 188                     Workforce
# 146                    Accessible
# 3                       Interrupt
# 47                      Secondary
# 132                       Primary
# 138                Primary branch
# 174                      Humanity
# 86              Scrum facilitator
# 55   Exempt under previous policy
# 189                     Personnel
# 173                        People
# 41                           Them
# 26                      Allowlist
# 115                Negative space
# 166                         Chair
# 137                Default branch
# 131                      Humanity
# 209               Detached object
# 13            Non-transparent box
# 74                     Basic test
# 0                          Cancel
# 1                            Halt
# 114                       Spacing
# 207           Unreferenced object
# 29                 Blinded review
# 197                        Freeze
# 103             Platform-specific
# 12                     Opaque box
# 73                     Quick test
# 67                       Humanity
# 144                      Standard
# 75                   Initial test
# 204                Gender changer
# 2                            Stop
# 82                        Primary
# 172                     Humankind
# 85                     Controller
# 25                 Exclusion list
# 53                  Legacy status
# 92           Compartmentalization
# 184                    Engineered
# 133                          Main
# 136                   Main branch
# 130                        People
# 91                      Isolation
# 9                   Standard user
# 183                     Synthetic
# 93                    Distinction
# 11                  Intended user
# 177                        People
# 205                Gender adapter
# 140            Marginalized group
# 31                 Blinded review
# 83                           Main
# 139        Underrepresented group
# 199                         Stall
# 100                      Built-in
# 23                       Denylist
# 24                      Blocklist
# 5                           Close
# 64                    Staff hours
# 185                    Artificial
# 123                    Indigenous
# 129                     Humankind
# 149       Users with disabilities
# 141    Specific demographic group
# 84                         Leader
# 165                   Chairperson
# 10                   General user
# 101                      Inherent
# 7                          Finish
# 59                           Team
# 142                       Typical
# 63                    Labor hours
# 186                   Constructed
# 148     Persons with disabilities
# 8                    Typical user
# 143                      Expected
# 60                         People
# 145                       Regular
# 147      People with disabilities
# 90                     Separation
# 66                         People
# 175                     Humankind
# 65                      Humankind
# 61                   Person-hours
# 6                            Stop
# 57                       Everyone
# 62                     Work hours
# 176                      Humanity
# 58                          Folks
# 4                             End
#
#                                      Modified Sentence  Similarity Score
# 19   The company detected a Unethical hacker attemp...          0.584426
# 161  The company prioritizes Team contribution when...          0.606165
# 18   The company detected a Malicious actor attempt...          0.610877
# 163  The company prioritizes Collaborative spirit w...          0.626185
# 35   The Receptacle connector allows for easy integ...          0.627351
# 20   The company detected a Attacker attempting to ...          0.638441
# 87   The Project facilitator facilitated the daily ...          0.642606
# 94   A Maintenance window was enforced during the s...          0.658593
# 30   The paper underwent a Anonymized review review...          0.661169
# 36   The Socket connector allows for easy integrati...          0.679458
# 98   The Actor with unclear motives hacker reported...          0.682887
# 72   Before deploying the code, we need to perform ...          0.690537
# 97   The Ambiguous actor hacker reported the vulner...          0.696217
# 206  The adapter functions as a Connector adapter f...          0.703491
# 99   The Semi-authorized actor hacker reported the ...          0.706695
# 195  The server operates within the Screened subnet...          0.715793
# 196  The server operates within the Isolated networ...          0.718277
# 88   The team opted for Ensemble programming to tac...          0.721668
# 194  The server operates within the Perimeter netwo...          0.728124
# 95   A Downtime was enforced during the system upgr...          0.728261
# 71   Before deploying the code, we need to perform ...          0.728782
# 32   The experiment was conducted under double-Anon...          0.731766
# 164  The company prioritizes Shared values when hir...          0.734874
# 170  The Team lead supervised the construction site...          0.734928
# 124  The land’s history is deeply rooted in First P...          0.736355
# 169  The Supervisor supervised the construction sit...          0.744094
# 171  The Site supervisor supervised the constructio...          0.745977
# 202  The new functionality was implemented through ...          0.754634
# 192  The network’s Screened subnet protects interna...          0.755507
# 16   The Glass box testing method allows developers...          0.759352
# 77   A quick Smoke test revealed several issues in ...          0.760604
# 168  The Coordinator called for a vote on the propo...          0.761286
# 158  His desk organization reflects a hint of Detai...          0.762296
# 159  His desk organization reflects a hint of Order...          0.771285
# 128  The Relay attack attack intercepted sensitive ...          0.777748
# 89   The team opted for Collaborative programming t...          0.777778
# 162  The company prioritizes Values alignment when ...          0.778899
# 120  The Security optimization team focused on opti...          0.783778
# 127  The Eavesdropping attack attack intercepted se...          0.785670
# 118  The Moderation team oversaw the cyber exercise...          0.785924
# 121  The Performance team focused on optimizing the...          0.787735
# 201  The new functionality was implemented through ...          0.787963
# 193  The network’s Isolated network protects intern...          0.788988
# 203  The new functionality was implemented through ...          0.790100
# 76   A quick Confidence test revealed several issue...          0.790785
# 79   Developers use a Sample value as a placeholder...          0.795430
# 52   Achieving Quantum preeminence marks a signific...          0.801404
# 45   The Leader database contains all the key recor...          0.805919
# 112  The Web lead updated the website’s layout for ...          0.809284
# 107  The web Primary updated the website’s layout f...          0.810848
# 167  The Presiding officer called for a vote on the...          0.812963
# 122  The Team [Specific Function] focused on optimi...          0.814945
# 125  The land’s history is deeply rooted in Origina...          0.814958
# 46   The Controller database contains all the key r...          0.816892
# 21   A Ethical hacker hacker helped identify securi...          0.817126
# 160  His desk organization reflects a hint of Neat ...          0.819068
# 104  The Security testing team simulated an attack ...          0.819837
# 126  The Intermediary attack attack intercepted sen...          0.824432
# 191  The network’s Perimeter network protects inter...          0.824664
# 15   The Transparent box testing method allows deve...          0.825408
# 70   Before deploying the code, we need to perform ...          0.825560
# 96   A Outage period was enforced during the system...          0.825777
# 117  The Oversight team oversaw the cyber exercise ...          0.826038
# 157  His desk organization reflects a hint of Organ...          0.827162
# 200  The application tends to Become blocked when h...          0.828610
# 78   Developers use a Placeholder value as a placeh...          0.829454
# 106  The Attack simulation team simulated an attack...          0.829734
# 80   Developers use a Example value as a placeholde...          0.831063
# 43   The Primary database contains all the key reco...          0.832613
# 22   A Security researcher hacker helped identify s...          0.832633
# 110  The web Controller updated the website’s layou...          0.833191
# 113  The Website maintainer updated the website’s l...          0.833405
# 190  The project required significant Team members ...          0.833890
# 37   They was responsible for coordinating the team...          0.836792
# 105  The Offensive security team simulated an attac...          0.838205
# 153  The plan was considered Innovative but turned ...          0.840000
# 42   Theirs programming skills greatly improved the...          0.840863
# 182  The Sales representative demonstrated the prod...          0.842884
# 180    The crew Operates the ship during long voyages.          0.843587
# 135  Changes were merged into the Controller branch...          0.844265
# 34   The cable is equipped with a Pin connector for...          0.844309
# 156  His desk organization reflects a hint of Metic...          0.844329
# 108  The web Main updated the website’s layout for ...          0.845296
# 49   The secondary system operates as a Follower to...          0.849255
# 81   Developers use a Test value as a placeholder d...          0.850563
# 17   The Open box testing method allows developers ...          0.850860
# 179      The crew Staffs the ship during long voyages.          0.851084
# 111  The Web administrator updated the website’s la...          0.852008
# 68   Before deploying the code, we need to perform ...          0.854385
# 116  The designer added Padding to improve the page...          0.855119
# 39   The credit for the innovative design is entire...          0.856372
# 50   The secondary system operates as a Agent to th...          0.857448
# 27   Only pre-approved devices are included in the ...          0.859077
# 38   They contribution to the discussion was insigh...          0.860024
# 33   The cable is equipped with a Plug connector fo...          0.860130
# 152  The plan was considered Surprising but turned ...          0.861411
# 150  The plan was considered Unconventional but tur...          0.867457
# 51   Achieving Quantum advantage marks a significan...          0.867519
# 119  The Control team oversaw the cyber exercise an...          0.867743
# 154  The plan was considered Remarkable but turned ...          0.869086
# 69   Before deploying the code, we need to perform ...          0.870917
# 44   The Main database contains all the key records...          0.872235
# 151  The plan was considered Unexpected but turned ...          0.874205
# 208  The cleanup script removed the Unlinked object...          0.875080
# 109  The web Leader updated the website’s layout fo...          0.876580
# 187  The project required significant Staffing to c...          0.876994
# 155  Theirs desk organization reflects a hint of OC...          0.877313
# 54   The older software was Retained status in desp...          0.877785
# 48   The secondary system operates as a Replica to ...          0.877979
# 181  The Salesperson demonstrated the product’s key...          0.878644
# 198  The application tends to Become unresponsive w...          0.879780
# 134  Changes were merged into the Leader branch for...          0.880295
# 102  The app includes a Default feature for photo e...          0.880555
# 28   Only pre-approved devices are included in the ...          0.882783
# 14   The algorithm functions as a Undocumented proc...          0.883828
# 56   The older software was Previously approved in ...          0.886144
# 40   They led the presentation with confidence and ...          0.886162
# 178       The crew Crews the ship during long voyages.          0.887521
# 188  The project required significant Workforce to ...          0.888754
# 146  The venue was upgraded to be accessible for Ac...          0.891089
# 3    The program will automatically Interrupt if a ...          0.891834
# 47   The secondary system operates as a Secondary t...          0.892284
# 132  Changes were merged into the Primary branch fo...          0.894577
# 138  Changes were merged into the Primary branch fo...          0.894577
# 174  Humanity has always sought to understand the u...          0.895734
# 86   The Scrum facilitator facilitated the daily st...          0.895948
# 55   The older software was Exempt under previous p...          0.897570
# 189  The project required significant Personnel to ...          0.898788
# 173  People has always sought to understand the uni...          0.899577
# 41   The team assigned the most critical task to Them.          0.900533
# 26   Only pre-approved devices are included in the ...          0.901145
# 115  The designer added Negative space to improve t...          0.902180
# 166  The Chair called for a vote on the proposed ch...          0.903277
# 137  Changes were merged into the Default branch fo...          0.905802
# 131  The Humanity-in-the-middle attack intercepted ...          0.906904
# 209  The cleanup script removed the Detached object...          0.907230
# 13   The algorithm functions as a Non-transparent b...          0.907371
# 74   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 1    The program will automatically Halt if a criti...          0.909458
# 114  The designer added Spacing to improve the page...          0.910357
# 207  The cleanup script removed the Unreferenced ob...          0.911102
# 29   The paper underwent a Blinded review review pr...          0.913216
# 197  The application tends to Freeze when handling ...          0.914745
# 103  The app includes a Platform-specific feature f...          0.917282
# 12   The algorithm functions as a Opaque box, with ...          0.917817
# 73   A quick Quick test revealed several issues in ...          0.918039
# 67   Completing the project required 100 Humanity h...          0.920907
# 144  The system is back to Standard after resolving...          0.921492
# 75   A quick Initial test revealed several issues i...          0.921538
# 204  The adapter functions as a Gender changer for ...          0.922449
# 2    The program will automatically Stop if a criti...          0.922640
# 82   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 85   The scrum Controller facilitated the daily sta...          0.925107
# 25   The IP address was added to the company’s Excl...          0.925768
# 53   The older software was Legacy status in despit...          0.925821
# 92   The system’s Compartmentalization of duties en...          0.926073
# 184  The reservoir is a Engineered structure design...          0.928353
# 133  Changes were merged into the Main branch for d...          0.928553
# 136  Changes were merged into the Main branch for d...          0.928553
# 130  The People-in-the-middle attack intercepted se...          0.929361
# 91   The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 93   The system’s Distinction of duties ensures sec...          0.930267
# 11   The app is designed to be intuitive for the In...          0.930680
# 177  People has made significant strides in technol...          0.931211
# 205  The adapter functions as a Gender adapter for ...          0.931559
# 140  Efforts to promote diversity aim to amplify th...          0.931869
# 31   The experiment was conducted under double-Blin...          0.931959
# 83   The scrum Main facilitated the daily stand-up ...          0.932176
# 139  Efforts to promote diversity aim to amplify th...          0.932201
# 199  The application tends to Stall when handling l...          0.935331
# 100  The app includes a Built-in feature for photo ...          0.937234
# 23   The IP address was added to the company’s Deny...          0.937353
# 24   The IP address was added to the company’s Bloc...          0.937636
# 5    The user chose to Close the installation proce...          0.937832
# 64   Completing the project required 100 Staff hour...          0.937897
# 185  The reservoir is a Artificial structure design...          0.939255
# 123  The land’s history is deeply rooted in Indigen...          0.939329
# 129  The Humankind-in-the-middle attack intercepted...          0.940031
# 149  The venue was upgraded to be accessible for Us...          0.940271
# 141  Efforts to promote diversity aim to amplify th...          0.941738
# 84   The scrum Leader facilitated the daily stand-u...          0.942709
# 165  The Chairperson called for a vote on the propo...          0.943595
# 10   The app is designed to be intuitive for the Ge...          0.944776
# 101  The app includes a Inherent feature for photo ...          0.945201
# 7    The user chose to Finish the installation proc...          0.948518
# 59   Hey Team, let’s gather for the meeting in five...          0.950417
# 142  The system is back to Typical after resolving ...          0.950920
# 63   Completing the project required 100 Labor hour...          0.951819
# 186  The reservoir is a Constructed structure desig...          0.953625
# 148  The venue was upgraded to be accessible for Pe...          0.954317
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 143  The system is back to Expected after resolving...          0.956891
# 60   Hey People, let’s gather for the meeting in fi...          0.957925
# 145  The system is back to Regular after resolving ...          0.958380
# 147  The venue was upgraded to be accessible for Pe...          0.958386
# 90   The system’s Separation of duties ensures secu...          0.958804
# 66   Completing the project required 100 People hou...          0.959826
# 175  Humankind has made significant strides in tech...          0.961535
# 65   Completing the project required 100 Humankind ...          0.962538
# 61   Completing the project required 100 Person-hou...          0.963118
# 6    The user chose to Stop the installation proces...          0.964866
# 57   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 62   Completing the project required 100 Work hours...          0.965177
# 176  Humanity has made significant strides in techn...          0.968785
# 58   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2_Reasoning-2_replacements.csv", index=False)

# %%
# PROMPT 1:
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Cancel", "Halt", "Stop", "Interrupt"],
    "Terminate": ["End", "Close", "Stop", "Finish"],
    "Average user": ["Typical user", "Standard user", "General user", "Intended user"],
    "Black box": ["Opaque box", "Non-transparent box", "Undocumented process"],
    "White box": ["Transparent box", "Glass box", "Open box"],
    "Black hat": ["Malicious actor", "Unethical hacker", "Attacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Denylist", "Blocklist", "Exclusion list"],
    "Whitelist": ["Allowlist", "Passlist", "Inclusion list"],
    "Blind": ["Blinded review", "Anonymized review"],
    "Double blind": ["Double-blinded review", "Fully anonymized review", "Independent review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Receptacle connector", "Socket connector"],
    "She": ["They"],
    "Her": ["They"],
    "Hers": ["Theirs"],
    "He": ["They"],
    "Him": ["Them"],
    "His": ["Theirs"],
    "Master": ["Primary", "Main", "Leader", "Controller"],
    "Slave": ["Secondary", "Replica", "Follower", "Agent"],
    "Quantum supremacy": ["Quantum advantage", "Quantum preeminence"],
    "Grandfathered": ["Legacy status", "Retained status", "Exempt under previous policy", "Previously approved"],
    "Guys": ["Everyone", "Folks", "Team", "People"],
    "Man hours": ["Person-hours", "Work hours", "Labor hours", "Staff hours"],
    "Sanity check": ["Quick check", "Basic check", "Initial check", "Confidence test", "Smoke test"],
    "Sanity test": ["Quick test", "Basic test", "Initial test", "Confidence test", "Smoke test"],
    "Dummy value": ["Placeholder value", "Sample value", "Example value", "Test value"],
    "Scrum master": ["Scrum facilitator", "Project facilitator"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Isolation", "Compartmentalization", "Distinction"],
    "Blackout period": ["Maintenance window", "Downtime", "Outage period"],
    "Gray hat": ["Ambiguous actor", "Actor with unclear motives", "Semi-authorized actor"],
    "Native": ["Built-in", "Inherent", "Default", "Platform-specific"],
    "Red team": ["Security testing team", "Offensive security team", "Attack simulation team"],
    "Web master": ["Web administrator", "Web lead", "Website maintainer"],
    "White space": ["Spacing", "Negative space", "Padding"],
    "White team": ["Oversight team", "Moderation team", "Control team"],
    "Yellow team": ["Security optimization team", "Performance team", "Team [Specific Function]"],
    "Aboriginal": ["Indigenous", "First Peoples", "Original"],
    "Brown bags": ["Informal learning session", "Lunch and learn session", "Knowledge sharing session"],
    "First-class citizen": ["Primary citizen", "Essential citizen", "Core component", "Fundamental element"],
    "Man-in-the-middle": ["Intermediary attack", "Eavesdropping attack", "Relay attack"],
    "Master branch": ["Main branch", "Default branch", "Primary branch"],
    "Minority": ["Underrepresented group", "Marginalized group", "Specific demographic group"],
    "Normal": ["Typical", "Expected", "Standard", "Regular"],
    "Handicapped": ["Accessible", "People with disabilities", "Persons with disabilities", "Users with disabilities"],
    "Crazy": ["Unconventional", "Unexpected", "Surprising", "Innovative", "Remarkable"],
    "OCD": ["Meticulous", "Organized", "Detail-oriented", "Orderly", "Neat"],
    "Culture fit": ["Team contribution", "Values alignment", "Collaborative spirit", "Shared values"],
    "Chairman": ["Chairperson", "Chair", "Presiding officer", "Coordinator"],
    "Foreman": ["Supervisor", "Team lead", "Site supervisor"],
    "Man": ["Humankind", "People", "Humanity"],
    "Mankind": ["Humankind", "Humanity", "People"],
    "Mans": ["Crews", "Staffs", "Operates"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Synthetic", "Engineered", "Artificial", "Constructed"],
    "Manpower": ["Staffing", "Workforce", "Personnel", "Team members"],
    "Demilitarized zone": ["Perimeter network", "Screened subnet", "Isolated network"],
    "DMZ": ["Perimeter network", "Screened subnet", "Isolated network"],
    "Hang": ["Freeze", "Become unresponsive", "Stall", "Become blocked"],
    "Daughter board": ["Expansion board", "Add-on board", "Secondary board"],
    "Gender bender": ["Gender changer", "Gender adapter", "Connector adapter"],
    "Orphaned object": ["Unreferenced object", "Unlinked object", "Detached object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 19   The company detected a black hat attempting to...           Black hat
# 161  The company prioritizes culture fit when hirin...         Culture fit
# 18   The company detected a black hat attempting to...           Black hat
# 163  The company prioritizes culture fit when hirin...         Culture fit
# 35   The female connector allows for easy integrati...    Female connector
# 20   The company detected a black hat attempting to...           Black hat
# 87   The scrum master facilitated the daily stand-u...        Scrum master
# 94   A blackout period was enforced during the syst...     Blackout period
# 30   The paper underwent a blind review process to ...               Blind
# 36   The female connector allows for easy integrati...    Female connector
# 98   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 72   Before deploying the code, we need to perform ...        Sanity check
# 97   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 206  The adapter functions as a gender bender for c...       Gender bender
# 99   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 195  The server operates within the DMZ for added s...                 DMZ
# 196  The server operates within the DMZ for added s...                 DMZ
# 88   The team opted for mob programming to tackle t...     Mob programming
# 194  The server operates within the DMZ for added s...                 DMZ
# 95   A blackout period was enforced during the syst...     Blackout period
# 71   Before deploying the code, we need to perform ...        Sanity check
# 32   The experiment was conducted under double-blin...               Blind
# 164  The company prioritizes culture fit when hirin...         Culture fit
# 170  The foreman supervised the construction site w...             Foreman
# 124  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 169  The foreman supervised the construction site w...             Foreman
# 171  The foreman supervised the construction site w...             Foreman
# 202  The new functionality was implemented through ...      Daughter board
# 192  The network’s demilitarized zone protects inte...  Demilitarized zone
# 16   The white box testing method allows developers...           White box
# 77   A quick sanity test revealed several issues in...         Sanity test
# 168  The chairman called for a vote on the proposed...            Chairman
# 158  His desk organization reflects a hint of OCD t...                 OCD
# 159  His desk organization reflects a hint of OCD t...                 OCD
# 128  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 89   The team opted for mob programming to tackle t...     Mob programming
# 162  The company prioritizes culture fit when hirin...         Culture fit
# 120  The yellow team focused on optimizing the soft...         Yellow team
# 127  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 118  The white team oversaw the cyber exercise and ...          White team
# 121  The yellow team focused on optimizing the soft...         Yellow team
# 201  The new functionality was implemented through ...      Daughter board
# 193  The network’s demilitarized zone protects inte...  Demilitarized zone
# 203  The new functionality was implemented through ...      Daughter board
# 76   A quick sanity test revealed several issues in...         Sanity test
# 79   Developers use a dummy value as a placeholder ...         Dummy value
# 52   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 45   The master database contains all the key recor...              Master
# 112  The web master updated the website’s layout fo...          Web master
# 107  The web master updated the website’s layout fo...              Master
# 167  The chairman called for a vote on the proposed...            Chairman
# 122  The yellow team focused on optimizing the soft...         Yellow team
# 125  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 46   The master database contains all the key recor...              Master
# 21   A white hat hacker helped identify security vu...           White hat
# 160  His desk organization reflects a hint of OCD t...                 OCD
# 104  The red team simulated an attack to test the o...            Red team
# 126  The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 191  The network’s demilitarized zone protects inte...  Demilitarized zone
# 15   The white box testing method allows developers...           White box
# 70   Before deploying the code, we need to perform ...        Sanity check
# 96   A blackout period was enforced during the syst...     Blackout period
# 117  The white team oversaw the cyber exercise and ...          White team
# 157  His desk organization reflects a hint of OCD t...                 OCD
# 200  The application tends to hang when handling la...                Hang
# 78   Developers use a dummy value as a placeholder ...         Dummy value
# 106  The red team simulated an attack to test the o...            Red team
# 80   Developers use a dummy value as a placeholder ...         Dummy value
# 43   The master database contains all the key recor...              Master
# 22   A white hat hacker helped identify security vu...           White hat
# 110  The web master updated the website’s layout fo...              Master
# 113  The web master updated the website’s layout fo...          Web master
# 190  The project required significant manpower to c...            Manpower
# 37   She was responsible for coordinating the team’...                 She
# 105  The red team simulated an attack to test the o...            Red team
# 153  The plan was considered crazy but turned out t...               Crazy
# 42   His programming skills greatly improved the pr...                 His
# 182  The salesman demonstrated the product’s key fe...            Salesman
# 180        The crew mans the ship during long voyages.                Mans
# 135  Changes were merged into the master branch for...              Master
# 34   The cable is equipped with a male connector fo...      Male connector
# 156  His desk organization reflects a hint of OCD t...                 OCD
# 108  The web master updated the website’s layout fo...              Master
# 49   The secondary system operates as a slave to th...               Slave
# 81   Developers use a dummy value as a placeholder ...         Dummy value
# 17   The white box testing method allows developers...           White box
# 179        The crew mans the ship during long voyages.                Mans
# 111  The web master updated the website’s layout fo...          Web master
# 68   Before deploying the code, we need to perform ...        Sanity check
# 116  The designer added white space to improve the ...         White space
# 39   The credit for the innovative design is entire...                Hers
# 50   The secondary system operates as a slave to th...               Slave
# 27   Only pre-approved devices are included in the ...           Whitelist
# 38   Her contribution to the discussion was insight...                 Her
# 33   The cable is equipped with a male connector fo...      Male connector
# 152  The plan was considered crazy but turned out t...               Crazy
# 150  The plan was considered crazy but turned out t...               Crazy
# 51   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 119  The white team oversaw the cyber exercise and ...          White team
# 154  The plan was considered crazy but turned out t...               Crazy
# 69   Before deploying the code, we need to perform ...        Sanity check
# 44   The master database contains all the key recor...              Master
# 151  The plan was considered crazy but turned out t...               Crazy
# 208  The cleanup script removed the orphaned object...     Orphaned object
# 109  The web master updated the website’s layout fo...              Master
# 187  The project required significant manpower to c...            Manpower
# 155  His desk organization reflects a hint of OCD t...                 His
# 54   The older software was grandfathered in despit...       Grandfathered
# 48   The secondary system operates as a slave to th...               Slave
# 181  The salesman demonstrated the product’s key fe...            Salesman
# 198  The application tends to hang when handling la...                Hang
# 134  Changes were merged into the master branch for...              Master
# 102  The app includes a native feature for photo ed...              Native
# 28   Only pre-approved devices are included in the ...           Whitelist
# 14   The algorithm functions as a black box, with n...           Black box
# 56   The older software was grandfathered in despit...       Grandfathered
# 40   He led the presentation with confidence and cl...                  He
# 178        The crew mans the ship during long voyages.                Mans
# 188  The project required significant manpower to c...            Manpower
# 146  The venue was upgraded to be accessible for ha...         Handicapped
# 3    The program will automatically abort if a crit...               Abort
# 47   The secondary system operates as a slave to th...               Slave
# 132  Changes were merged into the master branch for...              Master
# 138  Changes were merged into the master branch for...       Master branch
# 174  Man has always sought to understand the universe.                 Man
# 86   The scrum master facilitated the daily stand-u...        Scrum master
# 55   The older software was grandfathered in despit...       Grandfathered
# 189  The project required significant manpower to c...            Manpower
# 173  Man has always sought to understand the universe.                 Man
# 41    The team assigned the most critical task to him.                 Him
# 26   Only pre-approved devices are included in the ...           Whitelist
# 115  The designer added white space to improve the ...         White space
# 166  The chairman called for a vote on the proposed...            Chairman
# 137  Changes were merged into the master branch for...       Master branch
# 131  The man-in-the-middle attack intercepted sensi...                 Man
# 209  The cleanup script removed the orphaned object...     Orphaned object
# 13   The algorithm functions as a black box, with n...           Black box
# 74   A quick sanity test revealed several issues in...         Sanity test
# 0    The program will automatically abort if a crit...               Abort
# 1    The program will automatically abort if a crit...               Abort
# 114  The designer added white space to improve the ...         White space
# 207  The cleanup script removed the orphaned object...     Orphaned object
# 29   The paper underwent a blind review process to ...               Blind
# 197  The application tends to hang when handling la...                Hang
# 103  The app includes a native feature for photo ed...              Native
# 12   The algorithm functions as a black box, with n...           Black box
# 73   A quick sanity test revealed several issues in...         Sanity test
# 67   Completing the project required 100 man hours ...                 Man
# 144  The system is back to normal after resolving t...              Normal
# 75   A quick sanity test revealed several issues in...         Sanity test
# 204  The adapter functions as a gender bender for c...       Gender bender
# 2    The program will automatically abort if a crit...               Abort
# 82   The scrum master facilitated the daily stand-u...              Master
# 172  Man has always sought to understand the universe.                 Man
# 85   The scrum master facilitated the daily stand-u...              Master
# 25   The IP address was added to the company’s blac...           Blacklist
# 53   The older software was grandfathered in despit...       Grandfathered
# 92   The system’s segregation of duties ensures sec...         Segregation
# 184  The reservoir is a manmade structure designed ...             Manmade
# 133  Changes were merged into the master branch for...              Master
# 136  Changes were merged into the master branch for...       Master branch
# 130  The man-in-the-middle attack intercepted sensi...                 Man
# 91   The system’s segregation of duties ensures sec...         Segregation
# 9    The app is designed to be intuitive for the av...        Average user
# 183  The reservoir is a manmade structure designed ...             Manmade
# 93   The system’s segregation of duties ensures sec...         Segregation
# 11   The app is designed to be intuitive for the av...        Average user
# 177  Mankind has made significant strides in techno...             Mankind
# 205  The adapter functions as a gender bender for c...       Gender bender
# 140  Efforts to promote diversity aim to amplify th...            Minority
# 31   The experiment was conducted under double-blin...               Blind
# 83   The scrum master facilitated the daily stand-u...              Master
# 139  Efforts to promote diversity aim to amplify th...            Minority
# 199  The application tends to hang when handling la...                Hang
# 100  The app includes a native feature for photo ed...              Native
# 23   The IP address was added to the company’s blac...           Blacklist
# 24   The IP address was added to the company’s blac...           Blacklist
# 5    The user chose to terminate the installation p...           Terminate
# 64   Completing the project required 100 man hours ...           Man hours
# 185  The reservoir is a manmade structure designed ...             Manmade
# 123  The land’s history is deeply rooted in Aborigi...          Aboriginal
# 129  The man-in-the-middle attack intercepted sensi...                 Man
# 149  The venue was upgraded to be accessible for ha...         Handicapped
# 141  Efforts to promote diversity aim to amplify th...            Minority
# 84   The scrum master facilitated the daily stand-u...              Master
# 165  The chairman called for a vote on the proposed...            Chairman
# 10   The app is designed to be intuitive for the av...        Average user
# 101  The app includes a native feature for photo ed...              Native
# 7    The user chose to terminate the installation p...           Terminate
# 59   Hey guys, let’s gather for the meeting in five...                Guys
# 142  The system is back to normal after resolving t...              Normal
# 63   Completing the project required 100 man hours ...           Man hours
# 186  The reservoir is a manmade structure designed ...             Manmade
# 148  The venue was upgraded to be accessible for ha...         Handicapped
# 8    The app is designed to be intuitive for the av...        Average user
# 143  The system is back to normal after resolving t...              Normal
# 60   Hey guys, let’s gather for the meeting in five...                Guys
# 145  The system is back to normal after resolving t...              Normal
# 147  The venue was upgraded to be accessible for ha...         Handicapped
# 90   The system’s segregation of duties ensures sec...         Segregation
# 66   Completing the project required 100 man hours ...                 Man
# 175  Mankind has made significant strides in techno...             Mankind
# 65   Completing the project required 100 man hours ...                 Man
# 61   Completing the project required 100 man hours ...           Man hours
# 6    The user chose to terminate the installation p...           Terminate
# 57   Hey guys, let’s gather for the meeting in five...                Guys
# 62   Completing the project required 100 man hours ...           Man hours
# 176  Mankind has made significant strides in techno...             Mankind
# 58   Hey guys, let’s gather for the meeting in five...                Guys
# 4    The user chose to terminate the installation p...           Terminate
#
#                       Replacement  \
# 19               Unethical hacker
# 161             Team contribution
# 18                Malicious actor
# 163          Collaborative spirit
# 35           Receptacle connector
# 20                       Attacker
# 87            Project facilitator
# 94             Maintenance window
# 30              Anonymized review
# 36               Socket connector
# 98     Actor with unclear motives
# 72                     Smoke test
# 97                Ambiguous actor
# 206             Connector adapter
# 99          Semi-authorized actor
# 195               Screened subnet
# 196              Isolated network
# 88           Ensemble programming
# 194             Perimeter network
# 95                       Downtime
# 71                Confidence test
# 32              Anonymized review
# 164                 Shared values
# 170                     Team lead
# 124                 First Peoples
# 169                    Supervisor
# 171               Site supervisor
# 202                  Add-on board
# 192               Screened subnet
# 16                      Glass box
# 77                     Smoke test
# 168                   Coordinator
# 158               Detail-oriented
# 159                       Orderly
# 128                  Relay attack
# 89      Collaborative programming
# 162              Values alignment
# 120    Security optimization team
# 127          Eavesdropping attack
# 118               Moderation team
# 121              Performance team
# 201               Expansion board
# 193              Isolated network
# 203               Secondary board
# 76                Confidence test
# 79                   Sample value
# 52            Quantum preeminence
# 45                         Leader
# 112                      Web lead
# 107                       Primary
# 167             Presiding officer
# 122      Team [Specific Function]
# 125                      Original
# 46                     Controller
# 21                 Ethical hacker
# 160                          Neat
# 104         Security testing team
# 126           Intermediary attack
# 191             Perimeter network
# 15                Transparent box
# 70                  Initial check
# 96                  Outage period
# 117                Oversight team
# 157                     Organized
# 200                Become blocked
# 78              Placeholder value
# 106        Attack simulation team
# 80                  Example value
# 43                        Primary
# 22            Security researcher
# 110                    Controller
# 113            Website maintainer
# 190                  Team members
# 37                           They
# 105       Offensive security team
# 153                    Innovative
# 42                         Theirs
# 182          Sales representative
# 180                      Operates
# 135                    Controller
# 34                  Pin connector
# 156                    Meticulous
# 108                          Main
# 49                       Follower
# 81                     Test value
# 17                       Open box
# 179                        Staffs
# 111             Web administrator
# 68                    Quick check
# 116                       Padding
# 39                         Theirs
# 50                          Agent
# 27                       Passlist
# 38                           They
# 33                 Plug connector
# 152                    Surprising
# 150                Unconventional
# 51              Quantum advantage
# 119                  Control team
# 154                    Remarkable
# 69                    Basic check
# 44                           Main
# 151                    Unexpected
# 208               Unlinked object
# 109                        Leader
# 187                      Staffing
# 155                        Theirs
# 54                Retained status
# 48                        Replica
# 181                   Salesperson
# 198           Become unresponsive
# 134                        Leader
# 102                       Default
# 28                 Inclusion list
# 14           Undocumented process
# 56            Previously approved
# 40                           They
# 178                         Crews
# 188                     Workforce
# 146                    Accessible
# 3                       Interrupt
# 47                      Secondary
# 132                       Primary
# 138                Primary branch
# 174                      Humanity
# 86              Scrum facilitator
# 55   Exempt under previous policy
# 189                     Personnel
# 173                        People
# 41                           Them
# 26                      Allowlist
# 115                Negative space
# 166                         Chair
# 137                Default branch
# 131                      Humanity
# 209               Detached object
# 13            Non-transparent box
# 74                     Basic test
# 0                          Cancel
# 1                            Halt
# 114                       Spacing
# 207           Unreferenced object
# 29                 Blinded review
# 197                        Freeze
# 103             Platform-specific
# 12                     Opaque box
# 73                     Quick test
# 67                       Humanity
# 144                      Standard
# 75                   Initial test
# 204                Gender changer
# 2                            Stop
# 82                        Primary
# 172                     Humankind
# 85                     Controller
# 25                 Exclusion list
# 53                  Legacy status
# 92           Compartmentalization
# 184                    Engineered
# 133                          Main
# 136                   Main branch
# 130                        People
# 91                      Isolation
# 9                   Standard user
# 183                     Synthetic
# 93                    Distinction
# 11                  Intended user
# 177                        People
# 205                Gender adapter
# 140            Marginalized group
# 31                 Blinded review
# 83                           Main
# 139        Underrepresented group
# 199                         Stall
# 100                      Built-in
# 23                       Denylist
# 24                      Blocklist
# 5                           Close
# 64                    Staff hours
# 185                    Artificial
# 123                    Indigenous
# 129                     Humankind
# 149       Users with disabilities
# 141    Specific demographic group
# 84                         Leader
# 165                   Chairperson
# 10                   General user
# 101                      Inherent
# 7                          Finish
# 59                           Team
# 142                       Typical
# 63                    Labor hours
# 186                   Constructed
# 148     Persons with disabilities
# 8                    Typical user
# 143                      Expected
# 60                         People
# 145                       Regular
# 147      People with disabilities
# 90                     Separation
# 66                         People
# 175                     Humankind
# 65                      Humankind
# 61                   Person-hours
# 6                            Stop
# 57                       Everyone
# 62                     Work hours
# 176                      Humanity
# 58                          Folks
# 4                             End
#
#                                      Modified Sentence  Similarity Score
# 19   The company detected a Unethical hacker attemp...          0.584426
# 161  The company prioritizes Team contribution when...          0.606165
# 18   The company detected a Malicious actor attempt...          0.610877
# 163  The company prioritizes Collaborative spirit w...          0.626185
# 35   The Receptacle connector allows for easy integ...          0.627351
# 20   The company detected a Attacker attempting to ...          0.638441
# 87   The Project facilitator facilitated the daily ...          0.642606
# 94   A Maintenance window was enforced during the s...          0.658593
# 30   The paper underwent a Anonymized review review...          0.661169
# 36   The Socket connector allows for easy integrati...          0.679458
# 98   The Actor with unclear motives hacker reported...          0.682887
# 72   Before deploying the code, we need to perform ...          0.690537
# 97   The Ambiguous actor hacker reported the vulner...          0.696217
# 206  The adapter functions as a Connector adapter f...          0.703491
# 99   The Semi-authorized actor hacker reported the ...          0.706695
# 195  The server operates within the Screened subnet...          0.715793
# 196  The server operates within the Isolated networ...          0.718277
# 88   The team opted for Ensemble programming to tac...          0.721668
# 194  The server operates within the Perimeter netwo...          0.728124
# 95   A Downtime was enforced during the system upgr...          0.728261
# 71   Before deploying the code, we need to perform ...          0.728782
# 32   The experiment was conducted under double-Anon...          0.731766
# 164  The company prioritizes Shared values when hir...          0.734874
# 170  The Team lead supervised the construction site...          0.734928
# 124  The land’s history is deeply rooted in First P...          0.736355
# 169  The Supervisor supervised the construction sit...          0.744094
# 171  The Site supervisor supervised the constructio...          0.745977
# 202  The new functionality was implemented through ...          0.754634
# 192  The network’s Screened subnet protects interna...          0.755507
# 16   The Glass box testing method allows developers...          0.759352
# 77   A quick Smoke test revealed several issues in ...          0.760604
# 168  The Coordinator called for a vote on the propo...          0.761286
# 158  His desk organization reflects a hint of Detai...          0.762296
# 159  His desk organization reflects a hint of Order...          0.771285
# 128  The Relay attack attack intercepted sensitive ...          0.777748
# 89   The team opted for Collaborative programming t...          0.777778
# 162  The company prioritizes Values alignment when ...          0.778899
# 120  The Security optimization team focused on opti...          0.783778
# 127  The Eavesdropping attack attack intercepted se...          0.785670
# 118  The Moderation team oversaw the cyber exercise...          0.785924
# 121  The Performance team focused on optimizing the...          0.787735
# 201  The new functionality was implemented through ...          0.787963
# 193  The network’s Isolated network protects intern...          0.788988
# 203  The new functionality was implemented through ...          0.790100
# 76   A quick Confidence test revealed several issue...          0.790785
# 79   Developers use a Sample value as a placeholder...          0.795430
# 52   Achieving Quantum preeminence marks a signific...          0.801404
# 45   The Leader database contains all the key recor...          0.805919
# 112  The Web lead updated the website’s layout for ...          0.809284
# 107  The web Primary updated the website’s layout f...          0.810848
# 167  The Presiding officer called for a vote on the...          0.812963
# 122  The Team [Specific Function] focused on optimi...          0.814945
# 125  The land’s history is deeply rooted in Origina...          0.814958
# 46   The Controller database contains all the key r...          0.816892
# 21   A Ethical hacker hacker helped identify securi...          0.817126
# 160  His desk organization reflects a hint of Neat ...          0.819068
# 104  The Security testing team simulated an attack ...          0.819837
# 126  The Intermediary attack attack intercepted sen...          0.824432
# 191  The network’s Perimeter network protects inter...          0.824664
# 15   The Transparent box testing method allows deve...          0.825408
# 70   Before deploying the code, we need to perform ...          0.825560
# 96   A Outage period was enforced during the system...          0.825777
# 117  The Oversight team oversaw the cyber exercise ...          0.826038
# 157  His desk organization reflects a hint of Organ...          0.827162
# 200  The application tends to Become blocked when h...          0.828610
# 78   Developers use a Placeholder value as a placeh...          0.829454
# 106  The Attack simulation team simulated an attack...          0.829734
# 80   Developers use a Example value as a placeholde...          0.831063
# 43   The Primary database contains all the key reco...          0.832613
# 22   A Security researcher hacker helped identify s...          0.832633
# 110  The web Controller updated the website’s layou...          0.833191
# 113  The Website maintainer updated the website’s l...          0.833405
# 190  The project required significant Team members ...          0.833890
# 37   They was responsible for coordinating the team...          0.836792
# 105  The Offensive security team simulated an attac...          0.838205
# 153  The plan was considered Innovative but turned ...          0.840000
# 42   Theirs programming skills greatly improved the...          0.840863
# 182  The Sales representative demonstrated the prod...          0.842884
# 180    The crew Operates the ship during long voyages.          0.843587
# 135  Changes were merged into the Controller branch...          0.844265
# 34   The cable is equipped with a Pin connector for...          0.844309
# 156  His desk organization reflects a hint of Metic...          0.844329
# 108  The web Main updated the website’s layout for ...          0.845296
# 49   The secondary system operates as a Follower to...          0.849255
# 81   Developers use a Test value as a placeholder d...          0.850563
# 17   The Open box testing method allows developers ...          0.850860
# 179      The crew Staffs the ship during long voyages.          0.851084
# 111  The Web administrator updated the website’s la...          0.852008
# 68   Before deploying the code, we need to perform ...          0.854385
# 116  The designer added Padding to improve the page...          0.855119
# 39   The credit for the innovative design is entire...          0.856372
# 50   The secondary system operates as a Agent to th...          0.857448
# 27   Only pre-approved devices are included in the ...          0.859077
# 38   They contribution to the discussion was insigh...          0.860024
# 33   The cable is equipped with a Plug connector fo...          0.860130
# 152  The plan was considered Surprising but turned ...          0.861411
# 150  The plan was considered Unconventional but tur...          0.867457
# 51   Achieving Quantum advantage marks a significan...          0.867519
# 119  The Control team oversaw the cyber exercise an...          0.867743
# 154  The plan was considered Remarkable but turned ...          0.869086
# 69   Before deploying the code, we need to perform ...          0.870917
# 44   The Main database contains all the key records...          0.872235
# 151  The plan was considered Unexpected but turned ...          0.874205
# 208  The cleanup script removed the Unlinked object...          0.875080
# 109  The web Leader updated the website’s layout fo...          0.876580
# 187  The project required significant Staffing to c...          0.876994
# 155  Theirs desk organization reflects a hint of OC...          0.877313
# 54   The older software was Retained status in desp...          0.877785
# 48   The secondary system operates as a Replica to ...          0.877979
# 181  The Salesperson demonstrated the product’s key...          0.878644
# 198  The application tends to Become unresponsive w...          0.879780
# 134  Changes were merged into the Leader branch for...          0.880295
# 102  The app includes a Default feature for photo e...          0.880555
# 28   Only pre-approved devices are included in the ...          0.882783
# 14   The algorithm functions as a Undocumented proc...          0.883828
# 56   The older software was Previously approved in ...          0.886144
# 40   They led the presentation with confidence and ...          0.886162
# 178       The crew Crews the ship during long voyages.          0.887521
# 188  The project required significant Workforce to ...          0.888754
# 146  The venue was upgraded to be accessible for Ac...          0.891089
# 3    The program will automatically Interrupt if a ...          0.891834
# 47   The secondary system operates as a Secondary t...          0.892284
# 132  Changes were merged into the Primary branch fo...          0.894577
# 138  Changes were merged into the Primary branch fo...          0.894577
# 174  Humanity has always sought to understand the u...          0.895734
# 86   The Scrum facilitator facilitated the daily st...          0.895948
# 55   The older software was Exempt under previous p...          0.897570
# 189  The project required significant Personnel to ...          0.898788
# 173  People has always sought to understand the uni...          0.899577
# 41   The team assigned the most critical task to Them.          0.900533
# 26   Only pre-approved devices are included in the ...          0.901145
# 115  The designer added Negative space to improve t...          0.902180
# 166  The Chair called for a vote on the proposed ch...          0.903277
# 137  Changes were merged into the Default branch fo...          0.905802
# 131  The Humanity-in-the-middle attack intercepted ...          0.906904
# 209  The cleanup script removed the Detached object...          0.907230
# 13   The algorithm functions as a Non-transparent b...          0.907371
# 74   A quick Basic test revealed several issues in ...          0.907914
# 0    The program will automatically Cancel if a cri...          0.908169
# 1    The program will automatically Halt if a criti...          0.909458
# 114  The designer added Spacing to improve the page...          0.910357
# 207  The cleanup script removed the Unreferenced ob...          0.911102
# 29   The paper underwent a Blinded review review pr...          0.913216
# 197  The application tends to Freeze when handling ...          0.914745
# 103  The app includes a Platform-specific feature f...          0.917282
# 12   The algorithm functions as a Opaque box, with ...          0.917817
# 73   A quick Quick test revealed several issues in ...          0.918039
# 67   Completing the project required 100 Humanity h...          0.920907
# 144  The system is back to Standard after resolving...          0.921492
# 75   A quick Initial test revealed several issues i...          0.921538
# 204  The adapter functions as a Gender changer for ...          0.922449
# 2    The program will automatically Stop if a criti...          0.922640
# 82   The scrum Primary facilitated the daily stand-...          0.923873
# 172  Humankind has always sought to understand the ...          0.923943
# 85   The scrum Controller facilitated the daily sta...          0.925107
# 25   The IP address was added to the company’s Excl...          0.925768
# 53   The older software was Legacy status in despit...          0.925821
# 92   The system’s Compartmentalization of duties en...          0.926073
# 184  The reservoir is a Engineered structure design...          0.928353
# 133  Changes were merged into the Main branch for d...          0.928553
# 136  Changes were merged into the Main branch for d...          0.928553
# 130  The People-in-the-middle attack intercepted se...          0.929361
# 91   The system’s Isolation of duties ensures secur...          0.929556
# 9    The app is designed to be intuitive for the St...          0.929824
# 183  The reservoir is a Synthetic structure designe...          0.929992
# 93   The system’s Distinction of duties ensures sec...          0.930267
# 11   The app is designed to be intuitive for the In...          0.930680
# 177  People has made significant strides in technol...          0.931211
# 205  The adapter functions as a Gender adapter for ...          0.931559
# 140  Efforts to promote diversity aim to amplify th...          0.931869
# 31   The experiment was conducted under double-Blin...          0.931959
# 83   The scrum Main facilitated the daily stand-up ...          0.932176
# 139  Efforts to promote diversity aim to amplify th...          0.932201
# 199  The application tends to Stall when handling l...          0.935331
# 100  The app includes a Built-in feature for photo ...          0.937234
# 23   The IP address was added to the company’s Deny...          0.937353
# 24   The IP address was added to the company’s Bloc...          0.937636
# 5    The user chose to Close the installation proce...          0.937832
# 64   Completing the project required 100 Staff hour...          0.937897
# 185  The reservoir is a Artificial structure design...          0.939255
# 123  The land’s history is deeply rooted in Indigen...          0.939329
# 129  The Humankind-in-the-middle attack intercepted...          0.940031
# 149  The venue was upgraded to be accessible for Us...          0.940271
# 141  Efforts to promote diversity aim to amplify th...          0.941738
# 84   The scrum Leader facilitated the daily stand-u...          0.942709
# 165  The Chairperson called for a vote on the propo...          0.943595
# 10   The app is designed to be intuitive for the Ge...          0.944776
# 101  The app includes a Inherent feature for photo ...          0.945201
# 7    The user chose to Finish the installation proc...          0.948518
# 59   Hey Team, let’s gather for the meeting in five...          0.950417
# 142  The system is back to Typical after resolving ...          0.950920
# 63   Completing the project required 100 Labor hour...          0.951819
# 186  The reservoir is a Constructed structure desig...          0.953625
# 148  The venue was upgraded to be accessible for Pe...          0.954317
# 8    The app is designed to be intuitive for the Ty...          0.955607
# 143  The system is back to Expected after resolving...          0.956891
# 60   Hey People, let’s gather for the meeting in fi...          0.957925
# 145  The system is back to Regular after resolving ...          0.958380
# 147  The venue was upgraded to be accessible for Pe...          0.958386
# 90   The system’s Separation of duties ensures secu...          0.958804
# 66   Completing the project required 100 People hou...          0.959826
# 175  Humankind has made significant strides in tech...          0.961535
# 65   Completing the project required 100 Humankind ...          0.962538
# 61   Completing the project required 100 Person-hou...          0.963118
# 6    The user chose to Stop the installation proces...          0.964866
# 57   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 62   Completing the project required 100 Work hours...          0.965177
# 176  Humanity has made significant strides in techn...          0.968785
# 58   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 4    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GeminiFlash2_Reasoning-3_replacements.csv", index=False)
