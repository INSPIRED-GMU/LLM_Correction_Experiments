# %%
pip install sentence-transformers pandas
# Out:
# Collecting sentence-transformersNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\hana_\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.48.0)
# Requirement already satisfied: tqdm in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\hana_\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hana_\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hana_\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hana_\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#    ---------------------------------------- 0.0/275.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/275.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/275.9 kB 445.2 kB/s eta 0:00:01
#    ----------------- ---------------------- 122.9/275.9 kB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 275.9/275.9 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.4.1

# %%
# PROMPT 1:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "abort": "exit",
    "terminate": "cancel",
    "average user": "everyday user",
    "black box": "opaque model",
    "white box": "open box testing",
    "black hat": "malicious actor",
    "white hat": "ethical hacker",
    "blacklist": "blocklist",
    "whitelist": "allowlist",
    "blind": "anonymous",
    "double blind": "double anonymous",
    "male connector": "plug",
    "female connector": "socket",
    "she": "they",
    "her": "their",
    "hers": "theirs",
    "he": "they",
    "him": "them",
    "his": "their",
    "master": "primary",
    "slave": "replica",
    "quantum supremacy": "quantum advantage",
    "grandfathered": "legacy",
    "guys": "everyone",
    "man hours": "person-hours",
    "sanity check": "basic functionality check",
    "sanity test": "preliminary test",
    "dummy value": "placeholder value",
    "scrum master": "scrum lead",
    "mob programming": "collaborative programming session",
    "segregation": "separation of duties",
    "blackout period": "downtime period",
    "gray hat": "hacker with ambiguous ethics",
    "native": "built-in",
    "red team": "adversary simulation team",
    "web master": "web administrator",
    "white space": "negative space",
    "white team": "control team",
    "yellow team": "security advisory team",
    "aboriginal": "Indigenous",
    "brown bags": "lunch and learn sessions",
    "brown bag": "lunch and learn session",
    "first-class citizen": "fundamental object",
    "first-class citizens": "fundamental objects",
    "man-in-the-middle": "person-in-the-middle",
    "master branch": "main branch",
    "minority": "underrepresented groups",
    "normal": "usual state",
    "handicapped": "people with disabilities",
    "crazy": "unconventional",
    "OCD": "strong attention to detail",
    "culture fit": "cultural alignment",
    "chairman": "chair",
    "foreman": "site supervisor",
    "man": "humanity",
    "mankind": "humanity",
    "mans": "operates",
    "salesman": "salesperson",
    "manmade": "human-made",
    "manpower": "human resources",
    "demilitarized zone": "isolated network zone",
    "demilitarized zones": "isolated network zones",
    "DMZ": "isolated network segment",
    "hang": "become unresponsive",
    "daughter board": "expansion board",
    "gender bender": "connector adapter",
    "orphaned object": "unattached object"
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to replace harmful terms using regular expressions and track replacements
def replace_terms(sentence, replacements):
    harmful_term = None
    replacement_term = None
    for term, replacement in replacements.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            harmful_term = term
            replacement_term = replacement
            # Use case-insensitive matching and word boundaries
            sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
    return sentence, harmful_term, replacement_term

# Generate revised sentences and track replacements
revised_sentences = []
harmful_terms_list = []
replacement_terms_list = []

for sentence in original_sentences:
    revised_sentence, harmful_term, replacement_term = replace_terms(sentence, harmful_terms)
    revised_sentences.append(revised_sentence)
    harmful_terms_list.append(harmful_term)
    replacement_terms_list.append(replacement_term)

# Compute SBERT similarity scores
similarity_scores = [
    util.pytorch_cos_sim(model.encode(orig, convert_to_tensor=True), 
                         model.encode(revised, convert_to_tensor=True)).item()
    for orig, revised in zip(original_sentences, revised_sentences)
]

# Create DataFrame
df = pd.DataFrame({
    "Original Sentence": original_sentences,
    "Revised Sentence": revised_sentences,
    "Harmful Term": harmful_terms_list,
    "Replacement": replacement_terms_list,
    "Similarity Score": similarity_scores
})

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                     Original Sentence  \
# 12  The female connector allows for easy integrati...
# 5   The company detected a black hat attempting to...
# 41  Functions are treated as first-class citizens ...
# 40  The company hosted brown bag sessions to share...
# 48  His desk organization reflects a hint of OCD t...
# 62  The adapter functions as a gender bender for c...
# 59  The server operates within the DMZ for added s...
# 29  The team opted for mob programming to tackle t...
# 9   The paper underwent a blind review process to ...
# 51  The foreman supervised the construction site w...
# 32  The gray hat hacker reported the vulnerabiliti...
# 31  A blackout period was enforced during the syst...
# 38  The yellow team focused on optimizing the soft...
# 61  The new functionality was implemented through ...
# 34  The red team simulated an attack to test the o...
# 35  The web master updated the website’s layout fo...
# 6   A white hat hacker helped identify security vu...
# 27  Developers use a dummy value as a placeholder ...
# 19  The master database contains all the key recor...
# 13  She was responsible for coordinating the team’...
# 4   The white box testing method allows developers...
# 54        The crew mans the ship during long voyages.
# 25  Before deploying the code, we need to perform ...
# 11  The cable is equipped with a male connector fo...
# 15  The credit for the innovative design is entire...
# 14  Her contribution to the discussion was insight...
# 47  The plan was considered crazy but turned out t...
# 21  Achieving quantum supremacy marks a significan...
# 37  The white team oversaw the cyber exercise and ...
# 18  His programming skills greatly improved the pr...
# 58  The network’s demilitarized zone protects inte...
# 20  The secondary system operates as a slave to th...
# 55  The salesman demonstrated the product’s key fe...
# 60  The application tends to hang when handling la...
# 57  The project required significant manpower to c...
# 10  The experiment was conducted under double-blin...
# 16  He led the presentation with confidence and cl...
# 3   The algorithm functions as a black box, with n...
# 43  Changes were merged into the master branch for...
# 52  Man has always sought to understand the universe.
# 17   The team assigned the most critical task to him.
# 0   The program will automatically abort if a crit...
# 8   Only pre-approved devices are included in the ...
# 36  The designer added white space to improve the ...
# 26  A quick sanity test revealed several issues in...
# 50  The chairman called for a vote on the proposed...
# 63  The cleanup script removed the orphaned object...
# 49  The company prioritizes culture fit when hirin...
# 28  The scrum master facilitated the daily stand-u...
# 44  Efforts to promote diversity aim to amplify th...
# 42  The man-in-the-middle attack intercepted sensi...
# 2   The app is designed to be intuitive for the av...
# 22  The older software was grandfathered in despit...
# 1   The user chose to terminate the installation p...
# 45  The system is back to normal after resolving t...
# 33  The app includes a native feature for photo ed...
# 7   The IP address was added to the company’s blac...
# 39  The land’s history is deeply rooted in Aborigi...
# 30  The system’s segregation of duties ensures sec...
# 46  The venue was upgraded to be accessible for ha...
# 56  The reservoir is a manmade structure designed ...
# 24  Completing the project required 100 man hours ...
# 23  Hey guys, let’s gather for the meeting in five...
# 53  Mankind has made significant strides in techno...
#
#                                      Revised Sentence          Harmful Term  \
# 12  The socket allows for easy integration with ot...      female connector
# 5   The company detected a malicious actor attempt...             black hat
# 41  Functions are treated as fundamental objects i...  first-class citizens
# 40  The company hosted lunch and learn session ses...             brown bag
# 48  their desk organization reflects a hint of str...                   OCD
# 62  The adapter functions as a connector adapter f...         gender bender
# 59  The server operates within the isolated networ...                   DMZ
# 29  The team opted for collaborative programming s...       mob programming
# 9   The paper underwent a anonymous review process...                 blind
# 51  The site supervisor supervised the constructio...               foreman
# 32  The hacker with ambiguous ethics hacker report...              gray hat
# 31  A downtime period was enforced during the syst...       blackout period
# 38  The security advisory team focused on optimizi...           yellow team
# 61  The new functionality was implemented through ...        daughter board
# 34  The adversary simulation team simulated an att...              red team
# 35  The web primary updated the website’s layout f...                master
# 6   A ethical hacker hacker helped identify securi...             white hat
# 27  Developers use a placeholder value as a placeh...           dummy value
# 19  The primary database contains all the key reco...                master
# 13  they was responsible for coordinating the team...                   she
# 4   The open box testing testing method allows dev...             white box
# 54    The crew operates the ship during long voyages.                  mans
# 25  Before deploying the code, we need to perform ...          sanity check
# 11  The cable is equipped with a plug for compatib...        male connector
# 15  The credit for the innovative design is entire...                  hers
# 14  their contribution to the discussion was insig...                   her
# 47  The plan was considered unconventional but tur...                 crazy
# 21  Achieving quantum advantage marks a significan...     quantum supremacy
# 37  The control team oversaw the cyber exercise an...            white team
# 18  their programming skills greatly improved the ...                   his
# 58  The network’s isolated network zone protects i...    demilitarized zone
# 20  The secondary system operates as a replica to ...                 slave
# 55  The salesperson demonstrated the product’s key...              salesman
# 60  The application tends to become unresponsive w...                  hang
# 57  The project required significant human resourc...              manpower
# 10  The experiment was conducted under double-anon...                 blind
# 16  they led the presentation with confidence and ...                    he
# 3   The algorithm functions as a opaque model, wit...             black box
# 43  Changes were merged into the primary branch fo...                master
# 52  humanity has always sought to understand the u...                   man
# 17  The team assigned the most critical task to them.                   him
# 0   The program will automatically exit if a criti...                 abort
# 8   Only pre-approved devices are included in the ...             whitelist
# 36  The designer added negative space to improve t...           white space
# 26  A quick preliminary test revealed several issu...           sanity test
# 50  The chair called for a vote on the proposed ch...              chairman
# 63  The cleanup script removed the unattached obje...       orphaned object
# 49  The company prioritizes cultural alignment whe...           culture fit
# 28  The scrum primary facilitated the daily stand-...                master
# 44  Efforts to promote diversity aim to amplify th...              minority
# 42  The person-in-the-middle attack intercepted se...     man-in-the-middle
# 2   The app is designed to be intuitive for the ev...          average user
# 22  The older software was legacy in despite the n...         grandfathered
# 1   The user chose to cancel the installation proc...             terminate
# 45  The system is back to usual state after resolv...                normal
# 33  The app includes a built-in feature for photo ...                native
# 7   The IP address was added to the company’s bloc...             blacklist
# 39  The land’s history is deeply rooted in Indigen...            aboriginal
# 30  The system’s separation of duties of duties en...           segregation
# 46  The venue was upgraded to be accessible for pe...           handicapped
# 56  The reservoir is a human-made structure design...               manmade
# 24  Completing the project required 100 person-hou...             man hours
# 23  Hey everyone, let’s gather for the meeting in ...                  guys
# 53  humanity has made significant strides in techn...               mankind
#
#                           Replacement  Similarity Score
# 12                             socket          0.573467
# 5                     malicious actor          0.610877
# 41                fundamental objects          0.665082
# 40            lunch and learn session          0.682555
# 48         strong attention to detail          0.686194
# 62                  connector adapter          0.703491
# 59           isolated network segment          0.713629
# 29  collaborative programming session          0.723842
# 9                           anonymous          0.744736
# 51                    site supervisor          0.745977
# 32       hacker with ambiguous ethics          0.746019
# 31                    downtime period          0.785668
# 38             security advisory team          0.787955
# 61                    expansion board          0.787963
# 34          adversary simulation team          0.795411
# 35                            primary          0.810848
# 6                      ethical hacker          0.817126
# 27                  placeholder value          0.829454
# 19                            primary          0.832613
# 13                               they          0.836792
# 4                    open box testing          0.837855
# 54                           operates          0.843587
# 25          basic functionality check          0.849638
# 11                               plug          0.849646
# 15                             theirs          0.856372
# 14                              their          0.857565
# 47                     unconventional          0.867457
# 21                  quantum advantage          0.867519
# 37                       control team          0.867743
# 18                              their          0.873098
# 58              isolated network zone          0.877476
# 20                            replica          0.877979
# 55                        salesperson          0.878644
# 60                become unresponsive          0.879780
# 57                    human resources          0.882928
# 10                          anonymous          0.883819
# 16                               they          0.886162
# 3                        opaque model          0.892705
# 43                            primary          0.894577
# 52                           humanity          0.895734
# 17                               them          0.900533
# 0                                exit          0.900890
# 8                           allowlist          0.901145
# 36                     negative space          0.902180
# 26                   preliminary test          0.902828
# 50                              chair          0.903277
# 63                  unattached object          0.910826
# 49                 cultural alignment          0.911230
# 28                            primary          0.923873
# 44            underrepresented groups          0.926320
# 42               person-in-the-middle          0.929446
# 2                       everyday user          0.929511
# 22                             legacy          0.934483
# 1                              cancel          0.936486
# 45                        usual state          0.937071
# 33                           built-in          0.937234
# 7                           blocklist          0.937636
# 39                         Indigenous          0.939329
# 30               separation of duties          0.946082
# 46           people with disabilities          0.958386
# 56                         human-made          0.960701
# 24                       person-hours          0.963118
# 23                           everyone          0.965056
# 53                           humanity          0.968785

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4Reasoning1_replacements.csv", index=False)

# %%
# PROMPT 2:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "abort": "exit",
    "terminate": "cancel",
    "average user": "everyday user",
    "black box": "opaque model",
    "white box": "open box testing",
    "black hat": "malicious actor",
    "white hat": "ethical hacker",
    "blacklist": "blocklist",
    "whitelist": "allowlist",
    "blind": "anonymous",
    "double blind": "double anonymous",
    "male connector": "plug",
    "female connector": "socket",
    "she": "they",
    "her": "their",
    "hers": "theirs",
    "he": "they",
    "him": "them",
    "his": "their",
    "master": "primary",
    "slave": "replica",
    "quantum supremacy": "quantum advantage",
    "grandfathered": "legacy",
    "guys": "everyone",
    "man hours": "person-hours",
    "sanity check": "basic functionality check",
    "sanity test": "preliminary test",
    "dummy value": "placeholder value",
    "scrum master": "scrum lead",
    "mob programming": "collaborative programming session",
    "segregation": "separation of duties",
    "blackout period": "downtime period",
    "gray hat": "hacker with ambiguous ethics",
    "native": "built-in",
    "red team": "adversary simulation team",
    "web master": "web administrator",
    "white space": "negative space",
    "white team": "control team",
    "yellow team": "security advisory team",
    "aboriginal": "Indigenous",
    "brown bags": "lunch and learn sessions",
    "brown bag": "lunch and learn session",
    "first-class citizen": "fundamental entity",
    "first-class citizens": "fundamental entity",
    "man-in-the-middle": "person-in-the-middle",
    "master branch": "main branch",
    "minority": "underrepresented groups",
    "normal": "usual state",
    "handicapped": "people with disabilities",
    "crazy": "unconventional",
    "OCD": "strong attention to detail",
    "culture fit": "cultural alignment",
    "chairman": "chair",
    "foreman": "site supervisor",
    "man": "humanity",
    "mankind": "humanity",
    "mans": "operates",
    "salesman": "salesperson",
    "manmade": "human-made",
    "manpower": "human resources",
    "demilitarized zone": "isolated network zone",
    "demilitarized zones": "isolated network zones",
    "DMZ": "isolated network segment",
    "hang": "become unresponsive",
    "daughter board": "expansion board",
    "gender bender": "connector adapter",
    "orphaned object": "unattached object"
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to replace harmful terms using regular expressions and track replacements
def replace_terms(sentence, replacements):
    harmful_term = None
    replacement_term = None
    for term, replacement in replacements.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            harmful_term = term
            replacement_term = replacement
            # Use case-insensitive matching and word boundaries
            sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
    return sentence, harmful_term, replacement_term

# Generate revised sentences and track replacements
revised_sentences = []
harmful_terms_list = []
replacement_terms_list = []

for sentence in original_sentences:
    revised_sentence, harmful_term, replacement_term = replace_terms(sentence, harmful_terms)
    revised_sentences.append(revised_sentence)
    harmful_terms_list.append(harmful_term)
    replacement_terms_list.append(replacement_term)

# Compute SBERT similarity scores
similarity_scores = [
    util.pytorch_cos_sim(model.encode(orig, convert_to_tensor=True), 
                         model.encode(revised, convert_to_tensor=True)).item()
    for orig, revised in zip(original_sentences, revised_sentences)
]

# Create DataFrame
df = pd.DataFrame({
    "Original Sentence": original_sentences,
    "Revised Sentence": revised_sentences,
    "Harmful Term": harmful_terms_list,
    "Replacement": replacement_terms_list,
    "Similarity Score": similarity_scores
})

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                     Original Sentence  \
# 12  The female connector allows for easy integrati...
# 5   The company detected a black hat attempting to...
# 41  Functions are treated as first-class citizens ...
# 40  The company hosted brown bag sessions to share...
# 48  His desk organization reflects a hint of OCD t...
# 62  The adapter functions as a gender bender for c...
# 59  The server operates within the DMZ for added s...
# 29  The team opted for mob programming to tackle t...
# 9   The paper underwent a blind review process to ...
# 51  The foreman supervised the construction site w...
# 32  The gray hat hacker reported the vulnerabiliti...
# 31  A blackout period was enforced during the syst...
# 38  The yellow team focused on optimizing the soft...
# 61  The new functionality was implemented through ...
# 34  The red team simulated an attack to test the o...
# 35  The web master updated the website’s layout fo...
# 6   A white hat hacker helped identify security vu...
# 27  Developers use a dummy value as a placeholder ...
# 19  The master database contains all the key recor...
# 13  She was responsible for coordinating the team’...
# 4   The white box testing method allows developers...
# 54        The crew mans the ship during long voyages.
# 25  Before deploying the code, we need to perform ...
# 11  The cable is equipped with a male connector fo...
# 15  The credit for the innovative design is entire...
# 14  Her contribution to the discussion was insight...
# 47  The plan was considered crazy but turned out t...
# 21  Achieving quantum supremacy marks a significan...
# 37  The white team oversaw the cyber exercise and ...
# 18  His programming skills greatly improved the pr...
# 58  The network’s demilitarized zone protects inte...
# 20  The secondary system operates as a slave to th...
# 55  The salesman demonstrated the product’s key fe...
# 60  The application tends to hang when handling la...
# 57  The project required significant manpower to c...
# 10  The experiment was conducted under double-blin...
# 16  He led the presentation with confidence and cl...
# 3   The algorithm functions as a black box, with n...
# 43  Changes were merged into the master branch for...
# 52  Man has always sought to understand the universe.
# 17   The team assigned the most critical task to him.
# 0   The program will automatically abort if a crit...
# 8   Only pre-approved devices are included in the ...
# 36  The designer added white space to improve the ...
# 26  A quick sanity test revealed several issues in...
# 50  The chairman called for a vote on the proposed...
# 63  The cleanup script removed the orphaned object...
# 49  The company prioritizes culture fit when hirin...
# 28  The scrum master facilitated the daily stand-u...
# 44  Efforts to promote diversity aim to amplify th...
# 42  The man-in-the-middle attack intercepted sensi...
# 2   The app is designed to be intuitive for the av...
# 22  The older software was grandfathered in despit...
# 1   The user chose to terminate the installation p...
# 45  The system is back to normal after resolving t...
# 33  The app includes a native feature for photo ed...
# 7   The IP address was added to the company’s blac...
# 39  The land’s history is deeply rooted in Aborigi...
# 30  The system’s segregation of duties ensures sec...
# 46  The venue was upgraded to be accessible for ha...
# 56  The reservoir is a manmade structure designed ...
# 24  Completing the project required 100 man hours ...
# 23  Hey guys, let’s gather for the meeting in five...
# 53  Mankind has made significant strides in techno...
#
#                                      Revised Sentence          Harmful Term  \
# 12  The socket allows for easy integration with ot...      female connector
# 5   The company detected a malicious actor attempt...             black hat
# 41  Functions are treated as fundamental entity in...  first-class citizens
# 40  The company hosted lunch and learn session ses...             brown bag
# 48  their desk organization reflects a hint of str...                   OCD
# 62  The adapter functions as a connector adapter f...         gender bender
# 59  The server operates within the isolated networ...                   DMZ
# 29  The team opted for collaborative programming s...       mob programming
# 9   The paper underwent a anonymous review process...                 blind
# 51  The site supervisor supervised the constructio...               foreman
# 32  The hacker with ambiguous ethics hacker report...              gray hat
# 31  A downtime period was enforced during the syst...       blackout period
# 38  The security advisory team focused on optimizi...           yellow team
# 61  The new functionality was implemented through ...        daughter board
# 34  The adversary simulation team simulated an att...              red team
# 35  The web primary updated the website’s layout f...                master
# 6   A ethical hacker hacker helped identify securi...             white hat
# 27  Developers use a placeholder value as a placeh...           dummy value
# 19  The primary database contains all the key reco...                master
# 13  they was responsible for coordinating the team...                   she
# 4   The open box testing testing method allows dev...             white box
# 54    The crew operates the ship during long voyages.                  mans
# 25  Before deploying the code, we need to perform ...          sanity check
# 11  The cable is equipped with a plug for compatib...        male connector
# 15  The credit for the innovative design is entire...                  hers
# 14  their contribution to the discussion was insig...                   her
# 47  The plan was considered unconventional but tur...                 crazy
# 21  Achieving quantum advantage marks a significan...     quantum supremacy
# 37  The control team oversaw the cyber exercise an...            white team
# 18  their programming skills greatly improved the ...                   his
# 58  The network’s isolated network zone protects i...    demilitarized zone
# 20  The secondary system operates as a replica to ...                 slave
# 55  The salesperson demonstrated the product’s key...              salesman
# 60  The application tends to become unresponsive w...                  hang
# 57  The project required significant human resourc...              manpower
# 10  The experiment was conducted under double-anon...                 blind
# 16  they led the presentation with confidence and ...                    he
# 3   The algorithm functions as a opaque model, wit...             black box
# 43  Changes were merged into the primary branch fo...                master
# 52  humanity has always sought to understand the u...                   man
# 17  The team assigned the most critical task to them.                   him
# 0   The program will automatically exit if a criti...                 abort
# 8   Only pre-approved devices are included in the ...             whitelist
# 36  The designer added negative space to improve t...           white space
# 26  A quick preliminary test revealed several issu...           sanity test
# 50  The chair called for a vote on the proposed ch...              chairman
# 63  The cleanup script removed the unattached obje...       orphaned object
# 49  The company prioritizes cultural alignment whe...           culture fit
# 28  The scrum primary facilitated the daily stand-...                master
# 44  Efforts to promote diversity aim to amplify th...              minority
# 42  The person-in-the-middle attack intercepted se...     man-in-the-middle
# 2   The app is designed to be intuitive for the ev...          average user
# 22  The older software was legacy in despite the n...         grandfathered
# 1   The user chose to cancel the installation proc...             terminate
# 45  The system is back to usual state after resolv...                normal
# 33  The app includes a built-in feature for photo ...                native
# 7   The IP address was added to the company’s bloc...             blacklist
# 39  The land’s history is deeply rooted in Indigen...            aboriginal
# 30  The system’s separation of duties of duties en...           segregation
# 46  The venue was upgraded to be accessible for pe...           handicapped
# 56  The reservoir is a human-made structure design...               manmade
# 24  Completing the project required 100 person-hou...             man hours
# 23  Hey everyone, let’s gather for the meeting in ...                  guys
# 53  humanity has made significant strides in techn...               mankind
#
#                           Replacement  Similarity Score
# 12                             socket          0.573467
# 5                     malicious actor          0.610877
# 41                 fundamental entity          0.641492
# 40            lunch and learn session          0.682555
# 48         strong attention to detail          0.686194
# 62                  connector adapter          0.703491
# 59           isolated network segment          0.713629
# 29  collaborative programming session          0.723842
# 9                           anonymous          0.744736
# 51                    site supervisor          0.745977
# 32       hacker with ambiguous ethics          0.746019
# 31                    downtime period          0.785668
# 38             security advisory team          0.787955
# 61                    expansion board          0.787963
# 34          adversary simulation team          0.795411
# 35                            primary          0.810848
# 6                      ethical hacker          0.817126
# 27                  placeholder value          0.829454
# 19                            primary          0.832613
# 13                               they          0.836792
# 4                    open box testing          0.837855
# 54                           operates          0.843587
# 25          basic functionality check          0.849638
# 11                               plug          0.849646
# 15                             theirs          0.856372
# 14                              their          0.857565
# 47                     unconventional          0.867457
# 21                  quantum advantage          0.867519
# 37                       control team          0.867743
# 18                              their          0.873098
# 58              isolated network zone          0.877476
# 20                            replica          0.877979
# 55                        salesperson          0.878644
# 60                become unresponsive          0.879780
# 57                    human resources          0.882928
# 10                          anonymous          0.883819
# 16                               they          0.886162
# 3                        opaque model          0.892705
# 43                            primary          0.894577
# 52                           humanity          0.895734
# 17                               them          0.900533
# 0                                exit          0.900890
# 8                           allowlist          0.901145
# 36                     negative space          0.902180
# 26                   preliminary test          0.902828
# 50                              chair          0.903277
# 63                  unattached object          0.910826
# 49                 cultural alignment          0.911230
# 28                            primary          0.923873
# 44            underrepresented groups          0.926320
# 42               person-in-the-middle          0.929446
# 2                       everyday user          0.929511
# 22                             legacy          0.934483
# 1                              cancel          0.936486
# 45                        usual state          0.937071
# 33                           built-in          0.937234
# 7                           blocklist          0.937636
# 39                         Indigenous          0.939329
# 30               separation of duties          0.946082
# 46           people with disabilities          0.958386
# 56                         human-made          0.960701
# 24                       person-hours          0.963118
# 23                           everyone          0.965056
# 53                           humanity          0.968785

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4Reasoning2_replacements.csv", index=False)

# %%
# PROMPT 3
from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "abort": "stop",
    "terminate": "cancel",
    "average user": "typical user",
    "black box": "opaque system",
    "white box": "transparent system",
    "black hat": "malicious actor",
    "white hat": "ethical hacker",
    "blacklist": "blocklist",
    "whitelist": "allowlist",
    "blind": "anonymous",
    "double blind": "double-anonymous",
    "male connector": "plug connector",
    "female connector": "socket connector",
    "she": "they",
    "her": "them",
    "hers": "theirs",
    "he": "they",
    "him": "them",
    "his": "their",
    "master": "primary",
    "slave": "replica",
    "quantum supremacy": "quantum advantage",
    "grandfathered": "exempted",
    "guys": "everyone",
    "man hours": "work hours",
    "sanity check": "quick check",
    "sanity test": "smoke test",
    "dummy value": "placeholder value",
    "scrum master": "scrum lead",
    "mob programming": "ensemble programming",
    "segregation": "separation",
    "blackout period": "restricted period",
    "gray hat": "ethical hacker",
    "native": "built-in",
    "red team": "offensive security team",
    "web master": "web administrator",
    "white space": "padding/margin",
    "white team": "oversight team",
    "yellow team": "optimization team",
    "aboriginal": "Indigenous",
    "brown bags": "lunch and learn sessions",
    "brown bag": "lunch and learn session",
    "first-class citizen": "core element",
    "first-class citizens": "core elements",
    "man-in-the-middle": "on-path attack",
    "master branch": "main branch",
    "minority": "underrepresented group",
    "normal": "standard",
    "handicapped": "people with disabilities",
    "crazy": "unconventional",
    "OCD": "perfectionist tendencies",
    "culture fit": "values alignment",
    "chairman": "chairperson",
    "foreman": "site supervisor",
    "man": "human",
    "mankind": "humanity",
    "mans": "crew",
    "salesman": "sales representative",
    "manmade": "artificial",
    "manpower": "workforce",
    "demilitarized zone (DMZ)": "perimeter zone",
    "demilitarized zone": "perimeter zone",
    "DMZ": "perimeter zone",
    "demilitarized zones": "perimeter zones",
    "hang": "freeze",
    "daughter board": "auxiliary board",
    "gender bender": "connector adapter",
    "orphaned object": "unused object"
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.", 
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to replace harmful terms using regular expressions and track replacements
def replace_terms(sentence, replacements):
    harmful_term = None
    replacement_term = None
    for term, replacement in replacements.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            harmful_term = term
            replacement_term = replacement
            # Use case-insensitive matching and word boundaries
            sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
    return sentence, harmful_term, replacement_term

# Generate revised sentences and track replacements
revised_sentences = []
harmful_terms_list = []
replacement_terms_list = []

for sentence in original_sentences:
    revised_sentence, harmful_term, replacement_term = replace_terms(sentence, harmful_terms)
    revised_sentences.append(revised_sentence)
    harmful_terms_list.append(harmful_term)
    replacement_terms_list.append(replacement_term)

# Compute SBERT similarity scores
similarity_scores = [
    util.pytorch_cos_sim(model.encode(orig, convert_to_tensor=True), 
                         model.encode(revised, convert_to_tensor=True)).item()
    for orig, revised in zip(original_sentences, revised_sentences)
]

# Create DataFrame
df = pd.DataFrame({
    "Original Sentence": original_sentences,
    "Revised Sentence": revised_sentences,
    "Harmful Term": harmful_terms_list,
    "Replacement": replacement_terms_list,
    "Similarity Score": similarity_scores
})

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                     Original Sentence  \
# 5   The company detected a black hat attempting to...
# 41  Functions are treated as first-class citizens ...
# 12  The female connector allows for easy integrati...
# 40  The company hosted brown bag sessions to share...
# 62  The adapter functions as a gender bender for c...
# 48  His desk organization reflects a hint of OCD t...
# 29  The team opted for mob programming to tackle t...
# 4   The white box testing method allows developers...
# 9   The paper underwent a blind review process to ...
# 51  The foreman supervised the construction site w...
# 61  The new functionality was implemented through ...
# 59  The server operates within the DMZ for added s...
# 26  A quick sanity test revealed several issues in...
# 42  The man-in-the-middle attack intercepted sensi...
# 32  The gray hat hacker reported the vulnerabiliti...
# 49  The company prioritizes culture fit when hirin...
# 38  The yellow team focused on optimizing the soft...
# 31  A blackout period was enforced during the syst...
# 35  The web master updated the website’s layout fo...
# 6   A white hat hacker helped identify security vu...
# 37  The white team oversaw the cyber exercise and ...
# 27  Developers use a dummy value as a placeholder ...
# 19  The master database contains all the key recor...
# 13  She was responsible for coordinating the team’...
# 34  The red team simulated an attack to test the o...
# 55  The salesman demonstrated the product’s key fe...
# 25  Before deploying the code, we need to perform ...
# 15  The credit for the innovative design is entire...
# 14  Her contribution to the discussion was insight...
# 11  The cable is equipped with a male connector fo...
# 47  The plan was considered crazy but turned out t...
# 21  Achieving quantum supremacy marks a significan...
# 36  The designer added white space to improve the ...
# 18  His programming skills greatly improved the pr...
# 20  The secondary system operates as a slave to th...
# 10  The experiment was conducted under double-blin...
# 16  He led the presentation with confidence and cl...
# 57  The project required significant manpower to c...
# 22  The older software was grandfathered in despit...
# 43  Changes were merged into the master branch for...
# 54        The crew mans the ship during long voyages.
# 3   The algorithm functions as a black box, with n...
# 58  The network’s demilitarized zone protects inte...
# 17   The team assigned the most critical task to him.
# 8   Only pre-approved devices are included in the ...
# 60  The application tends to hang when handling la...
# 45  The system is back to normal after resolving t...
# 0   The program will automatically abort if a crit...
# 28  The scrum master facilitated the daily stand-u...
# 63  The cleanup script removed the orphaned object...
# 52  Man has always sought to understand the universe.
# 44  Efforts to promote diversity aim to amplify th...
# 1   The user chose to terminate the installation p...
# 33  The app includes a native feature for photo ed...
# 7   The IP address was added to the company’s blac...
# 56  The reservoir is a manmade structure designed ...
# 39  The land’s history is deeply rooted in Aborigi...
# 50  The chairman called for a vote on the proposed...
# 2   The app is designed to be intuitive for the av...
# 46  The venue was upgraded to be accessible for ha...
# 30  The system’s segregation of duties ensures sec...
# 23  Hey guys, let’s gather for the meeting in five...
# 24  Completing the project required 100 man hours ...
# 53  Mankind has made significant strides in techno...
#
#                                      Revised Sentence          Harmful Term  \
# 5   The company detected a malicious actor attempt...             black hat
# 41  Functions are treated as core elements in many...  first-class citizens
# 12  The socket connector allows for easy integrati...      female connector
# 40  The company hosted lunch and learn session ses...             brown bag
# 62  The adapter functions as a connector adapter f...         gender bender
# 48  their desk organization reflects a hint of per...                   OCD
# 29  The team opted for ensemble programming to tac...       mob programming
# 4   The transparent system testing method allows d...             white box
# 9   The paper underwent a anonymous review process...                 blind
# 51  The site supervisor supervised the constructio...               foreman
# 61  The new functionality was implemented through ...        daughter board
# 59  The server operates within the perimeter zone ...                   DMZ
# 26  A quick smoke test revealed several issues in ...           sanity test
# 42  The on-path attack attack intercepted sensitiv...     man-in-the-middle
# 32  The ethical hacker hacker reported the vulnera...              gray hat
# 49  The company prioritizes values alignment when ...           culture fit
# 38  The optimization team focused on optimizing th...           yellow team
# 31  A restricted period was enforced during the sy...       blackout period
# 35  The web primary updated the website’s layout f...                master
# 6   A ethical hacker hacker helped identify securi...             white hat
# 37  The oversight team oversaw the cyber exercise ...            white team
# 27  Developers use a placeholder value as a placeh...           dummy value
# 19  The primary database contains all the key reco...                master
# 13  they was responsible for coordinating the team...                   she
# 34  The offensive security team simulated an attac...              red team
# 55  The sales representative demonstrated the prod...              salesman
# 25  Before deploying the code, we need to perform ...          sanity check
# 15  The credit for the innovative design is entire...                  hers
# 14  them contribution to the discussion was insigh...                   her
# 11  The cable is equipped with a plug connector fo...        male connector
# 47  The plan was considered unconventional but tur...                 crazy
# 21  Achieving quantum advantage marks a significan...     quantum supremacy
# 36  The designer added padding/margin to improve t...           white space
# 18  their programming skills greatly improved the ...                   his
# 20  The secondary system operates as a replica to ...                 slave
# 10  The experiment was conducted under double-anon...                 blind
# 16  they led the presentation with confidence and ...                    he
# 57  The project required significant workforce to ...              manpower
# 22  The older software was exempted in despite the...         grandfathered
# 43  Changes were merged into the primary branch fo...                master
# 54        The crew crew the ship during long voyages.                  mans
# 3   The algorithm functions as a opaque system, wi...             black box
# 58  The network’s perimeter zone protects internal...    demilitarized zone
# 17  The team assigned the most critical task to them.                   him
# 8   Only pre-approved devices are included in the ...             whitelist
# 60  The application tends to freeze when handling ...                  hang
# 45  The system is back to standard after resolving...                normal
# 0   The program will automatically stop if a criti...                 abort
# 28  The scrum primary facilitated the daily stand-...                master
# 63  The cleanup script removed the unused object f...       orphaned object
# 52  human has always sought to understand the univ...                   man
# 44  Efforts to promote diversity aim to amplify th...              minority
# 1   The user chose to cancel the installation proc...             terminate
# 33  The app includes a built-in feature for photo ...                native
# 7   The IP address was added to the company’s bloc...             blacklist
# 56  The reservoir is a artificial structure design...               manmade
# 39  The land’s history is deeply rooted in Indigen...            aboriginal
# 50  The chairperson called for a vote on the propo...              chairman
# 2   The app is designed to be intuitive for the ty...          average user
# 46  The venue was upgraded to be accessible for pe...           handicapped
# 30  The system’s separation of duties ensures secu...           segregation
# 23  Hey everyone, let’s gather for the meeting in ...                  guys
# 24  Completing the project required 100 work hours...             man hours
# 53  humanity has made significant strides in techn...               mankind
#
#                  Replacement  Similarity Score
# 5            malicious actor          0.610877
# 41             core elements          0.644980
# 12          socket connector          0.679458
# 40   lunch and learn session          0.682555
# 62         connector adapter          0.703491
# 48  perfectionist tendencies          0.708530
# 29      ensemble programming          0.721668
# 4         transparent system          0.722767
# 9                  anonymous          0.744736
# 51           site supervisor          0.745977
# 61           auxiliary board          0.750979
# 59            perimeter zone          0.754267
# 26                smoke test          0.760604
# 42            on-path attack          0.769240
# 32            ethical hacker          0.777916
# 49          values alignment          0.778899
# 38         optimization team          0.787121
# 31         restricted period          0.810575
# 35                   primary          0.810848
# 6             ethical hacker          0.817126
# 37            oversight team          0.826038
# 27         placeholder value          0.829454
# 19                   primary          0.832613
# 13                      they          0.836792
# 34   offensive security team          0.838205
# 55      sales representative          0.842884
# 25               quick check          0.854385
# 15                    theirs          0.856372
# 14                      them          0.857843
# 11            plug connector          0.860130
# 47            unconventional          0.867457
# 21         quantum advantage          0.867519
# 36            padding/margin          0.872325
# 18                     their          0.873098
# 20                   replica          0.877979
# 10                 anonymous          0.883819
# 16                      they          0.886162
# 57                 workforce          0.888754
# 22                  exempted          0.892654
# 43                   primary          0.894577
# 54                      crew          0.896580
# 3              opaque system          0.898719
# 58            perimeter zone          0.899745
# 17                      them          0.900533
# 8                  allowlist          0.901145
# 60                    freeze          0.914745
# 45                  standard          0.921492
# 0                       stop          0.922640
# 28                   primary          0.923873
# 63             unused object          0.928053
# 52                     human          0.931410
# 44    underrepresented group          0.932201
# 1                     cancel          0.936486
# 33                  built-in          0.937234
# 7                  blocklist          0.937636
# 56                artificial          0.939255
# 39                Indigenous          0.939329
# 50               chairperson          0.943595
# 2               typical user          0.955607
# 46  people with disabilities          0.958386
# 30                separation          0.958804
# 23                  everyone          0.965056
# 24                work hours          0.965177
# 53                  humanity          0.968785

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4Reasoning3_replacements.csv", index=False)
