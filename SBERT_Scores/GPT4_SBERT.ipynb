# %%
pip install sentence-transformers pandas
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\hana_\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: pandas in c:\users\hana_\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.48.0)
# Requirement already satisfied: tqdm in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (0.27.1)
# Requirement already satisfied: Pillow in c:\users\hana_\anaconda3\lib\site-packages (from sentence-transformers) (10.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hana_\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hana_\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\hana_\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hana_\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hana_\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hana_\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\hana_\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hana_\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hana_\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hana_\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# PROMPT 1:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Halt", "Stop", "Exit"],
    "Terminate": ["End", "Cancel", "Stop"],
    "Average user": ["Typical user", "General user"],
    "Black box": ["Opaque system", "Unobservable system"],
    "White box": ["Transparent system", "Glass box testing"],
    "Black hat": ["Malicious hacker", "Unethical hacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Blocklist", "Denylist"],
    "Whitelist": ["Allowlist", "Approved list"],
    "Blind": ["Anonymous", "Unbiased"],
    "Double blind": ["Dual anonymous", "Impartial review"],
    "Male connector": ["Plug connector", "Pin connector"],
    "Female connector": ["Socket connector", "Receptacle connector"],
    "She": ["They"],
    "Her": ["Their"],
    "Hers": ["Theirs"],
    "He": ["They"],
    "Him": ["Them"],
    "His": ["Their"],
    "Master": ["Primary", "Main", "Leader"],
    "Slave": ["Secondary", "Replica", "Follower"],
    "Quantum supremacy": ["Quantum advantage", "Quantum superiority"],
    "Grandfathered": ["Legacy status", "Exempted"],
    "Guys": ["Everyone", "Team", "Folks"],
    "Man hours": ["Work hours", "Person hours"],
    "Sanity check": ["Quick check", "Validation check"],
    "Sanity test": ["Initial test", "Smoke test"],
    "Dummy value": ["Placeholder value", "Test value"],
    "Scrum master": ["Scrum lead", "Agile facilitator"],
    "Mob programming": ["Ensemble programming", "Collaborative programming"],
    "Segregation": ["Separation", "Division"],
    "Blackout period": ["Restricted period", "Downtime period"],
    "Gray hat": ["Ethical hacker", "Security researcher"],
    "Native": ["Built-in", "Default", "Integrated"],
    "Red team": ["Offensive security team", "Penetration testing team"],
    "Web master": ["Web administrator", "Site manager"],
    "White space": ["Blank space", "Open space"],
    "White team": ["Control team", "Oversight team"],
    "Yellow team": ["Security optimization team"],
    "Aboriginal": ["Indigenous"],
    "Brown bags": ["Lunch-and-learn sessions", "Informal learning sessions"],
    "Brown bag": ["Lunch-and-learn session", "Informal learning session"],
    "First-class citizen": ["Primary entity", "Core feature"],
    "First-class citizens": ["Primary entities", "Core features"],
    "Man-in-the-middle": ["Interception attack", "Relay attack"],
    "Master branch": ["Main branch", "Primary branch"],
    "Minority": ["Underrepresented group", "Marginalized group"],
    "Normal": ["Typical", "Standard", "Expected"],
    "Handicapped": ["Accessible", "Person with a disability"],
    "Crazy": ["Unconventional", "Unexpected", "Innovative"],
    "OCD": ["Detail-oriented", "Highly organized"],
    "Culture fit": ["Culture add", "Value alignment"],
    "Chairman": ["Chair", "Chairperson"],
    "Foreman": ["Supervisor", "Team lead"],
    "Man": ["Human", "Person"],
    "Mankind": ["Humanity", "Humankind"],
    "Mans": ["Operates", "Staffs"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Artificial", "Human-made", "Constructed"],
    "Manpower": ["Workforce", "Personnel", "Staffing"],
    "Demilitarized zone": ["Buffer zone", "Perimeter network"],
    "Demilitarized zones": ["Buffer zones", "Perimeter networks"],
    "DMZ": ["Network perimeter", "Security zone"],
    "Hang": ["Freeze", "Become unresponsive"],
    "Daughter board": ["Expansion board", "Auxiliary board"],
    "Gender bender": ["Gender adapter", "Connector adapter"],
    "Orphaned object": ["Unlinked object", "Unreferenced object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence          Harmful Term  \
# 13   The company detected a black hat attempting to...             Black hat
# 12   The company detected a black hat attempting to...             Black hat
# 27   The female connector allows for easy integrati...      Female connector
# 89   Functions are treated as first-class citizens ...  First-class citizens
# 87   The company hosted brown bag sessions to share...             Brown bag
# 88   Functions are treated as first-class citizens ...  First-class citizens
# 26   The female connector allows for easy integrati...      Female connector
# 86   The company hosted brown bag sessions to share...             Brown bag
# 141  The adapter functions as a gender bender for c...         Gender bender
# 62   The team opted for mob programming to tackle t...       Mob programming
# 10   The white box testing method allows developers...             White box
# 117  The foreman supervised the construction site w...               Foreman
# 116  The foreman supervised the construction site w...               Foreman
# 20   The paper underwent a blind review process to ...                 Blind
# 139  The new functionality was implemented through ...        Daughter board
# 11   The white box testing method allows developers...             White box
# 134  The server operates within the DMZ for added s...                   DMZ
# 54   A quick sanity test revealed several issues in...           Sanity test
# 113  The company prioritizes culture fit when hirin...           Culture fit
# 110  His desk organization reflects a hint of OCD t...                   OCD
# 21   The paper underwent a blind review process to ...                 Blind
# 69   The gray hat hacker reported the vulnerabiliti...              Gray hat
# 91   The man-in-the-middle attack intercepted sensi...     Man-in-the-middle
# 63   The team opted for mob programming to tackle t...       Mob programming
# 68   The gray hat hacker reported the vulnerabiliti...              Gray hat
# 61   The scrum master facilitated the daily stand-u...          Scrum master
# 84   The yellow team focused on optimizing the soft...           Yellow team
# 67   A blackout period was enforced during the syst...       Blackout period
# 74   The red team simulated an attack to test the o...              Red team
# 138  The new functionality was implemented through ...        Daughter board
# 36   The master database contains all the key recor...                Master
# 66   A blackout period was enforced during the syst...       Blackout period
# 75   The web master updated the website’s layout fo...                Master
# 135  The server operates within the DMZ for added s...                   DMZ
# 52   Before deploying the code, we need to perform ...          Sanity check
# 14   A white hat hacker helped identify security vu...             White hat
# 90   The man-in-the-middle attack intercepted sensi...     Man-in-the-middle
# 133  The network’s demilitarized zone protects inte...    Demilitarized zone
# 111  His desk organization reflects a hint of OCD t...                   OCD
# 83   The white team oversaw the cyber exercise and ...            White team
# 55   Developers use a dummy value as a placeholder ...           Dummy value
# 34   The master database contains all the key recor...                Master
# 15   A white hat hacker helped identify security vu...             White hat
# 28   She was responsible for coordinating the team’...                   She
# 73   The red team simulated an attack to test the o...              Red team
# 108  The plan was considered crazy but turned out t...                 Crazy
# 125  The salesman demonstrated the product’s key fe...              Salesman
# 122        The crew mans the ship during long voyages.                  Mans
# 25   The cable is equipped with a male connector fo...        Male connector
# 76   The web master updated the website’s layout fo...                Master
# 39   The secondary system operates as a slave to th...                 Slave
# 132  The network’s demilitarized zone protects inte...    Demilitarized zone
# 56   Developers use a dummy value as a placeholder ...           Dummy value
# 123        The crew mans the ship during long voyages.                  Mans
# 78   The web master updated the website’s layout fo...            Web master
# 51   Before deploying the code, we need to perform ...          Sanity check
# 30   The credit for the innovative design is entire...                  Hers
# 29   Her contribution to the discussion was insight...                   Her
# 24   The cable is equipped with a male connector fo...        Male connector
# 79   The web master updated the website’s layout fo...            Web master
# 106  The plan was considered crazy but turned out t...                 Crazy
# 40   Achieving quantum supremacy marks a significan...     Quantum supremacy
# 82   The white team oversaw the cyber exercise and ...            White team
# 35   The master database contains all the key recor...                Master
# 33   His programming skills greatly improved the pr...                   His
# 107  The plan was considered crazy but turned out t...                 Crazy
# 142  The cleanup script removed the orphaned object...       Orphaned object
# 77   The web master updated the website’s layout fo...                Master
# 131  The project required significant manpower to c...              Manpower
# 38   The secondary system operates as a slave to th...                 Slave
# 124  The salesman demonstrated the product’s key fe...              Salesman
# 137  The application tends to hang when handling la...                  Hang
# 96   Changes were merged into the master branch for...                Master
# 71   The app includes a native feature for photo ed...                Native
# 22   The experiment was conducted under double-blin...                 Blind
# 31   He led the presentation with confidence and cl...                    He
# 129  The project required significant manpower to c...              Manpower
# 104  The venue was upgraded to be accessible for ha...           Handicapped
# 37   The secondary system operates as a slave to th...                 Slave
# 43   The older software was grandfathered in despit...         Grandfathered
# 60   The scrum master facilitated the daily stand-u...          Scrum master
# 98   Changes were merged into the master branch for...         Master branch
# 94   Changes were merged into the master branch for...                Master
# 19   Only pre-approved devices are included in the ...             Whitelist
# 109  His desk organization reflects a hint of OCD t...                   His
# 8    The algorithm functions as a black box, with n...             Black box
# 130  The project required significant manpower to c...              Manpower
# 32    The team assigned the most critical task to him.                   Him
# 9    The algorithm functions as a black box, with n...             Black box
# 2    The program will automatically abort if a crit...                 Abort
# 18   Only pre-approved devices are included in the ...             Whitelist
# 114  The chairman called for a vote on the proposed...              Chairman
# 0    The program will automatically abort if a crit...                 Abort
# 143  The cleanup script removed the orphaned object...       Orphaned object
# 119  Man has always sought to understand the universe.                   Man
# 136  The application tends to hang when handling la...                  Hang
# 81   The designer added white space to improve the ...           White space
# 102  The system is back to normal after resolving t...                Normal
# 23   The experiment was conducted under double-blin...                 Blind
# 53   A quick sanity test revealed several issues in...           Sanity test
# 1    The program will automatically abort if a crit...                 Abort
# 57   The scrum master facilitated the daily stand-u...                Master
# 65   The system’s segregation of duties ensures sec...           Segregation
# 42   The older software was grandfathered in despit...         Grandfathered
# 105  The venue was upgraded to be accessible for ha...           Handicapped
# 95   Changes were merged into the master branch for...                Master
# 97   Changes were merged into the master branch for...         Master branch
# 93   The man-in-the-middle attack intercepted sensi...                   Man
# 118  Man has always sought to understand the universe.                   Man
# 140  The adapter functions as a gender bender for c...         Gender bender
# 100  Efforts to promote diversity aim to amplify th...              Minority
# 58   The scrum master facilitated the daily stand-u...                Master
# 99   Efforts to promote diversity aim to amplify th...              Minority
# 4    The user chose to terminate the installation p...             Terminate
# 70   The app includes a native feature for photo ed...                Native
# 17   The IP address was added to the company’s blac...             Blacklist
# 16   The IP address was added to the company’s blac...             Blacklist
# 72   The app includes a native feature for photo ed...                Native
# 126  The reservoir is a manmade structure designed ...               Manmade
# 85   The land’s history is deeply rooted in Aborigi...            Aboriginal
# 92   The man-in-the-middle attack intercepted sensi...                   Man
# 80   The designer added white space to improve the ...           White space
# 59   The scrum master facilitated the daily stand-u...                Master
# 115  The chairman called for a vote on the proposed...              Chairman
# 7    The app is designed to be intuitive for the av...          Average user
# 41   Achieving quantum supremacy marks a significan...     Quantum supremacy
# 112  The company prioritizes culture fit when hirin...           Culture fit
# 45   Hey guys, let’s gather for the meeting in five...                  Guys
# 101  The system is back to normal after resolving t...                Normal
# 128  The reservoir is a manmade structure designed ...               Manmade
# 6    The app is designed to be intuitive for the av...          Average user
# 103  The system is back to normal after resolving t...                Normal
# 64   The system’s segregation of duties ensures sec...           Segregation
# 127  The reservoir is a manmade structure designed ...               Manmade
# 121  Mankind has made significant strides in techno...               Mankind
# 5    The user chose to terminate the installation p...             Terminate
# 44   Hey guys, let’s gather for the meeting in five...                  Guys
# 47   Completing the project required 100 man hours ...             Man hours
# 120  Mankind has made significant strides in techno...               Mankind
# 48   Completing the project required 100 man hours ...             Man hours
# 50   Completing the project required 100 man hours ...                   Man
# 46   Hey guys, let’s gather for the meeting in five...                  Guys
# 3    The user chose to terminate the installation p...             Terminate
# 49   Completing the project required 100 man hours ...                   Man
#
#                     Replacement  \
# 13             Unethical hacker
# 12             Malicious hacker
# 27         Receptacle connector
# 89                Core features
# 87    Informal learning session
# 88             Primary entities
# 26             Socket connector
# 86      Lunch-and-learn session
# 141           Connector adapter
# 62         Ensemble programming
# 10           Transparent system
# 117                   Team lead
# 116                  Supervisor
# 20                    Anonymous
# 139             Auxiliary board
# 11            Glass box testing
# 134           Network perimeter
# 54                   Smoke test
# 113             Value alignment
# 110             Detail-oriented
# 21                     Unbiased
# 69          Security researcher
# 91                 Relay attack
# 63    Collaborative programming
# 68               Ethical hacker
# 61            Agile facilitator
# 84   Security optimization team
# 67              Downtime period
# 74     Penetration testing team
# 138             Expansion board
# 36                       Leader
# 66            Restricted period
# 75                      Primary
# 135               Security zone
# 52             Validation check
# 14               Ethical hacker
# 90          Interception attack
# 133           Perimeter network
# 111            Highly organized
# 83               Oversight team
# 55            Placeholder value
# 34                      Primary
# 15          Security researcher
# 28                         They
# 73      Offensive security team
# 108                  Innovative
# 125        Sales representative
# 122                    Operates
# 25                Pin connector
# 76                         Main
# 39                     Follower
# 132                 Buffer zone
# 56                   Test value
# 123                      Staffs
# 78            Web administrator
# 51                  Quick check
# 30                       Theirs
# 29                        Their
# 24               Plug connector
# 79                 Site manager
# 106              Unconventional
# 40            Quantum advantage
# 82                 Control team
# 35                         Main
# 33                        Their
# 107                  Unexpected
# 142             Unlinked object
# 77                       Leader
# 131                    Staffing
# 38                      Replica
# 124                 Salesperson
# 137         Become unresponsive
# 96                       Leader
# 71                      Default
# 22                    Anonymous
# 31                         They
# 129                   Workforce
# 104                  Accessible
# 37                    Secondary
# 43                     Exempted
# 60                   Scrum lead
# 98               Primary branch
# 94                      Primary
# 19                Approved list
# 109                       Their
# 8                 Opaque system
# 130                   Personnel
# 32                         Them
# 9           Unobservable system
# 2                          Exit
# 18                    Allowlist
# 114                       Chair
# 0                          Halt
# 143         Unreferenced object
# 119                      Person
# 136                      Freeze
# 81                   Open space
# 102                    Standard
# 23                     Unbiased
# 53                 Initial test
# 1                          Stop
# 57                      Primary
# 65                     Division
# 42                Legacy status
# 105    Person with a disability
# 95                         Main
# 97                  Main branch
# 93                       Person
# 118                       Human
# 140              Gender adapter
# 100          Marginalized group
# 58                         Main
# 99       Underrepresented group
# 4                        Cancel
# 70                     Built-in
# 17                     Denylist
# 16                    Blocklist
# 72                   Integrated
# 126                  Artificial
# 85                   Indigenous
# 92                        Human
# 80                  Blank space
# 59                       Leader
# 115                 Chairperson
# 7                  General user
# 41          Quantum superiority
# 112                 Culture add
# 45                         Team
# 101                     Typical
# 128                 Constructed
# 6                  Typical user
# 103                    Expected
# 64                   Separation
# 127                  Human-made
# 121                   Humankind
# 5                          Stop
# 44                     Everyone
# 47                   Work hours
# 120                    Humanity
# 48                 Person hours
# 50                       Person
# 46                        Folks
# 3                           End
# 49                        Human
#
#                                      Modified Sentence  Similarity Score
# 13   The company detected a Unethical hacker attemp...          0.584426
# 12   The company detected a Malicious hacker attemp...          0.601477
# 27   The Receptacle connector allows for easy integ...          0.627351
# 89   Functions are treated as Core features in many...          0.641356
# 87   The company hosted Informal learning session s...          0.674223
# 88   Functions are treated as Primary entities in m...          0.678419
# 26   The Socket connector allows for easy integrati...          0.679458
# 86   The company hosted Lunch-and-learn session ses...          0.695995
# 141  The adapter functions as a Connector adapter f...          0.703491
# 62   The team opted for Ensemble programming to tac...          0.721668
# 10   The Transparent system testing method allows d...          0.722767
# 117  The Team lead supervised the construction site...          0.734928
# 116  The Supervisor supervised the construction sit...          0.744094
# 20   The paper underwent a Anonymous review process...          0.744736
# 139  The new functionality was implemented through ...          0.750979
# 11   The Glass box testing testing method allows de...          0.750979
# 134  The server operates within the Network perimet...          0.756696
# 54   A quick Smoke test revealed several issues in ...          0.760604
# 113  The company prioritizes Value alignment when h...          0.761041
# 110  His desk organization reflects a hint of Detai...          0.762296
# 21   The paper underwent a Unbiased review process ...          0.766030
# 69   The Security researcher hacker reported the vu...          0.774555
# 91   The Relay attack attack intercepted sensitive ...          0.777748
# 63   The team opted for Collaborative programming t...          0.777778
# 68   The Ethical hacker hacker reported the vulnera...          0.777916
# 61   The Agile facilitator facilitated the daily st...          0.781870
# 84   The Security optimization team focused on opti...          0.783778
# 67   A Downtime period was enforced during the syst...          0.785668
# 74   The Penetration testing team simulated an atta...          0.787184
# 138  The new functionality was implemented through ...          0.787963
# 36   The Leader database contains all the key recor...          0.805919
# 66   A Restricted period was enforced during the sy...          0.810575
# 75   The web Primary updated the website’s layout f...          0.810848
# 135  The server operates within the Security zone f...          0.811244
# 52   Before deploying the code, we need to perform ...          0.815887
# 14   A Ethical hacker hacker helped identify securi...          0.817126
# 90   The Interception attack attack intercepted sen...          0.817796
# 133  The network’s Perimeter network protects inter...          0.824664
# 111  His desk organization reflects a hint of Highl...          0.824690
# 83   The Oversight team oversaw the cyber exercise ...          0.826038
# 55   Developers use a Placeholder value as a placeh...          0.829454
# 34   The Primary database contains all the key reco...          0.832613
# 15   A Security researcher hacker helped identify s...          0.832633
# 28   They was responsible for coordinating the team...          0.836792
# 73   The Offensive security team simulated an attac...          0.838205
# 108  The plan was considered Innovative but turned ...          0.840000
# 125  The Sales representative demonstrated the prod...          0.842884
# 122    The crew Operates the ship during long voyages.          0.843587
# 25   The cable is equipped with a Pin connector for...          0.844309
# 76   The web Main updated the website’s layout for ...          0.845296
# 39   The secondary system operates as a Follower to...          0.849255
# 132  The network’s Buffer zone protects internal sy...          0.849631
# 56   Developers use a Test value as a placeholder d...          0.850563
# 123      The crew Staffs the ship during long voyages.          0.851084
# 78   The Web administrator updated the website’s la...          0.852008
# 51   Before deploying the code, we need to perform ...          0.854385
# 30   The credit for the innovative design is entire...          0.856372
# 29   Their contribution to the discussion was insig...          0.857565
# 24   The cable is equipped with a Plug connector fo...          0.860130
# 79   The Site manager updated the website’s layout ...          0.865234
# 106  The plan was considered Unconventional but tur...          0.867457
# 40   Achieving Quantum advantage marks a significan...          0.867519
# 82   The Control team oversaw the cyber exercise an...          0.867743
# 35   The Main database contains all the key records...          0.872235
# 33   Their programming skills greatly improved the ...          0.873098
# 107  The plan was considered Unexpected but turned ...          0.874205
# 142  The cleanup script removed the Unlinked object...          0.875080
# 77   The web Leader updated the website’s layout fo...          0.876580
# 131  The project required significant Staffing to c...          0.876994
# 38   The secondary system operates as a Replica to ...          0.877979
# 124  The Salesperson demonstrated the product’s key...          0.878644
# 137  The application tends to Become unresponsive w...          0.879780
# 96   Changes were merged into the Leader branch for...          0.880295
# 71   The app includes a Default feature for photo e...          0.880555
# 22   The experiment was conducted under double-Anon...          0.883819
# 31   They led the presentation with confidence and ...          0.886162
# 129  The project required significant Workforce to ...          0.888754
# 104  The venue was upgraded to be accessible for Ac...          0.891089
# 37   The secondary system operates as a Secondary t...          0.892284
# 43   The older software was Exempted in despite the...          0.892654
# 60   The Scrum lead facilitated the daily stand-up ...          0.894375
# 98   Changes were merged into the Primary branch fo...          0.894577
# 94   Changes were merged into the Primary branch fo...          0.894577
# 19   Only pre-approved devices are included in the ...          0.897469
# 109  Their desk organization reflects a hint of OCD...          0.897488
# 8    The algorithm functions as a Opaque system, wi...          0.898719
# 130  The project required significant Personnel to ...          0.898788
# 32   The team assigned the most critical task to Them.          0.900533
# 9    The algorithm functions as a Unobservable syst...          0.900653
# 2    The program will automatically Exit if a criti...          0.900890
# 18   Only pre-approved devices are included in the ...          0.901145
# 114  The Chair called for a vote on the proposed ch...          0.903277
# 0    The program will automatically Halt if a criti...          0.909458
# 143  The cleanup script removed the Unreferenced ob...          0.911102
# 119  Person has always sought to understand the uni...          0.911396
# 136  The application tends to Freeze when handling ...          0.914745
# 81   The designer added Open space to improve the p...          0.920765
# 102  The system is back to Standard after resolving...          0.921492
# 23   The experiment was conducted under double-Unbi...          0.921516
# 53   A quick Initial test revealed several issues i...          0.921538
# 1    The program will automatically Stop if a criti...          0.922640
# 57   The scrum Primary facilitated the daily stand-...          0.923873
# 65   The system’s Division of duties ensures secure...          0.924723
# 42   The older software was Legacy status in despit...          0.925821
# 105  The venue was upgraded to be accessible for Pe...          0.926213
# 95   Changes were merged into the Main branch for d...          0.928553
# 97   Changes were merged into the Main branch for d...          0.928553
# 93   The Person-in-the-middle attack intercepted se...          0.929446
# 118  Human has always sought to understand the univ...          0.931410
# 140  The adapter functions as a Gender adapter for ...          0.931559
# 100  Efforts to promote diversity aim to amplify th...          0.931869
# 58   The scrum Main facilitated the daily stand-up ...          0.932176
# 99   Efforts to promote diversity aim to amplify th...          0.932201
# 4    The user chose to Cancel the installation proc...          0.936486
# 70   The app includes a Built-in feature for photo ...          0.937234
# 17   The IP address was added to the company’s Deny...          0.937353
# 16   The IP address was added to the company’s Bloc...          0.937636
# 72   The app includes a Integrated feature for phot...          0.938498
# 126  The reservoir is a Artificial structure design...          0.939255
# 85   The land’s history is deeply rooted in Indigen...          0.939329
# 92   The Human-in-the-middle attack intercepted sen...          0.941567
# 80   The designer added Blank space to improve the ...          0.942629
# 59   The scrum Leader facilitated the daily stand-u...          0.942709
# 115  The Chairperson called for a vote on the propo...          0.943595
# 7    The app is designed to be intuitive for the Ge...          0.944776
# 41   Achieving Quantum superiority marks a signific...          0.946091
# 112  The company prioritizes Culture add when hirin...          0.949814
# 45   Hey Team, let’s gather for the meeting in five...          0.950417
# 101  The system is back to Typical after resolving ...          0.950920
# 128  The reservoir is a Constructed structure desig...          0.953625
# 6    The app is designed to be intuitive for the Ty...          0.955607
# 103  The system is back to Expected after resolving...          0.956891
# 64   The system’s Separation of duties ensures secu...          0.958804
# 127  The reservoir is a Human-made structure design...          0.960701
# 121  Humankind has made significant strides in tech...          0.961535
# 5    The user chose to Stop the installation proces...          0.964866
# 44   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 47   Completing the project required 100 Work hours...          0.965177
# 120  Humanity has made significant strides in techn...          0.968785
# 48   Completing the project required 100 Person hou...          0.970870
# 50   Completing the project required 100 Person hou...          0.970870
# 46   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 3    The user chose to End the installation process...          0.975999
# 49   Completing the project required 100 Human hour...          0.980357

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4-1_replacements.csv", index=False)

# %%
# PROMPT 2:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Stop", "Halt", "Cancel"],
    "Terminate": ["End", "Cancel", "Stop"],
    "Average user": ["Typical user", "General user", "Standard user"],
    "Black box": ["Opaque system", "Closed system"],
    "White box": ["Transparent system", "Open system"],
    "Black hat": ["Malicious hacker", "Unethical hacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Blocklist", "Denylist"],
    "Whitelist": ["Allowlist", "Safelist"],
    "Blind": ["Anonymous", "Unbiased"],
    "Double blind": ["Double-anonymous", "Fully blinded"],
    "Male connector": ["Plug connector", "Insert connector"],
    "Female connector": ["Socket connector", "Receptacle connector"],
    "She/Her/Hers/He/Him/His": ["They/Them"],
    "Master": ["Primary", "Main", "Leader"],
    "Slave": ["Secondary", "Replica", "Worker"],
    "Quantum supremacy": ["Quantum advantage", "Quantum breakthrough"],
    "Grandfathered": ["Legacy status", "Exempt from new rules"],
    "Guys": ["Everyone", "Team", "Folks", "All"],
    "Man hours": ["Person hours", "Work hours", "Effort hours"],
    "Sanity check": ["Quick check", "Logic check", "Coherence check"],
    "Sanity test": ["Smoke test", "Preliminary test"],
    "Dummy value": ["Placeholder value", "Sample value"],
    "Scrum master": ["Scrum lead", "Agile facilitator"],
    "Mob programming": ["Collaborative programming", "Team programming"],
    "Segregation": ["Separation", "Division"],
    "Blackout period": ["Restricted period", "Downtime"],
    "Gray hat": ["Ethical hacker", "Security researcher"],
    "Native (in software)": ["Built-in", "Integrated", "First-party"],
    "Red team": ["Offensive security team", "Penetration testing team"],
    "Web master": ["Website administrator", "Web administrator"],
    "White space": ["Blank space", "Empty space"],
    "White team": ["Oversight team", "Neutral team"],
    "Yellow team": ["Security optimization team"],
    "Aboriginal": ["Indigenous"],
    "Brown bags": ["Lunch-and-learn sessions", "Informal learning sessions"],
    "First-class citizen": ["Core feature", "Fundamental entity"],
    "Man-in-the-middle": ["Intermediary attack", "Network interception attack"],
    "Master branch": ["Main branch", "Primary branch"],
    "Minority": ["Underrepresented group"],
    "Normal": ["Typical", "Expected", "Standard"],
    "Handicapped": ["Accessible", "Person with a disability"],
    "Crazy": ["Unconventional", "Wild", "Bold"],
    "OCD": ["Detail-oriented", "Meticulous"],
    "Culture fit": ["Culture add", "Value alignment"],
    "Chairman": ["Chair", "Chairperson"],
    "Foreman": ["Supervisor", "Lead worker"],
    "Man": ["Humanity", "People", "Humans"],
    "Mankind": ["Humankind", "Humanity"],
    "Mans": ["Operates", "Runs", "Staffs"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Human-made", "Artificial", "Constructed"],
    "Manpower": ["Workforce", "Staffing", "Labor"],
    "Demilitarized zone": ["Perimeter network", "Buffer zone"],
    "DMZ": ["Perimeter network", "Secure zone"],
    "Hang (application)": ["Freeze", "Become unresponsive"],
    "Daughter board": ["Expansion board", "Auxiliary board"],
    "Gender bender": ["Adapter", "Connector adapter"],
    "Orphaned object": ["Unlinked object", "Disconnected object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence        Harmful Term  \
# 14   The company detected a black hat attempting to...           Black hat
# 13   The company detected a black hat attempting to...           Black hat
# 28   The female connector allows for easy integrati...    Female connector
# 27   The female connector allows for easy integrati...    Female connector
# 132  The adapter functions as a gender bender for c...       Gender bender
# 108  The foreman supervised the construction site w...             Foreman
# 11   The white box testing method allows developers...           White box
# 131  The adapter functions as a gender bender for c...       Gender bender
# 127  The server operates within the DMZ for added s...                 DMZ
# 66   A blackout period was enforced during the syst...     Blackout period
# 107  The foreman supervised the construction site w...             Foreman
# 21   The paper underwent a blind review process to ...               Blind
# 130  The new functionality was implemented through ...      Daughter board
# 12   The white box testing method allows developers...           White box
# 52   A quick sanity test revealed several issues in...         Sanity test
# 104  The company prioritizes culture fit when hirin...         Culture fit
# 101  His desk organization reflects a hint of OCD t...                 OCD
# 22   The paper underwent a blind review process to ...               Blind
# 68   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 61   The team opted for mob programming to tackle t...     Mob programming
# 67   The gray hat hacker reported the vulnerabiliti...            Gray hat
# 60   The scrum master facilitated the daily stand-u...        Scrum master
# 80   The yellow team focused on optimizing the soft...         Yellow team
# 70   The red team simulated an attack to test the o...            Red team
# 129  The new functionality was implemented through ...      Daughter board
# 83   The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 128  The server operates within the DMZ for added s...                 DMZ
# 100  The plan was considered crazy but turned out t...               Crazy
# 55   Developers use a dummy value as a placeholder ...         Dummy value
# 62   The team opted for mob programming to tackle t...     Mob programming
# 31   The master database contains all the key recor...              Master
# 65   A blackout period was enforced during the syst...     Blackout period
# 71   The web master updated the website’s layout fo...              Master
# 15   A white hat hacker helped identify security vu...           White hat
# 115        The crew mans the ship during long voyages.                Mans
# 82   The man-in-the-middle attack intercepted sensi...   Man-in-the-middle
# 125  The network’s demilitarized zone protects inte...  Demilitarized zone
# 78   The white team oversaw the cyber exercise and ...          White team
# 38   The older software was grandfathered in despit...       Grandfathered
# 74   The web master updated the website’s layout fo...          Web master
# 54   Developers use a dummy value as a placeholder ...         Dummy value
# 29   The master database contains all the key recor...              Master
# 16   A white hat hacker helped identify security vu...           White hat
# 124  The project required significant manpower to c...            Manpower
# 26   The cable is equipped with a male connector fo...      Male connector
# 69   The red team simulated an attack to test the o...            Red team
# 51   Before deploying the code, we need to perform ...        Sanity check
# 118  The salesman demonstrated the product’s key fe...            Salesman
# 114        The crew mans the ship during long voyages.                Mans
# 102  His desk organization reflects a hint of OCD t...                 OCD
# 72   The web master updated the website’s layout fo...              Master
# 99   The plan was considered crazy but turned out t...               Crazy
# 126  The network’s demilitarized zone protects inte...  Demilitarized zone
# 116        The crew mans the ship during long voyages.                Mans
# 75   The web master updated the website’s layout fo...          Web master
# 49   Before deploying the code, we need to perform ...        Sanity check
# 50   Before deploying the code, we need to perform ...        Sanity check
# 79   The white team oversaw the cyber exercise and ...          White team
# 134  The cleanup script removed the orphaned object...     Orphaned object
# 25   The cable is equipped with a male connector fo...      Male connector
# 98   The plan was considered crazy but turned out t...               Crazy
# 35   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 34   The secondary system operates as a slave to th...               Slave
# 20   Only pre-approved devices are included in the ...           Whitelist
# 30   The master database contains all the key recor...              Master
# 133  The cleanup script removed the orphaned object...     Orphaned object
# 73   The web master updated the website’s layout fo...              Master
# 123  The project required significant manpower to c...            Manpower
# 36   Achieving quantum supremacy marks a significan...   Quantum supremacy
# 33   The secondary system operates as a slave to th...               Slave
# 117  The salesman demonstrated the product’s key fe...            Salesman
# 89   Changes were merged into the master branch for...              Master
# 23   The experiment was conducted under double-blin...               Blind
# 122  The project required significant manpower to c...            Manpower
# 10   The algorithm functions as a black box, with n...           Black box
# 96   The venue was upgraded to be accessible for ha...         Handicapped
# 32   The secondary system operates as a slave to th...               Slave
# 59   The scrum master facilitated the daily stand-u...        Scrum master
# 87   Changes were merged into the master branch for...              Master
# 91   Changes were merged into the master branch for...       Master branch
# 109  Man has always sought to understand the universe.                 Man
# 9    The algorithm functions as a black box, with n...           Black box
# 110  Man has always sought to understand the universe.                 Man
# 111  Man has always sought to understand the universe.                 Man
# 19   Only pre-approved devices are included in the ...           Whitelist
# 53   A quick sanity test revealed several issues in...         Sanity test
# 105  The chairman called for a vote on the proposed...            Chairman
# 84   The man-in-the-middle attack intercepted sensi...                 Man
# 2    The program will automatically abort if a crit...               Abort
# 1    The program will automatically abort if a crit...               Abort
# 77   The designer added white space to improve the ...         White space
# 46   Completing the project required 100 man hours ...                 Man
# 95   The system is back to normal after resolving t...              Normal
# 24   The experiment was conducted under double-blin...               Blind
# 0    The program will automatically abort if a crit...               Abort
# 56   The scrum master facilitated the daily stand-u...              Master
# 64   The system’s segregation of duties ensures sec...         Segregation
# 86   The man-in-the-middle attack intercepted sensi...                 Man
# 37   The older software was grandfathered in despit...       Grandfathered
# 97   The venue was upgraded to be accessible for ha...         Handicapped
# 88   Changes were merged into the master branch for...              Master
# 90   Changes were merged into the master branch for...       Master branch
# 85   The man-in-the-middle attack intercepted sensi...                 Man
# 8    The app is designed to be intuitive for the av...        Average user
# 57   The scrum master facilitated the daily stand-u...              Master
# 92   Efforts to promote diversity aim to amplify th...            Minority
# 4    The user chose to terminate the installation p...           Terminate
# 18   The IP address was added to the company’s blac...           Blacklist
# 17   The IP address was added to the company’s blac...           Blacklist
# 120  The reservoir is a manmade structure designed ...             Manmade
# 81   The land’s history is deeply rooted in Aborigi...          Aboriginal
# 76   The designer added white space to improve the ...         White space
# 58   The scrum master facilitated the daily stand-u...              Master
# 106  The chairman called for a vote on the proposed...            Chairman
# 7    The app is designed to be intuitive for the av...        Average user
# 48   Completing the project required 100 man hours ...                 Man
# 103  The company prioritizes culture fit when hirin...         Culture fit
# 40   Hey guys, let’s gather for the meeting in five...                Guys
# 93   The system is back to normal after resolving t...              Normal
# 121  The reservoir is a manmade structure designed ...             Manmade
# 6    The app is designed to be intuitive for the av...        Average user
# 94   The system is back to normal after resolving t...              Normal
# 45   Completing the project required 100 man hours ...           Man hours
# 63   The system’s segregation of duties ensures sec...         Segregation
# 47   Completing the project required 100 man hours ...                 Man
# 119  The reservoir is a manmade structure designed ...             Manmade
# 112  Mankind has made significant strides in techno...             Mankind
# 5    The user chose to terminate the installation p...           Terminate
# 39   Hey guys, let’s gather for the meeting in five...                Guys
# 44   Completing the project required 100 man hours ...           Man hours
# 113  Mankind has made significant strides in techno...             Mankind
# 42   Hey guys, let’s gather for the meeting in five...                Guys
# 43   Completing the project required 100 man hours ...           Man hours
# 41   Hey guys, let’s gather for the meeting in five...                Guys
# 3    The user chose to terminate the installation p...           Terminate
#
#                      Replacement  \
# 14              Unethical hacker
# 13              Malicious hacker
# 28          Receptacle connector
# 27              Socket connector
# 132            Connector adapter
# 108                  Lead worker
# 11            Transparent system
# 131                      Adapter
# 127            Perimeter network
# 66                      Downtime
# 107                   Supervisor
# 21                     Anonymous
# 130              Auxiliary board
# 12                   Open system
# 52                    Smoke test
# 104              Value alignment
# 101              Detail-oriented
# 22                      Unbiased
# 68           Security researcher
# 61     Collaborative programming
# 67                Ethical hacker
# 60             Agile facilitator
# 80    Security optimization team
# 70      Penetration testing team
# 129              Expansion board
# 83   Network interception attack
# 128                  Secure zone
# 100                         Bold
# 55                  Sample value
# 62              Team programming
# 31                        Leader
# 65             Restricted period
# 71                       Primary
# 15                Ethical hacker
# 115                         Runs
# 82           Intermediary attack
# 125            Perimeter network
# 78                Oversight team
# 38         Exempt from new rules
# 74         Website administrator
# 54             Placeholder value
# 29                       Primary
# 16           Security researcher
# 124                        Labor
# 26              Insert connector
# 69       Offensive security team
# 51               Coherence check
# 118         Sales representative
# 114                     Operates
# 102                   Meticulous
# 72                          Main
# 99                          Wild
# 126                  Buffer zone
# 116                       Staffs
# 75             Web administrator
# 49                   Quick check
# 50                   Logic check
# 79                  Neutral team
# 134          Disconnected object
# 25                Plug connector
# 98                Unconventional
# 35             Quantum advantage
# 34                        Worker
# 20                      Safelist
# 30                          Main
# 133              Unlinked object
# 73                        Leader
# 123                     Staffing
# 36          Quantum breakthrough
# 33                       Replica
# 117                  Salesperson
# 89                        Leader
# 23                     Anonymous
# 122                    Workforce
# 10                 Closed system
# 96                    Accessible
# 32                     Secondary
# 59                    Scrum lead
# 87                       Primary
# 91                Primary branch
# 109                     Humanity
# 9                  Opaque system
# 110                       People
# 111                       Humans
# 19                     Allowlist
# 53              Preliminary test
# 105                        Chair
# 84                      Humanity
# 2                         Cancel
# 1                           Halt
# 77                   Empty space
# 46                      Humanity
# 95                      Standard
# 24                      Unbiased
# 0                           Stop
# 56                       Primary
# 64                      Division
# 86                        Humans
# 37                 Legacy status
# 97      Person with a disability
# 88                          Main
# 90                   Main branch
# 85                        People
# 8                  Standard user
# 57                          Main
# 92        Underrepresented group
# 4                         Cancel
# 18                      Denylist
# 17                     Blocklist
# 120                   Artificial
# 81                    Indigenous
# 76                   Blank space
# 58                        Leader
# 106                  Chairperson
# 7                   General user
# 48                        Humans
# 103                  Culture add
# 40                          Team
# 93                       Typical
# 121                  Constructed
# 6                   Typical user
# 94                      Expected
# 45                  Effort hours
# 63                    Separation
# 47                        People
# 119                   Human-made
# 112                    Humankind
# 5                           Stop
# 39                      Everyone
# 44                    Work hours
# 113                     Humanity
# 42                           All
# 43                  Person hours
# 41                         Folks
# 3                            End
#
#                                      Modified Sentence  Similarity Score
# 14   The company detected a Unethical hacker attemp...          0.584426
# 13   The company detected a Malicious hacker attemp...          0.601477
# 28   The Receptacle connector allows for easy integ...          0.627351
# 27   The Socket connector allows for easy integrati...          0.679458
# 132  The adapter functions as a Connector adapter f...          0.703491
# 108  The Lead worker supervised the construction si...          0.712054
# 11   The Transparent system testing method allows d...          0.722767
# 131  The adapter functions as a Adapter for connect...          0.727360
# 127  The server operates within the Perimeter netwo...          0.728124
# 66   A Downtime was enforced during the system upgr...          0.728261
# 107  The Supervisor supervised the construction sit...          0.744094
# 21   The paper underwent a Anonymous review process...          0.744736
# 130  The new functionality was implemented through ...          0.750979
# 12   The Open system testing method allows develope...          0.751868
# 52   A quick Smoke test revealed several issues in ...          0.760604
# 104  The company prioritizes Value alignment when h...          0.761041
# 101  His desk organization reflects a hint of Detai...          0.762296
# 22   The paper underwent a Unbiased review process ...          0.766030
# 68   The Security researcher hacker reported the vu...          0.774555
# 61   The team opted for Collaborative programming t...          0.777778
# 67   The Ethical hacker hacker reported the vulnera...          0.777916
# 60   The Agile facilitator facilitated the daily st...          0.781870
# 80   The Security optimization team focused on opti...          0.783778
# 70   The Penetration testing team simulated an atta...          0.787184
# 129  The new functionality was implemented through ...          0.787963
# 83   The Network interception attack attack interce...          0.788320
# 128  The server operates within the Secure zone for...          0.791678
# 100  The plan was considered Bold but turned out to...          0.792576
# 55   Developers use a Sample value as a placeholder...          0.795430
# 62   The team opted for Team programming to tackle ...          0.801736
# 31   The Leader database contains all the key recor...          0.805919
# 65   A Restricted period was enforced during the sy...          0.810575
# 71   The web Primary updated the website’s layout f...          0.810848
# 15   A Ethical hacker hacker helped identify securi...          0.817126
# 115        The crew Runs the ship during long voyages.          0.819893
# 82   The Intermediary attack attack intercepted sen...          0.824432
# 125  The network’s Perimeter network protects inter...          0.824664
# 78   The Oversight team oversaw the cyber exercise ...          0.826038
# 38   The older software was Exempt from new rules i...          0.826695
# 74   The Website administrator updated the website’...          0.827574
# 54   Developers use a Placeholder value as a placeh...          0.829454
# 29   The Primary database contains all the key reco...          0.832613
# 16   A Security researcher hacker helped identify s...          0.832633
# 124  The project required significant Labor to comp...          0.833852
# 26   The cable is equipped with a Insert connector ...          0.836977
# 69   The Offensive security team simulated an attac...          0.838205
# 51   Before deploying the code, we need to perform ...          0.842882
# 118  The Sales representative demonstrated the prod...          0.842884
# 114    The crew Operates the ship during long voyages.          0.843587
# 102  His desk organization reflects a hint of Metic...          0.844329
# 72   The web Main updated the website’s layout for ...          0.845296
# 99   The plan was considered Wild but turned out to...          0.846853
# 126  The network’s Buffer zone protects internal sy...          0.849631
# 116      The crew Staffs the ship during long voyages.          0.851084
# 75   The Web administrator updated the website’s la...          0.852008
# 49   Before deploying the code, we need to perform ...          0.854385
# 50   Before deploying the code, we need to perform ...          0.855941
# 79   The Neutral team oversaw the cyber exercise an...          0.858996
# 134  The cleanup script removed the Disconnected ob...          0.859831
# 25   The cable is equipped with a Plug connector fo...          0.860130
# 98   The plan was considered Unconventional but tur...          0.867457
# 35   Achieving Quantum advantage marks a significan...          0.867519
# 34   The secondary system operates as a Worker to t...          0.867971
# 20   Only pre-approved devices are included in the ...          0.870903
# 30   The Main database contains all the key records...          0.872235
# 133  The cleanup script removed the Unlinked object...          0.875080
# 73   The web Leader updated the website’s layout fo...          0.876580
# 123  The project required significant Staffing to c...          0.876994
# 36   Achieving Quantum breakthrough marks a signifi...          0.877870
# 33   The secondary system operates as a Replica to ...          0.877979
# 117  The Salesperson demonstrated the product’s key...          0.878644
# 89   Changes were merged into the Leader branch for...          0.880295
# 23   The experiment was conducted under double-Anon...          0.883819
# 122  The project required significant Workforce to ...          0.888754
# 10   The algorithm functions as a Closed system, wi...          0.889084
# 96   The venue was upgraded to be accessible for Ac...          0.891089
# 32   The secondary system operates as a Secondary t...          0.892284
# 59   The Scrum lead facilitated the daily stand-up ...          0.894375
# 87   Changes were merged into the Primary branch fo...          0.894577
# 91   Changes were merged into the Primary branch fo...          0.894577
# 109  Humanity has always sought to understand the u...          0.895734
# 9    The algorithm functions as a Opaque system, wi...          0.898719
# 110  People has always sought to understand the uni...          0.899577
# 111  Humans has always sought to understand the uni...          0.900007
# 19   Only pre-approved devices are included in the ...          0.901145
# 53   A quick Preliminary test revealed several issu...          0.902828
# 105  The Chair called for a vote on the proposed ch...          0.903277
# 84   The Humanity-in-the-middle attack intercepted ...          0.906904
# 2    The program will automatically Cancel if a cri...          0.908169
# 1    The program will automatically Halt if a criti...          0.909458
# 77   The designer added Empty space to improve the ...          0.918833
# 46   Completing the project required 100 Humanity h...          0.920907
# 95   The system is back to Standard after resolving...          0.921492
# 24   The experiment was conducted under double-Unbi...          0.921516
# 0    The program will automatically Stop if a criti...          0.922640
# 56   The scrum Primary facilitated the daily stand-...          0.923873
# 64   The system’s Division of duties ensures secure...          0.924723
# 86   The Humans-in-the-middle attack intercepted se...          0.925123
# 37   The older software was Legacy status in despit...          0.925821
# 97   The venue was upgraded to be accessible for Pe...          0.926213
# 88   Changes were merged into the Main branch for d...          0.928553
# 90   Changes were merged into the Main branch for d...          0.928553
# 85   The People-in-the-middle attack intercepted se...          0.929361
# 8    The app is designed to be intuitive for the St...          0.929824
# 57   The scrum Main facilitated the daily stand-up ...          0.932176
# 92   Efforts to promote diversity aim to amplify th...          0.932201
# 4    The user chose to Cancel the installation proc...          0.936486
# 18   The IP address was added to the company’s Deny...          0.937353
# 17   The IP address was added to the company’s Bloc...          0.937636
# 120  The reservoir is a Artificial structure design...          0.939255
# 81   The land’s history is deeply rooted in Indigen...          0.939329
# 76   The designer added Blank space to improve the ...          0.942629
# 58   The scrum Leader facilitated the daily stand-u...          0.942709
# 106  The Chairperson called for a vote on the propo...          0.943595
# 7    The app is designed to be intuitive for the Ge...          0.944776
# 48   Completing the project required 100 Humans hou...          0.946899
# 103  The company prioritizes Culture add when hirin...          0.949814
# 40   Hey Team, let’s gather for the meeting in five...          0.950417
# 93   The system is back to Typical after resolving ...          0.950920
# 121  The reservoir is a Constructed structure desig...          0.953625
# 6    The app is designed to be intuitive for the Ty...          0.955607
# 94   The system is back to Expected after resolving...          0.956891
# 45   Completing the project required 100 Effort hou...          0.958456
# 63   The system’s Separation of duties ensures secu...          0.958804
# 47   Completing the project required 100 People hou...          0.959826
# 119  The reservoir is a Human-made structure design...          0.960701
# 112  Humankind has made significant strides in tech...          0.961535
# 5    The user chose to Stop the installation proces...          0.964866
# 39   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 44   Completing the project required 100 Work hours...          0.965177
# 113  Humanity has made significant strides in techn...          0.968785
# 42   Hey All, let’s gather for the meeting in five ...          0.970328
# 43   Completing the project required 100 Person hou...          0.970870
# 41   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 3    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4-2_replacements.csv", index=False)

# %%
# PROMPT 3:

from sentence_transformers import SentenceTransformer, util
import pandas as pd
import re

# Load the SBERT model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Dictionary of terms and their replacements (all 64 terms)
harmful_terms = {
    "Abort": ["Halt", "Stop", "Cancel"],
    "Terminate": ["End", "Stop", "Complete"],
    "Average user": ["Typical user", "General user"],
    "Black box": ["Opaque system", "Unobservable process"],
    "White box": ["Transparent system", "Open process"],
    "Black hat": ["Malicious hacker", "Unauthorized attacker"],
    "White hat": ["Ethical hacker", "Security researcher"],
    "Blacklist": ["Blocklist", "Denylist"],
    "Whitelist": ["Allowlist", "Approved list"],
    "Blind": ["Anonymous", "Unbiased"],
    "Double blind": ["Fully anonymous", "Unbiased testing"],
    "Male connector": ["Plug", "Insert connector"],
    "Female connector": ["Socket", "Receiving connector"],
    "She": ["They", "Use specific names"],
    "Her": ["Their", "Use specific names"],
    "Hers": ["Theirs", "Use specific names"],
    "He": ["They", "Use specific names"],
    "Him": ["Them", "Use specific names"],
    "His": ["Their", "Use specific names"],
    "Master": ["Primary", "Main"],
    "Slave": ["Secondary", "Replica", "Worker"],
    "Quantum supremacy": ["Quantum advantage", "Quantum breakthrough"],
    "Grandfathered": ["Legacy status", "Exempted"],
    "Guys": ["Everyone", "Team", "Folks"],
    "Man hours": ["Person hours", "Work hours"],
    "Sanity check": ["Quick check", "Validation check"],
    "Sanity test": ["Preliminary test", "Basic functionality test"],
    "Dummy value": ["Placeholder value", "Test value"],
    "Scrum master": ["Scrum lead", "Scrum facilitator"],
    "Mob programming": ["Ensemble programming", "Group programming"],
    "Segregation": ["Separation", "Division"],
    "Blackout period": ["Restricted period", "Downtime"],
    "Gray hat": ["Independent security researcher"],
    "Native": ["Built-in", "Default"],
    "Red team": ["Offensive security team", "Attack simulation team"],
    "Web master": ["Website administrator", "Web manager"],
    "White space": ["Empty space", "Spacing"],
    "White team": ["Neutral team", "Oversight team"],
    "Yellow team": ["Security optimization team"],
    "Aboriginal": ["Indigenous"],
    "Brown bags": ["Lunch-and-learn sessions"],
    "Brown bag": ["Lunch-and-learn session"],
    "First-class citizen": ["Core feature", "Primary element"],
    "First-class citizens": ["Core features", "Primary elements"],
    "Man-in-the-middle": ["Interception attack", "Relay attack"],
    "Master branch": ["Main branch", "Primary branch"],
    "Minority": ["Underrepresented group", "Marginalized group"],
    "Normal": ["Expected", "Standard"],
    "Handicapped": ["Accessible", "Person with a disability"],
    "Crazy": ["Unconventional", "Unexpected"],
    "OCD": ["Highly organized", "Detail-oriented"],
    "Culture fit": ["Culture add", "Value alignment"],
    "Chairman": ["Chair", "Chairperson"],
    "Foreman": ["Supervisor", "Team lead"],
    "Man": ["Humanity", "People"],
    "Mankind": ["Humankind", "Humanity"],
    "Mans": ["Staffs", "Operates"],
    "Salesman": ["Salesperson", "Sales representative"],
    "Manmade": ["Artificial", "Human-made"],
    "Manpower": ["Workforce", "Personnel"],
    "Demilitarized zone": ["Perimeter network", "Buffer zone"],
    "Demilitarized zones": ["Perimeter networks", "Buffer zones"],
    "DMZ": ["Perimeter network", "Isolated network"],
    "Hang": ["Freeze", "Become unresponsive"],
    "Daughter board": ["Auxiliary board", "Expansion board"],
    "Gender bender": ["Adapter", "Converter"],
    "Orphaned object": ["Unlinked object", "Unassociated object"]
}

# Example sentences that include harmful terms
original_sentences = [
    "The program will automatically abort if a critical error occurs during execution.", 
    "The user chose to terminate the installation process after encountering an error.", 
    "The app is designed to be intuitive for the average user.", 
    "The algorithm functions as a black box, with no transparency about how decisions are made.", 
    "The white box testing method allows developers to see the internal workings of the code.", 
    "The company detected a black hat attempting to infiltrate their systems.", 
    "A white hat hacker helped identify security vulnerabilities in the new software.", 
    "The IP address was added to the company’s blacklist after repeated failed login attempts.", 
    "Only pre-approved devices are included in the network’s whitelist.", 
    "The paper underwent a blind review process to ensure impartiality.", 
    "The experiment was conducted under double-blind conditions to eliminate bias.", 
    "The cable is equipped with a male connector for compatibility with standard ports.", 
    "The female connector allows for easy integration with other components.", 
    "She was responsible for coordinating the team’s efforts on the project.", 
    "Her contribution to the discussion was insightful and appreciated.", 
    "The credit for the innovative design is entirely hers.", 
    "He led the presentation with confidence and clarity.", 
    "The team assigned the most critical task to him.", 
    "His programming skills greatly improved the project’s outcome.", 
    "The master database contains all the key records for the organization.", 
    "The secondary system operates as a slave to the primary server.", 
    "Achieving quantum supremacy marks a significant milestone in computing.", 
    "The older software was grandfathered in despite the new policy.", 
    "Hey guys, let’s gather for the meeting in five minutes.", 
    "Completing the project required 100 man hours of effort.", 
    "Before deploying the code, we need to perform a sanity check.", 
    "A quick sanity test revealed several issues in the new feature.", 
    "Developers use a dummy value as a placeholder during testing.", 
    "The scrum master facilitated the daily stand-up meeting.", 
    "The team opted for mob programming to tackle the complex issue collaboratively.", 
    "The system’s segregation of duties ensures secure operations.", 
    "A blackout period was enforced during the system upgrade.", 
    "The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.", 
    "The app includes a native feature for photo editing.", 
    "The red team simulated an attack to test the organization’s defenses.", 
    "The web master updated the website’s layout for better usability.", 
    "The designer added white space to improve the page's readability.", 
    "The white team oversaw the cyber exercise and ensured fair play.", 
    "The yellow team focused on optimizing the software’s security during development.", 
    "The land’s history is deeply rooted in Aboriginal culture and traditions.",
    "The company hosted brown bag sessions to share knowledge informally.", 
    "Functions are treated as first-class citizens in many programming languages.", 
    "The man-in-the-middle attack intercepted sensitive information during transmission.", 
    "Changes were merged into the master branch for deployment.", 
    "Efforts to promote diversity aim to amplify the voices of the minority.", 
    "The system is back to normal after resolving the outage.", 
    "The venue was upgraded to be accessible for handicapped individuals.", 
    "The plan was considered crazy but turned out to be a brilliant success.", 
    "His desk organization reflects a hint of OCD tendencies.", 
    "The company prioritizes culture fit when hiring new employees.", 
    "The chairman called for a vote on the proposed changes.", 
    "The foreman supervised the construction site with expertise.", 
    "Man has always sought to understand the universe.", 
    "Mankind has made significant strides in technology over the centuries.", 
    "The crew mans the ship during long voyages.", 
    "The salesman demonstrated the product’s key features effectively.", 
    "The reservoir is a manmade structure designed for water storage.", 
    "The project required significant manpower to complete on time.", 
    "The network’s demilitarized zone protects internal systems from external threats.", 
    "The server operates within the DMZ for added security.", 
    "The application tends to hang when handling large datasets.", 
    "The new functionality was implemented through a daughter board.", 
    "The adapter functions as a gender bender for connecting devices.", 
    "The cleanup script removed the orphaned object from the database."
]

# Function to generate modified sentences with replacements
def generate_replacements(sentence, term, replacements):
    modified_sentences = []
    for replacement in replacements:
        modified_sentence = re.sub(rf'\b{re.escape(term)}\b', replacement, sentence, flags=re.IGNORECASE)
        modified_sentences.append((replacement, modified_sentence))
    return modified_sentences

# Compute similarity scores for each replacement
results = []
for sentence in original_sentences:
    for term, replacements in harmful_terms.items():
        if re.search(rf'\b{re.escape(term)}\b', sentence, flags=re.IGNORECASE):
            modified_versions = generate_replacements(sentence, term, replacements)
            for replacement, modified_sentence in modified_versions:
                score = util.pytorch_cos_sim(model.encode(sentence, convert_to_tensor=True), 
                                             model.encode(modified_sentence, convert_to_tensor=True)).item()
                results.append({
                    "Original Sentence": sentence,
                    "Harmful Term": term,
                    "Replacement": replacement,
                    "Modified Sentence": modified_sentence,
                    "Similarity Score": score
                })

# Convert results to a DataFrame and display
df = pd.DataFrame(results)

# Adjust display options to show all rows
pd.set_option('display.max_rows', None)

# Display the dataframe sorted by similarity score
df_sorted = df.sort_values(by="Similarity Score", ascending=True)
df_sorted
# Out:
#                                      Original Sentence          Harmful Term  \
# 26   The female connector allows for easy integrati...      Female connector
# 35   He led the presentation with confidence and cl...                    He
# 12   The company detected a black hat attempting to...             Black hat
# 13   The company detected a black hat attempting to...             Black hat
# 37    The team assigned the most critical task to him.                   Him
# 88   Functions are treated as first-class citizens ...  First-class citizens
# 39   His programming skills greatly improved the pr...                   His
# 31   Her contribution to the discussion was insight...                   Her
# 29   She was responsible for coordinating the team’...                   She
# 89   Functions are treated as first-class citizens ...  First-class citizens
# 27   The female connector allows for easy integrati...      Female connector
# 87   The company hosted brown bag sessions to share...             Brown bag
# 131  The server operates within the DMZ for added s...                   DMZ
# 11   The white box testing method allows developers...             White box
# 66   The team opted for mob programming to tackle t...       Mob programming
# 10   The white box testing method allows developers...             White box
# 107  His desk organization reflects a hint of OCD t...                   His
# 136  The adapter functions as a gender bender for c...         Gender bender
# 130  The server operates within the DMZ for added s...                   DMZ
# 71   A blackout period was enforced during the syst...       Blackout period
# 33   The credit for the innovative design is entire...                  Hers
# 137  The adapter functions as a gender bender for c...         Gender bender
# 115  The foreman supervised the construction site w...               Foreman
# 114  The foreman supervised the construction site w...               Foreman
# 20   The paper underwent a blind review process to ...                 Blind
# 134  The new functionality was implemented through ...        Daughter board
# 111  The company prioritizes culture fit when hirin...           Culture fit
# 109  His desk organization reflects a hint of OCD t...                   OCD
# 21   The paper underwent a blind review process to ...                 Blind
# 72   The gray hat hacker reported the vulnerabiliti...              Gray hat
# 91   The man-in-the-middle attack intercepted sensi...     Man-in-the-middle
# 85   The yellow team focused on optimizing the soft...           Yellow team
# 135  The new functionality was implemented through ...        Daughter board
# 67   The team opted for mob programming to tackle t...       Mob programming
# 70   A blackout period was enforced during the syst...       Blackout period
# 77   The web master updated the website’s layout fo...                Master
# 57   Before deploying the code, we need to perform ...          Sanity check
# 14   A white hat hacker helped identify security vu...             White hat
# 90   The man-in-the-middle attack intercepted sensi...     Man-in-the-middle
# 128  The network’s demilitarized zone protects inte...    Demilitarized zone
# 108  His desk organization reflects a hint of OCD t...                   OCD
# 84   The white team oversaw the cyber exercise and ...            White team
# 79   The web master updated the website’s layout fo...            Web master
# 59   A quick sanity test revealed several issues in...           Sanity test
# 60   Developers use a dummy value as a placeholder ...           Dummy value
# 76   The red team simulated an attack to test the o...              Red team
# 40   The master database contains all the key recor...                Master
# 15   A white hat hacker helped identify security vu...             White hat
# 28   She was responsible for coordinating the team’...                   She
# 25   The cable is equipped with a male connector fo...        Male connector
# 75   The red team simulated an attack to test the o...              Red team
# 123  The salesman demonstrated the product’s key fe...              Salesman
# 121        The crew mans the ship during long voyages.                  Mans
# 78   The web master updated the website’s layout fo...                Master
# 129  The network’s demilitarized zone protects inte...    Demilitarized zone
# 24   The cable is equipped with a male connector fo...        Male connector
# 61   Developers use a dummy value as a placeholder ...           Dummy value
# 120        The crew mans the ship during long voyages.                  Mans
# 56   Before deploying the code, we need to perform ...          Sanity check
# 32   The credit for the innovative design is entire...                  Hers
# 30   Her contribution to the discussion was insight...                   Her
# 83   The white team oversaw the cyber exercise and ...            White team
# 104  The plan was considered crazy but turned out t...                 Crazy
# 45   Achieving quantum supremacy marks a significan...     Quantum supremacy
# 44   The secondary system operates as a slave to th...                 Slave
# 41   The master database contains all the key recor...                Master
# 38   His programming skills greatly improved the pr...                   His
# 105  The plan was considered crazy but turned out t...                 Crazy
# 138  The cleanup script removed the orphaned object...       Orphaned object
# 46   Achieving quantum supremacy marks a significan...     Quantum supremacy
# 43   The secondary system operates as a slave to th...                 Slave
# 122  The salesman demonstrated the product’s key fe...              Salesman
# 133  The application tends to hang when handling la...                  Hang
# 74   The app includes a native feature for photo ed...                Native
# 22   The experiment was conducted under double-blin...                 Blind
# 34   He led the presentation with confidence and cl...                    He
# 126  The project required significant manpower to c...              Manpower
# 80   The web master updated the website’s layout fo...            Web master
# 102  The venue was upgraded to be accessible for ha...           Handicapped
# 42   The secondary system operates as a slave to th...                 Slave
# 48   The older software was grandfathered in despit...         Grandfathered
# 64   The scrum master facilitated the daily stand-u...          Scrum master
# 94   Changes were merged into the master branch for...                Master
# 97   Changes were merged into the master branch for...         Master branch
# 116  Man has always sought to understand the universe.                   Man
# 65   The scrum master facilitated the daily stand-u...          Scrum master
# 19   Only pre-approved devices are included in the ...             Whitelist
# 106  His desk organization reflects a hint of OCD t...                   His
# 8    The algorithm functions as a black box, with n...             Black box
# 127  The project required significant manpower to c...              Manpower
# 117  Man has always sought to understand the universe.                   Man
# 36    The team assigned the most critical task to him.                   Him
# 18   Only pre-approved devices are included in the ...             Whitelist
# 58   A quick sanity test revealed several issues in...           Sanity test
# 9    The algorithm functions as a black box, with n...             Black box
# 112  The chairman called for a vote on the proposed...              Chairman
# 92   The man-in-the-middle attack intercepted sensi...                   Man
# 2    The program will automatically abort if a crit...                 Abort
# 0    The program will automatically abort if a crit...                 Abort
# 82   The designer added white space to improve the ...           White space
# 132  The application tends to hang when handling la...                  Hang
# 81   The designer added white space to improve the ...           White space
# 54   Completing the project required 100 man hours ...                   Man
# 101  The system is back to normal after resolving t...                Normal
# 23   The experiment was conducted under double-blin...                 Blind
# 1    The program will automatically abort if a crit...                 Abort
# 5    The user chose to terminate the installation p...             Terminate
# 62   The scrum master facilitated the daily stand-u...                Master
# 69   The system’s segregation of duties ensures sec...           Segregation
# 139  The cleanup script removed the orphaned object...       Orphaned object
# 47   The older software was grandfathered in despit...         Grandfathered
# 103  The venue was upgraded to be accessible for ha...           Handicapped
# 96   Changes were merged into the master branch for...         Master branch
# 95   Changes were merged into the master branch for...                Master
# 93   The man-in-the-middle attack intercepted sensi...                   Man
# 99   Efforts to promote diversity aim to amplify th...              Minority
# 63   The scrum master facilitated the daily stand-u...                Master
# 98   Efforts to promote diversity aim to amplify th...              Minority
# 73   The app includes a native feature for photo ed...                Native
# 17   The IP address was added to the company’s blac...             Blacklist
# 16   The IP address was added to the company’s blac...             Blacklist
# 124  The reservoir is a manmade structure designed ...               Manmade
# 86   The land’s history is deeply rooted in Aborigi...            Aboriginal
# 113  The chairman called for a vote on the proposed...              Chairman
# 7    The app is designed to be intuitive for the av...          Average user
# 110  The company prioritizes culture fit when hirin...           Culture fit
# 50   Hey guys, let’s gather for the meeting in five...                  Guys
# 6    The app is designed to be intuitive for the av...          Average user
# 100  The system is back to normal after resolving t...                Normal
# 68   The system’s segregation of duties ensures sec...           Segregation
# 55   Completing the project required 100 man hours ...                   Man
# 125  The reservoir is a manmade structure designed ...               Manmade
# 118  Mankind has made significant strides in techno...               Mankind
# 4    The user chose to terminate the installation p...             Terminate
# 49   Hey guys, let’s gather for the meeting in five...                  Guys
# 53   Completing the project required 100 man hours ...             Man hours
# 119  Mankind has made significant strides in techno...               Mankind
# 52   Completing the project required 100 man hours ...             Man hours
# 51   Hey guys, let’s gather for the meeting in five...                  Guys
# 3    The user chose to terminate the installation p...             Terminate
#
#                          Replacement  \
# 26                            Socket
# 35                Use specific names
# 12                  Malicious hacker
# 13             Unauthorized attacker
# 37                Use specific names
# 88                     Core features
# 39                Use specific names
# 31                Use specific names
# 29                Use specific names
# 89                  Primary elements
# 27               Receiving connector
# 87           Lunch-and-learn session
# 131                 Isolated network
# 11                      Open process
# 66              Ensemble programming
# 10                Transparent system
# 107               Use specific names
# 136                          Adapter
# 130                Perimeter network
# 71                          Downtime
# 33                Use specific names
# 137                        Converter
# 115                        Team lead
# 114                       Supervisor
# 20                         Anonymous
# 134                  Auxiliary board
# 111                  Value alignment
# 109                  Detail-oriented
# 21                          Unbiased
# 72   Independent security researcher
# 91                      Relay attack
# 85        Security optimization team
# 135                  Expansion board
# 67                 Group programming
# 70                 Restricted period
# 77                           Primary
# 57                  Validation check
# 14                    Ethical hacker
# 90               Interception attack
# 128                Perimeter network
# 108                 Highly organized
# 84                    Oversight team
# 79             Website administrator
# 59          Basic functionality test
# 60                 Placeholder value
# 76            Attack simulation team
# 40                           Primary
# 15               Security researcher
# 28                              They
# 25                  Insert connector
# 75           Offensive security team
# 123             Sales representative
# 121                         Operates
# 78                              Main
# 129                      Buffer zone
# 24                              Plug
# 61                        Test value
# 120                           Staffs
# 56                       Quick check
# 32                            Theirs
# 30                             Their
# 83                      Neutral team
# 104                   Unconventional
# 45                 Quantum advantage
# 44                            Worker
# 41                              Main
# 38                             Their
# 105                       Unexpected
# 138                  Unlinked object
# 46              Quantum breakthrough
# 43                           Replica
# 122                      Salesperson
# 133              Become unresponsive
# 74                           Default
# 22                         Anonymous
# 34                              They
# 126                        Workforce
# 80                       Web manager
# 102                       Accessible
# 42                         Secondary
# 48                          Exempted
# 64                        Scrum lead
# 94                           Primary
# 97                    Primary branch
# 116                         Humanity
# 65                 Scrum facilitator
# 19                     Approved list
# 106                            Their
# 8                      Opaque system
# 127                        Personnel
# 117                           People
# 36                              Them
# 18                         Allowlist
# 58                  Preliminary test
# 9               Unobservable process
# 112                            Chair
# 92                          Humanity
# 2                             Cancel
# 0                               Halt
# 82                           Spacing
# 132                           Freeze
# 81                       Empty space
# 54                          Humanity
# 101                         Standard
# 23                          Unbiased
# 1                               Stop
# 5                           Complete
# 62                           Primary
# 69                          Division
# 139              Unassociated object
# 47                     Legacy status
# 103         Person with a disability
# 96                       Main branch
# 95                              Main
# 93                            People
# 99                Marginalized group
# 63                              Main
# 98            Underrepresented group
# 73                          Built-in
# 17                          Denylist
# 16                         Blocklist
# 124                       Artificial
# 86                        Indigenous
# 113                      Chairperson
# 7                       General user
# 110                      Culture add
# 50                              Team
# 6                       Typical user
# 100                         Expected
# 68                        Separation
# 55                            People
# 125                       Human-made
# 118                        Humankind
# 4                               Stop
# 49                          Everyone
# 53                        Work hours
# 119                         Humanity
# 52                      Person hours
# 51                             Folks
# 3                                End
#
#                                      Modified Sentence  Similarity Score
# 26   The Socket allows for easy integration with ot...          0.573467
# 35   Use specific names led the presentation with c...          0.573573
# 12   The company detected a Malicious hacker attemp...          0.601477
# 13   The company detected a Unauthorized attacker a...          0.601788
# 37   The team assigned the most critical task to Us...          0.640173
# 88   Functions are treated as Core features in many...          0.641356
# 39   Use specific names programming skills greatly ...          0.659806
# 31   Use specific names contribution to the discuss...          0.670337
# 29   Use specific names was responsible for coordin...          0.670666
# 89   Functions are treated as Primary elements in m...          0.675208
# 27   The Receiving connector allows for easy integr...          0.678612
# 87   The company hosted Lunch-and-learn session ses...          0.695995
# 131  The server operates within the Isolated networ...          0.718277
# 11   The Open process testing method allows develop...          0.719934
# 66   The team opted for Ensemble programming to tac...          0.721668
# 10   The Transparent system testing method allows d...          0.722767
# 107  Use specific names desk organization reflects ...          0.726022
# 136  The adapter functions as a Adapter for connect...          0.727360
# 130  The server operates within the Perimeter netwo...          0.728124
# 71   A Downtime was enforced during the system upgr...          0.728261
# 33   The credit for the innovative design is entire...          0.732194
# 137  The adapter functions as a Converter for conne...          0.734185
# 115  The Team lead supervised the construction site...          0.734928
# 114  The Supervisor supervised the construction sit...          0.744094
# 20   The paper underwent a Anonymous review process...          0.744736
# 134  The new functionality was implemented through ...          0.750979
# 111  The company prioritizes Value alignment when h...          0.761041
# 109  His desk organization reflects a hint of Detai...          0.762296
# 21   The paper underwent a Unbiased review process ...          0.766030
# 72   The Independent security researcher hacker rep...          0.767957
# 91   The Relay attack attack intercepted sensitive ...          0.777748
# 85   The Security optimization team focused on opti...          0.783778
# 135  The new functionality was implemented through ...          0.787963
# 67   The team opted for Group programming to tackle...          0.806803
# 70   A Restricted period was enforced during the sy...          0.810575
# 77   The web Primary updated the website’s layout f...          0.810848
# 57   Before deploying the code, we need to perform ...          0.815887
# 14   A Ethical hacker hacker helped identify securi...          0.817126
# 90   The Interception attack attack intercepted sen...          0.817796
# 128  The network’s Perimeter network protects inter...          0.824664
# 108  His desk organization reflects a hint of Highl...          0.824690
# 84   The Oversight team oversaw the cyber exercise ...          0.826038
# 79   The Website administrator updated the website’...          0.827574
# 59   A quick Basic functionality test revealed seve...          0.829202
# 60   Developers use a Placeholder value as a placeh...          0.829454
# 76   The Attack simulation team simulated an attack...          0.829734
# 40   The Primary database contains all the key reco...          0.832613
# 15   A Security researcher hacker helped identify s...          0.832633
# 28   They was responsible for coordinating the team...          0.836792
# 25   The cable is equipped with a Insert connector ...          0.836977
# 75   The Offensive security team simulated an attac...          0.838205
# 123  The Sales representative demonstrated the prod...          0.842884
# 121    The crew Operates the ship during long voyages.          0.843587
# 78   The web Main updated the website’s layout for ...          0.845296
# 129  The network’s Buffer zone protects internal sy...          0.849631
# 24   The cable is equipped with a Plug for compatib...          0.849646
# 61   Developers use a Test value as a placeholder d...          0.850563
# 120      The crew Staffs the ship during long voyages.          0.851084
# 56   Before deploying the code, we need to perform ...          0.854385
# 32   The credit for the innovative design is entire...          0.856372
# 30   Their contribution to the discussion was insig...          0.857565
# 83   The Neutral team oversaw the cyber exercise an...          0.858996
# 104  The plan was considered Unconventional but tur...          0.867457
# 45   Achieving Quantum advantage marks a significan...          0.867519
# 44   The secondary system operates as a Worker to t...          0.867971
# 41   The Main database contains all the key records...          0.872235
# 38   Their programming skills greatly improved the ...          0.873098
# 105  The plan was considered Unexpected but turned ...          0.874205
# 138  The cleanup script removed the Unlinked object...          0.875080
# 46   Achieving Quantum breakthrough marks a signifi...          0.877870
# 43   The secondary system operates as a Replica to ...          0.877979
# 122  The Salesperson demonstrated the product’s key...          0.878644
# 133  The application tends to Become unresponsive w...          0.879780
# 74   The app includes a Default feature for photo e...          0.880555
# 22   The experiment was conducted under double-Anon...          0.883819
# 34   They led the presentation with confidence and ...          0.886162
# 126  The project required significant Workforce to ...          0.888754
# 80   The Web manager updated the website’s layout f...          0.889376
# 102  The venue was upgraded to be accessible for Ac...          0.891089
# 42   The secondary system operates as a Secondary t...          0.892284
# 48   The older software was Exempted in despite the...          0.892654
# 64   The Scrum lead facilitated the daily stand-up ...          0.894375
# 94   Changes were merged into the Primary branch fo...          0.894577
# 97   Changes were merged into the Primary branch fo...          0.894577
# 116  Humanity has always sought to understand the u...          0.895734
# 65   The Scrum facilitator facilitated the daily st...          0.895948
# 19   Only pre-approved devices are included in the ...          0.897469
# 106  Their desk organization reflects a hint of OCD...          0.897488
# 8    The algorithm functions as a Opaque system, wi...          0.898719
# 127  The project required significant Personnel to ...          0.898788
# 117  People has always sought to understand the uni...          0.899577
# 36   The team assigned the most critical task to Them.          0.900533
# 18   Only pre-approved devices are included in the ...          0.901145
# 58   A quick Preliminary test revealed several issu...          0.902828
# 9    The algorithm functions as a Unobservable proc...          0.902955
# 112  The Chair called for a vote on the proposed ch...          0.903277
# 92   The Humanity-in-the-middle attack intercepted ...          0.906904
# 2    The program will automatically Cancel if a cri...          0.908169
# 0    The program will automatically Halt if a criti...          0.909458
# 82   The designer added Spacing to improve the page...          0.910357
# 132  The application tends to Freeze when handling ...          0.914745
# 81   The designer added Empty space to improve the ...          0.918833
# 54   Completing the project required 100 Humanity h...          0.920907
# 101  The system is back to Standard after resolving...          0.921492
# 23   The experiment was conducted under double-Unbi...          0.921516
# 1    The program will automatically Stop if a criti...          0.922640
# 5    The user chose to Complete the installation pr...          0.923700
# 62   The scrum Primary facilitated the daily stand-...          0.923873
# 69   The system’s Division of duties ensures secure...          0.924723
# 139  The cleanup script removed the Unassociated ob...          0.924789
# 47   The older software was Legacy status in despit...          0.925821
# 103  The venue was upgraded to be accessible for Pe...          0.926213
# 96   Changes were merged into the Main branch for d...          0.928553
# 95   Changes were merged into the Main branch for d...          0.928553
# 93   The People-in-the-middle attack intercepted se...          0.929361
# 99   Efforts to promote diversity aim to amplify th...          0.931869
# 63   The scrum Main facilitated the daily stand-up ...          0.932176
# 98   Efforts to promote diversity aim to amplify th...          0.932201
# 73   The app includes a Built-in feature for photo ...          0.937234
# 17   The IP address was added to the company’s Deny...          0.937353
# 16   The IP address was added to the company’s Bloc...          0.937636
# 124  The reservoir is a Artificial structure design...          0.939255
# 86   The land’s history is deeply rooted in Indigen...          0.939329
# 113  The Chairperson called for a vote on the propo...          0.943595
# 7    The app is designed to be intuitive for the Ge...          0.944776
# 110  The company prioritizes Culture add when hirin...          0.949814
# 50   Hey Team, let’s gather for the meeting in five...          0.950417
# 6    The app is designed to be intuitive for the Ty...          0.955607
# 100  The system is back to Expected after resolving...          0.956891
# 68   The system’s Separation of duties ensures secu...          0.958804
# 55   Completing the project required 100 People hou...          0.959826
# 125  The reservoir is a Human-made structure design...          0.960701
# 118  Humankind has made significant strides in tech...          0.961535
# 4    The user chose to Stop the installation proces...          0.964866
# 49   Hey Everyone, let’s gather for the meeting in ...          0.965056
# 53   Completing the project required 100 Work hours...          0.965177
# 119  Humanity has made significant strides in techn...          0.968785
# 52   Completing the project required 100 Person hou...          0.970870
# 51   Hey Folks, let’s gather for the meeting in fiv...          0.975638
# 3    The user chose to End the installation process...          0.975999

# %%
df[["Harmful Term", "Replacement", "Similarity Score"]].to_csv("C:/Users/hana_/Downloads/GPT4-3_replacements.csv", index=False)
