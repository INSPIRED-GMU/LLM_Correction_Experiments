# %%
from transformers import BartTokenizer, BartForConditionalGeneration

# Load the BART tokenizer and model
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large')

# Define input text and split it into sections
input_text = """Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for each harmful term in this list. For example, for 'Abort,' you might say 'Stop the operation' instead.
Abort: The program will automatically abort if a critical error occurs during execution.
Terminate: The user chose to terminate the installation process after encountering an error.
Average user: The app is designed to be intuitive for the average user.
Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
White box: The white box testing method allows developers to see the internal workings of the code.
Black hat: The company detected a black hat attempting to infiltrate their systems.
White hat: A white hat hacker helped identify security vulnerabilities in the new software.
Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
Whitelist: Only pre-approved devices are included in the network’s whitelist.
Blind: The paper underwent a blind review process to ensure impartiality.
Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
Male connector: The cable is equipped with a male connector for compatibility with standard ports.
Female connector: The female connector allows for easy integration with other components.
She: She was responsible for coordinating the team’s efforts on the project.
Her: Her contribution to the discussion was insightful and appreciated.
Hers: The credit for the innovative design is entirely hers.
He: He led the presentation with confidence and clarity.
Him: The team assigned the most critical task to him.
His: His programming skills greatly improved the project’s outcome.
Master: The master database contains all the key records for the organization.
Slave: The secondary system operates as a slave to the primary server.
Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
Grandfathered: The older software was grandfathered in despite the new policy.
Guys: Hey guys, let’s gather for the meeting in five minutes.
Man hours: Completing the project required 100 man hours of effort.
Sanity check: Before deploying the code, we need to perform a sanity check.
Sanity test: A quick sanity test revealed several issues in the new feature.
Dummy value: Developers use a dummy value as a placeholder during testing.
Scrum master: The scrum master facilitated the daily stand-up meeting.
Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
Segregation: The system’s segregation of duties ensures secure operations.
Blackout period: A blackout period was enforced during the system upgrade.
Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
Native: The app includes a native feature for photo editing.
Red team: The red team simulated an attack to test the organization’s defenses.
Web master: The web master updated the website’s layout for better usability.
White space: The designer added white space to improve the page's readability.
White team: The white team oversaw the cyber exercise and ensured fair play.
Yellow team: The yellow team focused on optimizing the software’s security during development.
Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
Brown bags: The company hosted brown bag sessions to share knowledge informally.
First-class citizen: Functions are treated as first-class citizens in many programming languages.
Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
Master branch: Changes were merged into the master branch for deployment.
Minority: Efforts to promote diversity aim to amplify the voices of the minority.
Normal: The system is back to normal after resolving the outage.
Handicapped: The venue was upgraded to be accessible for handicapped individuals.
Crazy: The plan was considered crazy but turned out to be a brilliant success.
OCD: His desk organization reflects a hint of OCD tendencies.
Culture fit: The company prioritizes culture fit when hiring new employees.
Chairman: The chairman called for a vote on the proposed changes.
Foreman: The foreman supervised the construction site with expertise.
Man: Man has always sought to understand the universe.
Mankind: Mankind has made significant strides in technology over the centuries.
Mans: The crew mans the ship during long voyages.
Salesman: The salesman demonstrated the product’s key features effectively.
Manmade: The reservoir is a manmade structure designed for water storage.
Manpower: The project required significant manpower to complete on time.
Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
DMZ: The server operates within the DMZ for added security.
Hang: The application tends to hang when handling large datasets.
Daughter board: The new functionality was implemented through a daughter board.
Gender bender: The adapter functions as a gender bender for connecting devices.
Orphaned object: The cleanup script removed the orphaned object from the database."""

# Split the input text into sections
sections = [section for section in input_text.split('\n')[1:] if section]

# Define the task prefix
task_prefix = "Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: "

# Generate suggestions for each section
results = []
for section in sections:
    input_text = task_prefix + section + " For example, for 'Abort,' you might say 'Stop the operation' instead."
    input_ids = tokenizer.encode(input_text, return_tensors='pt')
    outputs = model.generate(input_ids, max_length=50)
    suggestion = tokenizer.decode(outputs[0], skip_special_tokens=True)
    results.append({"sequence": section, "suggestion": suggestion})

# Display the results in a more understandable way
for result in results:
    print(f"Term: {result['sequence']}\nSuggestion: {result['suggestion']}\n")
# Out:
# Term: Abort: The program will automatically abort if a critical error occurs during execution.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Abort: The program will automatically abort if a critical error occurs during execution.
#
# Term: Terminate: The user chose to terminate the installation process after encountering an error.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Terminate: The user chose to terminate the installation process after encountering an error.
#
# Term: Average user: The app is designed to be intuitive for the average user.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Black box: The algorithm functions as a black box, with no transparency about how
#
# Term: White box: The white box testing method allows developers to see the internal workings of the code.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Black hat: The company detected a black hat attempting to infiltrate their systems.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: White hat: A white hat hacker helped identify security vulnerabilities in the new software.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Whitelist: Only pre-approved devices are included in the network’s whitelist.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Blind: The paper underwent a blind review process to ensure impartiality.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
#
# Term: Male connector: The cable is equipped with a male connector for compatibility with standard ports.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Female connector: The female connector allows for easy integration with other components.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: She: She was responsible for coordinating the team’s efforts on the project.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Her: Her contribution to the discussion was insightful and appreciated.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Hers: The credit for the innovative design is entirely hers.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: He: He led the presentation with confidence and clarity.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Him: The team assigned the most critical task to him.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: His: His programming skills greatly improved the project’s outcome.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Master: The master database contains all the key records for the organization.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Slave: The secondary system operates as a slave to the primary server.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Grandfathered: The older software was grandfathered in despite the new policy.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Grandfathered: The older software was grandfathered in despite the new policy
#
# Term: Guys: Hey guys, let’s gather for the meeting in five minutes.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Man hours: Completing the project required 100 man hours of effort.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Sanity check: Before deploying the code, we need to perform a sanity check.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Sanity check: Before deploying the code, we need to perform a sanity check
#
# Term: Sanity test: A quick sanity test revealed several issues in the new feature.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Dummy value: Developers use a dummy value as a placeholder during testing.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Dummy value: Developers use a dummy value as a placeholder during testing. For
#
# Term: Scrum master: The scrum master facilitated the daily stand-up meeting.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Segregation: The system’s segregation of duties ensures secure operations.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Blackout period: A blackout period was enforced during the system upgrade.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Native: The app includes a native feature for photo editing.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Red team: The red team simulated an attack to test the organization’s defenses.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Web master: The web master updated the website’s layout for better usability.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: White space: The designer added white space to improve the page's readability.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: White space: The designer added white space to improve the page's readability.
#
# Term: White team: The white team oversaw the cyber exercise and ensured fair play.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Yellow team: The yellow team focused on optimizing the software’s security during development.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Brown bags: The company hosted brown bag sessions to share knowledge informally.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: First-class citizen: Functions are treated as first-class citizens in many programming languages.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: First-class citizen: Functions are treated as first-class citizens in many programming
#
# Term: Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Master branch: Changes were merged into the master branch for deployment.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Minority: Efforts to promote diversity aim to amplify the voices of the minority.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for the following term: Minority: Efforts to promote diversity aim to amplify the voices of the minority.
#
# Term: Normal: The system is back to normal after resolving the outage.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Handicapped: The venue was upgraded to be accessible for handicapped individuals.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Crazy: The plan was considered crazy but turned out to be a brilliant success.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: OCD: His desk organization reflects a hint of OCD tendencies.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Culture fit: The company prioritizes culture fit when hiring new employees.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Chairman: The chairman called for a vote on the proposed changes.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Foreman: The foreman supervised the construction site with expertise.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Man: Man has always sought to understand the universe.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Mankind: Mankind has made significant strides in technology over the centuries.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Mans: The crew mans the ship during long voyages.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Salesman: The salesman demonstrated the product’s key features effectively.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Manmade: The reservoir is a manmade structure designed for water storage.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Manpower: The project required significant manpower to complete on time.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: DMZ: The server operates within the DMZ for added security.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Hang: The application tends to hang when handling large datasets.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Daughter board: The new functionality was implemented through a daughter board.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Gender bender: The adapter functions as a gender bender for connecting devices.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following
#
# Term: Orphaned object: The cleanup script removed the orphaned object from the database.
# Suggestion: Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. For example, for 'Abort,' you might say 'Stop the operation' instead. Suggest inclusive alternatives for the following

# %%
from transformers import BertTokenizer, BertForSequenceClassification, BartTokenizer, BartForConditionalGeneration
import torch

# Load the BERT tokenizer and model
bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertForSequenceClassification.from_pretrained('bert-base-uncased')

# Load the BART tokenizer and model
bart_tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')
bart_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large')

# Define input text and split it into sections
input_text = """Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for each harmful term in this list:
Abort: The program will automatically abort if a critical error occurs during execution.
Terminate: The user chose to terminate the installation process after encountering an error.
Average user: The app is designed to be intuitive for the average user.
Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
White box: The white box testing method allows developers to see the internal workings of the code.
Black hat: The company detected a black hat attempting to infiltrate their systems.
White hat: A white hat hacker helped identify security vulnerabilities in the new software.
Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
Whitelist: Only pre-approved devices are included in the network’s whitelist.
Blind: The paper underwent a blind review process to ensure impartiality.
Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
Male connector: The cable is equipped with a male connector for compatibility with standard ports.
Female connector: The female connector allows for easy integration with other components.
She: She was responsible for coordinating the team’s efforts on the project.
Her: Her contribution to the discussion was insightful and appreciated.
Hers: The credit for the innovative design is entirely hers.
He: He led the presentation with confidence and clarity.
Him: The team assigned the most critical task to him.
His: His programming skills greatly improved the project’s outcome.
Master: The master database contains all the key records for the organization.
Slave: The secondary system operates as a slave to the primary server.
Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
Grandfathered: The older software was grandfathered in despite the new policy.
Guys: Hey guys, let’s gather for the meeting in five minutes.
Man hours: Completing the project required 100 man hours of effort.
Sanity check: Before deploying the code, we need to perform a sanity check.
Sanity test: A quick sanity test revealed several issues in the new feature.
Dummy value: Developers use a dummy value as a placeholder during testing.
Scrum master: The scrum master facilitated the daily stand-up meeting.
Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
Segregation: The system’s segregation of duties ensures secure operations.
Blackout period: A blackout period was enforced during the system upgrade.
Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
Native: The app includes a native feature for photo editing.
Red team: The red team simulated an attack to test the organization’s defenses.
Web master: The web master updated the website’s layout for better usability.
White space: The designer added white space to improve the page's readability.
White team: The white team oversaw the cyber exercise and ensured fair play.
Yellow team: The yellow team focused on optimizing the software’s security during development.
Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
Brown bags: The company hosted brown bag sessions to share knowledge informally.
First-class citizen: Functions are treated as first-class citizens in many programming languages.
Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
Master branch: Changes were merged into the master branch for deployment.
Minority: Efforts to promote diversity aim to amplify the voices of the minority.
Normal: The system is back to normal after resolving the outage.
Handicapped: The venue was upgraded to be accessible for handicapped individuals.
Crazy: The plan was considered crazy but turned out to be a brilliant success.
OCD: His desk organization reflects a hint of OCD tendencies.
Culture fit: The company prioritizes culture fit when hiring new employees.
Chairman: The chairman called for a vote on the proposed changes.
Foreman: The foreman supervised the construction site with expertise.
Man: Man has always sought to understand the universe.
Mankind: Mankind has made significant strides in technology over the centuries.
Mans: The crew mans the ship during long voyages.
Salesman: The salesman demonstrated the product’s key features effectively.
Manmade: The reservoir is a manmade structure designed for water storage.
Manpower: The project required significant manpower to complete on time.
Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
DMZ: The server operates within the DMZ for added security.
Hang: The application tends to hang when handling large datasets.
Daughter board: The new functionality was implemented through a daughter board.
Gender bender: The adapter functions as a gender bender for connecting devices.
Orphaned object: The cleanup script removed the orphaned object from the database."""

# Split the input text into sections
sections = [section for section in input_text.split('\n')[1:] if section]

# Define the task prefix
task_prefix = "Suggest inclusive alternatives for the following term: "

# Classify each section with BERT and generate alternatives with BART
results = []
for section in sections:
    term = section.split(':')[0]
    inputs = bert_tokenizer(section, return_tensors="pt", truncation=True, padding=True)
    outputs = bert_model(**inputs)
    scores = torch.softmax(outputs.logits, dim=1)
    is_harmful = scores[0][0] < scores[0][1]
    
    if is_harmful:
        input_text = task_prefix + section + " For example, for 'Abort,' you might say 'Stop the operation' instead."
        input_ids = bart_tokenizer.encode(input_text, return_tensors='pt')
        outputs = bart_model.generate(input_ids, max_length=50)
        suggestion = bart_tokenizer.decode(outputs[0], skip_special_tokens=True)
    else:
        suggestion = "This term is not identified as harmful."
    
    results.append({"sequence": section, "suggestion": suggestion})

# Display the results in a more understandable way
for result in results:
    print(f"Term: {result['sequence']}\nSuggestion: {result['suggestion']}\n")
