# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Load the T5 tokenizer and model
tokenizer = T5Tokenizer.from_pretrained('t5-large')
model = T5ForConditionalGeneration.from_pretrained('t5-large')

# Define your input text and split it into sections
input_text = """Each of the terms in this list have the potential of being used in harmful/non-inclusive technical contexts. Suggest inclusive alternatives for each harmful term in this list:
Abort: The program will automatically abort if a critical error occurs during execution.
Terminate: The user chose to terminate the installation process after encountering an error.
Average user: The app is designed to be intuitive for the average user.
Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
White box: The white box testing method allows developers to see the internal workings of the code.
Black hat: The company detected a black hat attempting to infiltrate their systems.
White hat: A white hat hacker helped identify security vulnerabilities in the new software.
Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
Whitelist: Only pre-approved devices are included in the network’s whitelist.
Blind: The paper underwent a blind review process to ensure impartiality.
Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
Male connector: The cable is equipped with a male connector for compatibility with standard ports.
Female connector: The female connector allows for easy integration with other components.
She: She was responsible for coordinating the team’s efforts on the project.
Her: Her contribution to the discussion was insightful and appreciated.
Hers: The credit for the innovative design is entirely hers.
He: He led the presentation with confidence and clarity.
Him: The team assigned the most critical task to him.
His: His programming skills greatly improved the project’s outcome.
Master: The master database contains all the key records for the organization.
Slave: The secondary system operates as a slave to the primary server.
Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
Grandfathered: The older software was grandfathered in despite the new policy.
Guys: Hey guys, let’s gather for the meeting in five minutes.
Man hours: Completing the project required 100 man hours of effort.
Sanity check: Before deploying the code, we need to perform a sanity check.
Sanity test: A quick sanity test revealed several issues in the new feature.
Dummy value: Developers use a dummy value as a placeholder during testing.
Scrum master: The scrum master facilitated the daily stand-up meeting.
Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
Segregation: The system’s segregation of duties ensures secure operations.
Blackout period: A blackout period was enforced during the system upgrade.
Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
Native: The app includes a native feature for photo editing.
Red team: The red team simulated an attack to test the organization’s defenses.
Web master: The web master updated the website’s layout for better usability.
White space: The designer added white space to improve the page's readability.
White team: The white team oversaw the cyber exercise and ensured fair play.
Yellow team: The yellow team focused on optimizing the software’s security during development.
Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
Brown bags: The company hosted brown bag sessions to share knowledge informally.
First-class citizen: Functions are treated as first-class citizens in many programming languages.
Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
Master branch: Changes were merged into the master branch for deployment.
Minority: Efforts to promote diversity aim to amplify the voices of the minority.
Normal: The system is back to normal after resolving the outage.
Handicapped: The venue was upgraded to be accessible for handicapped individuals.
Crazy: The plan was considered crazy but turned out to be a brilliant success.
OCD: His desk organization reflects a hint of OCD tendencies.
Culture fit: The company prioritizes culture fit when hiring new employees.
Chairman: The chairman called for a vote on the proposed changes.
Foreman: The foreman supervised the construction site with expertise.
Man: Man has always sought to understand the universe.
Mankind: Mankind has made significant strides in technology over the centuries.
Mans: The crew mans the ship during long voyages.
Salesman: The salesman demonstrated the product’s key features effectively.
Manmade: The reservoir is a manmade structure designed for water storage.
Manpower: The project required significant manpower to complete on time.
Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
DMZ: The server operates within the DMZ for added security.
Hang: The application tends to hang when handling large datasets.
Daughter board: The new functionality was implemented through a daughter board.
Gender bender: The adapter functions as a gender bender for connecting devices.
Orphaned object: The cleanup script removed the orphaned object from the database."""

# Split the input text into sections
sections = [section for section in input_text.split('\n')[1:] if section]

# Define the task prefix
task_prefix = "Suggest inclusive alternatives for the following term: "

# Generate suggestions for each section
results = []
for section in sections:
    input_text = task_prefix + section
    input_ids = tokenizer.encode(input_text, return_tensors='pt')
    outputs = model.generate(input_ids, max_length=50)
    suggestion = tokenizer.decode(outputs[0], skip_special_tokens=True)
    results.append({"sequence": section, "suggestion": suggestion})

# Display the results in a more understandable way
for result in results:
    print(f"Term: {result['sequence']}\nSuggestion: {result['suggestion']}\n")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Term: Abort: The program will automatically abort if a critical error occurs during execution.
# Suggestion: : Abort: The program will automatically abort if a critical error occurs during execution.. The program will automatically abort if a critical error occurs during execution..uggest
#
# Term: Terminate: The user chose to terminate the installation process after encountering an error.
# Suggestion: The user chose to terminate the installation process after encountering an error. the installation process. the installation process after encountering an error. The user chose to terminate the installation process after encountering an error.. inclusive
#
# Term: Average user: The app is designed to be intuitive for the average user.
# Suggestion: : Average user: The app is designed to be intuitive for the average user.. Average user: The app is designed to be intuitive for the average user. Average user:.. Average user: The app is designed to
#
# Term: Black box: The algorithm functions as a black box, with no transparency about how decisions are made.
# Suggestion: : Black box: The algorithm functions as a black box, with no transparency about how decisions are made.: The algorithm functions as a black box, with no transparency about how decisions are made. black box: The
#
# Term: White box: The white box testing method allows developers to see the internal workings of the code.
# Suggestion: . White box: The white box testing method allows developers to see the internal workings of the code. White box: The white box testing method allows developers to see the internal workings of the code....
#
# Term: Black hat: The company detected a black hat attempting to infiltrate their systems.
# Suggestion: : The company detected a black hat attempting to infiltrate their systems.... Black hat: The company detected a black hat attempting to infiltrate their systems.
#
# Term: White hat: A white hat hacker helped identify security vulnerabilities in the new software.
# Suggestion: hat: White hat hacker: A white hat hacker helped identify security vulnerabilities in the new software.. White hat: A white hat hacker helped identify security vulnerabilities in the new software. White hat
#
# Term: Blacklist: The IP address was added to the company’s blacklist after repeated failed login attempts.
# Suggestion: : was added to the company’s blacklist after repeated failed login attempts. after repeated failed login attempts. after repeated failed login attempts.: The IP address was added to the company’s blacklist after repeated failed
#
# Term: Whitelist: Only pre-approved devices are included in the network’s whitelist.
# Suggestion: ..: Only pre-approved devices are included in the network’s whitelist.: Only pre-approved devices are included in the network’s whitelist.: Only pre-approved devices.uggest
#
# Term: Blind: The paper underwent a blind review process to ensure impartiality.
# Suggestion: blind: The paper underwent a blind review process to ensure impartiality. Blind: to ensure impartiality. Blind: to ensure impartiality. Blind: The paper underwent a blind review process to ensure impartiality.
#
# Term: Double blind: The experiment was conducted under double-blind conditions to eliminate bias.
# Suggestion: : The experiment was conducted under double-blind conditions to eliminate bias.... Double blind: The experiment was conducted under double-blind conditions to eliminate bias. Double blind: The experiment was conducted under double-
#
# Term: Male connector: The cable is equipped with a male connector for compatibility with standard ports.
# Suggestion: . The cable is equipped with a male connector for compatibility with standard ports.. Male connector: The cable is equipped with a male connector for compatibility with standard ports..... inclusive
#
# Term: Female connector: The female connector allows for easy integration with other components.
# Suggestion: : Female connector: The female connector allows for easy integration of other components.... Female connector: The female connector allows for easy integration of other components. Suggest inclusive alternatives: Female connector: The female connector allows
#
# Term: She: She was responsible for coordinating the team’s efforts on the project.
# Suggestion: :. He: He was responsible for coordinating the team’s efforts on the project. He: He was responsible for coordinating the team’s efforts on the project.... inclusive alternatives:
#
# Term: Her: Her contribution to the discussion was insightful and appreciated.
# Suggestion: :.. Her: Her contribution was insightful and appreciated. Her: Her contribution was insightful and appreciated. Her: Her contribution was insightful and appreciated. Her: Her contribution was insightful and appreciated. Her: Her:. Her
#
# Term: Hers: The credit for the innovative design is entirely hers.
# Suggestion: : Hers: The credit for the innovative design is entirely hers... Hers: The credit for the innovative design is entirely hers.: The credit for the innovative design is entirely hers.:
#
# Term: He: He led the presentation with confidence and clarity.
# Suggestion: .. He: He led the presentation with confidence and clarity. He: He led the presentation with confidence and clarity.. He: He led the presentation with confidence and clarity.. He: He led the presentation with confidence
#
# Term: Him: The team assigned the most critical task to him.
# Suggestion: :.... Him: The team assigned the most critical task to him.. inclusive alternatives to the following term: Him: The team assigned the most critical task to him..: inclusive alternatives
#
# Term: His: His programming skills greatly improved the project’s outcome.
# Suggestion: : His: His programming skills greatly improved the project’s outcome.. Her: Her programming skills greatly improved the project’s outcome.. Her: His programming skills greatly improved the project’s outcome. His: His
#
# Term: Master: The master database contains all the key records for the organization.
# Suggestion: : Master: The master database contains all the key records for the organization.... Master: The master database contains all the key records for the organization.. Master: The master database contains all the key records for the
#
# Term: Slave: The secondary system operates as a slave to the primary server.
# Suggestion: : server. Slave: server. Slave: The secondary system operates as a slave to the primary server. server. Slave: The secondary system operates as a slave to the primary server.
#
# Term: Quantum supremacy: Achieving quantum supremacy marks a significant milestone in computing.
# Suggestion: : Achieving quantum supremacy marks a significant milestone in computing. Achieving quantum supremacy: in computing. supremacy: Achieving quantum supremacy marks a significant milestone in computing. Quantum
#
# Term: Grandfathered: The older software was grandfathered in despite the new policy.
# Suggestion: :: The older software was grandfathered in despite the new policy..: The older software was grandfathered in despite the new policy.. inclusive alternatives: Grandfathered: The older
#
# Term: Guys: Hey guys, let’s gather for the meeting in five minutes.
# Suggestion: : Guys: Hey guys, let’s gather in five minutes. Guys:. Guys: Hey guys, let’s gather in five minutes. Guys: Hey guys, let’s gather in five minutes.. Guys:
#
# Term: Man hours: Completing the project required 100 man hours of effort.
# Suggestion: inclusive alternatives: the project required 100 man hours of effort.. Man hours: Completing the project required 100 man hours of effort. Man hours: Completing the project required 100 man hours of effort. Man hours
#
# Term: Sanity check: Before deploying the code, we need to perform a sanity check.
# Suggestion: :: the code. Before deploying the code, we need to perform a sanity check. Before deploying the code. Before deploying the code. Before deploying the code. Before deploying the
#
# Term: Sanity test: A quick sanity test revealed several issues in the new feature.
# Suggestion: test: A quick sanity test revealed several issues in the new feature... Sanity test: A quick sanity test revealed several issues in the new feature.::.
#
# Term: Dummy value: Developers use a dummy value as a placeholder during testing.
# Suggestion: value:s use a dummy value as a placeholder during testing. a dummy value as a placeholder during testing. during testing. Dummy value: Developers use a dummy
#
# Term: Scrum master: The scrum master facilitated the daily stand-up meeting.
# Suggestion: . Scrum master: The scrum master facilitated the daily stand-up meeting. Scrum master:. Scrum master:.. Scrum master: The scrum master facilitated the daily stand-up meeting
#
# Term: Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
# Suggestion: inclusive alternatives: Mob programming: for mob programming to tackle the complex issue collaboratively. Mob programming:ly. Mob programming: The team opted for mob programming to tackle the complex issue collaboratively.
#
# Term: Segregation: The system’s segregation of duties ensures secure operations.
# Suggestion: ensures secure operations.. ensures secure operations.. Segregation: The system’s segregation of duties ensures secure operations.. inclusive alternatives to the following term: Segregation.
#
# Term: Blackout period: A blackout period was enforced during the system upgrade.
# Suggestion: period: A blackout period was enforced during the system upgrade.. Blackout period: A blackout period was enforced during the system upgrade...est inclusive alternatives to the following term: Blackout period
#
# Term: Gray hat: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration.
# Suggestion: hacker: The gray hat hacker reported the vulnerabilities after exploiting them for demonstration. the vulnerabilities.. Suggest inclusive alternatives for the following term: Gray hat: The gray hat hacker reported the vulnerabilities
#
# Term: Native: The app includes a native feature for photo editing.
# Suggestion: for photo editing. for photo editing. Native: The app includes a native feature for photo editing.. Native: The app includes a native feature for photo editing.. Native: The app includes native feature for photo
#
# Term: Red team: The red team simulated an attack to test the organization’s defenses.
# Suggestion: ’s defenses.. Red team: The red team simulated an attack to test the organization’s defenses. Red team: The red team simulated an attack to test the organization’s defenses. Red team:
#
# Term: Web master: The web master updated the website’s layout for better usability.
# Suggestion: ’s layout for better usability. layout. Web master:’s layout. Web master: The web master updated the website’s layout for better usability.. The web master updated the website’s layout for
#
# Term: White space: The designer added white space to improve the page's readability.
# Suggestion: . The designer added white space to improve the page's readability. White space: The designer added white space to improve the page's readability.. White space: The designer added white space to improve the page'
#
# Term: White team: The white team oversaw the cyber exercise and ensured fair play.
# Suggestion: the cyber exercise and ensured fair play. White team: The white team oversaw the cyber exercise and ensured fair play. White team: The white team oversaw the cyber exercise and ensured fair play. White team: The white
#
# Term: Yellow team: The yellow team focused on optimizing the software’s security during development.
# Suggestion: : Yellow team: The yellow team focused on optimizing the software’s security during development... The yellow team focused on optimizing the software’s security during development. yellow team: The yellow team focused on
#
# Term: Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions.
# Suggestion: : Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions... Aboriginal: The land’s history is deeply rooted in Aboriginal culture and traditions. Aboriginal: The land’s history
#
# Term: Brown bags: The company hosted brown bag sessions to share knowledge informally.
# Suggestion: : Brown bags: The company hosted brown bag sessions to share knowledge formally. to share knowledge formally. Brown bags:. Brown bags: The company hosted brown bag sessions to share knowledge formally.. Brown bags:
#
# Term: First-class citizen: Functions are treated as first-class citizens in many programming languages.
# Suggestion: -class citizen: Functions are treated as first-class citizens in many programming languages.s:: Functions are treated as first-class citizens in many programming languages.-class citizen: Functions are treated as first
#
# Term: Man-in-the-middle: The man-in-the-middle attack intercepted sensitive information during transmission.
# Suggestion: -the-middle attack: The man-in-the-middle attack intercepted sensitive information during transmission.the-middle attack:-the-middle attack: The attack intercepte
#
# Term: Master branch: Changes were merged into the master branch for deployment.
# Suggestion: into the master branch for deployment. Master branch: Changes were merged into the master branch for deployment. Master branch:. Master branch: Changes were merged into the master branch for deployment..: Master branch
#
# Term: Minority: Efforts to promote diversity aim to amplify the voices of the minority.
# Suggestion: Diversity:a the minority. Minority: Efforts to promote diversity aim to amplify the voices of the minority. Promote diversity.uggest inclusive alternatives to the following term: Minority
#
# Term: Normal: The system is back to normal after resolving the outage.
# Suggestion: :. Normal: The system is back to normal after resolving the outage. Normal: The system is back to normal after resolving the outage. Normal:. Normal: The system is back to
#
# Term: Handicapped: The venue was upgraded to be accessible for handicapped individuals.
# Suggestion: : Handicapped: The venue was upgraded to be accessible for handicapped individuals.. Handicapped: The venue was upgraded to be accessible for handicapped individuals.. Handicapped: The venue was upgraded to be accessible
#
# Term: Crazy: The plan was considered crazy but turned out to be a brilliant success.
# Suggestion: : Crazy: The plan was considered crazy but turned out to be a brilliant success. Brilliant:. Brilliant: The plan was considered brilliant but turned out to be a brilliant success... Brilliant: The plan
#
# Term: OCD: His desk organization reflects a hint of OCD tendencies.
# Suggestion: :. reflects a hint of OCD tendencies. OCD: His desk organization reflects a hint of OCD tendencies. OCD:. OCD: His desk organization reflects a
#
# Term: Culture fit: The company prioritizes culture fit when hiring new employees.
# Suggestion: : Culture fit: The company prioritizes culture fit when hiring new employees. when hiring new employees. when hiring new employees. when hiring new employees. Culture fit: The company prioritizes culture fit when hiring new employees.
#
# Term: Chairman: The chairman called for a vote on the proposed changes.
# Suggestion: inclusive alternatives: Chairman: The chairman called for a vote on the proposed changes. Chairman:. Chairman: The chairman called for a vote on the proposed changes.. Chairman: Chairman: Chairman: inclusive alternatives
#
# Term: Foreman: The foreman supervised the construction site with expertise.
# Suggestion: The foreman supervised the construction site with expertise... Foreman: The foreman supervised the construction site with expertise...uggest inclusive alternatives to the following term: Fore
#
# Term: Man: Man has always sought to understand the universe.
# Suggestion: inclusive alternatives: Man: Man has always sought to understand the universe... Man: Man has always sought to understand the universe. Man: Man has always sought to understand the universe. Man: Man has always sought to
#
# Term: Mankind: Mankind has made significant strides in technology over the centuries.
# Suggestion: : Mankind: Mankind has made significant strides in technology over the centuries.. Mankind: Mankind has made significant strides in technology over the centuries. Technology: Mankind: Mankind has made significant strides in
#
# Term: Mans: The crew mans the ship during long voyages.
# Suggestion: : The crew mans the ship during long voyages. the ship during long voyages. the ship during long voyages. the ship during long voyages. Mans: The crew mans the ship during long voyage
#
# Term: Salesman: The salesman demonstrated the product’s key features effectively.
# Suggestion: :. Product: The product’s key features were clearly demonstrated. Product: The product’s key features were clearly demonstrated. Product: The product’s key features were clearly demonstrated. Product: The product’s key features were
#
# Term: Manmade: The reservoir is a manmade structure designed for water storage.
# Suggestion: : Manmade: The reservoir is a manmade structure designed for water storage.:. Manmade: The reservoir is a manmade structure designed for water storage. Manmade: The reservoir is a manmade
#
# Term: Manpower: The project required significant manpower to complete on time.
# Suggestion: : Manpower: The project required significant manpower to complete on time.. Manpower: The project required significant manpower to complete on time. Manpower: The project required significant manpower to complete on time. Man
#
# Term: Demilitarized zone: The network’s demilitarized zone protects internal systems from external threats.
# Suggestion: : The network’s demilitarized zone protects internal systems from external threats. Demilitarized zone: from external threats. Demilitarized zone: The network’s demilitarized zone protects
#
# Term: DMZ: The server operates within the DMZ for added security.
# Suggestion: : DMZ:: DMZ: The server operates within the DMZ for added security. DMZ: The server operates within the DMZ for added security. DMZ: The server
#
# Term: Hang: The application tends to hang when handling large datasets.
# Suggestion: : Hang: The application tends to hang when handling large datasets.. Hang: The application tends to hang when handling large datasets.. Hang: The application tends to hang when handling large datasets.
#
# Term: Daughter board: The new functionality was implemented through a daughter board.
# Suggestion: was implemented through a daughter board.. The new functionality was implemented through a daughter board.. Suggest inclusive alternatives for the following term: Daughter board: The new functionality was implemented through a daughter board.
#
# Term: Gender bender: The adapter functions as a gender bender for connecting devices.
# Suggestion: bender: The adapter functions as a gender bender for connecting devices.. bender: The adapter functions as a gender bender for connecting devices.: The adapter functions as a gender bend
#
# Term: Orphaned object: The cleanup script removed the orphaned object from the database.
# Suggestion: object from the database.. object. The cleanup script removed the orphaned object from the database.. The cleanup script removed the orphaned object from the database.. script.:
